# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
train = pd.read_csv("../data/schemas/warm_up/TrainSet.csv", sep=",")
validation = pd.read_csv("../data/schemas/warm_up/ValidationSet.csv", sep=",")
test = pd.read_csv("../data/schemas/warm_up/TestSet.csv", sep=",")

# %%
# Global variables

NUM_OF_TIMESTEPS_INPUT = 48
NUM_OF_TIMESTEPS_OUTPUT = 24

THRESHOLD = 0.4   # For feature selection

# %%
columns_to_predict = ["kg_CO2/kWh", "Avg solar generation"]

independent_variables = []

for column in train:
    if abs(train[column].corr(train[columns_to_predict[0]])) > THRESHOLD: #or abs(train[column].corr(train[columns_to_predict[1]])) > THRESHOLD:
        independent_variables.append(column)

independent_variables = [var for var in independent_variables if var not in columns_to_predict]
    
if "Index" in independent_variables:
    independent_variables.remove("Index")
if "Solar Generation (W/kW)_1" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_1")
if "Solar Generation (W/kW)_2" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_2")
if "Solar Generation (W/kW)_3" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_3")
    
print(independent_variables)
# Out:
# ['Hour_1', 'Hour_2', 'Hour_3', 'Occupant Count (people)_3', '12h Outdoor Drybulb Temperature (C)', '24h Outdoor Drybulb Temperature (C)', '12h Outdoor Relative Humidity (%)', '6h Direct Solar Radiation (W/m2)', '12h Direct Solar Radiation (W/m2)']

# %% [markdown]
# Prepare the data

# %%
# Split the X and Y for all sets

# Train set
X_train_default = train[independent_variables]
Y_train_default = train[columns_to_predict]

# Validation set, also include the data from train that was used only as output to get more datapoints
X_val_default = pd.concat([X_train_default.tail(NUM_OF_TIMESTEPS_OUTPUT), validation[independent_variables]], ignore_index=True)
Y_val_default = pd.concat([Y_train_default.tail(NUM_OF_TIMESTEPS_OUTPUT), validation[columns_to_predict]], ignore_index=True)

# Test set, also include the data from train that was used only as output to get more datapoints
X_test_default = pd.concat([X_val_default.tail(NUM_OF_TIMESTEPS_OUTPUT), test[independent_variables]], ignore_index=True)
Y_test_default = pd.concat([Y_val_default.tail(NUM_OF_TIMESTEPS_OUTPUT), test[columns_to_predict]], ignore_index=True)

NUM_OF_ROWS_TRAIN, NUM_OF_FEATURES = X_train_default.shape

print(X_train_default.shape)
print(X_val_default.shape)
print(X_test_default.shape)
# Out:
# (576, 9)
# (96, 9)
# (96, 9)

# %%
# Function to prepare the data into batches that will be passed into the model

def create_sequences(input_data, output_data, timesteps_input, timesteps_output):
    sequences, targets = [], []
    for i in range(len(input_data) - timesteps_input - timesteps_output + 1):
        seq = input_data[i:i + timesteps_input]
        target = output_data[i + timesteps_input: i + timesteps_input + timesteps_output]
        sequences.append(seq)
        targets.append(target)

    return np.array(sequences), np.array(targets)

# %%
X_train, Y_train = create_sequences(X_train_default, Y_train_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)
X_val, Y_val = create_sequences(X_val_default, Y_val_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)
X_test, Y_test = create_sequences(X_test_default, Y_test_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)

print(f"X_train = {X_train.shape}, Y_train = {Y_train.shape}\n"
      f"X_val = {X_val.shape}, Y_val = {Y_val.shape}\n"
      f"X_test = {X_test.shape}, Y_test = {Y_test.shape}")
# Out:
# X_train = (505, 48, 9), Y_train = (505, 24, 2)
# X_val = (25, 48, 9), Y_val = (25, 24, 2)
# X_test = (25, 48, 9), Y_test = (25, 24, 2)

# %%
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras import layers, models
import time

tscv = TimeSeriesSplit(n_splits = 4, test_size=24) # For cross-validation

callback = keras.callbacks.EarlyStopping(monitor='loss', patience = 5) #patience parameter to be adjusted

loss = []
val_loss = []
loss_1 = []
val_loss_1 = []
loss_2 = []
val_loss_2 = []

# Input layer
input_layer = layers.Input(shape=(NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))

# Dense layers for variable 1
lstm1 = layers.GRU(72, activation='leaky_relu', return_sequences=True)(input_layer)
lstm2 = layers.GRU(48, activation='leaky_relu', return_sequences=True)(lstm1)
lstm3 = layers.GRU(24, activation='leaky_relu', return_sequences=False)(lstm2)
output_variable1 = layers.Dense(24, name='output_variable1')(lstm3)

# Dense layers for variable 2
dense4 = layers.GRU(72, activation='leaky_relu', return_sequences=True)(input_layer)
dense5 = layers.GRU(48, activation='leaky_relu', return_sequences=True)(dense4)
dense6 = layers.GRU(24, activation='leaky_relu', return_sequences=False)(dense5)
output_variable2 = layers.Dense(24, name='output_variable2')(dense6)


# Define the model
model = models.Model(inputs=input_layer, outputs=[output_variable1, output_variable2])

model.compile(
    optimizer='adam',
    loss={'output_variable1': 'mean_squared_error', 'output_variable2': 'mean_squared_error'}
) #types of optimizer, loss function to be adjusted
    
start = time.time()

for train_data, test_data in tscv.split(X_train):
    X_train_current_split, X_test_current_split = X_train[train_data], X_train[test_data]
    y_train_current_split, y_test_current_split = Y_train[train_data], Y_train[test_data]
    
    history = model.fit(X_train_current_split, y={"output_variable1": y_train_current_split[:, :, 0], 
                                                  "output_variable2": y_train_current_split[:, :, 1]},
              epochs=100, 
              validation_data=(
                  X_test_current_split,
                {
                    "output_variable1": y_test_current_split[:, :, 0],
                    "output_variable2": y_test_current_split[:, :, 1],
                },
              ),
              # validation_split = 0.8,
              verbose=1,
              callbacks=callback
    )
    loss.append(model.history.history['loss'])
    val_loss.append(model.history.history['val_loss'])
    
    loss_1.append(model.history.history['output_variable1_loss'])
    val_loss_1.append(model.history.history['val_output_variable1_loss'])
    
    loss_2.append(model.history.history['output_variable2_loss'])
    val_loss_2.append(model.history.history['val_output_variable2_loss'])
    
end = time.time()

print(f"Training time = {end - start} seconds")
# Out:
# Epoch 1/100
# 13/13 [==============================] - 14s 179ms/step - loss: 0.4777 - output_variable1_loss: 0.3032 - output_variable2_loss: 0.1745 - val_loss: 0.6591 - val_output_variable1_loss: 0.5638 - val_output_variable2_loss: 0.0953
# Epoch 2/100
# 13/13 [==============================] - 1s 61ms/step - loss: 0.3055 - output_variable1_loss: 0.1713 - output_variable2_loss: 0.1343 - val_loss: 0.4034 - val_output_variable1_loss: 0.3290 - val_output_variable2_loss: 0.0743
# Epoch 3/100
# 13/13 [==============================] - 1s 61ms/step - loss: 0.2010 - output_variable1_loss: 0.1010 - output_variable2_loss: 0.1000 - val_loss: 0.2261 - val_output_variable1_loss: 0.1670 - val_output_variable2_loss: 0.0591
# Epoch 4/100
# 13/13 [==============================] - 1s 60ms/step - loss: 0.1373 - output_variable1_loss: 0.0606 - output_variable2_loss: 0.0767 - val_loss: 0.1990 - val_output_variable1_loss: 0.1471 - val_output_variable2_loss: 0.0519
# Epoch 5/100
# 13/13 [==============================] - 1s 61ms/step - loss: 0.1070 - output_variable1_loss: 0.0472 - output_variable2_loss: 0.0598 - val_loss: 0.1712 - val_output_variable1_loss: 0.1274 - val_output_variable2_loss: 0.0438
# Epoch 6/100
# 13/13 [==============================] - 1s 64ms/step - loss: 0.0878 - output_variable1_loss: 0.0436 - output_variable2_loss: 0.0442 - val_loss: 0.1438 - val_output_variable1_loss: 0.1102 - val_output_variable2_loss: 0.0336
# Epoch 7/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0719 - output_variable1_loss: 0.0407 - output_variable2_loss: 0.0312 - val_loss: 0.0868 - val_output_variable1_loss: 0.0624 - val_output_variable2_loss: 0.0244
# Epoch 8/100
# 13/13 [==============================] - 1s 64ms/step - loss: 0.0598 - output_variable1_loss: 0.0383 - output_variable2_loss: 0.0215 - val_loss: 0.0474 - val_output_variable1_loss: 0.0294 - val_output_variable2_loss: 0.0181
# Epoch 9/100
# 13/13 [==============================] - 1s 61ms/step - loss: 0.0530 - output_variable1_loss: 0.0370 - output_variable2_loss: 0.0160 - val_loss: 0.0737 - val_output_variable1_loss: 0.0589 - val_output_variable2_loss: 0.0149
# Epoch 10/100
# 13/13 [==============================] - 1s 63ms/step - loss: 0.0491 - output_variable1_loss: 0.0364 - output_variable2_loss: 0.0127 - val_loss: 0.0613 - val_output_variable1_loss: 0.0493 - val_output_variable2_loss: 0.0120
# Epoch 11/100
# 13/13 [==============================] - 1s 60ms/step - loss: 0.0459 - output_variable1_loss: 0.0352 - output_variable2_loss: 0.0106 - val_loss: 0.0515 - val_output_variable1_loss: 0.0408 - val_output_variable2_loss: 0.0107
# Epoch 12/100
# 13/13 [==============================] - 1s 60ms/step - loss: 0.0439 - output_variable1_loss: 0.0346 - output_variable2_loss: 0.0092 - val_loss: 0.0445 - val_output_variable1_loss: 0.0347 - val_output_variable2_loss: 0.0098
# Epoch 13/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0413 - output_variable1_loss: 0.0333 - output_variable2_loss: 0.0080 - val_loss: 0.0453 - val_output_variable1_loss: 0.0362 - val_output_variable2_loss: 0.0092
# Epoch 14/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0388 - output_variable1_loss: 0.0316 - output_variable2_loss: 0.0072 - val_loss: 0.0432 - val_output_variable1_loss: 0.0339 - val_output_variable2_loss: 0.0093
# Epoch 15/100
# 13/13 [==============================] - 1s 61ms/step - loss: 0.0365 - output_variable1_loss: 0.0301 - output_variable2_loss: 0.0065 - val_loss: 0.0395 - val_output_variable1_loss: 0.0294 - val_output_variable2_loss: 0.0101
# Epoch 16/100
# 13/13 [==============================] - 1s 65ms/step - loss: 0.0344 - output_variable1_loss: 0.0286 - output_variable2_loss: 0.0058 - val_loss: 0.0529 - val_output_variable1_loss: 0.0453 - val_output_variable2_loss: 0.0075
# Epoch 17/100
# 13/13 [==============================] - 1s 64ms/step - loss: 0.0322 - output_variable1_loss: 0.0270 - output_variable2_loss: 0.0052 - val_loss: 0.0400 - val_output_variable1_loss: 0.0318 - val_output_variable2_loss: 0.0082
# Epoch 18/100
# 13/13 [==============================] - 1s 59ms/step - loss: 0.0302 - output_variable1_loss: 0.0253 - output_variable2_loss: 0.0049 - val_loss: 0.0507 - val_output_variable1_loss: 0.0433 - val_output_variable2_loss: 0.0074
# Epoch 19/100
# 13/13 [==============================] - 1s 60ms/step - loss: 0.0281 - output_variable1_loss: 0.0238 - output_variable2_loss: 0.0044 - val_loss: 0.0470 - val_output_variable1_loss: 0.0395 - val_output_variable2_loss: 0.0075
# Epoch 20/100
# 13/13 [==============================] - 1s 60ms/step - loss: 0.0273 - output_variable1_loss: 0.0233 - output_variable2_loss: 0.0040 - val_loss: 0.0528 - val_output_variable1_loss: 0.0467 - val_output_variable2_loss: 0.0061
# Epoch 21/100
# 13/13 [==============================] - 1s 60ms/step - loss: 0.0267 - output_variable1_loss: 0.0229 - output_variable2_loss: 0.0039 - val_loss: 0.0499 - val_output_variable1_loss: 0.0428 - val_output_variable2_loss: 0.0070
# Epoch 22/100
# 13/13 [==============================] - 1s 61ms/step - loss: 0.0245 - output_variable1_loss: 0.0209 - output_variable2_loss: 0.0037 - val_loss: 0.0589 - val_output_variable1_loss: 0.0523 - val_output_variable2_loss: 0.0066
# Epoch 23/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0237 - output_variable1_loss: 0.0201 - output_variable2_loss: 0.0036 - val_loss: 0.0421 - val_output_variable1_loss: 0.0353 - val_output_variable2_loss: 0.0068
# Epoch 24/100
# 13/13 [==============================] - 1s 61ms/step - loss: 0.0227 - output_variable1_loss: 0.0192 - output_variable2_loss: 0.0034 - val_loss: 0.0652 - val_output_variable1_loss: 0.0589 - val_output_variable2_loss: 0.0063
# Epoch 25/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0235 - output_variable1_loss: 0.0202 - output_variable2_loss: 0.0034 - val_loss: 0.0586 - val_output_variable1_loss: 0.0525 - val_output_variable2_loss: 0.0061
# Epoch 26/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0215 - output_variable1_loss: 0.0183 - output_variable2_loss: 0.0032 - val_loss: 0.0588 - val_output_variable1_loss: 0.0524 - val_output_variable2_loss: 0.0064
# Epoch 27/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0208 - output_variable1_loss: 0.0176 - output_variable2_loss: 0.0032 - val_loss: 0.0689 - val_output_variable1_loss: 0.0625 - val_output_variable2_loss: 0.0064
# Epoch 28/100
# 13/13 [==============================] - 1s 61ms/step - loss: 0.0205 - output_variable1_loss: 0.0174 - output_variable2_loss: 0.0031 - val_loss: 0.0657 - val_output_variable1_loss: 0.0590 - val_output_variable2_loss: 0.0067
# Epoch 29/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0203 - output_variable1_loss: 0.0173 - output_variable2_loss: 0.0030 - val_loss: 0.0843 - val_output_variable1_loss: 0.0783 - val_output_variable2_loss: 0.0059
# Epoch 30/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0200 - output_variable1_loss: 0.0169 - output_variable2_loss: 0.0032 - val_loss: 0.0551 - val_output_variable1_loss: 0.0493 - val_output_variable2_loss: 0.0057
# Epoch 31/100
# 13/13 [==============================] - 1s 61ms/step - loss: 0.0192 - output_variable1_loss: 0.0162 - output_variable2_loss: 0.0030 - val_loss: 0.0735 - val_output_variable1_loss: 0.0674 - val_output_variable2_loss: 0.0061
# Epoch 32/100
# 13/13 [==============================] - 1s 60ms/step - loss: 0.0187 - output_variable1_loss: 0.0157 - output_variable2_loss: 0.0030 - val_loss: 0.0575 - val_output_variable1_loss: 0.0511 - val_output_variable2_loss: 0.0064
# Epoch 33/100
# 13/13 [==============================] - 1s 60ms/step - loss: 0.0188 - output_variable1_loss: 0.0157 - output_variable2_loss: 0.0031 - val_loss: 0.0860 - val_output_variable1_loss: 0.0803 - val_output_variable2_loss: 0.0056
# Epoch 34/100
# 13/13 [==============================] - 1s 61ms/step - loss: 0.0186 - output_variable1_loss: 0.0156 - output_variable2_loss: 0.0030 - val_loss: 0.0823 - val_output_variable1_loss: 0.0757 - val_output_variable2_loss: 0.0066
# Epoch 35/100
# 13/13 [==============================] - 1s 60ms/step - loss: 0.0168 - output_variable1_loss: 0.0141 - output_variable2_loss: 0.0027 - val_loss: 0.0931 - val_output_variable1_loss: 0.0868 - val_output_variable2_loss: 0.0063
# Epoch 36/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0164 - output_variable1_loss: 0.0137 - output_variable2_loss: 0.0026 - val_loss: 0.0947 - val_output_variable1_loss: 0.0883 - val_output_variable2_loss: 0.0064
# Epoch 37/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0161 - output_variable1_loss: 0.0134 - output_variable2_loss: 0.0027 - val_loss: 0.1237 - val_output_variable1_loss: 0.1172 - val_output_variable2_loss: 0.0064
# Epoch 38/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0164 - output_variable1_loss: 0.0137 - output_variable2_loss: 0.0027 - val_loss: 0.0759 - val_output_variable1_loss: 0.0694 - val_output_variable2_loss: 0.0065
# Epoch 39/100
# 13/13 [==============================] - 1s 68ms/step - loss: 0.0168 - output_variable1_loss: 0.0138 - output_variable2_loss: 0.0029 - val_loss: 0.0932 - val_output_variable1_loss: 0.0865 - val_output_variable2_loss: 0.0067
# Epoch 40/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0158 - output_variable1_loss: 0.0131 - output_variable2_loss: 0.0027 - val_loss: 0.1033 - val_output_variable1_loss: 0.0965 - val_output_variable2_loss: 0.0068
# Epoch 41/100
# 13/13 [==============================] - 1s 63ms/step - loss: 0.0146 - output_variable1_loss: 0.0120 - output_variable2_loss: 0.0026 - val_loss: 0.0880 - val_output_variable1_loss: 0.0815 - val_output_variable2_loss: 0.0065
# Epoch 42/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0146 - output_variable1_loss: 0.0122 - output_variable2_loss: 0.0024 - val_loss: 0.0863 - val_output_variable1_loss: 0.0796 - val_output_variable2_loss: 0.0067
# Epoch 43/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0138 - output_variable1_loss: 0.0114 - output_variable2_loss: 0.0024 - val_loss: 0.1013 - val_output_variable1_loss: 0.0951 - val_output_variable2_loss: 0.0062
# Epoch 44/100
# 13/13 [==============================] - 1s 64ms/step - loss: 0.0140 - output_variable1_loss: 0.0115 - output_variable2_loss: 0.0025 - val_loss: 0.1079 - val_output_variable1_loss: 0.1007 - val_output_variable2_loss: 0.0072
# Epoch 45/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0144 - output_variable1_loss: 0.0121 - output_variable2_loss: 0.0023 - val_loss: 0.1147 - val_output_variable1_loss: 0.1074 - val_output_variable2_loss: 0.0073
# Epoch 46/100
# 13/13 [==============================] - 1s 61ms/step - loss: 0.0134 - output_variable1_loss: 0.0111 - output_variable2_loss: 0.0023 - val_loss: 0.0830 - val_output_variable1_loss: 0.0759 - val_output_variable2_loss: 0.0070
# Epoch 47/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0132 - output_variable1_loss: 0.0110 - output_variable2_loss: 0.0022 - val_loss: 0.0912 - val_output_variable1_loss: 0.0841 - val_output_variable2_loss: 0.0071
# Epoch 48/100
# 13/13 [==============================] - 1s 61ms/step - loss: 0.0129 - output_variable1_loss: 0.0107 - output_variable2_loss: 0.0022 - val_loss: 0.0861 - val_output_variable1_loss: 0.0791 - val_output_variable2_loss: 0.0070
# Epoch 49/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0147 - output_variable1_loss: 0.0126 - output_variable2_loss: 0.0022 - val_loss: 0.1169 - val_output_variable1_loss: 0.1103 - val_output_variable2_loss: 0.0066
# Epoch 50/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0132 - output_variable1_loss: 0.0111 - output_variable2_loss: 0.0021 - val_loss: 0.1037 - val_output_variable1_loss: 0.0974 - val_output_variable2_loss: 0.0063
# Epoch 51/100
# 13/13 [==============================] - 1s 60ms/step - loss: 0.0128 - output_variable1_loss: 0.0106 - output_variable2_loss: 0.0022 - val_loss: 0.1079 - val_output_variable1_loss: 0.1005 - val_output_variable2_loss: 0.0074
# Epoch 52/100
# 13/13 [==============================] - 1s 60ms/step - loss: 0.0118 - output_variable1_loss: 0.0098 - output_variable2_loss: 0.0021 - val_loss: 0.1078 - val_output_variable1_loss: 0.1010 - val_output_variable2_loss: 0.0067
# Epoch 53/100
# 13/13 [==============================] - 1s 60ms/step - loss: 0.0116 - output_variable1_loss: 0.0096 - output_variable2_loss: 0.0020 - val_loss: 0.1234 - val_output_variable1_loss: 0.1166 - val_output_variable2_loss: 0.0068
# Epoch 54/100
# 13/13 [==============================] - 1s 60ms/step - loss: 0.0120 - output_variable1_loss: 0.0100 - output_variable2_loss: 0.0020 - val_loss: 0.0910 - val_output_variable1_loss: 0.0840 - val_output_variable2_loss: 0.0070
# Epoch 55/100
# 13/13 [==============================] - 1s 60ms/step - loss: 0.0120 - output_variable1_loss: 0.0098 - output_variable2_loss: 0.0022 - val_loss: 0.0839 - val_output_variable1_loss: 0.0776 - val_output_variable2_loss: 0.0064
# Epoch 56/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0120 - output_variable1_loss: 0.0099 - output_variable2_loss: 0.0021 - val_loss: 0.1127 - val_output_variable1_loss: 0.1057 - val_output_variable2_loss: 0.0070
# Epoch 57/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0115 - output_variable1_loss: 0.0096 - output_variable2_loss: 0.0019 - val_loss: 0.1019 - val_output_variable1_loss: 0.0955 - val_output_variable2_loss: 0.0063
# Epoch 58/100
# 13/13 [==============================] - 1s 64ms/step - loss: 0.0109 - output_variable1_loss: 0.0090 - output_variable2_loss: 0.0020 - val_loss: 0.1152 - val_output_variable1_loss: 0.1078 - val_output_variable2_loss: 0.0073
# Epoch 59/100
# 13/13 [==============================] - 1s 63ms/step - loss: 0.0109 - output_variable1_loss: 0.0091 - output_variable2_loss: 0.0018 - val_loss: 0.1002 - val_output_variable1_loss: 0.0937 - val_output_variable2_loss: 0.0065
# Epoch 60/100
# 13/13 [==============================] - 1s 61ms/step - loss: 0.0101 - output_variable1_loss: 0.0084 - output_variable2_loss: 0.0018 - val_loss: 0.1014 - val_output_variable1_loss: 0.0951 - val_output_variable2_loss: 0.0063
# Epoch 61/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0098 - output_variable1_loss: 0.0081 - output_variable2_loss: 0.0017 - val_loss: 0.0970 - val_output_variable1_loss: 0.0908 - val_output_variable2_loss: 0.0062
# Epoch 62/100
# 13/13 [==============================] - 1s 67ms/step - loss: 0.0097 - output_variable1_loss: 0.0080 - output_variable2_loss: 0.0017 - val_loss: 0.0931 - val_output_variable1_loss: 0.0873 - val_output_variable2_loss: 0.0058
# Epoch 63/100
# 13/13 [==============================] - 1s 65ms/step - loss: 0.0095 - output_variable1_loss: 0.0078 - output_variable2_loss: 0.0017 - val_loss: 0.1063 - val_output_variable1_loss: 0.1002 - val_output_variable2_loss: 0.0061
# Epoch 64/100
# 13/13 [==============================] - 1s 63ms/step - loss: 0.0098 - output_variable1_loss: 0.0081 - output_variable2_loss: 0.0016 - val_loss: 0.0992 - val_output_variable1_loss: 0.0926 - val_output_variable2_loss: 0.0067
# Epoch 65/100
# 13/13 [==============================] - 1s 65ms/step - loss: 0.0096 - output_variable1_loss: 0.0080 - output_variable2_loss: 0.0017 - val_loss: 0.0957 - val_output_variable1_loss: 0.0891 - val_output_variable2_loss: 0.0065
# Epoch 66/100
# 13/13 [==============================] - 1s 65ms/step - loss: 0.0096 - output_variable1_loss: 0.0079 - output_variable2_loss: 0.0017 - val_loss: 0.0945 - val_output_variable1_loss: 0.0883 - val_output_variable2_loss: 0.0062
# Epoch 67/100
# 13/13 [==============================] - 1s 65ms/step - loss: 0.0092 - output_variable1_loss: 0.0076 - output_variable2_loss: 0.0016 - val_loss: 0.0978 - val_output_variable1_loss: 0.0916 - val_output_variable2_loss: 0.0062
# Epoch 68/100
# 13/13 [==============================] - 1s 66ms/step - loss: 0.0091 - output_variable1_loss: 0.0075 - output_variable2_loss: 0.0016 - val_loss: 0.1006 - val_output_variable1_loss: 0.0943 - val_output_variable2_loss: 0.0064
# Epoch 69/100
# 13/13 [==============================] - 1s 66ms/step - loss: 0.0088 - output_variable1_loss: 0.0073 - output_variable2_loss: 0.0015 - val_loss: 0.0886 - val_output_variable1_loss: 0.0832 - val_output_variable2_loss: 0.0054
# Epoch 70/100
# 13/13 [==============================] - 1s 63ms/step - loss: 0.0090 - output_variable1_loss: 0.0074 - output_variable2_loss: 0.0016 - val_loss: 0.0972 - val_output_variable1_loss: 0.0914 - val_output_variable2_loss: 0.0057
# Epoch 71/100
# 13/13 [==============================] - 1s 67ms/step - loss: 0.0088 - output_variable1_loss: 0.0073 - output_variable2_loss: 0.0015 - val_loss: 0.1004 - val_output_variable1_loss: 0.0947 - val_output_variable2_loss: 0.0057
# Epoch 72/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0083 - output_variable1_loss: 0.0069 - output_variable2_loss: 0.0014 - val_loss: 0.0907 - val_output_variable1_loss: 0.0850 - val_output_variable2_loss: 0.0057
# Epoch 73/100
# 13/13 [==============================] - 1s 66ms/step - loss: 0.0083 - output_variable1_loss: 0.0069 - output_variable2_loss: 0.0014 - val_loss: 0.0993 - val_output_variable1_loss: 0.0940 - val_output_variable2_loss: 0.0053
# Epoch 74/100
# 13/13 [==============================] - 1s 65ms/step - loss: 0.0084 - output_variable1_loss: 0.0069 - output_variable2_loss: 0.0015 - val_loss: 0.0906 - val_output_variable1_loss: 0.0853 - val_output_variable2_loss: 0.0053
# Epoch 75/100
# 13/13 [==============================] - 1s 64ms/step - loss: 0.0080 - output_variable1_loss: 0.0066 - output_variable2_loss: 0.0014 - val_loss: 0.0938 - val_output_variable1_loss: 0.0881 - val_output_variable2_loss: 0.0057
# Epoch 76/100
# 13/13 [==============================] - 1s 64ms/step - loss: 0.0078 - output_variable1_loss: 0.0065 - output_variable2_loss: 0.0014 - val_loss: 0.0898 - val_output_variable1_loss: 0.0845 - val_output_variable2_loss: 0.0053
# Epoch 77/100
# 13/13 [==============================] - 1s 63ms/step - loss: 0.0080 - output_variable1_loss: 0.0067 - output_variable2_loss: 0.0013 - val_loss: 0.0977 - val_output_variable1_loss: 0.0918 - val_output_variable2_loss: 0.0060
# Epoch 78/100
# 13/13 [==============================] - 1s 63ms/step - loss: 0.0080 - output_variable1_loss: 0.0066 - output_variable2_loss: 0.0014 - val_loss: 0.0975 - val_output_variable1_loss: 0.0925 - val_output_variable2_loss: 0.0050
# Epoch 79/100
# 13/13 [==============================] - 1s 64ms/step - loss: 0.0077 - output_variable1_loss: 0.0063 - output_variable2_loss: 0.0014 - val_loss: 0.0935 - val_output_variable1_loss: 0.0879 - val_output_variable2_loss: 0.0057
# Epoch 80/100
# 13/13 [==============================] - 1s 72ms/step - loss: 0.0077 - output_variable1_loss: 0.0063 - output_variable2_loss: 0.0014 - val_loss: 0.0935 - val_output_variable1_loss: 0.0878 - val_output_variable2_loss: 0.0057
# Epoch 81/100
# 13/13 [==============================] - 1s 76ms/step - loss: 0.0076 - output_variable1_loss: 0.0061 - output_variable2_loss: 0.0015 - val_loss: 0.1003 - val_output_variable1_loss: 0.0953 - val_output_variable2_loss: 0.0051
# Epoch 82/100
# 13/13 [==============================] - 1s 63ms/step - loss: 0.0074 - output_variable1_loss: 0.0061 - output_variable2_loss: 0.0014 - val_loss: 0.0857 - val_output_variable1_loss: 0.0808 - val_output_variable2_loss: 0.0049
# Epoch 83/100
# 13/13 [==============================] - 1s 64ms/step - loss: 0.0074 - output_variable1_loss: 0.0060 - output_variable2_loss: 0.0013 - val_loss: 0.1022 - val_output_variable1_loss: 0.0970 - val_output_variable2_loss: 0.0051
# Epoch 84/100
# 13/13 [==============================] - 1s 65ms/step - loss: 0.0072 - output_variable1_loss: 0.0058 - output_variable2_loss: 0.0014 - val_loss: 0.0949 - val_output_variable1_loss: 0.0902 - val_output_variable2_loss: 0.0047
# Epoch 85/100
# 13/13 [==============================] - 1s 63ms/step - loss: 0.0070 - output_variable1_loss: 0.0056 - output_variable2_loss: 0.0013 - val_loss: 0.0916 - val_output_variable1_loss: 0.0860 - val_output_variable2_loss: 0.0056
# Epoch 86/100
# 13/13 [==============================] - 1s 64ms/step - loss: 0.0069 - output_variable1_loss: 0.0056 - output_variable2_loss: 0.0013 - val_loss: 0.0929 - val_output_variable1_loss: 0.0879 - val_output_variable2_loss: 0.0050
# Epoch 87/100
# 13/13 [==============================] - 1s 67ms/step - loss: 0.0068 - output_variable1_loss: 0.0055 - output_variable2_loss: 0.0013 - val_loss: 0.1029 - val_output_variable1_loss: 0.0978 - val_output_variable2_loss: 0.0051
# Epoch 88/100
# 13/13 [==============================] - 1s 64ms/step - loss: 0.0067 - output_variable1_loss: 0.0056 - output_variable2_loss: 0.0012 - val_loss: 0.0926 - val_output_variable1_loss: 0.0880 - val_output_variable2_loss: 0.0046
# Epoch 89/100
# 13/13 [==============================] - 1s 66ms/step - loss: 0.0068 - output_variable1_loss: 0.0056 - output_variable2_loss: 0.0012 - val_loss: 0.0901 - val_output_variable1_loss: 0.0846 - val_output_variable2_loss: 0.0054
# Epoch 90/100
# 13/13 [==============================] - 1s 74ms/step - loss: 0.0068 - output_variable1_loss: 0.0056 - output_variable2_loss: 0.0012 - val_loss: 0.0931 - val_output_variable1_loss: 0.0885 - val_output_variable2_loss: 0.0046
# Epoch 91/100
# 13/13 [==============================] - 1s 67ms/step - loss: 0.0069 - output_variable1_loss: 0.0057 - output_variable2_loss: 0.0012 - val_loss: 0.0951 - val_output_variable1_loss: 0.0904 - val_output_variable2_loss: 0.0047
# Epoch 92/100
# 13/13 [==============================] - 1s 65ms/step - loss: 0.0069 - output_variable1_loss: 0.0057 - output_variable2_loss: 0.0012 - val_loss: 0.0897 - val_output_variable1_loss: 0.0845 - val_output_variable2_loss: 0.0052
# Epoch 93/100
# 13/13 [==============================] - 1s 67ms/step - loss: 0.0065 - output_variable1_loss: 0.0054 - output_variable2_loss: 0.0011 - val_loss: 0.0957 - val_output_variable1_loss: 0.0905 - val_output_variable2_loss: 0.0052
# Epoch 94/100
# 13/13 [==============================] - 1s 65ms/step - loss: 0.0066 - output_variable1_loss: 0.0054 - output_variable2_loss: 0.0011 - val_loss: 0.0860 - val_output_variable1_loss: 0.0811 - val_output_variable2_loss: 0.0049
# Epoch 95/100
# 13/13 [==============================] - 1s 67ms/step - loss: 0.0064 - output_variable1_loss: 0.0052 - output_variable2_loss: 0.0012 - val_loss: 0.0936 - val_output_variable1_loss: 0.0885 - val_output_variable2_loss: 0.0051
# Epoch 96/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0062 - output_variable1_loss: 0.0050 - output_variable2_loss: 0.0012 - val_loss: 0.0868 - val_output_variable1_loss: 0.0818 - val_output_variable2_loss: 0.0050
# Epoch 97/100
# 13/13 [==============================] - 1s 66ms/step - loss: 0.0060 - output_variable1_loss: 0.0048 - output_variable2_loss: 0.0012 - val_loss: 0.0937 - val_output_variable1_loss: 0.0888 - val_output_variable2_loss: 0.0049
# Epoch 98/100
# 13/13 [==============================] - 1s 69ms/step - loss: 0.0061 - output_variable1_loss: 0.0049 - output_variable2_loss: 0.0011 - val_loss: 0.0907 - val_output_variable1_loss: 0.0855 - val_output_variable2_loss: 0.0052
# Epoch 99/100
# 13/13 [==============================] - 1s 67ms/step - loss: 0.0060 - output_variable1_loss: 0.0049 - output_variable2_loss: 0.0011 - val_loss: 0.0845 - val_output_variable1_loss: 0.0796 - val_output_variable2_loss: 0.0049
# Epoch 100/100
# 13/13 [==============================] - 1s 63ms/step - loss: 0.0060 - output_variable1_loss: 0.0049 - output_variable2_loss: 0.0011 - val_loss: 0.0905 - val_output_variable1_loss: 0.0855 - val_output_variable2_loss: 0.0050
# Epoch 1/100
# 14/14 [==============================] - 1s 69ms/step - loss: 0.0098 - output_variable1_loss: 0.0085 - output_variable2_loss: 0.0013 - val_loss: 0.0370 - val_output_variable1_loss: 0.0341 - val_output_variable2_loss: 0.0029
# Epoch 2/100
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0088 - output_variable1_loss: 0.0076 - output_variable2_loss: 0.0012 - val_loss: 0.0326 - val_output_variable1_loss: 0.0298 - val_output_variable2_loss: 0.0028
# Epoch 3/100
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0084 - output_variable1_loss: 0.0073 - output_variable2_loss: 0.0011 - val_loss: 0.0290 - val_output_variable1_loss: 0.0263 - val_output_variable2_loss: 0.0027
# Epoch 4/100
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0079 - output_variable1_loss: 0.0067 - output_variable2_loss: 0.0012 - val_loss: 0.0301 - val_output_variable1_loss: 0.0272 - val_output_variable2_loss: 0.0029
# Epoch 5/100
# 14/14 [==============================] - 1s 63ms/step - loss: 0.0077 - output_variable1_loss: 0.0065 - output_variable2_loss: 0.0012 - val_loss: 0.0286 - val_output_variable1_loss: 0.0260 - val_output_variable2_loss: 0.0026
# Epoch 6/100
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0074 - output_variable1_loss: 0.0063 - output_variable2_loss: 0.0012 - val_loss: 0.0301 - val_output_variable1_loss: 0.0267 - val_output_variable2_loss: 0.0033
# Epoch 7/100
# 14/14 [==============================] - 1s 60ms/step - loss: 0.0077 - output_variable1_loss: 0.0065 - output_variable2_loss: 0.0011 - val_loss: 0.0338 - val_output_variable1_loss: 0.0305 - val_output_variable2_loss: 0.0032
# Epoch 8/100
# 14/14 [==============================] - 1s 62ms/step - loss: 0.0072 - output_variable1_loss: 0.0061 - output_variable2_loss: 0.0011 - val_loss: 0.0273 - val_output_variable1_loss: 0.0242 - val_output_variable2_loss: 0.0031
# Epoch 9/100
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0071 - output_variable1_loss: 0.0060 - output_variable2_loss: 0.0011 - val_loss: 0.0303 - val_output_variable1_loss: 0.0270 - val_output_variable2_loss: 0.0033
# Epoch 10/100
# 14/14 [==============================] - 1s 65ms/step - loss: 0.0068 - output_variable1_loss: 0.0057 - output_variable2_loss: 0.0011 - val_loss: 0.0268 - val_output_variable1_loss: 0.0238 - val_output_variable2_loss: 0.0030
# Epoch 11/100
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0068 - output_variable1_loss: 0.0057 - output_variable2_loss: 0.0011 - val_loss: 0.0268 - val_output_variable1_loss: 0.0244 - val_output_variable2_loss: 0.0024
# Epoch 12/100
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0065 - output_variable1_loss: 0.0055 - output_variable2_loss: 0.0011 - val_loss: 0.0262 - val_output_variable1_loss: 0.0235 - val_output_variable2_loss: 0.0027
# Epoch 13/100
# 14/14 [==============================] - 1s 62ms/step - loss: 0.0063 - output_variable1_loss: 0.0051 - output_variable2_loss: 0.0012 - val_loss: 0.0319 - val_output_variable1_loss: 0.0291 - val_output_variable2_loss: 0.0027
# Epoch 14/100
# 14/14 [==============================] - 1s 63ms/step - loss: 0.0060 - output_variable1_loss: 0.0048 - output_variable2_loss: 0.0012 - val_loss: 0.0245 - val_output_variable1_loss: 0.0219 - val_output_variable2_loss: 0.0026
# Epoch 15/100
# 14/14 [==============================] - 1s 63ms/step - loss: 0.0057 - output_variable1_loss: 0.0046 - output_variable2_loss: 0.0011 - val_loss: 0.0281 - val_output_variable1_loss: 0.0260 - val_output_variable2_loss: 0.0022
# Epoch 16/100
# 14/14 [==============================] - 1s 62ms/step - loss: 0.0057 - output_variable1_loss: 0.0046 - output_variable2_loss: 0.0012 - val_loss: 0.0274 - val_output_variable1_loss: 0.0246 - val_output_variable2_loss: 0.0027
# Epoch 17/100
# 14/14 [==============================] - 1s 64ms/step - loss: 0.0056 - output_variable1_loss: 0.0045 - output_variable2_loss: 0.0011 - val_loss: 0.0249 - val_output_variable1_loss: 0.0222 - val_output_variable2_loss: 0.0028
# Epoch 18/100
# 14/14 [==============================] - 1s 65ms/step - loss: 0.0054 - output_variable1_loss: 0.0044 - output_variable2_loss: 0.0010 - val_loss: 0.0254 - val_output_variable1_loss: 0.0228 - val_output_variable2_loss: 0.0026
# Epoch 19/100
# 14/14 [==============================] - 1s 64ms/step - loss: 0.0053 - output_variable1_loss: 0.0043 - output_variable2_loss: 9.6170e-04 - val_loss: 0.0308 - val_output_variable1_loss: 0.0283 - val_output_variable2_loss: 0.0025
# Epoch 20/100
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0052 - output_variable1_loss: 0.0042 - output_variable2_loss: 9.8849e-04 - val_loss: 0.0289 - val_output_variable1_loss: 0.0264 - val_output_variable2_loss: 0.0024
# Epoch 21/100
# 14/14 [==============================] - 1s 64ms/step - loss: 0.0050 - output_variable1_loss: 0.0040 - output_variable2_loss: 0.0010 - val_loss: 0.0286 - val_output_variable1_loss: 0.0250 - val_output_variable2_loss: 0.0036
# Epoch 22/100
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0049 - output_variable1_loss: 0.0039 - output_variable2_loss: 0.0011 - val_loss: 0.0259 - val_output_variable1_loss: 0.0235 - val_output_variable2_loss: 0.0025
# Epoch 23/100
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0047 - output_variable1_loss: 0.0038 - output_variable2_loss: 9.4961e-04 - val_loss: 0.0250 - val_output_variable1_loss: 0.0226 - val_output_variable2_loss: 0.0024
# Epoch 24/100
# 14/14 [==============================] - 1s 63ms/step - loss: 0.0046 - output_variable1_loss: 0.0037 - output_variable2_loss: 9.2304e-04 - val_loss: 0.0289 - val_output_variable1_loss: 0.0261 - val_output_variable2_loss: 0.0028
# Epoch 25/100
# 14/14 [==============================] - 1s 64ms/step - loss: 0.0047 - output_variable1_loss: 0.0038 - output_variable2_loss: 9.5949e-04 - val_loss: 0.0265 - val_output_variable1_loss: 0.0241 - val_output_variable2_loss: 0.0024
# Epoch 26/100
# 14/14 [==============================] - 1s 64ms/step - loss: 0.0050 - output_variable1_loss: 0.0041 - output_variable2_loss: 9.0862e-04 - val_loss: 0.0291 - val_output_variable1_loss: 0.0265 - val_output_variable2_loss: 0.0026
# Epoch 27/100
# 14/14 [==============================] - 1s 62ms/step - loss: 0.0048 - output_variable1_loss: 0.0039 - output_variable2_loss: 8.7618e-04 - val_loss: 0.0343 - val_output_variable1_loss: 0.0317 - val_output_variable2_loss: 0.0026
# Epoch 28/100
# 14/14 [==============================] - 1s 65ms/step - loss: 0.0045 - output_variable1_loss: 0.0036 - output_variable2_loss: 9.2000e-04 - val_loss: 0.0291 - val_output_variable1_loss: 0.0266 - val_output_variable2_loss: 0.0025
# Epoch 29/100
# 14/14 [==============================] - 1s 63ms/step - loss: 0.0045 - output_variable1_loss: 0.0036 - output_variable2_loss: 8.9819e-04 - val_loss: 0.0273 - val_output_variable1_loss: 0.0246 - val_output_variable2_loss: 0.0027
# Epoch 30/100
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0044 - output_variable1_loss: 0.0035 - output_variable2_loss: 8.9488e-04 - val_loss: 0.0256 - val_output_variable1_loss: 0.0229 - val_output_variable2_loss: 0.0026
# Epoch 31/100
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0042 - output_variable1_loss: 0.0034 - output_variable2_loss: 8.5312e-04 - val_loss: 0.0288 - val_output_variable1_loss: 0.0262 - val_output_variable2_loss: 0.0026
# Epoch 32/100
# 14/14 [==============================] - 1s 62ms/step - loss: 0.0043 - output_variable1_loss: 0.0034 - output_variable2_loss: 8.9644e-04 - val_loss: 0.0299 - val_output_variable1_loss: 0.0268 - val_output_variable2_loss: 0.0031
# Epoch 33/100
# 14/14 [==============================] - 1s 63ms/step - loss: 0.0044 - output_variable1_loss: 0.0035 - output_variable2_loss: 9.6075e-04 - val_loss: 0.0283 - val_output_variable1_loss: 0.0258 - val_output_variable2_loss: 0.0025
# Epoch 34/100
# 14/14 [==============================] - 1s 64ms/step - loss: 0.0042 - output_variable1_loss: 0.0033 - output_variable2_loss: 8.6218e-04 - val_loss: 0.0298 - val_output_variable1_loss: 0.0271 - val_output_variable2_loss: 0.0027
# Epoch 35/100
# 14/14 [==============================] - 1s 62ms/step - loss: 0.0041 - output_variable1_loss: 0.0032 - output_variable2_loss: 8.6366e-04 - val_loss: 0.0289 - val_output_variable1_loss: 0.0271 - val_output_variable2_loss: 0.0019
# Epoch 36/100
# 14/14 [==============================] - 1s 64ms/step - loss: 0.0041 - output_variable1_loss: 0.0032 - output_variable2_loss: 8.8522e-04 - val_loss: 0.0304 - val_output_variable1_loss: 0.0276 - val_output_variable2_loss: 0.0027
# Epoch 37/100
# 14/14 [==============================] - 1s 64ms/step - loss: 0.0040 - output_variable1_loss: 0.0031 - output_variable2_loss: 8.7032e-04 - val_loss: 0.0299 - val_output_variable1_loss: 0.0271 - val_output_variable2_loss: 0.0028
# Epoch 38/100
# 14/14 [==============================] - 1s 61ms/step - loss: 0.0040 - output_variable1_loss: 0.0031 - output_variable2_loss: 8.5167e-04 - val_loss: 0.0298 - val_output_variable1_loss: 0.0277 - val_output_variable2_loss: 0.0021
# Epoch 39/100
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0039 - output_variable1_loss: 0.0031 - output_variable2_loss: 8.3562e-04 - val_loss: 0.0319 - val_output_variable1_loss: 0.0298 - val_output_variable2_loss: 0.0021
# Epoch 40/100
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0039 - output_variable1_loss: 0.0031 - output_variable2_loss: 8.3434e-04 - val_loss: 0.0309 - val_output_variable1_loss: 0.0284 - val_output_variable2_loss: 0.0025
# Epoch 41/100
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0039 - output_variable1_loss: 0.0031 - output_variable2_loss: 7.9336e-04 - val_loss: 0.0307 - val_output_variable1_loss: 0.0282 - val_output_variable2_loss: 0.0025
# Epoch 42/100
# 14/14 [==============================] - 1s 66ms/step - loss: 0.0038 - output_variable1_loss: 0.0030 - output_variable2_loss: 8.0120e-04 - val_loss: 0.0304 - val_output_variable1_loss: 0.0283 - val_output_variable2_loss: 0.0021
# Epoch 43/100
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0038 - output_variable1_loss: 0.0030 - output_variable2_loss: 8.3925e-04 - val_loss: 0.0316 - val_output_variable1_loss: 0.0292 - val_output_variable2_loss: 0.0024
# Epoch 44/100
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0039 - output_variable1_loss: 0.0030 - output_variable2_loss: 8.9683e-04 - val_loss: 0.0340 - val_output_variable1_loss: 0.0314 - val_output_variable2_loss: 0.0026
# Epoch 45/100
# 14/14 [==============================] - 1s 58ms/step - loss: 0.0039 - output_variable1_loss: 0.0031 - output_variable2_loss: 8.5361e-04 - val_loss: 0.0302 - val_output_variable1_loss: 0.0276 - val_output_variable2_loss: 0.0026
# Epoch 46/100
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0038 - output_variable1_loss: 0.0030 - output_variable2_loss: 8.3757e-04 - val_loss: 0.0329 - val_output_variable1_loss: 0.0298 - val_output_variable2_loss: 0.0030
# Epoch 47/100
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0038 - output_variable1_loss: 0.0029 - output_variable2_loss: 9.0216e-04 - val_loss: 0.0294 - val_output_variable1_loss: 0.0273 - val_output_variable2_loss: 0.0021
# Epoch 1/100
# 15/15 [==============================] - 1s 64ms/step - loss: 0.0049 - output_variable1_loss: 0.0039 - output_variable2_loss: 9.4970e-04 - val_loss: 0.0107 - val_output_variable1_loss: 0.0096 - val_output_variable2_loss: 0.0012
# Epoch 2/100
# 15/15 [==============================] - 1s 56ms/step - loss: 0.0047 - output_variable1_loss: 0.0038 - output_variable2_loss: 9.1008e-04 - val_loss: 0.0117 - val_output_variable1_loss: 0.0095 - val_output_variable2_loss: 0.0022
# Epoch 3/100
# 15/15 [==============================] - 1s 57ms/step - loss: 0.0045 - output_variable1_loss: 0.0036 - output_variable2_loss: 9.0508e-04 - val_loss: 0.0119 - val_output_variable1_loss: 0.0109 - val_output_variable2_loss: 0.0010
# Epoch 4/100
# 15/15 [==============================] - 1s 57ms/step - loss: 0.0042 - output_variable1_loss: 0.0033 - output_variable2_loss: 8.5692e-04 - val_loss: 0.0124 - val_output_variable1_loss: 0.0108 - val_output_variable2_loss: 0.0016
# Epoch 5/100
# 15/15 [==============================] - 1s 57ms/step - loss: 0.0040 - output_variable1_loss: 0.0032 - output_variable2_loss: 8.7541e-04 - val_loss: 0.0122 - val_output_variable1_loss: 0.0111 - val_output_variable2_loss: 0.0012
# Epoch 6/100
# 15/15 [==============================] - 1s 56ms/step - loss: 0.0040 - output_variable1_loss: 0.0032 - output_variable2_loss: 8.7576e-04 - val_loss: 0.0132 - val_output_variable1_loss: 0.0116 - val_output_variable2_loss: 0.0016
# Epoch 7/100
# 15/15 [==============================] - 1s 56ms/step - loss: 0.0040 - output_variable1_loss: 0.0030 - output_variable2_loss: 9.2041e-04 - val_loss: 0.0132 - val_output_variable1_loss: 0.0120 - val_output_variable2_loss: 0.0012
# Epoch 8/100
# 15/15 [==============================] - 1s 56ms/step - loss: 0.0038 - output_variable1_loss: 0.0030 - output_variable2_loss: 8.0286e-04 - val_loss: 0.0131 - val_output_variable1_loss: 0.0116 - val_output_variable2_loss: 0.0015
# Epoch 9/100
# 15/15 [==============================] - 1s 63ms/step - loss: 0.0040 - output_variable1_loss: 0.0032 - output_variable2_loss: 8.0438e-04 - val_loss: 0.0119 - val_output_variable1_loss: 0.0106 - val_output_variable2_loss: 0.0013
# Epoch 10/100
# 15/15 [==============================] - 1s 56ms/step - loss: 0.0038 - output_variable1_loss: 0.0030 - output_variable2_loss: 8.5350e-04 - val_loss: 0.0125 - val_output_variable1_loss: 0.0114 - val_output_variable2_loss: 0.0010
# Epoch 11/100
# 15/15 [==============================] - 1s 57ms/step - loss: 0.0037 - output_variable1_loss: 0.0029 - output_variable2_loss: 8.3645e-04 - val_loss: 0.0124 - val_output_variable1_loss: 0.0111 - val_output_variable2_loss: 0.0013
# Epoch 12/100
# 15/15 [==============================] - 1s 58ms/step - loss: 0.0038 - output_variable1_loss: 0.0029 - output_variable2_loss: 8.6031e-04 - val_loss: 0.0140 - val_output_variable1_loss: 0.0127 - val_output_variable2_loss: 0.0013
# Epoch 13/100
# 15/15 [==============================] - 1s 56ms/step - loss: 0.0038 - output_variable1_loss: 0.0029 - output_variable2_loss: 8.2717e-04 - val_loss: 0.0145 - val_output_variable1_loss: 0.0131 - val_output_variable2_loss: 0.0014
# Epoch 14/100
# 15/15 [==============================] - 1s 58ms/step - loss: 0.0039 - output_variable1_loss: 0.0031 - output_variable2_loss: 7.8924e-04 - val_loss: 0.0136 - val_output_variable1_loss: 0.0121 - val_output_variable2_loss: 0.0015
# Epoch 15/100
# 15/15 [==============================] - 1s 60ms/step - loss: 0.0040 - output_variable1_loss: 0.0031 - output_variable2_loss: 8.5024e-04 - val_loss: 0.0129 - val_output_variable1_loss: 0.0113 - val_output_variable2_loss: 0.0016
# Epoch 16/100
# 15/15 [==============================] - 1s 56ms/step - loss: 0.0039 - output_variable1_loss: 0.0030 - output_variable2_loss: 9.0214e-04 - val_loss: 0.0120 - val_output_variable1_loss: 0.0108 - val_output_variable2_loss: 0.0012
# Epoch 1/100
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0040 - output_variable1_loss: 0.0032 - output_variable2_loss: 8.2324e-04 - val_loss: 0.0264 - val_output_variable1_loss: 0.0242 - val_output_variable2_loss: 0.0022
# Epoch 2/100
# 16/16 [==============================] - 1s 57ms/step - loss: 0.0042 - output_variable1_loss: 0.0034 - output_variable2_loss: 8.7427e-04 - val_loss: 0.0355 - val_output_variable1_loss: 0.0308 - val_output_variable2_loss: 0.0047
# Epoch 3/100
# 16/16 [==============================] - 1s 61ms/step - loss: 0.0045 - output_variable1_loss: 0.0035 - output_variable2_loss: 0.0010 - val_loss: 0.0345 - val_output_variable1_loss: 0.0291 - val_output_variable2_loss: 0.0054
# Epoch 4/100
# 16/16 [==============================] - 1s 55ms/step - loss: 0.0044 - output_variable1_loss: 0.0030 - output_variable2_loss: 0.0014 - val_loss: 0.0446 - val_output_variable1_loss: 0.0430 - val_output_variable2_loss: 0.0016
# Epoch 5/100
# 16/16 [==============================] - 1s 56ms/step - loss: 0.0041 - output_variable1_loss: 0.0031 - output_variable2_loss: 9.9776e-04 - val_loss: 0.0480 - val_output_variable1_loss: 0.0470 - val_output_variable2_loss: 9.4376e-04
# Epoch 6/100
# 16/16 [==============================] - 1s 58ms/step - loss: 0.0041 - output_variable1_loss: 0.0032 - output_variable2_loss: 9.0896e-04 - val_loss: 0.0512 - val_output_variable1_loss: 0.0499 - val_output_variable2_loss: 0.0013

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss_1):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss_1[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error 1", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss_2):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss_2[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error 2", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
# Evaluate the model on the test data
predictions_1 = []
predictions_2 = []
#print(len(eval_target_variables))

for i in range(len(Y_val)):
    current_batch = X_val[i].reshape((1, NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))
    curr_pred1, curr_pred2 = model.predict(current_batch)
    predictions_1.append(curr_pred1)
    predictions_2.append(curr_pred2)
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_1):
    ax = axs[i]
    # TODO seems to work but check why column[0]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_val[i, :, 0], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_2):
    ax = axs[i]
    # TODO seems to work but check why column[0]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_val[i, :, 1], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
rmse = 0
for i in range(len(predictions_1)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_1[i][0], Y_val[i, :, 0]))}')
    rmse += sqrt(mean_squared_error(predictions_1[i][0], Y_val[i, :, 0]))

rmse /= len(predictions_1)    
print(f"RMSE for {columns_to_predict[0]} = {rmse}")

rmse = 0
for i in range(len(predictions_2)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_2[i][0], Y_val[i, :, 1]))}')
    rmse += sqrt(mean_squared_error(predictions_2[i][0], Y_val[i, :, 1]))

rmse /= len(predictions_2)    
print(f"RMSE for {columns_to_predict[1]} = {rmse}")
# Out:
# RMSE for kg_CO2/kWh = 0.14361102816760238
# RMSE for Avg solar generation = 0.029913894734621232

# %%
# Evaluate the model on the test data
predictions_1_test = []
predictions_2_test = []
#print(len(eval_target_variables))

for i in range(len(Y_test)):
    current_batch = X_test[i].reshape((1, NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))
    curr_pred1, curr_pred2 = model.predict(current_batch)
    predictions_1_test.append(curr_pred1)
    predictions_2_test.append(curr_pred2)
# Out:
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 48ms/step

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_1_test):
    ax = axs[i]
    # TODO seems to work but check why column[0]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_test[i, :, 0], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_2_test):
    ax = axs[i]
    # TODO seems to work but check why column[0]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_test[i, :, 1], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
rmse = 0
for i in range(len(predictions_1_test)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_1[i][0], Y_val[i, :, 0]))}')
    rmse += sqrt(mean_squared_error(predictions_1_test[i][0], Y_test[i, :, 0]))

rmse /= len(predictions_1_test)    
print(f"RMSE for {columns_to_predict[0]} = {rmse}")

rmse = 0
for i in range(len(predictions_2_test)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_2[i][0], Y_val[i, :, 1]))}')
    rmse += sqrt(mean_squared_error(predictions_2_test[i][0], Y_test[i, :, 1]))

rmse /= len(predictions_2_test)    
print(f"RMSE for {columns_to_predict[1]} = {rmse}")
# Out:
# RMSE for kg_CO2/kWh = 0.1656353117470372
# RMSE for Avg solar generation = 0.037371703087500846

# %%
a = []
for column in predictions_1_test:
    a.append(column[0])
    
b = []
for column in predictions_2_test:
    b.append(column[0])

predictions1 = pd.DataFrame(a)
predictions1.to_csv('../data/results/carbon_gru.csv', index=False, header=False)
predictions2 = pd.DataFrame(b)
predictions2.to_csv('../data/results/solar_gru.csv', index=False, header=False)
