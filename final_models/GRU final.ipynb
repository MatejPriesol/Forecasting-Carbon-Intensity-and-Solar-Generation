# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
train = pd.read_csv("../data/schemas/warm_up/TrainSet.csv", sep=",")
validation = pd.read_csv("../data/schemas/warm_up/ValidationSet.csv", sep=",")
test = pd.read_csv("../data/schemas/warm_up/TestSet.csv", sep=",")

# %%
# Global variables

NUM_OF_TIMESTEPS_INPUT = 48
NUM_OF_TIMESTEPS_OUTPUT = 24

THRESHOLD = 0.4   # For feature selection

# %%
columns_to_predict = ["kg_CO2/kWh", "Avg solar generation"]

independent_variables = []

for column in train:
    if abs(train[column].corr(train[columns_to_predict[0]])) > THRESHOLD: #or abs(train[column].corr(train[columns_to_predict[1]])) > THRESHOLD:
        independent_variables.append(column)

independent_variables = [var for var in independent_variables if var not in columns_to_predict]
    
if "Index" in independent_variables:
    independent_variables.remove("Index")
if "Solar Generation (W/kW)_1" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_1")
if "Solar Generation (W/kW)_2" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_2")
if "Solar Generation (W/kW)_3" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_3")
    
print(independent_variables)
# Out:
# ['Hour_1', 'Hour_2', 'Hour_3', 'Occupant Count (people)_3', '12h Outdoor Drybulb Temperature (C)', '24h Outdoor Drybulb Temperature (C)', '12h Outdoor Relative Humidity (%)', '6h Direct Solar Radiation (W/m2)', '12h Direct Solar Radiation (W/m2)']

# %% [markdown]
# Prepare the data

# %%
# Split the X and Y for all sets

# Train set
X_train_default = train[independent_variables]
Y_train_default = train[columns_to_predict]

# Validation set, also include the data from train that was used only as output to get more datapoints
X_val_default = pd.concat([X_train_default.tail(NUM_OF_TIMESTEPS_OUTPUT), validation[independent_variables]], ignore_index=True)
Y_val_default = pd.concat([Y_train_default.tail(NUM_OF_TIMESTEPS_OUTPUT), validation[columns_to_predict]], ignore_index=True)

# Test set, also include the data from train that was used only as output to get more datapoints
X_test_default = pd.concat([X_val_default.tail(NUM_OF_TIMESTEPS_OUTPUT), test[independent_variables]], ignore_index=True)
Y_test_default = pd.concat([Y_val_default.tail(NUM_OF_TIMESTEPS_OUTPUT), test[columns_to_predict]], ignore_index=True)

NUM_OF_ROWS_TRAIN, NUM_OF_FEATURES = X_train_default.shape

print(X_train_default.shape)
print(X_val_default.shape)
print(X_test_default.shape)
# Out:
# (576, 9)
# (96, 9)
# (96, 9)

# %%
# Function to prepare the data into batches that will be passed into the model

def create_sequences(input_data, output_data, timesteps_input, timesteps_output):
    sequences, targets = [], []
    for i in range(len(input_data) - timesteps_input - timesteps_output + 1):
        seq = input_data[i:i + timesteps_input]
        target = output_data[i + timesteps_input: i + timesteps_input + timesteps_output]
        sequences.append(seq)
        targets.append(target)

    return np.array(sequences), np.array(targets)

# %%
X_train, Y_train = create_sequences(X_train_default, Y_train_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)
X_val, Y_val = create_sequences(X_val_default, Y_val_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)
X_test, Y_test = create_sequences(X_test_default, Y_test_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)

print(f"X_train = {X_train.shape}, Y_train = {Y_train.shape}\n"
      f"X_val = {X_val.shape}, Y_val = {Y_val.shape}\n"
      f"X_test = {X_test.shape}, Y_test = {Y_test.shape}")
# Out:
# X_train = (505, 48, 9), Y_train = (505, 24, 2)
# X_val = (25, 48, 9), Y_val = (25, 24, 2)
# X_test = (25, 48, 9), Y_test = (25, 24, 2)

# %%
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras import layers, models

tscv = TimeSeriesSplit(n_splits = 4, test_size=24) # For cross-validation

callback = keras.callbacks.EarlyStopping(monitor='loss', patience = 7) #patience parameter to be adjusted

loss = []
val_loss = []
loss_1 = []
val_loss_1 = []
loss_2 = []
val_loss_2 = []

# Input layer
input_layer = layers.Input(shape=(NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))

# Dense layers for variable 1
lstm1 = layers.GRU(48, activation='leaky_relu', return_sequences=True)(input_layer)
lstm2 = layers.GRU(48, activation='leaky_relu', return_sequences=True)(lstm1)
lstm3 = layers.GRU(24, activation='leaky_relu', return_sequences=False)(lstm2)
output_variable1 = layers.Dense(24, name='output_variable1')(lstm3)

# Dense layers for variable 2
dense4 = layers.GRU(48, activation='leaky_relu', return_sequences=True)(input_layer)
dense5 = layers.GRU(48, activation='leaky_relu', return_sequences=True)(dense4)
dense6 = layers.GRU(24, activation='leaky_relu', return_sequences=False)(dense5)
output_variable2 = layers.Dense(24, name='output_variable2')(dense6)


# Define the model
model = models.Model(inputs=input_layer, outputs=[output_variable1, output_variable2])

model.compile(
    optimizer='adam',
    loss={'output_variable1': 'mean_squared_error', 'output_variable2': 'mean_squared_error'}
) #types of optimizer, loss function to be adjusted
    
    
for train_data, test_data in tscv.split(X_train):
    X_train_current_split, X_test_current_split = X_train[train_data], X_train[test_data]
    y_train_current_split, y_test_current_split = Y_train[train_data], Y_train[test_data]
    
    history = model.fit(X_train_current_split, y={"output_variable1": y_train_current_split[:, :, 0], 
                                                  "output_variable2": y_train_current_split[:, :, 1]},
              epochs=100, 
              validation_data=(
                  X_test_current_split,
                {
                    "output_variable1": y_test_current_split[:, :, 0],
                    "output_variable2": y_test_current_split[:, :, 1],
                },
              ),
              # validation_split = 0.8,
              verbose=1,
              callbacks=callback
    )
    loss.append(model.history.history['loss'])
    val_loss.append(model.history.history['val_loss'])
    
    loss_1.append(model.history.history['output_variable1_loss'])
    val_loss_1.append(model.history.history['val_output_variable1_loss'])
    
    loss_2.append(model.history.history['output_variable2_loss'])
    val_loss_2.append(model.history.history['val_output_variable2_loss'])
# Out:
# Epoch 1/100
# 13/13 [==============================] - 6s 100ms/step - loss: 0.4887 - output_variable1_loss: 0.3164 - output_variable2_loss: 0.1723 - val_loss: 0.7677 - val_output_variable1_loss: 0.6716 - val_output_variable2_loss: 0.0961
# Epoch 2/100
# 13/13 [==============================] - 0s 27ms/step - loss: 0.3658 - output_variable1_loss: 0.2245 - output_variable2_loss: 0.1414 - val_loss: 0.4817 - val_output_variable1_loss: 0.4002 - val_output_variable2_loss: 0.0815
# Epoch 3/100
# 13/13 [==============================] - 0s 28ms/step - loss: 0.2393 - output_variable1_loss: 0.1234 - output_variable2_loss: 0.1158 - val_loss: 0.2912 - val_output_variable1_loss: 0.2277 - val_output_variable2_loss: 0.0636
# Epoch 4/100
# 13/13 [==============================] - 0s 28ms/step - loss: 0.1461 - output_variable1_loss: 0.0647 - output_variable2_loss: 0.0814 - val_loss: 0.1938 - val_output_variable1_loss: 0.1512 - val_output_variable2_loss: 0.0426
# Epoch 5/100
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0964 - output_variable1_loss: 0.0488 - output_variable2_loss: 0.0477 - val_loss: 0.1585 - val_output_variable1_loss: 0.1264 - val_output_variable2_loss: 0.0322
# Epoch 6/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0738 - output_variable1_loss: 0.0432 - output_variable2_loss: 0.0306 - val_loss: 0.1649 - val_output_variable1_loss: 0.1405 - val_output_variable2_loss: 0.0244
# Epoch 7/100
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0618 - output_variable1_loss: 0.0403 - output_variable2_loss: 0.0215 - val_loss: 0.1160 - val_output_variable1_loss: 0.0964 - val_output_variable2_loss: 0.0196
# Epoch 8/100
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0534 - output_variable1_loss: 0.0371 - output_variable2_loss: 0.0163 - val_loss: 0.0990 - val_output_variable1_loss: 0.0847 - val_output_variable2_loss: 0.0143
# Epoch 9/100
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0484 - output_variable1_loss: 0.0350 - output_variable2_loss: 0.0135 - val_loss: 0.0711 - val_output_variable1_loss: 0.0588 - val_output_variable2_loss: 0.0123
# Epoch 10/100
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0440 - output_variable1_loss: 0.0323 - output_variable2_loss: 0.0116 - val_loss: 0.0432 - val_output_variable1_loss: 0.0315 - val_output_variable2_loss: 0.0117
# Epoch 11/100
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0409 - output_variable1_loss: 0.0307 - output_variable2_loss: 0.0102 - val_loss: 0.0433 - val_output_variable1_loss: 0.0322 - val_output_variable2_loss: 0.0111
# Epoch 12/100
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0383 - output_variable1_loss: 0.0291 - output_variable2_loss: 0.0092 - val_loss: 0.0665 - val_output_variable1_loss: 0.0549 - val_output_variable2_loss: 0.0116
# Epoch 13/100
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0368 - output_variable1_loss: 0.0286 - output_variable2_loss: 0.0083 - val_loss: 0.0405 - val_output_variable1_loss: 0.0313 - val_output_variable2_loss: 0.0092
# Epoch 14/100
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0339 - output_variable1_loss: 0.0266 - output_variable2_loss: 0.0072 - val_loss: 0.0495 - val_output_variable1_loss: 0.0403 - val_output_variable2_loss: 0.0092
# Epoch 15/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0321 - output_variable1_loss: 0.0256 - output_variable2_loss: 0.0066 - val_loss: 0.0484 - val_output_variable1_loss: 0.0400 - val_output_variable2_loss: 0.0084
# Epoch 16/100
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0304 - output_variable1_loss: 0.0245 - output_variable2_loss: 0.0059 - val_loss: 0.0374 - val_output_variable1_loss: 0.0299 - val_output_variable2_loss: 0.0075
# Epoch 17/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0287 - output_variable1_loss: 0.0234 - output_variable2_loss: 0.0053 - val_loss: 0.0526 - val_output_variable1_loss: 0.0455 - val_output_variable2_loss: 0.0071
# Epoch 18/100
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0275 - output_variable1_loss: 0.0226 - output_variable2_loss: 0.0049 - val_loss: 0.0340 - val_output_variable1_loss: 0.0276 - val_output_variable2_loss: 0.0064
# Epoch 19/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0270 - output_variable1_loss: 0.0222 - output_variable2_loss: 0.0048 - val_loss: 0.0589 - val_output_variable1_loss: 0.0517 - val_output_variable2_loss: 0.0072
# Epoch 20/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0254 - output_variable1_loss: 0.0209 - output_variable2_loss: 0.0045 - val_loss: 0.0428 - val_output_variable1_loss: 0.0362 - val_output_variable2_loss: 0.0067
# Epoch 21/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0251 - output_variable1_loss: 0.0209 - output_variable2_loss: 0.0041 - val_loss: 0.0357 - val_output_variable1_loss: 0.0298 - val_output_variable2_loss: 0.0060
# Epoch 22/100
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0239 - output_variable1_loss: 0.0200 - output_variable2_loss: 0.0039 - val_loss: 0.0568 - val_output_variable1_loss: 0.0509 - val_output_variable2_loss: 0.0060
# Epoch 23/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0232 - output_variable1_loss: 0.0192 - output_variable2_loss: 0.0039 - val_loss: 0.0545 - val_output_variable1_loss: 0.0489 - val_output_variable2_loss: 0.0056
# Epoch 24/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0232 - output_variable1_loss: 0.0194 - output_variable2_loss: 0.0038 - val_loss: 0.0399 - val_output_variable1_loss: 0.0342 - val_output_variable2_loss: 0.0057
# Epoch 25/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0217 - output_variable1_loss: 0.0178 - output_variable2_loss: 0.0039 - val_loss: 0.0456 - val_output_variable1_loss: 0.0395 - val_output_variable2_loss: 0.0060
# Epoch 26/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0208 - output_variable1_loss: 0.0172 - output_variable2_loss: 0.0036 - val_loss: 0.0471 - val_output_variable1_loss: 0.0421 - val_output_variable2_loss: 0.0051
# Epoch 27/100
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0218 - output_variable1_loss: 0.0183 - output_variable2_loss: 0.0034 - val_loss: 0.0650 - val_output_variable1_loss: 0.0599 - val_output_variable2_loss: 0.0051
# Epoch 28/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0225 - output_variable1_loss: 0.0191 - output_variable2_loss: 0.0034 - val_loss: 0.0602 - val_output_variable1_loss: 0.0549 - val_output_variable2_loss: 0.0053
# Epoch 29/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0215 - output_variable1_loss: 0.0182 - output_variable2_loss: 0.0033 - val_loss: 0.0796 - val_output_variable1_loss: 0.0746 - val_output_variable2_loss: 0.0050
# Epoch 30/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0205 - output_variable1_loss: 0.0172 - output_variable2_loss: 0.0032 - val_loss: 0.0602 - val_output_variable1_loss: 0.0552 - val_output_variable2_loss: 0.0051
# Epoch 31/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0194 - output_variable1_loss: 0.0161 - output_variable2_loss: 0.0032 - val_loss: 0.0623 - val_output_variable1_loss: 0.0573 - val_output_variable2_loss: 0.0050
# Epoch 32/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0183 - output_variable1_loss: 0.0152 - output_variable2_loss: 0.0031 - val_loss: 0.0774 - val_output_variable1_loss: 0.0724 - val_output_variable2_loss: 0.0050
# Epoch 33/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0181 - output_variable1_loss: 0.0149 - output_variable2_loss: 0.0032 - val_loss: 0.0829 - val_output_variable1_loss: 0.0777 - val_output_variable2_loss: 0.0052
# Epoch 34/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0177 - output_variable1_loss: 0.0145 - output_variable2_loss: 0.0032 - val_loss: 0.0697 - val_output_variable1_loss: 0.0643 - val_output_variable2_loss: 0.0054
# Epoch 35/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0173 - output_variable1_loss: 0.0141 - output_variable2_loss: 0.0033 - val_loss: 0.1017 - val_output_variable1_loss: 0.0976 - val_output_variable2_loss: 0.0041
# Epoch 36/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0175 - output_variable1_loss: 0.0142 - output_variable2_loss: 0.0033 - val_loss: 0.0695 - val_output_variable1_loss: 0.0652 - val_output_variable2_loss: 0.0043
# Epoch 37/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0165 - output_variable1_loss: 0.0133 - output_variable2_loss: 0.0032 - val_loss: 0.0853 - val_output_variable1_loss: 0.0807 - val_output_variable2_loss: 0.0045
# Epoch 38/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0160 - output_variable1_loss: 0.0129 - output_variable2_loss: 0.0031 - val_loss: 0.0963 - val_output_variable1_loss: 0.0917 - val_output_variable2_loss: 0.0045
# Epoch 39/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0153 - output_variable1_loss: 0.0124 - output_variable2_loss: 0.0030 - val_loss: 0.0788 - val_output_variable1_loss: 0.0738 - val_output_variable2_loss: 0.0050
# Epoch 40/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0152 - output_variable1_loss: 0.0122 - output_variable2_loss: 0.0030 - val_loss: 0.0955 - val_output_variable1_loss: 0.0910 - val_output_variable2_loss: 0.0045
# Epoch 41/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0146 - output_variable1_loss: 0.0118 - output_variable2_loss: 0.0028 - val_loss: 0.0973 - val_output_variable1_loss: 0.0928 - val_output_variable2_loss: 0.0046
# Epoch 42/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0142 - output_variable1_loss: 0.0113 - output_variable2_loss: 0.0029 - val_loss: 0.0862 - val_output_variable1_loss: 0.0816 - val_output_variable2_loss: 0.0046
# Epoch 43/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0138 - output_variable1_loss: 0.0110 - output_variable2_loss: 0.0029 - val_loss: 0.0912 - val_output_variable1_loss: 0.0863 - val_output_variable2_loss: 0.0049
# Epoch 44/100
# 13/13 [==============================] - 0s 31ms/step - loss: 0.0133 - output_variable1_loss: 0.0106 - output_variable2_loss: 0.0028 - val_loss: 0.0782 - val_output_variable1_loss: 0.0739 - val_output_variable2_loss: 0.0043
# Epoch 45/100
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0139 - output_variable1_loss: 0.0111 - output_variable2_loss: 0.0027 - val_loss: 0.1012 - val_output_variable1_loss: 0.0963 - val_output_variable2_loss: 0.0049
# Epoch 46/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0127 - output_variable1_loss: 0.0101 - output_variable2_loss: 0.0027 - val_loss: 0.0932 - val_output_variable1_loss: 0.0885 - val_output_variable2_loss: 0.0047
# Epoch 47/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0124 - output_variable1_loss: 0.0097 - output_variable2_loss: 0.0027 - val_loss: 0.0782 - val_output_variable1_loss: 0.0736 - val_output_variable2_loss: 0.0046
# Epoch 48/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0127 - output_variable1_loss: 0.0100 - output_variable2_loss: 0.0027 - val_loss: 0.0943 - val_output_variable1_loss: 0.0898 - val_output_variable2_loss: 0.0045
# Epoch 49/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0122 - output_variable1_loss: 0.0095 - output_variable2_loss: 0.0027 - val_loss: 0.0896 - val_output_variable1_loss: 0.0853 - val_output_variable2_loss: 0.0044
# Epoch 50/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0119 - output_variable1_loss: 0.0091 - output_variable2_loss: 0.0027 - val_loss: 0.0781 - val_output_variable1_loss: 0.0732 - val_output_variable2_loss: 0.0049
# Epoch 51/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0113 - output_variable1_loss: 0.0087 - output_variable2_loss: 0.0027 - val_loss: 0.0882 - val_output_variable1_loss: 0.0834 - val_output_variable2_loss: 0.0048
# Epoch 52/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0110 - output_variable1_loss: 0.0083 - output_variable2_loss: 0.0027 - val_loss: 0.0853 - val_output_variable1_loss: 0.0813 - val_output_variable2_loss: 0.0040
# Epoch 53/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0106 - output_variable1_loss: 0.0080 - output_variable2_loss: 0.0026 - val_loss: 0.0748 - val_output_variable1_loss: 0.0702 - val_output_variable2_loss: 0.0046
# Epoch 54/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0107 - output_variable1_loss: 0.0082 - output_variable2_loss: 0.0025 - val_loss: 0.0800 - val_output_variable1_loss: 0.0752 - val_output_variable2_loss: 0.0048
# Epoch 55/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0103 - output_variable1_loss: 0.0078 - output_variable2_loss: 0.0026 - val_loss: 0.0802 - val_output_variable1_loss: 0.0755 - val_output_variable2_loss: 0.0047
# Epoch 56/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0099 - output_variable1_loss: 0.0074 - output_variable2_loss: 0.0025 - val_loss: 0.0817 - val_output_variable1_loss: 0.0770 - val_output_variable2_loss: 0.0047
# Epoch 57/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0098 - output_variable1_loss: 0.0072 - output_variable2_loss: 0.0026 - val_loss: 0.0948 - val_output_variable1_loss: 0.0900 - val_output_variable2_loss: 0.0048
# Epoch 58/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0100 - output_variable1_loss: 0.0075 - output_variable2_loss: 0.0025 - val_loss: 0.0858 - val_output_variable1_loss: 0.0810 - val_output_variable2_loss: 0.0048
# Epoch 59/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0096 - output_variable1_loss: 0.0071 - output_variable2_loss: 0.0025 - val_loss: 0.0821 - val_output_variable1_loss: 0.0779 - val_output_variable2_loss: 0.0042
# Epoch 60/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0094 - output_variable1_loss: 0.0070 - output_variable2_loss: 0.0024 - val_loss: 0.0834 - val_output_variable1_loss: 0.0782 - val_output_variable2_loss: 0.0052
# Epoch 61/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0091 - output_variable1_loss: 0.0067 - output_variable2_loss: 0.0024 - val_loss: 0.0869 - val_output_variable1_loss: 0.0817 - val_output_variable2_loss: 0.0053
# Epoch 62/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0091 - output_variable1_loss: 0.0068 - output_variable2_loss: 0.0024 - val_loss: 0.0845 - val_output_variable1_loss: 0.0798 - val_output_variable2_loss: 0.0048
# Epoch 63/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0091 - output_variable1_loss: 0.0068 - output_variable2_loss: 0.0024 - val_loss: 0.0921 - val_output_variable1_loss: 0.0873 - val_output_variable2_loss: 0.0048
# Epoch 64/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0090 - output_variable1_loss: 0.0066 - output_variable2_loss: 0.0024 - val_loss: 0.0845 - val_output_variable1_loss: 0.0800 - val_output_variable2_loss: 0.0045
# Epoch 65/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0086 - output_variable1_loss: 0.0064 - output_variable2_loss: 0.0022 - val_loss: 0.0816 - val_output_variable1_loss: 0.0763 - val_output_variable2_loss: 0.0054
# Epoch 66/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0086 - output_variable1_loss: 0.0063 - output_variable2_loss: 0.0023 - val_loss: 0.0977 - val_output_variable1_loss: 0.0929 - val_output_variable2_loss: 0.0048
# Epoch 67/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0087 - output_variable1_loss: 0.0065 - output_variable2_loss: 0.0022 - val_loss: 0.0856 - val_output_variable1_loss: 0.0807 - val_output_variable2_loss: 0.0049
# Epoch 68/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0087 - output_variable1_loss: 0.0065 - output_variable2_loss: 0.0023 - val_loss: 0.0793 - val_output_variable1_loss: 0.0744 - val_output_variable2_loss: 0.0049
# Epoch 69/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0084 - output_variable1_loss: 0.0061 - output_variable2_loss: 0.0022 - val_loss: 0.0789 - val_output_variable1_loss: 0.0733 - val_output_variable2_loss: 0.0056
# Epoch 70/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0084 - output_variable1_loss: 0.0063 - output_variable2_loss: 0.0022 - val_loss: 0.0820 - val_output_variable1_loss: 0.0768 - val_output_variable2_loss: 0.0052
# Epoch 71/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0080 - output_variable1_loss: 0.0058 - output_variable2_loss: 0.0022 - val_loss: 0.0895 - val_output_variable1_loss: 0.0845 - val_output_variable2_loss: 0.0051
# Epoch 72/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0079 - output_variable1_loss: 0.0058 - output_variable2_loss: 0.0021 - val_loss: 0.0852 - val_output_variable1_loss: 0.0807 - val_output_variable2_loss: 0.0046
# Epoch 73/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0077 - output_variable1_loss: 0.0056 - output_variable2_loss: 0.0021 - val_loss: 0.0821 - val_output_variable1_loss: 0.0770 - val_output_variable2_loss: 0.0051
# Epoch 74/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0077 - output_variable1_loss: 0.0055 - output_variable2_loss: 0.0021 - val_loss: 0.0834 - val_output_variable1_loss: 0.0784 - val_output_variable2_loss: 0.0050
# Epoch 75/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0077 - output_variable1_loss: 0.0056 - output_variable2_loss: 0.0021 - val_loss: 0.0898 - val_output_variable1_loss: 0.0849 - val_output_variable2_loss: 0.0049
# Epoch 76/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0077 - output_variable1_loss: 0.0056 - output_variable2_loss: 0.0022 - val_loss: 0.0855 - val_output_variable1_loss: 0.0805 - val_output_variable2_loss: 0.0050
# Epoch 77/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0079 - output_variable1_loss: 0.0057 - output_variable2_loss: 0.0022 - val_loss: 0.0888 - val_output_variable1_loss: 0.0831 - val_output_variable2_loss: 0.0057
# Epoch 78/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0080 - output_variable1_loss: 0.0058 - output_variable2_loss: 0.0022 - val_loss: 0.0982 - val_output_variable1_loss: 0.0923 - val_output_variable2_loss: 0.0059
# Epoch 79/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0077 - output_variable1_loss: 0.0056 - output_variable2_loss: 0.0021 - val_loss: 0.0920 - val_output_variable1_loss: 0.0871 - val_output_variable2_loss: 0.0049
# Epoch 80/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0076 - output_variable1_loss: 0.0055 - output_variable2_loss: 0.0021 - val_loss: 0.0982 - val_output_variable1_loss: 0.0926 - val_output_variable2_loss: 0.0056
# Epoch 81/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0071 - output_variable1_loss: 0.0051 - output_variable2_loss: 0.0020 - val_loss: 0.0902 - val_output_variable1_loss: 0.0853 - val_output_variable2_loss: 0.0049
# Epoch 82/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0070 - output_variable1_loss: 0.0051 - output_variable2_loss: 0.0019 - val_loss: 0.0890 - val_output_variable1_loss: 0.0835 - val_output_variable2_loss: 0.0055
# Epoch 83/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0069 - output_variable1_loss: 0.0050 - output_variable2_loss: 0.0019 - val_loss: 0.0885 - val_output_variable1_loss: 0.0828 - val_output_variable2_loss: 0.0057
# Epoch 84/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0068 - output_variable1_loss: 0.0049 - output_variable2_loss: 0.0019 - val_loss: 0.0874 - val_output_variable1_loss: 0.0818 - val_output_variable2_loss: 0.0056
# Epoch 85/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0068 - output_variable1_loss: 0.0049 - output_variable2_loss: 0.0019 - val_loss: 0.0931 - val_output_variable1_loss: 0.0881 - val_output_variable2_loss: 0.0051
# Epoch 86/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0067 - output_variable1_loss: 0.0048 - output_variable2_loss: 0.0019 - val_loss: 0.0955 - val_output_variable1_loss: 0.0900 - val_output_variable2_loss: 0.0055
# Epoch 87/100
# 13/13 [==============================] - 0s 31ms/step - loss: 0.0067 - output_variable1_loss: 0.0048 - output_variable2_loss: 0.0019 - val_loss: 0.0869 - val_output_variable1_loss: 0.0819 - val_output_variable2_loss: 0.0049
# Epoch 88/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0067 - output_variable1_loss: 0.0048 - output_variable2_loss: 0.0019 - val_loss: 0.0911 - val_output_variable1_loss: 0.0859 - val_output_variable2_loss: 0.0052
# Epoch 89/100
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0065 - output_variable1_loss: 0.0046 - output_variable2_loss: 0.0019 - val_loss: 0.0905 - val_output_variable1_loss: 0.0851 - val_output_variable2_loss: 0.0054
# Epoch 90/100
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0065 - output_variable1_loss: 0.0046 - output_variable2_loss: 0.0018 - val_loss: 0.0899 - val_output_variable1_loss: 0.0848 - val_output_variable2_loss: 0.0051
# Epoch 91/100
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0068 - output_variable1_loss: 0.0050 - output_variable2_loss: 0.0018 - val_loss: 0.0860 - val_output_variable1_loss: 0.0805 - val_output_variable2_loss: 0.0055
# Epoch 92/100
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0064 - output_variable1_loss: 0.0046 - output_variable2_loss: 0.0018 - val_loss: 0.0920 - val_output_variable1_loss: 0.0867 - val_output_variable2_loss: 0.0052
# Epoch 93/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0063 - output_variable1_loss: 0.0046 - output_variable2_loss: 0.0018 - val_loss: 0.0937 - val_output_variable1_loss: 0.0884 - val_output_variable2_loss: 0.0053
# Epoch 94/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0064 - output_variable1_loss: 0.0045 - output_variable2_loss: 0.0019 - val_loss: 0.0924 - val_output_variable1_loss: 0.0868 - val_output_variable2_loss: 0.0056
# Epoch 95/100
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0063 - output_variable1_loss: 0.0044 - output_variable2_loss: 0.0019 - val_loss: 0.0916 - val_output_variable1_loss: 0.0862 - val_output_variable2_loss: 0.0054
# Epoch 96/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0062 - output_variable1_loss: 0.0044 - output_variable2_loss: 0.0018 - val_loss: 0.0828 - val_output_variable1_loss: 0.0775 - val_output_variable2_loss: 0.0053
# Epoch 97/100
# 13/13 [==============================] - 0s 31ms/step - loss: 0.0062 - output_variable1_loss: 0.0045 - output_variable2_loss: 0.0017 - val_loss: 0.0910 - val_output_variable1_loss: 0.0852 - val_output_variable2_loss: 0.0057
# Epoch 98/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0059 - output_variable1_loss: 0.0042 - output_variable2_loss: 0.0016 - val_loss: 0.0977 - val_output_variable1_loss: 0.0916 - val_output_variable2_loss: 0.0061
# Epoch 99/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0058 - output_variable1_loss: 0.0041 - output_variable2_loss: 0.0016 - val_loss: 0.0955 - val_output_variable1_loss: 0.0901 - val_output_variable2_loss: 0.0054
# Epoch 100/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0058 - output_variable1_loss: 0.0041 - output_variable2_loss: 0.0017 - val_loss: 0.0868 - val_output_variable1_loss: 0.0808 - val_output_variable2_loss: 0.0059
# Epoch 1/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0097 - output_variable1_loss: 0.0079 - output_variable2_loss: 0.0018 - val_loss: 0.0449 - val_output_variable1_loss: 0.0423 - val_output_variable2_loss: 0.0027
# Epoch 2/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0090 - output_variable1_loss: 0.0073 - output_variable2_loss: 0.0017 - val_loss: 0.0442 - val_output_variable1_loss: 0.0416 - val_output_variable2_loss: 0.0026
# Epoch 3/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0086 - output_variable1_loss: 0.0068 - output_variable2_loss: 0.0018 - val_loss: 0.0424 - val_output_variable1_loss: 0.0403 - val_output_variable2_loss: 0.0021
# Epoch 4/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0084 - output_variable1_loss: 0.0068 - output_variable2_loss: 0.0016 - val_loss: 0.0383 - val_output_variable1_loss: 0.0359 - val_output_variable2_loss: 0.0024
# Epoch 5/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0081 - output_variable1_loss: 0.0065 - output_variable2_loss: 0.0016 - val_loss: 0.0399 - val_output_variable1_loss: 0.0369 - val_output_variable2_loss: 0.0030
# Epoch 6/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0080 - output_variable1_loss: 0.0064 - output_variable2_loss: 0.0017 - val_loss: 0.0394 - val_output_variable1_loss: 0.0361 - val_output_variable2_loss: 0.0033
# Epoch 7/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0081 - output_variable1_loss: 0.0065 - output_variable2_loss: 0.0017 - val_loss: 0.0341 - val_output_variable1_loss: 0.0315 - val_output_variable2_loss: 0.0026
# Epoch 8/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0078 - output_variable1_loss: 0.0062 - output_variable2_loss: 0.0016 - val_loss: 0.0335 - val_output_variable1_loss: 0.0305 - val_output_variable2_loss: 0.0029
# Epoch 9/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0073 - output_variable1_loss: 0.0057 - output_variable2_loss: 0.0016 - val_loss: 0.0345 - val_output_variable1_loss: 0.0317 - val_output_variable2_loss: 0.0028
# Epoch 10/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0069 - output_variable1_loss: 0.0053 - output_variable2_loss: 0.0016 - val_loss: 0.0314 - val_output_variable1_loss: 0.0288 - val_output_variable2_loss: 0.0026
# Epoch 11/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0068 - output_variable1_loss: 0.0052 - output_variable2_loss: 0.0016 - val_loss: 0.0314 - val_output_variable1_loss: 0.0290 - val_output_variable2_loss: 0.0024
# Epoch 12/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0067 - output_variable1_loss: 0.0051 - output_variable2_loss: 0.0016 - val_loss: 0.0344 - val_output_variable1_loss: 0.0318 - val_output_variable2_loss: 0.0026
# Epoch 13/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0067 - output_variable1_loss: 0.0051 - output_variable2_loss: 0.0016 - val_loss: 0.0311 - val_output_variable1_loss: 0.0287 - val_output_variable2_loss: 0.0025
# Epoch 14/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0067 - output_variable1_loss: 0.0050 - output_variable2_loss: 0.0017 - val_loss: 0.0272 - val_output_variable1_loss: 0.0247 - val_output_variable2_loss: 0.0025
# Epoch 15/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0065 - output_variable1_loss: 0.0048 - output_variable2_loss: 0.0017 - val_loss: 0.0327 - val_output_variable1_loss: 0.0306 - val_output_variable2_loss: 0.0021
# Epoch 16/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0062 - output_variable1_loss: 0.0045 - output_variable2_loss: 0.0017 - val_loss: 0.0292 - val_output_variable1_loss: 0.0267 - val_output_variable2_loss: 0.0025
# Epoch 17/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0058 - output_variable1_loss: 0.0042 - output_variable2_loss: 0.0015 - val_loss: 0.0279 - val_output_variable1_loss: 0.0256 - val_output_variable2_loss: 0.0023
# Epoch 18/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0058 - output_variable1_loss: 0.0043 - output_variable2_loss: 0.0015 - val_loss: 0.0306 - val_output_variable1_loss: 0.0277 - val_output_variable2_loss: 0.0029
# Epoch 19/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0061 - output_variable1_loss: 0.0045 - output_variable2_loss: 0.0015 - val_loss: 0.0331 - val_output_variable1_loss: 0.0310 - val_output_variable2_loss: 0.0021
# Epoch 20/100
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0058 - output_variable1_loss: 0.0043 - output_variable2_loss: 0.0015 - val_loss: 0.0290 - val_output_variable1_loss: 0.0269 - val_output_variable2_loss: 0.0021
# Epoch 21/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0058 - output_variable1_loss: 0.0043 - output_variable2_loss: 0.0015 - val_loss: 0.0272 - val_output_variable1_loss: 0.0252 - val_output_variable2_loss: 0.0020
# Epoch 22/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0056 - output_variable1_loss: 0.0041 - output_variable2_loss: 0.0015 - val_loss: 0.0276 - val_output_variable1_loss: 0.0252 - val_output_variable2_loss: 0.0024
# Epoch 23/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0058 - output_variable1_loss: 0.0044 - output_variable2_loss: 0.0014 - val_loss: 0.0264 - val_output_variable1_loss: 0.0239 - val_output_variable2_loss: 0.0025
# Epoch 24/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0057 - output_variable1_loss: 0.0042 - output_variable2_loss: 0.0015 - val_loss: 0.0277 - val_output_variable1_loss: 0.0256 - val_output_variable2_loss: 0.0021
# Epoch 25/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0053 - output_variable1_loss: 0.0038 - output_variable2_loss: 0.0015 - val_loss: 0.0273 - val_output_variable1_loss: 0.0244 - val_output_variable2_loss: 0.0029
# Epoch 26/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0052 - output_variable1_loss: 0.0038 - output_variable2_loss: 0.0015 - val_loss: 0.0265 - val_output_variable1_loss: 0.0239 - val_output_variable2_loss: 0.0026
# Epoch 27/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0051 - output_variable1_loss: 0.0037 - output_variable2_loss: 0.0015 - val_loss: 0.0296 - val_output_variable1_loss: 0.0273 - val_output_variable2_loss: 0.0023
# Epoch 28/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0051 - output_variable1_loss: 0.0037 - output_variable2_loss: 0.0014 - val_loss: 0.0278 - val_output_variable1_loss: 0.0256 - val_output_variable2_loss: 0.0022
# Epoch 29/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0051 - output_variable1_loss: 0.0036 - output_variable2_loss: 0.0014 - val_loss: 0.0272 - val_output_variable1_loss: 0.0248 - val_output_variable2_loss: 0.0024
# Epoch 30/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0050 - output_variable1_loss: 0.0035 - output_variable2_loss: 0.0015 - val_loss: 0.0251 - val_output_variable1_loss: 0.0227 - val_output_variable2_loss: 0.0024
# Epoch 31/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0049 - output_variable1_loss: 0.0035 - output_variable2_loss: 0.0014 - val_loss: 0.0279 - val_output_variable1_loss: 0.0251 - val_output_variable2_loss: 0.0028
# Epoch 32/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0050 - output_variable1_loss: 0.0035 - output_variable2_loss: 0.0014 - val_loss: 0.0264 - val_output_variable1_loss: 0.0240 - val_output_variable2_loss: 0.0024
# Epoch 33/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0050 - output_variable1_loss: 0.0035 - output_variable2_loss: 0.0015 - val_loss: 0.0240 - val_output_variable1_loss: 0.0215 - val_output_variable2_loss: 0.0024
# Epoch 34/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0050 - output_variable1_loss: 0.0036 - output_variable2_loss: 0.0015 - val_loss: 0.0248 - val_output_variable1_loss: 0.0228 - val_output_variable2_loss: 0.0020
# Epoch 35/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0047 - output_variable1_loss: 0.0034 - output_variable2_loss: 0.0013 - val_loss: 0.0248 - val_output_variable1_loss: 0.0219 - val_output_variable2_loss: 0.0029
# Epoch 36/100
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0049 - output_variable1_loss: 0.0035 - output_variable2_loss: 0.0014 - val_loss: 0.0219 - val_output_variable1_loss: 0.0200 - val_output_variable2_loss: 0.0019
# Epoch 37/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0050 - output_variable1_loss: 0.0036 - output_variable2_loss: 0.0014 - val_loss: 0.0269 - val_output_variable1_loss: 0.0247 - val_output_variable2_loss: 0.0022
# Epoch 38/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0046 - output_variable1_loss: 0.0032 - output_variable2_loss: 0.0014 - val_loss: 0.0242 - val_output_variable1_loss: 0.0213 - val_output_variable2_loss: 0.0029
# Epoch 39/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0046 - output_variable1_loss: 0.0031 - output_variable2_loss: 0.0015 - val_loss: 0.0234 - val_output_variable1_loss: 0.0213 - val_output_variable2_loss: 0.0021
# Epoch 40/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0047 - output_variable1_loss: 0.0033 - output_variable2_loss: 0.0014 - val_loss: 0.0234 - val_output_variable1_loss: 0.0211 - val_output_variable2_loss: 0.0022
# Epoch 41/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0045 - output_variable1_loss: 0.0032 - output_variable2_loss: 0.0013 - val_loss: 0.0242 - val_output_variable1_loss: 0.0217 - val_output_variable2_loss: 0.0024
# Epoch 42/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0045 - output_variable1_loss: 0.0031 - output_variable2_loss: 0.0014 - val_loss: 0.0240 - val_output_variable1_loss: 0.0212 - val_output_variable2_loss: 0.0028
# Epoch 43/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0044 - output_variable1_loss: 0.0031 - output_variable2_loss: 0.0013 - val_loss: 0.0242 - val_output_variable1_loss: 0.0222 - val_output_variable2_loss: 0.0021
# Epoch 44/100
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0043 - output_variable1_loss: 0.0031 - output_variable2_loss: 0.0013 - val_loss: 0.0278 - val_output_variable1_loss: 0.0257 - val_output_variable2_loss: 0.0020
# Epoch 45/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0044 - output_variable1_loss: 0.0031 - output_variable2_loss: 0.0013 - val_loss: 0.0228 - val_output_variable1_loss: 0.0201 - val_output_variable2_loss: 0.0027
# Epoch 46/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0044 - output_variable1_loss: 0.0031 - output_variable2_loss: 0.0013 - val_loss: 0.0229 - val_output_variable1_loss: 0.0207 - val_output_variable2_loss: 0.0021
# Epoch 47/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0044 - output_variable1_loss: 0.0031 - output_variable2_loss: 0.0013 - val_loss: 0.0233 - val_output_variable1_loss: 0.0206 - val_output_variable2_loss: 0.0027
# Epoch 48/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0043 - output_variable1_loss: 0.0030 - output_variable2_loss: 0.0013 - val_loss: 0.0217 - val_output_variable1_loss: 0.0199 - val_output_variable2_loss: 0.0017
# Epoch 49/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0042 - output_variable1_loss: 0.0030 - output_variable2_loss: 0.0013 - val_loss: 0.0246 - val_output_variable1_loss: 0.0223 - val_output_variable2_loss: 0.0023
# Epoch 50/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0041 - output_variable1_loss: 0.0029 - output_variable2_loss: 0.0012 - val_loss: 0.0220 - val_output_variable1_loss: 0.0192 - val_output_variable2_loss: 0.0028
# Epoch 51/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0041 - output_variable1_loss: 0.0028 - output_variable2_loss: 0.0013 - val_loss: 0.0229 - val_output_variable1_loss: 0.0207 - val_output_variable2_loss: 0.0022
# Epoch 52/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0040 - output_variable1_loss: 0.0028 - output_variable2_loss: 0.0012 - val_loss: 0.0228 - val_output_variable1_loss: 0.0208 - val_output_variable2_loss: 0.0020
# Epoch 53/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0040 - output_variable1_loss: 0.0028 - output_variable2_loss: 0.0012 - val_loss: 0.0239 - val_output_variable1_loss: 0.0208 - val_output_variable2_loss: 0.0031
# Epoch 54/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0040 - output_variable1_loss: 0.0027 - output_variable2_loss: 0.0013 - val_loss: 0.0229 - val_output_variable1_loss: 0.0208 - val_output_variable2_loss: 0.0021
# Epoch 55/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0039 - output_variable1_loss: 0.0027 - output_variable2_loss: 0.0012 - val_loss: 0.0235 - val_output_variable1_loss: 0.0210 - val_output_variable2_loss: 0.0025
# Epoch 56/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0040 - output_variable1_loss: 0.0028 - output_variable2_loss: 0.0012 - val_loss: 0.0233 - val_output_variable1_loss: 0.0212 - val_output_variable2_loss: 0.0021
# Epoch 57/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0038 - output_variable1_loss: 0.0027 - output_variable2_loss: 0.0012 - val_loss: 0.0220 - val_output_variable1_loss: 0.0197 - val_output_variable2_loss: 0.0024
# Epoch 58/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0038 - output_variable1_loss: 0.0027 - output_variable2_loss: 0.0011 - val_loss: 0.0222 - val_output_variable1_loss: 0.0202 - val_output_variable2_loss: 0.0020
# Epoch 59/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0039 - output_variable1_loss: 0.0027 - output_variable2_loss: 0.0012 - val_loss: 0.0231 - val_output_variable1_loss: 0.0202 - val_output_variable2_loss: 0.0029
# Epoch 60/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0039 - output_variable1_loss: 0.0027 - output_variable2_loss: 0.0012 - val_loss: 0.0226 - val_output_variable1_loss: 0.0201 - val_output_variable2_loss: 0.0024
# Epoch 61/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0038 - output_variable1_loss: 0.0026 - output_variable2_loss: 0.0011 - val_loss: 0.0244 - val_output_variable1_loss: 0.0222 - val_output_variable2_loss: 0.0022
# Epoch 62/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0039 - output_variable1_loss: 0.0027 - output_variable2_loss: 0.0011 - val_loss: 0.0214 - val_output_variable1_loss: 0.0192 - val_output_variable2_loss: 0.0022
# Epoch 63/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0038 - output_variable1_loss: 0.0026 - output_variable2_loss: 0.0011 - val_loss: 0.0233 - val_output_variable1_loss: 0.0213 - val_output_variable2_loss: 0.0021
# Epoch 64/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0037 - output_variable1_loss: 0.0026 - output_variable2_loss: 0.0011 - val_loss: 0.0235 - val_output_variable1_loss: 0.0212 - val_output_variable2_loss: 0.0023
# Epoch 65/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0037 - output_variable1_loss: 0.0026 - output_variable2_loss: 0.0011 - val_loss: 0.0194 - val_output_variable1_loss: 0.0174 - val_output_variable2_loss: 0.0020
# Epoch 66/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0038 - output_variable1_loss: 0.0026 - output_variable2_loss: 0.0011 - val_loss: 0.0229 - val_output_variable1_loss: 0.0205 - val_output_variable2_loss: 0.0025
# Epoch 67/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0038 - output_variable1_loss: 0.0027 - output_variable2_loss: 0.0012 - val_loss: 0.0227 - val_output_variable1_loss: 0.0207 - val_output_variable2_loss: 0.0021
# Epoch 68/100
# 14/14 [==============================] - 0s 36ms/step - loss: 0.0039 - output_variable1_loss: 0.0028 - output_variable2_loss: 0.0011 - val_loss: 0.0226 - val_output_variable1_loss: 0.0204 - val_output_variable2_loss: 0.0023
# Epoch 69/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0037 - output_variable1_loss: 0.0026 - output_variable2_loss: 0.0011 - val_loss: 0.0224 - val_output_variable1_loss: 0.0202 - val_output_variable2_loss: 0.0022
# Epoch 70/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0036 - output_variable1_loss: 0.0025 - output_variable2_loss: 0.0011 - val_loss: 0.0206 - val_output_variable1_loss: 0.0180 - val_output_variable2_loss: 0.0026
# Epoch 71/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0037 - output_variable1_loss: 0.0025 - output_variable2_loss: 0.0012 - val_loss: 0.0228 - val_output_variable1_loss: 0.0204 - val_output_variable2_loss: 0.0024
# Epoch 72/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0039 - output_variable1_loss: 0.0025 - output_variable2_loss: 0.0014 - val_loss: 0.0218 - val_output_variable1_loss: 0.0195 - val_output_variable2_loss: 0.0023
# Epoch 73/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0036 - output_variable1_loss: 0.0024 - output_variable2_loss: 0.0012 - val_loss: 0.0219 - val_output_variable1_loss: 0.0192 - val_output_variable2_loss: 0.0027
# Epoch 74/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0036 - output_variable1_loss: 0.0024 - output_variable2_loss: 0.0012 - val_loss: 0.0226 - val_output_variable1_loss: 0.0203 - val_output_variable2_loss: 0.0023
# Epoch 75/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0035 - output_variable1_loss: 0.0025 - output_variable2_loss: 0.0011 - val_loss: 0.0218 - val_output_variable1_loss: 0.0197 - val_output_variable2_loss: 0.0021
# Epoch 76/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0035 - output_variable1_loss: 0.0025 - output_variable2_loss: 0.0010 - val_loss: 0.0215 - val_output_variable1_loss: 0.0189 - val_output_variable2_loss: 0.0026
# Epoch 77/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0035 - output_variable1_loss: 0.0025 - output_variable2_loss: 0.0011 - val_loss: 0.0225 - val_output_variable1_loss: 0.0202 - val_output_variable2_loss: 0.0022
# Epoch 78/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0034 - output_variable1_loss: 0.0024 - output_variable2_loss: 0.0010 - val_loss: 0.0214 - val_output_variable1_loss: 0.0193 - val_output_variable2_loss: 0.0020
# Epoch 79/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0033 - output_variable1_loss: 0.0023 - output_variable2_loss: 0.0010 - val_loss: 0.0217 - val_output_variable1_loss: 0.0198 - val_output_variable2_loss: 0.0019
# Epoch 80/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0033 - output_variable1_loss: 0.0023 - output_variable2_loss: 0.0010 - val_loss: 0.0224 - val_output_variable1_loss: 0.0202 - val_output_variable2_loss: 0.0022
# Epoch 81/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0034 - output_variable1_loss: 0.0024 - output_variable2_loss: 0.0010 - val_loss: 0.0205 - val_output_variable1_loss: 0.0185 - val_output_variable2_loss: 0.0020
# Epoch 82/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0034 - output_variable1_loss: 0.0023 - output_variable2_loss: 0.0011 - val_loss: 0.0232 - val_output_variable1_loss: 0.0208 - val_output_variable2_loss: 0.0023
# Epoch 83/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0033 - output_variable1_loss: 0.0023 - output_variable2_loss: 0.0011 - val_loss: 0.0220 - val_output_variable1_loss: 0.0192 - val_output_variable2_loss: 0.0028
# Epoch 84/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0035 - output_variable1_loss: 0.0023 - output_variable2_loss: 0.0012 - val_loss: 0.0218 - val_output_variable1_loss: 0.0195 - val_output_variable2_loss: 0.0022
# Epoch 85/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0036 - output_variable1_loss: 0.0024 - output_variable2_loss: 0.0011 - val_loss: 0.0217 - val_output_variable1_loss: 0.0197 - val_output_variable2_loss: 0.0020
# Epoch 86/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0033 - output_variable1_loss: 0.0023 - output_variable2_loss: 0.0010 - val_loss: 0.0214 - val_output_variable1_loss: 0.0191 - val_output_variable2_loss: 0.0023
# Epoch 87/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0032 - output_variable1_loss: 0.0022 - output_variable2_loss: 9.9845e-04 - val_loss: 0.0207 - val_output_variable1_loss: 0.0190 - val_output_variable2_loss: 0.0016
# Epoch 88/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0032 - output_variable1_loss: 0.0022 - output_variable2_loss: 9.9425e-04 - val_loss: 0.0212 - val_output_variable1_loss: 0.0191 - val_output_variable2_loss: 0.0022
# Epoch 89/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0032 - output_variable1_loss: 0.0022 - output_variable2_loss: 9.9812e-04 - val_loss: 0.0208 - val_output_variable1_loss: 0.0184 - val_output_variable2_loss: 0.0024
# Epoch 90/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0032 - output_variable1_loss: 0.0022 - output_variable2_loss: 0.0010 - val_loss: 0.0223 - val_output_variable1_loss: 0.0204 - val_output_variable2_loss: 0.0019
# Epoch 91/100
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0033 - output_variable1_loss: 0.0023 - output_variable2_loss: 0.0010 - val_loss: 0.0215 - val_output_variable1_loss: 0.0193 - val_output_variable2_loss: 0.0023
# Epoch 92/100
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0032 - output_variable1_loss: 0.0022 - output_variable2_loss: 9.9268e-04 - val_loss: 0.0228 - val_output_variable1_loss: 0.0208 - val_output_variable2_loss: 0.0020
# Epoch 93/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0031 - output_variable1_loss: 0.0022 - output_variable2_loss: 9.4678e-04 - val_loss: 0.0211 - val_output_variable1_loss: 0.0190 - val_output_variable2_loss: 0.0021
# Epoch 94/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0031 - output_variable1_loss: 0.0022 - output_variable2_loss: 9.3426e-04 - val_loss: 0.0213 - val_output_variable1_loss: 0.0194 - val_output_variable2_loss: 0.0019
# Epoch 95/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0030 - output_variable1_loss: 0.0021 - output_variable2_loss: 9.3896e-04 - val_loss: 0.0220 - val_output_variable1_loss: 0.0199 - val_output_variable2_loss: 0.0020
# Epoch 96/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0031 - output_variable1_loss: 0.0021 - output_variable2_loss: 9.5534e-04 - val_loss: 0.0215 - val_output_variable1_loss: 0.0194 - val_output_variable2_loss: 0.0021
# Epoch 97/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0030 - output_variable1_loss: 0.0021 - output_variable2_loss: 9.4470e-04 - val_loss: 0.0221 - val_output_variable1_loss: 0.0203 - val_output_variable2_loss: 0.0018
# Epoch 98/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0031 - output_variable1_loss: 0.0021 - output_variable2_loss: 9.3830e-04 - val_loss: 0.0211 - val_output_variable1_loss: 0.0190 - val_output_variable2_loss: 0.0022
# Epoch 99/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0032 - output_variable1_loss: 0.0022 - output_variable2_loss: 9.3724e-04 - val_loss: 0.0215 - val_output_variable1_loss: 0.0196 - val_output_variable2_loss: 0.0019
# Epoch 100/100
# 14/14 [==============================] - 0s 29ms/step - loss: 0.0032 - output_variable1_loss: 0.0022 - output_variable2_loss: 9.6217e-04 - val_loss: 0.0207 - val_output_variable1_loss: 0.0187 - val_output_variable2_loss: 0.0020
# Epoch 1/100
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0042 - output_variable1_loss: 0.0032 - output_variable2_loss: 9.5568e-04 - val_loss: 0.0196 - val_output_variable1_loss: 0.0189 - val_output_variable2_loss: 6.8398e-04
# Epoch 2/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0043 - output_variable1_loss: 0.0032 - output_variable2_loss: 0.0010 - val_loss: 0.0224 - val_output_variable1_loss: 0.0214 - val_output_variable2_loss: 9.9017e-04
# Epoch 3/100
# ...
# Epoch 12/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0034 - output_variable1_loss: 0.0025 - output_variable2_loss: 8.9481e-04 - val_loss: 0.0190 - val_output_variable1_loss: 0.0184 - val_output_variable2_loss: 6.1678e-04
# Epoch 13/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0033 - output_variable1_loss: 0.0023 - output_variable2_loss: 9.2046e-04 - val_loss: 0.0176 - val_output_variable1_loss: 0.0170 - val_output_variable2_loss: 5.5903e-04
# Epoch 14/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.0031 - output_variable1_loss: 0.0022 - output_variable2_loss: 8.7845e-04 - val_loss: 0.0183 - val_output_variable1_loss: 0.0178 - val_output_variable2_loss: 4.7109e-04
# Epoch 15/100
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0031 - output_variable1_loss: 0.0022 - output_variable2_loss: 9.2621e-04 - val_loss: 0.0188 - val_output_variable1_loss: 0.0181 - val_output_variable2_loss: 7.2940e-04
# Epoch 16/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0031 - output_variable1_loss: 0.0021 - output_variable2_loss: 9.4298e-04 - val_loss: 0.0159 - val_output_variable1_loss: 0.0150 - val_output_variable2_loss: 8.4028e-04
# Epoch 17/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0031 - output_variable1_loss: 0.0022 - output_variable2_loss: 9.2295e-04 - val_loss: 0.0187 - val_output_variable1_loss: 0.0182 - val_output_variable2_loss: 5.7195e-04
# Epoch 18/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0030 - output_variable1_loss: 0.0022 - output_variable2_loss: 8.5502e-04 - val_loss: 0.0181 - val_output_variable1_loss: 0.0175 - val_output_variable2_loss: 5.5763e-04
# Epoch 19/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0029 - output_variable1_loss: 0.0021 - output_variable2_loss: 8.5192e-04 - val_loss: 0.0186 - val_output_variable1_loss: 0.0181 - val_output_variable2_loss: 4.8833e-04
# Epoch 20/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0029 - output_variable1_loss: 0.0020 - output_variable2_loss: 8.2119e-04 - val_loss: 0.0185 - val_output_variable1_loss: 0.0178 - val_output_variable2_loss: 7.4319e-04
# Epoch 21/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0028 - output_variable1_loss: 0.0020 - output_variable2_loss: 8.6201e-04 - val_loss: 0.0195 - val_output_variable1_loss: 0.0187 - val_output_variable2_loss: 7.3067e-04
# Epoch 22/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0029 - output_variable1_loss: 0.0020 - output_variable2_loss: 8.3451e-04 - val_loss: 0.0180 - val_output_variable1_loss: 0.0175 - val_output_variable2_loss: 5.4756e-04
# Epoch 23/100
# 15/15 [==============================] - 0s 28ms/step - loss: 0.0029 - output_variable1_loss: 0.0020 - output_variable2_loss: 8.5676e-04 - val_loss: 0.0185 - val_output_variable1_loss: 0.0178 - val_output_variable2_loss: 7.0236e-04
# Epoch 24/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0029 - output_variable1_loss: 0.0020 - output_variable2_loss: 8.5616e-04 - val_loss: 0.0178 - val_output_variable1_loss: 0.0171 - val_output_variable2_loss: 6.6743e-04
# Epoch 25/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0028 - output_variable1_loss: 0.0020 - output_variable2_loss: 8.2721e-04 - val_loss: 0.0165 - val_output_variable1_loss: 0.0160 - val_output_variable2_loss: 4.9764e-04
# Epoch 26/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0029 - output_variable1_loss: 0.0021 - output_variable2_loss: 8.7225e-04 - val_loss: 0.0182 - val_output_variable1_loss: 0.0175 - val_output_variable2_loss: 7.2132e-04
# Epoch 27/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0028 - output_variable1_loss: 0.0020 - output_variable2_loss: 8.7111e-04 - val_loss: 0.0167 - val_output_variable1_loss: 0.0162 - val_output_variable2_loss: 5.1995e-04
# Epoch 28/100
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0029 - output_variable1_loss: 0.0020 - output_variable2_loss: 8.4591e-04 - val_loss: 0.0152 - val_output_variable1_loss: 0.0146 - val_output_variable2_loss: 5.6561e-04
# Epoch 29/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0030 - output_variable1_loss: 0.0021 - output_variable2_loss: 8.7608e-04 - val_loss: 0.0178 - val_output_variable1_loss: 0.0173 - val_output_variable2_loss: 5.2804e-04
# Epoch 30/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0028 - output_variable1_loss: 0.0019 - output_variable2_loss: 8.7095e-04 - val_loss: 0.0169 - val_output_variable1_loss: 0.0164 - val_output_variable2_loss: 5.1498e-04
# Epoch 31/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0027 - output_variable1_loss: 0.0019 - output_variable2_loss: 8.1891e-04 - val_loss: 0.0171 - val_output_variable1_loss: 0.0165 - val_output_variable2_loss: 5.9213e-04
# Epoch 32/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0027 - output_variable1_loss: 0.0018 - output_variable2_loss: 8.5622e-04 - val_loss: 0.0164 - val_output_variable1_loss: 0.0157 - val_output_variable2_loss: 7.3126e-04
# Epoch 33/100
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0027 - output_variable1_loss: 0.0019 - output_variable2_loss: 8.0688e-04 - val_loss: 0.0155 - val_output_variable1_loss: 0.0149 - val_output_variable2_loss: 5.9335e-04
# Epoch 34/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0027 - output_variable1_loss: 0.0019 - output_variable2_loss: 8.0189e-04 - val_loss: 0.0162 - val_output_variable1_loss: 0.0158 - val_output_variable2_loss: 4.2792e-04
# Epoch 35/100
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0026 - output_variable1_loss: 0.0018 - output_variable2_loss: 7.8661e-04 - val_loss: 0.0170 - val_output_variable1_loss: 0.0164 - val_output_variable2_loss: 6.7330e-04
# Epoch 36/100
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0026 - output_variable1_loss: 0.0018 - output_variable2_loss: 8.2127e-04 - val_loss: 0.0175 - val_output_variable1_loss: 0.0168 - val_output_variable2_loss: 7.6342e-04
# Epoch 37/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0026 - output_variable1_loss: 0.0018 - output_variable2_loss: 7.8478e-04 - val_loss: 0.0172 - val_output_variable1_loss: 0.0166 - val_output_variable2_loss: 5.2172e-04
# Epoch 38/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0027 - output_variable1_loss: 0.0019 - output_variable2_loss: 7.7095e-04 - val_loss: 0.0188 - val_output_variable1_loss: 0.0182 - val_output_variable2_loss: 6.5965e-04
# Epoch 39/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0027 - output_variable1_loss: 0.0019 - output_variable2_loss: 7.9251e-04 - val_loss: 0.0181 - val_output_variable1_loss: 0.0174 - val_output_variable2_loss: 6.4299e-04
# Epoch 40/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0027 - output_variable1_loss: 0.0019 - output_variable2_loss: 7.9807e-04 - val_loss: 0.0156 - val_output_variable1_loss: 0.0151 - val_output_variable2_loss: 5.5689e-04
# Epoch 41/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0026 - output_variable1_loss: 0.0018 - output_variable2_loss: 7.8326e-04 - val_loss: 0.0173 - val_output_variable1_loss: 0.0168 - val_output_variable2_loss: 5.6955e-04
# Epoch 42/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0025 - output_variable1_loss: 0.0017 - output_variable2_loss: 7.7801e-04 - val_loss: 0.0177 - val_output_variable1_loss: 0.0173 - val_output_variable2_loss: 4.2442e-04
# Epoch 43/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0025 - output_variable1_loss: 0.0017 - output_variable2_loss: 7.8424e-04 - val_loss: 0.0168 - val_output_variable1_loss: 0.0164 - val_output_variable2_loss: 4.3925e-04
# Epoch 44/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0025 - output_variable1_loss: 0.0017 - output_variable2_loss: 7.6493e-04 - val_loss: 0.0177 - val_output_variable1_loss: 0.0171 - val_output_variable2_loss: 6.5881e-04
# Epoch 45/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0026 - output_variable1_loss: 0.0017 - output_variable2_loss: 8.7496e-04 - val_loss: 0.0161 - val_output_variable1_loss: 0.0154 - val_output_variable2_loss: 6.0395e-04
# Epoch 46/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0026 - output_variable1_loss: 0.0018 - output_variable2_loss: 7.8736e-04 - val_loss: 0.0165 - val_output_variable1_loss: 0.0158 - val_output_variable2_loss: 7.1090e-04
# Epoch 47/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0025 - output_variable1_loss: 0.0017 - output_variable2_loss: 8.0233e-04 - val_loss: 0.0182 - val_output_variable1_loss: 0.0176 - val_output_variable2_loss: 5.8163e-04
# Epoch 48/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0025 - output_variable1_loss: 0.0017 - output_variable2_loss: 7.7699e-04 - val_loss: 0.0151 - val_output_variable1_loss: 0.0146 - val_output_variable2_loss: 5.2959e-04
# Epoch 49/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0025 - output_variable1_loss: 0.0017 - output_variable2_loss: 7.8744e-04 - val_loss: 0.0173 - val_output_variable1_loss: 0.0167 - val_output_variable2_loss: 6.8588e-04
# Epoch 50/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0024 - output_variable1_loss: 0.0017 - output_variable2_loss: 7.4834e-04 - val_loss: 0.0177 - val_output_variable1_loss: 0.0171 - val_output_variable2_loss: 5.0885e-04
# Epoch 51/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0024 - output_variable1_loss: 0.0016 - output_variable2_loss: 7.3824e-04 - val_loss: 0.0177 - val_output_variable1_loss: 0.0173 - val_output_variable2_loss: 3.6771e-04
# Epoch 52/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0024 - output_variable1_loss: 0.0016 - output_variable2_loss: 7.6471e-04 - val_loss: 0.0162 - val_output_variable1_loss: 0.0155 - val_output_variable2_loss: 7.3524e-04
# Epoch 53/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0024 - output_variable1_loss: 0.0016 - output_variable2_loss: 7.7673e-04 - val_loss: 0.0165 - val_output_variable1_loss: 0.0160 - val_output_variable2_loss: 4.4643e-04
# Epoch 54/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0023 - output_variable1_loss: 0.0016 - output_variable2_loss: 7.3245e-04 - val_loss: 0.0158 - val_output_variable1_loss: 0.0152 - val_output_variable2_loss: 6.3028e-04
# Epoch 55/100
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0024 - output_variable1_loss: 0.0017 - output_variable2_loss: 7.6870e-04 - val_loss: 0.0157 - val_output_variable1_loss: 0.0152 - val_output_variable2_loss: 5.7907e-04
# Epoch 56/100
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0023 - output_variable1_loss: 0.0016 - output_variable2_loss: 7.5252e-04 - val_loss: 0.0175 - val_output_variable1_loss: 0.0171 - val_output_variable2_loss: 3.7566e-04
# Epoch 57/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0025 - output_variable1_loss: 0.0017 - output_variable2_loss: 8.1365e-04 - val_loss: 0.0168 - val_output_variable1_loss: 0.0163 - val_output_variable2_loss: 4.6842e-04
# Epoch 58/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0026 - output_variable1_loss: 0.0019 - output_variable2_loss: 7.8417e-04 - val_loss: 0.0148 - val_output_variable1_loss: 0.0142 - val_output_variable2_loss: 5.8583e-04
# Epoch 59/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0025 - output_variable1_loss: 0.0017 - output_variable2_loss: 7.7810e-04 - val_loss: 0.0170 - val_output_variable1_loss: 0.0166 - val_output_variable2_loss: 4.2733e-04
# Epoch 60/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0023 - output_variable1_loss: 0.0016 - output_variable2_loss: 7.5009e-04 - val_loss: 0.0160 - val_output_variable1_loss: 0.0157 - val_output_variable2_loss: 3.4849e-04
# Epoch 61/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0022 - output_variable1_loss: 0.0015 - output_variable2_loss: 6.9528e-04 - val_loss: 0.0157 - val_output_variable1_loss: 0.0153 - val_output_variable2_loss: 4.1468e-04
# Epoch 62/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0023 - output_variable1_loss: 0.0015 - output_variable2_loss: 7.7222e-04 - val_loss: 0.0163 - val_output_variable1_loss: 0.0153 - val_output_variable2_loss: 0.0010
# Epoch 63/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0024 - output_variable1_loss: 0.0015 - output_variable2_loss: 8.5443e-04 - val_loss: 0.0169 - val_output_variable1_loss: 0.0161 - val_output_variable2_loss: 7.1970e-04
# Epoch 64/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0024 - output_variable1_loss: 0.0015 - output_variable2_loss: 8.4757e-04 - val_loss: 0.0156 - val_output_variable1_loss: 0.0148 - val_output_variable2_loss: 8.0435e-04
# Epoch 65/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0024 - output_variable1_loss: 0.0016 - output_variable2_loss: 7.7665e-04 - val_loss: 0.0164 - val_output_variable1_loss: 0.0158 - val_output_variable2_loss: 5.9248e-04
# Epoch 66/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0023 - output_variable1_loss: 0.0016 - output_variable2_loss: 7.6386e-04 - val_loss: 0.0165 - val_output_variable1_loss: 0.0160 - val_output_variable2_loss: 4.9381e-04
# Epoch 67/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0023 - output_variable1_loss: 0.0015 - output_variable2_loss: 7.2344e-04 - val_loss: 0.0170 - val_output_variable1_loss: 0.0166 - val_output_variable2_loss: 4.4405e-04
# Epoch 68/100
# 15/15 [==============================] - 0s 29ms/step - loss: 0.0023 - output_variable1_loss: 0.0015 - output_variable2_loss: 7.0788e-04 - val_loss: 0.0153 - val_output_variable1_loss: 0.0150 - val_output_variable2_loss: 3.7286e-04
# Epoch 1/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0029 - output_variable1_loss: 0.0023 - output_variable2_loss: 6.8139e-04 - val_loss: 0.0340 - val_output_variable1_loss: 0.0328 - val_output_variable2_loss: 0.0011
# Epoch 2/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0035 - output_variable1_loss: 0.0027 - output_variable2_loss: 7.7717e-04 - val_loss: 0.0391 - val_output_variable1_loss: 0.0304 - val_output_variable2_loss: 0.0086
# Epoch 3/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0041 - output_variable1_loss: 0.0024 - output_variable2_loss: 0.0017 - val_loss: 0.0147 - val_output_variable1_loss: 0.0133 - val_output_variable2_loss: 0.0015
# Epoch 4/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0039 - output_variable1_loss: 0.0026 - output_variable2_loss: 0.0013 - val_loss: 0.0254 - val_output_variable1_loss: 0.0232 - val_output_variable2_loss: 0.0022
# Epoch 5/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0038 - output_variable1_loss: 0.0028 - output_variable2_loss: 0.0010 - val_loss: 0.0221 - val_output_variable1_loss: 0.0207 - val_output_variable2_loss: 0.0014
# Epoch 6/100
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0034 - output_variable1_loss: 0.0025 - output_variable2_loss: 8.9660e-04 - val_loss: 0.0222 - val_output_variable1_loss: 0.0206 - val_output_variable2_loss: 0.0016
# Epoch 7/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0031 - output_variable1_loss: 0.0023 - output_variable2_loss: 8.4673e-04 - val_loss: 0.0131 - val_output_variable1_loss: 0.0120 - val_output_variable2_loss: 0.0011
# Epoch 8/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0045 - output_variable1_loss: 0.0037 - output_variable2_loss: 7.7391e-04 - val_loss: 0.0222 - val_output_variable1_loss: 0.0211 - val_output_variable2_loss: 0.0010

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss_1):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss_1[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error 1", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss_2):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss_2[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error 2", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
# Evaluate the model on the test data
predictions_1 = []
predictions_2 = []
#print(len(eval_target_variables))

for i in range(len(Y_val)):
    current_batch = X_val[i].reshape((1, NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))
    curr_pred1, curr_pred2 = model.predict(current_batch)
    predictions_1.append(curr_pred1)
    predictions_2.append(curr_pred2)
# Out:
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_1):
    ax = axs[i]
    # TODO seems to work but check why column[0]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_val[i, :, 0], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_2):
    ax = axs[i]
    # TODO seems to work but check why column[0]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_val[i, :, 1], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
rmse = 0
for i in range(len(predictions_1)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_1[i][0], Y_val[i, :, 0]))}')
    rmse += sqrt(mean_squared_error(predictions_1[i][0], Y_val[i, :, 0]))

rmse /= len(predictions_1)    
print(f"RMSE for {columns_to_predict[0]} = {rmse}")

rmse = 0
for i in range(len(predictions_2)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_2[i][0], Y_val[i, :, 1]))}')
    rmse += sqrt(mean_squared_error(predictions_2[i][0], Y_val[i, :, 1]))

rmse /= len(predictions_2)    
print(f"RMSE for {columns_to_predict[1]} = {rmse}")
# Out:
# RMSE for kg_CO2/kWh = 0.1244331204520114
# RMSE for Avg solar generation = 0.0387965463005703

# %%
# Evaluate the model on the test data
predictions_1_test = []
predictions_2_test = []
#print(len(eval_target_variables))

for i in range(len(Y_test)):
    current_batch = X_test[i].reshape((1, NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))
    curr_pred1, curr_pred2 = model.predict(current_batch)
    predictions_1_test.append(curr_pred1)
    predictions_2_test.append(curr_pred2)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_1_test):
    ax = axs[i]
    # TODO seems to work but check why column[0]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_test[i, :, 0], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_2_test):
    ax = axs[i]
    # TODO seems to work but check why column[0]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_test[i, :, 1], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
rmse = 0
for i in range(len(predictions_1_test)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_1[i][0], Y_val[i, :, 0]))}')
    rmse += sqrt(mean_squared_error(predictions_1_test[i][0], Y_test[i, :, 0]))

rmse /= len(predictions_1_test)    
print(f"RMSE for {columns_to_predict[0]} = {rmse}")

rmse = 0
for i in range(len(predictions_2_test)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_2[i][0], Y_val[i, :, 1]))}')
    rmse += sqrt(mean_squared_error(predictions_2_test[i][0], Y_test[i, :, 1]))

rmse /= len(predictions_2_test)    
print(f"RMSE for {columns_to_predict[1]} = {rmse}")
# Out:
# RMSE for kg_CO2/kWh = 0.13146171318426736
# RMSE for Avg solar generation = 0.041961144619095746
