# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
train = pd.read_csv("../data/schemas/warm_up/TrainSet.csv", sep=",")
validation = pd.read_csv("../data/schemas/warm_up/ValidationSet.csv", sep=",")
test = pd.read_csv("../data/schemas/warm_up/TestSet.csv", sep=",")

# %%
# Global variables

NUM_OF_TIMESTEPS_INPUT = 48
NUM_OF_TIMESTEPS_OUTPUT = 24

THRESHOLD = 0.4   # For feature selection

# %%
columns_to_predict = ["kg_CO2/kWh", "Avg solar generation"]

independent_variables = []

for column in train:
    if abs(train[column].corr(train[columns_to_predict[0]])) > THRESHOLD: #or abs(train[column].corr(train[columns_to_predict[1]])) > THRESHOLD:
        independent_variables.append(column)

independent_variables = [var for var in independent_variables if var not in columns_to_predict]
    
if "Index" in independent_variables:
    independent_variables.remove("Index")
if "Solar Generation (W/kW)_1" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_1")
if "Solar Generation (W/kW)_2" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_2")
if "Solar Generation (W/kW)_3" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_3")
    
print(independent_variables)
# Out:
# ['Hour_1', 'Hour_2', 'Hour_3', 'Occupant Count (people)_3', '12h Outdoor Drybulb Temperature (C)', '24h Outdoor Drybulb Temperature (C)', '12h Outdoor Relative Humidity (%)', '6h Direct Solar Radiation (W/m2)', '12h Direct Solar Radiation (W/m2)']

# %% [markdown]
# Prepare the data

# %%
# Split the X and Y for all sets

# Train set
X_train_default = train[independent_variables]
Y_train_default = train[columns_to_predict]

# Validation set, also include the data from train that was used only as output to get more datapoints
X_val_default = pd.concat([X_train_default.tail(NUM_OF_TIMESTEPS_OUTPUT), validation[independent_variables]], ignore_index=True)
Y_val_default = pd.concat([Y_train_default.tail(NUM_OF_TIMESTEPS_OUTPUT), validation[columns_to_predict]], ignore_index=True)

# Test set, also include the data from train that was used only as output to get more datapoints
X_test_default = pd.concat([X_val_default.tail(NUM_OF_TIMESTEPS_OUTPUT), test[independent_variables]], ignore_index=True)
Y_test_default = pd.concat([Y_val_default.tail(NUM_OF_TIMESTEPS_OUTPUT), test[columns_to_predict]], ignore_index=True)

NUM_OF_ROWS_TRAIN, NUM_OF_FEATURES = X_train_default.shape

print(X_train_default.shape)
print(X_val_default.shape)
print(X_test_default.shape)
# Out:
# (576, 9)
# (96, 9)
# (96, 9)

# %%
# Function to prepare the data into batches that will be passed into the model

def create_sequences(input_data, output_data, timesteps_input, timesteps_output):
    sequences, targets = [], []
    for i in range(len(input_data) - timesteps_input - timesteps_output + 1):
        seq = input_data[i:i + timesteps_input]
        target = output_data[i + timesteps_input: i + timesteps_input + timesteps_output]
        sequences.append(seq)
        targets.append(target)

    return np.array(sequences), np.array(targets)

# %%
X_train, Y_train = create_sequences(X_train_default, Y_train_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)
X_val, Y_val = create_sequences(X_val_default, Y_val_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)
X_test, Y_test = create_sequences(X_test_default, Y_test_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)

print(f"X_train = {X_train.shape}, Y_train = {Y_train.shape}\n"
      f"X_val = {X_val.shape}, Y_val = {Y_val.shape}\n"
      f"X_test = {X_test.shape}, Y_test = {Y_test.shape}")
# Out:
# X_train = (505, 48, 9), Y_train = (505, 24, 2)
# X_val = (25, 48, 9), Y_val = (25, 24, 2)
# X_test = (25, 48, 9), Y_test = (25, 24, 2)

# %%
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras import layers, models
import time

tscv = TimeSeriesSplit(n_splits = 4, test_size=24) # For cross-validation

callback = keras.callbacks.EarlyStopping(monitor='loss', patience = 6) #patience parameter to be adjusted

loss = []
val_loss = []
loss_1 = []
val_loss_1 = []
loss_2 = []
val_loss_2 = []

# Input layer
input_layer = layers.Input(shape=(NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))

# Dense layers for variable 1
lstm1 = layers.GRU(48, activation='leaky_relu', return_sequences=True)(input_layer)
lstm2 = layers.GRU(48, activation='leaky_relu', return_sequences=True)(lstm1)
lstm3 = layers.GRU(24, activation='leaky_relu', return_sequences=False)(lstm2)
output_variable1 = layers.Dense(24, name='output_variable1')(lstm3)

# Dense layers for variable 2
dense4 = layers.GRU(48, activation='leaky_relu', return_sequences=True)(input_layer)
dense5 = layers.GRU(48, activation='leaky_relu', return_sequences=True)(dense4)
dense6 = layers.GRU(24, activation='leaky_relu', return_sequences=False)(dense5)
output_variable2 = layers.Dense(24, name='output_variable2')(dense6)


# Define the model
model = models.Model(inputs=input_layer, outputs=[output_variable1, output_variable2])

model.compile(
    optimizer='adam',
    loss={'output_variable1': 'mean_squared_error', 'output_variable2': 'mean_squared_error'}
) #types of optimizer, loss function to be adjusted
    
start = time.time()

for train_data, test_data in tscv.split(X_train):
    X_train_current_split, X_test_current_split = X_train[train_data], X_train[test_data]
    y_train_current_split, y_test_current_split = Y_train[train_data], Y_train[test_data]
    
    history = model.fit(X_train_current_split, y={"output_variable1": y_train_current_split[:, :, 0], 
                                                  "output_variable2": y_train_current_split[:, :, 1]},
              epochs=100, 
              validation_data=(
                  X_test_current_split,
                {
                    "output_variable1": y_test_current_split[:, :, 0],
                    "output_variable2": y_test_current_split[:, :, 1],
                },
              ),
              # validation_split = 0.8,
              verbose=1,
              callbacks=callback
    )
    loss.append(model.history.history['loss'])
    val_loss.append(model.history.history['val_loss'])
    
    loss_1.append(model.history.history['output_variable1_loss'])
    val_loss_1.append(model.history.history['val_output_variable1_loss'])
    
    loss_2.append(model.history.history['output_variable2_loss'])
    val_loss_2.append(model.history.history['val_output_variable2_loss'])
    
end = time.time()

print(f"Training time = {end - start} seconds")
# Out:
# Epoch 1/100
# 13/13 [==============================] - 6s 83ms/step - loss: 0.4732 - output_variable1_loss: 0.3083 - output_variable2_loss: 0.1649 - val_loss: 0.7025 - val_output_variable1_loss: 0.6114 - val_output_variable2_loss: 0.0911
# Epoch 2/100
# 13/13 [==============================] - 0s 28ms/step - loss: 0.2988 - output_variable1_loss: 0.1755 - output_variable2_loss: 0.1233 - val_loss: 0.3795 - val_output_variable1_loss: 0.3135 - val_output_variable2_loss: 0.0660
# Epoch 3/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.1798 - output_variable1_loss: 0.0972 - output_variable2_loss: 0.0826 - val_loss: 0.2689 - val_output_variable1_loss: 0.2225 - val_output_variable2_loss: 0.0464
# Epoch 4/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.1108 - output_variable1_loss: 0.0594 - output_variable2_loss: 0.0515 - val_loss: 0.1933 - val_output_variable1_loss: 0.1593 - val_output_variable2_loss: 0.0340
# Epoch 5/100
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0791 - output_variable1_loss: 0.0466 - output_variable2_loss: 0.0325 - val_loss: 0.1634 - val_output_variable1_loss: 0.1392 - val_output_variable2_loss: 0.0242
# Epoch 6/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0641 - output_variable1_loss: 0.0430 - output_variable2_loss: 0.0211 - val_loss: 0.1533 - val_output_variable1_loss: 0.1358 - val_output_variable2_loss: 0.0175
# Epoch 7/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0535 - output_variable1_loss: 0.0393 - output_variable2_loss: 0.0142 - val_loss: 0.1451 - val_output_variable1_loss: 0.1293 - val_output_variable2_loss: 0.0158
# Epoch 8/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0477 - output_variable1_loss: 0.0365 - output_variable2_loss: 0.0113 - val_loss: 0.0818 - val_output_variable1_loss: 0.0716 - val_output_variable2_loss: 0.0102
# Epoch 9/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0429 - output_variable1_loss: 0.0336 - output_variable2_loss: 0.0093 - val_loss: 0.0496 - val_output_variable1_loss: 0.0393 - val_output_variable2_loss: 0.0103
# Epoch 10/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0395 - output_variable1_loss: 0.0312 - output_variable2_loss: 0.0083 - val_loss: 0.0785 - val_output_variable1_loss: 0.0692 - val_output_variable2_loss: 0.0093
# Epoch 11/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0370 - output_variable1_loss: 0.0297 - output_variable2_loss: 0.0074 - val_loss: 0.0619 - val_output_variable1_loss: 0.0528 - val_output_variable2_loss: 0.0091
# Epoch 12/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0337 - output_variable1_loss: 0.0271 - output_variable2_loss: 0.0066 - val_loss: 0.0531 - val_output_variable1_loss: 0.0455 - val_output_variable2_loss: 0.0076
# Epoch 13/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0319 - output_variable1_loss: 0.0257 - output_variable2_loss: 0.0061 - val_loss: 0.0763 - val_output_variable1_loss: 0.0685 - val_output_variable2_loss: 0.0079
# Epoch 14/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0305 - output_variable1_loss: 0.0250 - output_variable2_loss: 0.0056 - val_loss: 0.0595 - val_output_variable1_loss: 0.0528 - val_output_variable2_loss: 0.0067
# Epoch 15/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0286 - output_variable1_loss: 0.0237 - output_variable2_loss: 0.0049 - val_loss: 0.0579 - val_output_variable1_loss: 0.0515 - val_output_variable2_loss: 0.0064
# Epoch 16/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0275 - output_variable1_loss: 0.0230 - output_variable2_loss: 0.0045 - val_loss: 0.0572 - val_output_variable1_loss: 0.0510 - val_output_variable2_loss: 0.0063
# Epoch 17/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0270 - output_variable1_loss: 0.0227 - output_variable2_loss: 0.0042 - val_loss: 0.0433 - val_output_variable1_loss: 0.0377 - val_output_variable2_loss: 0.0056
# Epoch 18/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0261 - output_variable1_loss: 0.0221 - output_variable2_loss: 0.0040 - val_loss: 0.0481 - val_output_variable1_loss: 0.0426 - val_output_variable2_loss: 0.0055
# Epoch 19/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0253 - output_variable1_loss: 0.0214 - output_variable2_loss: 0.0039 - val_loss: 0.0474 - val_output_variable1_loss: 0.0416 - val_output_variable2_loss: 0.0058
# Epoch 20/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0250 - output_variable1_loss: 0.0212 - output_variable2_loss: 0.0038 - val_loss: 0.0540 - val_output_variable1_loss: 0.0486 - val_output_variable2_loss: 0.0054
# Epoch 21/100
# 13/13 [==============================] - 0s 31ms/step - loss: 0.0249 - output_variable1_loss: 0.0212 - output_variable2_loss: 0.0037 - val_loss: 0.0611 - val_output_variable1_loss: 0.0556 - val_output_variable2_loss: 0.0055
# Epoch 22/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0241 - output_variable1_loss: 0.0207 - output_variable2_loss: 0.0034 - val_loss: 0.0471 - val_output_variable1_loss: 0.0426 - val_output_variable2_loss: 0.0046
# Epoch 23/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0234 - output_variable1_loss: 0.0201 - output_variable2_loss: 0.0033 - val_loss: 0.0466 - val_output_variable1_loss: 0.0415 - val_output_variable2_loss: 0.0051
# Epoch 24/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0230 - output_variable1_loss: 0.0198 - output_variable2_loss: 0.0032 - val_loss: 0.0460 - val_output_variable1_loss: 0.0405 - val_output_variable2_loss: 0.0054
# Epoch 25/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0228 - output_variable1_loss: 0.0197 - output_variable2_loss: 0.0031 - val_loss: 0.0462 - val_output_variable1_loss: 0.0410 - val_output_variable2_loss: 0.0051
# Epoch 26/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0227 - output_variable1_loss: 0.0196 - output_variable2_loss: 0.0031 - val_loss: 0.0557 - val_output_variable1_loss: 0.0507 - val_output_variable2_loss: 0.0049
# Epoch 27/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0222 - output_variable1_loss: 0.0192 - output_variable2_loss: 0.0030 - val_loss: 0.0444 - val_output_variable1_loss: 0.0395 - val_output_variable2_loss: 0.0049
# Epoch 28/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0218 - output_variable1_loss: 0.0187 - output_variable2_loss: 0.0031 - val_loss: 0.0461 - val_output_variable1_loss: 0.0414 - val_output_variable2_loss: 0.0047
# Epoch 29/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0230 - output_variable1_loss: 0.0200 - output_variable2_loss: 0.0030 - val_loss: 0.0644 - val_output_variable1_loss: 0.0598 - val_output_variable2_loss: 0.0046
# Epoch 30/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0224 - output_variable1_loss: 0.0194 - output_variable2_loss: 0.0030 - val_loss: 0.0475 - val_output_variable1_loss: 0.0429 - val_output_variable2_loss: 0.0046
# Epoch 31/100
# 13/13 [==============================] - 0s 31ms/step - loss: 0.0220 - output_variable1_loss: 0.0190 - output_variable2_loss: 0.0030 - val_loss: 0.0513 - val_output_variable1_loss: 0.0468 - val_output_variable2_loss: 0.0045
# Epoch 32/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0221 - output_variable1_loss: 0.0188 - output_variable2_loss: 0.0033 - val_loss: 0.0616 - val_output_variable1_loss: 0.0562 - val_output_variable2_loss: 0.0054
# Epoch 33/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0209 - output_variable1_loss: 0.0180 - output_variable2_loss: 0.0030 - val_loss: 0.0563 - val_output_variable1_loss: 0.0511 - val_output_variable2_loss: 0.0051
# Epoch 34/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0206 - output_variable1_loss: 0.0178 - output_variable2_loss: 0.0028 - val_loss: 0.0539 - val_output_variable1_loss: 0.0486 - val_output_variable2_loss: 0.0052
# Epoch 35/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0207 - output_variable1_loss: 0.0178 - output_variable2_loss: 0.0029 - val_loss: 0.0552 - val_output_variable1_loss: 0.0511 - val_output_variable2_loss: 0.0041
# Epoch 36/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0200 - output_variable1_loss: 0.0172 - output_variable2_loss: 0.0028 - val_loss: 0.0616 - val_output_variable1_loss: 0.0561 - val_output_variable2_loss: 0.0054
# Epoch 37/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0195 - output_variable1_loss: 0.0168 - output_variable2_loss: 0.0028 - val_loss: 0.0552 - val_output_variable1_loss: 0.0508 - val_output_variable2_loss: 0.0044
# Epoch 38/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0190 - output_variable1_loss: 0.0162 - output_variable2_loss: 0.0028 - val_loss: 0.0609 - val_output_variable1_loss: 0.0563 - val_output_variable2_loss: 0.0045
# Epoch 39/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0190 - output_variable1_loss: 0.0163 - output_variable2_loss: 0.0027 - val_loss: 0.0620 - val_output_variable1_loss: 0.0573 - val_output_variable2_loss: 0.0047
# Epoch 40/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0187 - output_variable1_loss: 0.0160 - output_variable2_loss: 0.0027 - val_loss: 0.0687 - val_output_variable1_loss: 0.0643 - val_output_variable2_loss: 0.0044
# Epoch 41/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0188 - output_variable1_loss: 0.0161 - output_variable2_loss: 0.0027 - val_loss: 0.0681 - val_output_variable1_loss: 0.0630 - val_output_variable2_loss: 0.0051
# Epoch 42/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0192 - output_variable1_loss: 0.0165 - output_variable2_loss: 0.0027 - val_loss: 0.0729 - val_output_variable1_loss: 0.0679 - val_output_variable2_loss: 0.0050
# Epoch 43/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0177 - output_variable1_loss: 0.0152 - output_variable2_loss: 0.0025 - val_loss: 0.0718 - val_output_variable1_loss: 0.0674 - val_output_variable2_loss: 0.0045
# Epoch 44/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0176 - output_variable1_loss: 0.0151 - output_variable2_loss: 0.0025 - val_loss: 0.0770 - val_output_variable1_loss: 0.0727 - val_output_variable2_loss: 0.0043
# Epoch 45/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0174 - output_variable1_loss: 0.0149 - output_variable2_loss: 0.0025 - val_loss: 0.0790 - val_output_variable1_loss: 0.0742 - val_output_variable2_loss: 0.0048
# Epoch 46/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0175 - output_variable1_loss: 0.0149 - output_variable2_loss: 0.0026 - val_loss: 0.0708 - val_output_variable1_loss: 0.0665 - val_output_variable2_loss: 0.0043
# Epoch 47/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0165 - output_variable1_loss: 0.0139 - output_variable2_loss: 0.0026 - val_loss: 0.0693 - val_output_variable1_loss: 0.0646 - val_output_variable2_loss: 0.0048
# Epoch 48/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0171 - output_variable1_loss: 0.0146 - output_variable2_loss: 0.0025 - val_loss: 0.0757 - val_output_variable1_loss: 0.0713 - val_output_variable2_loss: 0.0045
# Epoch 49/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0166 - output_variable1_loss: 0.0143 - output_variable2_loss: 0.0023 - val_loss: 0.0726 - val_output_variable1_loss: 0.0682 - val_output_variable2_loss: 0.0044
# Epoch 50/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0159 - output_variable1_loss: 0.0135 - output_variable2_loss: 0.0024 - val_loss: 0.0737 - val_output_variable1_loss: 0.0693 - val_output_variable2_loss: 0.0043
# Epoch 51/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0148 - output_variable1_loss: 0.0126 - output_variable2_loss: 0.0022 - val_loss: 0.0806 - val_output_variable1_loss: 0.0762 - val_output_variable2_loss: 0.0044
# Epoch 52/100
# 13/13 [==============================] - 0s 31ms/step - loss: 0.0144 - output_variable1_loss: 0.0122 - output_variable2_loss: 0.0022 - val_loss: 0.0784 - val_output_variable1_loss: 0.0733 - val_output_variable2_loss: 0.0051
# Epoch 53/100
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0143 - output_variable1_loss: 0.0121 - output_variable2_loss: 0.0022 - val_loss: 0.0862 - val_output_variable1_loss: 0.0817 - val_output_variable2_loss: 0.0045
# Epoch 54/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0150 - output_variable1_loss: 0.0127 - output_variable2_loss: 0.0023 - val_loss: 0.0960 - val_output_variable1_loss: 0.0919 - val_output_variable2_loss: 0.0041
# Epoch 55/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0143 - output_variable1_loss: 0.0121 - output_variable2_loss: 0.0022 - val_loss: 0.0748 - val_output_variable1_loss: 0.0703 - val_output_variable2_loss: 0.0046
# Epoch 56/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0136 - output_variable1_loss: 0.0114 - output_variable2_loss: 0.0022 - val_loss: 0.0925 - val_output_variable1_loss: 0.0874 - val_output_variable2_loss: 0.0051
# Epoch 57/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0134 - output_variable1_loss: 0.0112 - output_variable2_loss: 0.0022 - val_loss: 0.0956 - val_output_variable1_loss: 0.0914 - val_output_variable2_loss: 0.0042
# Epoch 58/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0136 - output_variable1_loss: 0.0114 - output_variable2_loss: 0.0021 - val_loss: 0.0899 - val_output_variable1_loss: 0.0857 - val_output_variable2_loss: 0.0043
# Epoch 59/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0129 - output_variable1_loss: 0.0108 - output_variable2_loss: 0.0021 - val_loss: 0.0830 - val_output_variable1_loss: 0.0780 - val_output_variable2_loss: 0.0049
# Epoch 60/100
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0125 - output_variable1_loss: 0.0105 - output_variable2_loss: 0.0020 - val_loss: 0.0912 - val_output_variable1_loss: 0.0866 - val_output_variable2_loss: 0.0046
# Epoch 61/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0123 - output_variable1_loss: 0.0103 - output_variable2_loss: 0.0019 - val_loss: 0.0788 - val_output_variable1_loss: 0.0749 - val_output_variable2_loss: 0.0039
# Epoch 62/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0124 - output_variable1_loss: 0.0104 - output_variable2_loss: 0.0020 - val_loss: 0.0960 - val_output_variable1_loss: 0.0912 - val_output_variable2_loss: 0.0047
# Epoch 63/100
# 13/13 [==============================] - 0s 31ms/step - loss: 0.0119 - output_variable1_loss: 0.0100 - output_variable2_loss: 0.0019 - val_loss: 0.0843 - val_output_variable1_loss: 0.0796 - val_output_variable2_loss: 0.0047
# Epoch 64/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0117 - output_variable1_loss: 0.0098 - output_variable2_loss: 0.0019 - val_loss: 0.0975 - val_output_variable1_loss: 0.0932 - val_output_variable2_loss: 0.0043
# Epoch 65/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0117 - output_variable1_loss: 0.0098 - output_variable2_loss: 0.0019 - val_loss: 0.0856 - val_output_variable1_loss: 0.0812 - val_output_variable2_loss: 0.0044
# Epoch 66/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0113 - output_variable1_loss: 0.0095 - output_variable2_loss: 0.0018 - val_loss: 0.0919 - val_output_variable1_loss: 0.0873 - val_output_variable2_loss: 0.0046
# Epoch 67/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0114 - output_variable1_loss: 0.0095 - output_variable2_loss: 0.0018 - val_loss: 0.0865 - val_output_variable1_loss: 0.0820 - val_output_variable2_loss: 0.0045
# Epoch 68/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0111 - output_variable1_loss: 0.0093 - output_variable2_loss: 0.0018 - val_loss: 0.0900 - val_output_variable1_loss: 0.0856 - val_output_variable2_loss: 0.0044
# Epoch 69/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0111 - output_variable1_loss: 0.0094 - output_variable2_loss: 0.0017 - val_loss: 0.0868 - val_output_variable1_loss: 0.0824 - val_output_variable2_loss: 0.0044
# Epoch 70/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0110 - output_variable1_loss: 0.0094 - output_variable2_loss: 0.0017 - val_loss: 0.0930 - val_output_variable1_loss: 0.0887 - val_output_variable2_loss: 0.0043
# Epoch 71/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0107 - output_variable1_loss: 0.0090 - output_variable2_loss: 0.0016 - val_loss: 0.0974 - val_output_variable1_loss: 0.0930 - val_output_variable2_loss: 0.0044
# Epoch 72/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0107 - output_variable1_loss: 0.0090 - output_variable2_loss: 0.0017 - val_loss: 0.0797 - val_output_variable1_loss: 0.0754 - val_output_variable2_loss: 0.0043
# Epoch 73/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0108 - output_variable1_loss: 0.0091 - output_variable2_loss: 0.0016 - val_loss: 0.0882 - val_output_variable1_loss: 0.0838 - val_output_variable2_loss: 0.0044
# Epoch 74/100
# 13/13 [==============================] - 0s 31ms/step - loss: 0.0107 - output_variable1_loss: 0.0091 - output_variable2_loss: 0.0016 - val_loss: 0.0967 - val_output_variable1_loss: 0.0931 - val_output_variable2_loss: 0.0036
# Epoch 75/100
# 13/13 [==============================] - 0s 31ms/step - loss: 0.0108 - output_variable1_loss: 0.0092 - output_variable2_loss: 0.0017 - val_loss: 0.0838 - val_output_variable1_loss: 0.0803 - val_output_variable2_loss: 0.0035
# Epoch 76/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0108 - output_variable1_loss: 0.0092 - output_variable2_loss: 0.0016 - val_loss: 0.0720 - val_output_variable1_loss: 0.0690 - val_output_variable2_loss: 0.0030
# Epoch 77/100
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0107 - output_variable1_loss: 0.0091 - output_variable2_loss: 0.0016 - val_loss: 0.0846 - val_output_variable1_loss: 0.0810 - val_output_variable2_loss: 0.0036
# Epoch 1/100
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0134 - output_variable1_loss: 0.0117 - output_variable2_loss: 0.0017 - val_loss: 0.0356 - val_output_variable1_loss: 0.0333 - val_output_variable2_loss: 0.0023
# Epoch 2/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0127 - output_variable1_loss: 0.0111 - output_variable2_loss: 0.0016 - val_loss: 0.0366 - val_output_variable1_loss: 0.0336 - val_output_variable2_loss: 0.0030
# Epoch 3/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0131 - output_variable1_loss: 0.0115 - output_variable2_loss: 0.0016 - val_loss: 0.0323 - val_output_variable1_loss: 0.0306 - val_output_variable2_loss: 0.0017
# Epoch 4/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0129 - output_variable1_loss: 0.0112 - output_variable2_loss: 0.0016 - val_loss: 0.0326 - val_output_variable1_loss: 0.0306 - val_output_variable2_loss: 0.0020
# Epoch 5/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0122 - output_variable1_loss: 0.0107 - output_variable2_loss: 0.0015 - val_loss: 0.0292 - val_output_variable1_loss: 0.0273 - val_output_variable2_loss: 0.0019
# Epoch 6/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0123 - output_variable1_loss: 0.0108 - output_variable2_loss: 0.0015 - val_loss: 0.0317 - val_output_variable1_loss: 0.0299 - val_output_variable2_loss: 0.0018
# Epoch 7/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0112 - output_variable1_loss: 0.0097 - output_variable2_loss: 0.0015 - val_loss: 0.0274 - val_output_variable1_loss: 0.0256 - val_output_variable2_loss: 0.0018
# Epoch 8/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0110 - output_variable1_loss: 0.0096 - output_variable2_loss: 0.0014 - val_loss: 0.0325 - val_output_variable1_loss: 0.0307 - val_output_variable2_loss: 0.0018
# Epoch 9/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0106 - output_variable1_loss: 0.0092 - output_variable2_loss: 0.0014 - val_loss: 0.0267 - val_output_variable1_loss: 0.0242 - val_output_variable2_loss: 0.0026
# Epoch 10/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0101 - output_variable1_loss: 0.0088 - output_variable2_loss: 0.0013 - val_loss: 0.0307 - val_output_variable1_loss: 0.0289 - val_output_variable2_loss: 0.0018
# Epoch 11/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0100 - output_variable1_loss: 0.0087 - output_variable2_loss: 0.0013 - val_loss: 0.0294 - val_output_variable1_loss: 0.0270 - val_output_variable2_loss: 0.0024
# Epoch 12/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0097 - output_variable1_loss: 0.0085 - output_variable2_loss: 0.0013 - val_loss: 0.0304 - val_output_variable1_loss: 0.0284 - val_output_variable2_loss: 0.0021
# Epoch 13/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0097 - output_variable1_loss: 0.0085 - output_variable2_loss: 0.0012 - val_loss: 0.0245 - val_output_variable1_loss: 0.0228 - val_output_variable2_loss: 0.0017
# Epoch 14/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0096 - output_variable1_loss: 0.0084 - output_variable2_loss: 0.0012 - val_loss: 0.0290 - val_output_variable1_loss: 0.0269 - val_output_variable2_loss: 0.0021
# Epoch 15/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0094 - output_variable1_loss: 0.0082 - output_variable2_loss: 0.0012 - val_loss: 0.0241 - val_output_variable1_loss: 0.0221 - val_output_variable2_loss: 0.0021
# Epoch 16/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0090 - output_variable1_loss: 0.0078 - output_variable2_loss: 0.0012 - val_loss: 0.0376 - val_output_variable1_loss: 0.0357 - val_output_variable2_loss: 0.0019
# Epoch 17/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0088 - output_variable1_loss: 0.0076 - output_variable2_loss: 0.0011 - val_loss: 0.0375 - val_output_variable1_loss: 0.0353 - val_output_variable2_loss: 0.0022
# Epoch 18/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0085 - output_variable1_loss: 0.0073 - output_variable2_loss: 0.0011 - val_loss: 0.0371 - val_output_variable1_loss: 0.0352 - val_output_variable2_loss: 0.0019
# Epoch 19/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0088 - output_variable1_loss: 0.0076 - output_variable2_loss: 0.0012 - val_loss: 0.0314 - val_output_variable1_loss: 0.0292 - val_output_variable2_loss: 0.0022
# Epoch 20/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0087 - output_variable1_loss: 0.0075 - output_variable2_loss: 0.0012 - val_loss: 0.0303 - val_output_variable1_loss: 0.0285 - val_output_variable2_loss: 0.0018
# Epoch 21/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0084 - output_variable1_loss: 0.0072 - output_variable2_loss: 0.0012 - val_loss: 0.0398 - val_output_variable1_loss: 0.0381 - val_output_variable2_loss: 0.0017
# Epoch 22/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0080 - output_variable1_loss: 0.0068 - output_variable2_loss: 0.0012 - val_loss: 0.0341 - val_output_variable1_loss: 0.0326 - val_output_variable2_loss: 0.0014
# Epoch 23/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0077 - output_variable1_loss: 0.0065 - output_variable2_loss: 0.0011 - val_loss: 0.0259 - val_output_variable1_loss: 0.0241 - val_output_variable2_loss: 0.0018
# Epoch 24/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0080 - output_variable1_loss: 0.0067 - output_variable2_loss: 0.0013 - val_loss: 0.0371 - val_output_variable1_loss: 0.0346 - val_output_variable2_loss: 0.0025
# Epoch 25/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0078 - output_variable1_loss: 0.0066 - output_variable2_loss: 0.0012 - val_loss: 0.0452 - val_output_variable1_loss: 0.0437 - val_output_variable2_loss: 0.0014
# Epoch 26/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0075 - output_variable1_loss: 0.0064 - output_variable2_loss: 0.0011 - val_loss: 0.0349 - val_output_variable1_loss: 0.0327 - val_output_variable2_loss: 0.0022
# Epoch 27/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0073 - output_variable1_loss: 0.0062 - output_variable2_loss: 0.0012 - val_loss: 0.0343 - val_output_variable1_loss: 0.0330 - val_output_variable2_loss: 0.0013
# Epoch 28/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0070 - output_variable1_loss: 0.0059 - output_variable2_loss: 0.0011 - val_loss: 0.0387 - val_output_variable1_loss: 0.0370 - val_output_variable2_loss: 0.0017
# Epoch 29/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0069 - output_variable1_loss: 0.0059 - output_variable2_loss: 0.0010 - val_loss: 0.0354 - val_output_variable1_loss: 0.0335 - val_output_variable2_loss: 0.0019
# Epoch 30/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0070 - output_variable1_loss: 0.0059 - output_variable2_loss: 0.0010 - val_loss: 0.0361 - val_output_variable1_loss: 0.0342 - val_output_variable2_loss: 0.0019
# Epoch 31/100
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0070 - output_variable1_loss: 0.0060 - output_variable2_loss: 9.8409e-04 - val_loss: 0.0294 - val_output_variable1_loss: 0.0273 - val_output_variable2_loss: 0.0021
# Epoch 32/100
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0069 - output_variable1_loss: 0.0059 - output_variable2_loss: 9.8719e-04 - val_loss: 0.0364 - val_output_variable1_loss: 0.0347 - val_output_variable2_loss: 0.0018
# Epoch 33/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0067 - output_variable1_loss: 0.0058 - output_variable2_loss: 9.5105e-04 - val_loss: 0.0533 - val_output_variable1_loss: 0.0513 - val_output_variable2_loss: 0.0020
# Epoch 34/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0064 - output_variable1_loss: 0.0054 - output_variable2_loss: 9.5282e-04 - val_loss: 0.0351 - val_output_variable1_loss: 0.0334 - val_output_variable2_loss: 0.0017
# Epoch 35/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0064 - output_variable1_loss: 0.0054 - output_variable2_loss: 9.6579e-04 - val_loss: 0.0474 - val_output_variable1_loss: 0.0450 - val_output_variable2_loss: 0.0024
# Epoch 36/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0064 - output_variable1_loss: 0.0054 - output_variable2_loss: 0.0010 - val_loss: 0.0376 - val_output_variable1_loss: 0.0358 - val_output_variable2_loss: 0.0018
# Epoch 37/100
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0060 - output_variable1_loss: 0.0050 - output_variable2_loss: 0.0010 - val_loss: 0.0368 - val_output_variable1_loss: 0.0354 - val_output_variable2_loss: 0.0014
# Epoch 38/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0058 - output_variable1_loss: 0.0049 - output_variable2_loss: 9.4151e-04 - val_loss: 0.0331 - val_output_variable1_loss: 0.0313 - val_output_variable2_loss: 0.0018
# Epoch 39/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0057 - output_variable1_loss: 0.0048 - output_variable2_loss: 9.2259e-04 - val_loss: 0.0365 - val_output_variable1_loss: 0.0347 - val_output_variable2_loss: 0.0018
# Epoch 40/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0057 - output_variable1_loss: 0.0047 - output_variable2_loss: 9.0935e-04 - val_loss: 0.0402 - val_output_variable1_loss: 0.0386 - val_output_variable2_loss: 0.0015
# Epoch 41/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0057 - output_variable1_loss: 0.0048 - output_variable2_loss: 9.5822e-04 - val_loss: 0.0368 - val_output_variable1_loss: 0.0356 - val_output_variable2_loss: 0.0012
# Epoch 42/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0057 - output_variable1_loss: 0.0047 - output_variable2_loss: 9.7104e-04 - val_loss: 0.0357 - val_output_variable1_loss: 0.0340 - val_output_variable2_loss: 0.0017
# Epoch 43/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0055 - output_variable1_loss: 0.0046 - output_variable2_loss: 9.2267e-04 - val_loss: 0.0377 - val_output_variable1_loss: 0.0360 - val_output_variable2_loss: 0.0017
# Epoch 44/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0056 - output_variable1_loss: 0.0047 - output_variable2_loss: 9.2777e-04 - val_loss: 0.0425 - val_output_variable1_loss: 0.0403 - val_output_variable2_loss: 0.0022
# Epoch 45/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0054 - output_variable1_loss: 0.0045 - output_variable2_loss: 9.2568e-04 - val_loss: 0.0451 - val_output_variable1_loss: 0.0431 - val_output_variable2_loss: 0.0020
# Epoch 46/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0054 - output_variable1_loss: 0.0045 - output_variable2_loss: 9.2743e-04 - val_loss: 0.0420 - val_output_variable1_loss: 0.0400 - val_output_variable2_loss: 0.0020
# Epoch 47/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0053 - output_variable1_loss: 0.0044 - output_variable2_loss: 9.0675e-04 - val_loss: 0.0416 - val_output_variable1_loss: 0.0400 - val_output_variable2_loss: 0.0016
# Epoch 48/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0054 - output_variable1_loss: 0.0045 - output_variable2_loss: 8.9552e-04 - val_loss: 0.0438 - val_output_variable1_loss: 0.0418 - val_output_variable2_loss: 0.0019
# Epoch 49/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0051 - output_variable1_loss: 0.0043 - output_variable2_loss: 8.6554e-04 - val_loss: 0.0434 - val_output_variable1_loss: 0.0413 - val_output_variable2_loss: 0.0022
# Epoch 50/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0054 - output_variable1_loss: 0.0045 - output_variable2_loss: 8.5161e-04 - val_loss: 0.0322 - val_output_variable1_loss: 0.0307 - val_output_variable2_loss: 0.0015
# Epoch 51/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0050 - output_variable1_loss: 0.0042 - output_variable2_loss: 8.3308e-04 - val_loss: 0.0289 - val_output_variable1_loss: 0.0270 - val_output_variable2_loss: 0.0020
# Epoch 52/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0048 - output_variable1_loss: 0.0040 - output_variable2_loss: 8.3434e-04 - val_loss: 0.0377 - val_output_variable1_loss: 0.0362 - val_output_variable2_loss: 0.0015
# Epoch 53/100
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0047 - output_variable1_loss: 0.0038 - output_variable2_loss: 8.8662e-04 - val_loss: 0.0375 - val_output_variable1_loss: 0.0361 - val_output_variable2_loss: 0.0015
# Epoch 54/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0047 - output_variable1_loss: 0.0038 - output_variable2_loss: 8.8204e-04 - val_loss: 0.0349 - val_output_variable1_loss: 0.0334 - val_output_variable2_loss: 0.0014
# Epoch 55/100
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0047 - output_variable1_loss: 0.0039 - output_variable2_loss: 8.3521e-04 - val_loss: 0.0349 - val_output_variable1_loss: 0.0333 - val_output_variable2_loss: 0.0016
# Epoch 56/100
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0046 - output_variable1_loss: 0.0037 - output_variable2_loss: 8.4039e-04 - val_loss: 0.0384 - val_output_variable1_loss: 0.0366 - val_output_variable2_loss: 0.0018
# Epoch 57/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0044 - output_variable1_loss: 0.0036 - output_variable2_loss: 8.2529e-04 - val_loss: 0.0343 - val_output_variable1_loss: 0.0324 - val_output_variable2_loss: 0.0019
# Epoch 58/100
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0043 - output_variable1_loss: 0.0035 - output_variable2_loss: 7.9411e-04 - val_loss: 0.0399 - val_output_variable1_loss: 0.0381 - val_output_variable2_loss: 0.0018
# Epoch 59/100
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0044 - output_variable1_loss: 0.0036 - output_variable2_loss: 8.1294e-04 - val_loss: 0.0392 - val_output_variable1_loss: 0.0374 - val_output_variable2_loss: 0.0018
# Epoch 60/100
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0043 - output_variable1_loss: 0.0035 - output_variable2_loss: 8.0101e-04 - val_loss: 0.0397 - val_output_variable1_loss: 0.0377 - val_output_variable2_loss: 0.0020
# Epoch 61/100
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0043 - output_variable1_loss: 0.0035 - output_variable2_loss: 8.0055e-04 - val_loss: 0.0370 - val_output_variable1_loss: 0.0347 - val_output_variable2_loss: 0.0023
# Epoch 62/100
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0046 - output_variable1_loss: 0.0037 - output_variable2_loss: 8.7332e-04 - val_loss: 0.0441 - val_output_variable1_loss: 0.0422 - val_output_variable2_loss: 0.0019
# Epoch 63/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0044 - output_variable1_loss: 0.0036 - output_variable2_loss: 7.9433e-04 - val_loss: 0.0390 - val_output_variable1_loss: 0.0370 - val_output_variable2_loss: 0.0020
# Epoch 64/100
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0043 - output_variable1_loss: 0.0035 - output_variable2_loss: 7.9694e-04 - val_loss: 0.0346 - val_output_variable1_loss: 0.0333 - val_output_variable2_loss: 0.0014
# Epoch 65/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0041 - output_variable1_loss: 0.0033 - output_variable2_loss: 8.2318e-04 - val_loss: 0.0352 - val_output_variable1_loss: 0.0335 - val_output_variable2_loss: 0.0018
# Epoch 66/100
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0041 - output_variable1_loss: 0.0033 - output_variable2_loss: 8.1463e-04 - val_loss: 0.0370 - val_output_variable1_loss: 0.0355 - val_output_variable2_loss: 0.0015
# Epoch 67/100
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0041 - output_variable1_loss: 0.0033 - output_variable2_loss: 8.3093e-04 - val_loss: 0.0363 - val_output_variable1_loss: 0.0339 - val_output_variable2_loss: 0.0024
# Epoch 68/100
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0041 - output_variable1_loss: 0.0033 - output_variable2_loss: 8.4475e-04 - val_loss: 0.0368 - val_output_variable1_loss: 0.0345 - val_output_variable2_loss: 0.0023
# Epoch 69/100
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0042 - output_variable1_loss: 0.0034 - output_variable2_loss: 7.8386e-04 - val_loss: 0.0395 - val_output_variable1_loss: 0.0378 - val_output_variable2_loss: 0.0017
# Epoch 70/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0042 - output_variable1_loss: 0.0035 - output_variable2_loss: 7.8438e-04 - val_loss: 0.0364 - val_output_variable1_loss: 0.0349 - val_output_variable2_loss: 0.0015
# Epoch 71/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0039 - output_variable1_loss: 0.0032 - output_variable2_loss: 7.6127e-04 - val_loss: 0.0352 - val_output_variable1_loss: 0.0334 - val_output_variable2_loss: 0.0019
# Epoch 72/100
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0038 - output_variable1_loss: 0.0031 - output_variable2_loss: 7.3384e-04 - val_loss: 0.0392 - val_output_variable1_loss: 0.0378 - val_output_variable2_loss: 0.0014
# Epoch 73/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0039 - output_variable1_loss: 0.0031 - output_variable2_loss: 7.4085e-04 - val_loss: 0.0356 - val_output_variable1_loss: 0.0338 - val_output_variable2_loss: 0.0018
# Epoch 74/100
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0038 - output_variable1_loss: 0.0031 - output_variable2_loss: 7.1241e-04 - val_loss: 0.0328 - val_output_variable1_loss: 0.0312 - val_output_variable2_loss: 0.0015
# Epoch 75/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0038 - output_variable1_loss: 0.0031 - output_variable2_loss: 7.2807e-04 - val_loss: 0.0416 - val_output_variable1_loss: 0.0394 - val_output_variable2_loss: 0.0023
# Epoch 76/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0037 - output_variable1_loss: 0.0029 - output_variable2_loss: 7.5579e-04 - val_loss: 0.0413 - val_output_variable1_loss: 0.0398 - val_output_variable2_loss: 0.0015
# Epoch 77/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0038 - output_variable1_loss: 0.0030 - output_variable2_loss: 7.3999e-04 - val_loss: 0.0404 - val_output_variable1_loss: 0.0386 - val_output_variable2_loss: 0.0018
# Epoch 78/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0038 - output_variable1_loss: 0.0031 - output_variable2_loss: 7.4891e-04 - val_loss: 0.0330 - val_output_variable1_loss: 0.0313 - val_output_variable2_loss: 0.0016
# Epoch 79/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0038 - output_variable1_loss: 0.0031 - output_variable2_loss: 7.3550e-04 - val_loss: 0.0417 - val_output_variable1_loss: 0.0400 - val_output_variable2_loss: 0.0017
# Epoch 80/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0037 - output_variable1_loss: 0.0030 - output_variable2_loss: 7.3595e-04 - val_loss: 0.0447 - val_output_variable1_loss: 0.0428 - val_output_variable2_loss: 0.0019
# Epoch 81/100
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0037 - output_variable1_loss: 0.0029 - output_variable2_loss: 7.3322e-04 - val_loss: 0.0415 - val_output_variable1_loss: 0.0400 - val_output_variable2_loss: 0.0016
# Epoch 82/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0036 - output_variable1_loss: 0.0029 - output_variable2_loss: 7.6509e-04 - val_loss: 0.0371 - val_output_variable1_loss: 0.0348 - val_output_variable2_loss: 0.0023
# Epoch 83/100
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0037 - output_variable1_loss: 0.0029 - output_variable2_loss: 7.9270e-04 - val_loss: 0.0406 - val_output_variable1_loss: 0.0391 - val_output_variable2_loss: 0.0015
# Epoch 84/100
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0036 - output_variable1_loss: 0.0029 - output_variable2_loss: 7.2312e-04 - val_loss: 0.0461 - val_output_variable1_loss: 0.0443 - val_output_variable2_loss: 0.0018
# Epoch 85/100
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0035 - output_variable1_loss: 0.0028 - output_variable2_loss: 7.1460e-04 - val_loss: 0.0394 - val_output_variable1_loss: 0.0376 - val_output_variable2_loss: 0.0018
# Epoch 86/100
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0035 - output_variable1_loss: 0.0028 - output_variable2_loss: 7.1253e-04 - val_loss: 0.0514 - val_output_variable1_loss: 0.0492 - val_output_variable2_loss: 0.0022
# Epoch 87/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0034 - output_variable1_loss: 0.0027 - output_variable2_loss: 7.0330e-04 - val_loss: 0.0407 - val_output_variable1_loss: 0.0389 - val_output_variable2_loss: 0.0017
# Epoch 88/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0034 - output_variable1_loss: 0.0027 - output_variable2_loss: 7.0451e-04 - val_loss: 0.0356 - val_output_variable1_loss: 0.0340 - val_output_variable2_loss: 0.0016
# Epoch 89/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0033 - output_variable1_loss: 0.0026 - output_variable2_loss: 7.0516e-04 - val_loss: 0.0413 - val_output_variable1_loss: 0.0395 - val_output_variable2_loss: 0.0018
# Epoch 90/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0034 - output_variable1_loss: 0.0027 - output_variable2_loss: 7.2469e-04 - val_loss: 0.0419 - val_output_variable1_loss: 0.0400 - val_output_variable2_loss: 0.0019
# Epoch 91/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0034 - output_variable1_loss: 0.0027 - output_variable2_loss: 7.0485e-04 - val_loss: 0.0409 - val_output_variable1_loss: 0.0394 - val_output_variable2_loss: 0.0015
# Epoch 92/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0034 - output_variable1_loss: 0.0027 - output_variable2_loss: 7.0979e-04 - val_loss: 0.0388 - val_output_variable1_loss: 0.0369 - val_output_variable2_loss: 0.0019
# Epoch 93/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0033 - output_variable1_loss: 0.0026 - output_variable2_loss: 7.0083e-04 - val_loss: 0.0450 - val_output_variable1_loss: 0.0436 - val_output_variable2_loss: 0.0014
# Epoch 94/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0033 - output_variable1_loss: 0.0026 - output_variable2_loss: 7.0573e-04 - val_loss: 0.0446 - val_output_variable1_loss: 0.0429 - val_output_variable2_loss: 0.0017
# Epoch 95/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0033 - output_variable1_loss: 0.0025 - output_variable2_loss: 7.1831e-04 - val_loss: 0.0447 - val_output_variable1_loss: 0.0426 - val_output_variable2_loss: 0.0021
# Epoch 96/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0032 - output_variable1_loss: 0.0025 - output_variable2_loss: 6.6425e-04 - val_loss: 0.0391 - val_output_variable1_loss: 0.0374 - val_output_variable2_loss: 0.0017
# Epoch 97/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0032 - output_variable1_loss: 0.0026 - output_variable2_loss: 6.6703e-04 - val_loss: 0.0396 - val_output_variable1_loss: 0.0375 - val_output_variable2_loss: 0.0020
# Epoch 98/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0032 - output_variable1_loss: 0.0026 - output_variable2_loss: 6.7505e-04 - val_loss: 0.0403 - val_output_variable1_loss: 0.0385 - val_output_variable2_loss: 0.0018
# Epoch 99/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0032 - output_variable1_loss: 0.0025 - output_variable2_loss: 6.8067e-04 - val_loss: 0.0409 - val_output_variable1_loss: 0.0396 - val_output_variable2_loss: 0.0013
# Epoch 100/100
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0032 - output_variable1_loss: 0.0025 - output_variable2_loss: 7.0116e-04 - val_loss: 0.0446 - val_output_variable1_loss: 0.0427 - val_output_variable2_loss: 0.0019
# Epoch 1/100
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0053 - output_variable1_loss: 0.0046 - output_variable2_loss: 7.6814e-04 - val_loss: 0.0134 - val_output_variable1_loss: 0.0125 - val_output_variable2_loss: 9.3100e-04
# Epoch 2/100
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0046 - output_variable1_loss: 0.0038 - output_variable2_loss: 7.7824e-04 - val_loss: 0.0153 - val_output_variable1_loss: 0.0142 - val_output_variable2_loss: 0.0011
# Epoch 3/100
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0041 - output_variable1_loss: 0.0034 - output_variable2_loss: 7.1359e-04 - val_loss: 0.0206 - val_output_variable1_loss: 0.0194 - val_output_variable2_loss: 0.0012
# Epoch 4/100
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0044 - output_variable1_loss: 0.0036 - output_variable2_loss: 7.2056e-04 - val_loss: 0.0146 - val_output_variable1_loss: 0.0137 - val_output_variable2_loss: 9.3199e-04
# Epoch 5/100
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0040 - output_variable1_loss: 0.0033 - output_variable2_loss: 7.1623e-04 - val_loss: 0.0186 - val_output_variable1_loss: 0.0173 - val_output_variable2_loss: 0.0013
# Epoch 6/100
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0042 - output_variable1_loss: 0.0035 - output_variable2_loss: 6.9028e-04 - val_loss: 0.0180 - val_output_variable1_loss: 0.0172 - val_output_variable2_loss: 8.2729e-04
# Epoch 7/100
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0040 - output_variable1_loss: 0.0033 - output_variable2_loss: 7.0946e-04 - val_loss: 0.0104 - val_output_variable1_loss: 0.0098 - val_output_variable2_loss: 6.4300e-04
# Epoch 8/100
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0041 - output_variable1_loss: 0.0033 - output_variable2_loss: 7.8038e-04 - val_loss: 0.0107 - val_output_variable1_loss: 0.0101 - val_output_variable2_loss: 6.0808e-04
# Epoch 9/100
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0039 - output_variable1_loss: 0.0032 - output_variable2_loss: 6.8086e-04 - val_loss: 0.0129 - val_output_variable1_loss: 0.0121 - val_output_variable2_loss: 7.8781e-04
# Epoch 10/100
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0040 - output_variable1_loss: 0.0033 - output_variable2_loss: 6.9449e-04 - val_loss: 0.0124 - val_output_variable1_loss: 0.0115 - val_output_variable2_loss: 8.9351e-04
# Epoch 11/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.0036 - output_variable1_loss: 0.0030 - output_variable2_loss: 6.7970e-04 - val_loss: 0.0128 - val_output_variable1_loss: 0.0121 - val_output_variable2_loss: 6.6681e-04
# Epoch 12/100
# 15/15 [==============================] - 1s 34ms/step - loss: 0.0035 - output_variable1_loss: 0.0028 - output_variable2_loss: 6.4740e-04 - val_loss: 0.0134 - val_output_variable1_loss: 0.0123 - val_output_variable2_loss: 0.0011
# Epoch 13/100
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0032 - output_variable1_loss: 0.0026 - output_variable2_loss: 6.5923e-04 - val_loss: 0.0143 - val_output_variable1_loss: 0.0135 - val_output_variable2_loss: 7.7819e-04
# Epoch 14/100
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0033 - output_variable1_loss: 0.0026 - output_variable2_loss: 6.5997e-04 - val_loss: 0.0145 - val_output_variable1_loss: 0.0138 - val_output_variable2_loss: 7.1257e-04
# Epoch 15/100
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0032 - output_variable1_loss: 0.0026 - output_variable2_loss: 6.5659e-04 - val_loss: 0.0163 - val_output_variable1_loss: 0.0156 - val_output_variable2_loss: 6.7307e-04
# Epoch 16/100
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0033 - output_variable1_loss: 0.0027 - output_variable2_loss: 6.5331e-04 - val_loss: 0.0149 - val_output_variable1_loss: 0.0140 - val_output_variable2_loss: 8.8082e-04
# Epoch 17/100
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0031 - output_variable1_loss: 0.0025 - output_variable2_loss: 6.4214e-04 - val_loss: 0.0145 - val_output_variable1_loss: 0.0136 - val_output_variable2_loss: 9.1419e-04
# Epoch 18/100
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0032 - output_variable1_loss: 0.0025 - output_variable2_loss: 6.5501e-04 - val_loss: 0.0119 - val_output_variable1_loss: 0.0111 - val_output_variable2_loss: 7.9192e-04
# Epoch 19/100
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0032 - output_variable1_loss: 0.0025 - output_variable2_loss: 6.5680e-04 - val_loss: 0.0106 - val_output_variable1_loss: 0.0098 - val_output_variable2_loss: 7.9546e-04
# Epoch 20/100
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0033 - output_variable1_loss: 0.0025 - output_variable2_loss: 7.4744e-04 - val_loss: 0.0122 - val_output_variable1_loss: 0.0112 - val_output_variable2_loss: 9.5586e-04
# Epoch 21/100
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0031 - output_variable1_loss: 0.0024 - output_variable2_loss: 6.5597e-04 - val_loss: 0.0135 - val_output_variable1_loss: 0.0129 - val_output_variable2_loss: 6.6619e-04
# Epoch 22/100
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0031 - output_variable1_loss: 0.0025 - output_variable2_loss: 6.3276e-04 - val_loss: 0.0129 - val_output_variable1_loss: 0.0121 - val_output_variable2_loss: 7.9682e-04
# Epoch 23/100
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0031 - output_variable1_loss: 0.0024 - output_variable2_loss: 6.5547e-04 - val_loss: 0.0138 - val_output_variable1_loss: 0.0124 - val_output_variable2_loss: 0.0013
# Epoch 24/100
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0031 - output_variable1_loss: 0.0025 - output_variable2_loss: 6.7203e-04 - val_loss: 0.0146 - val_output_variable1_loss: 0.0138 - val_output_variable2_loss: 8.6557e-04
# Epoch 25/100
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0031 - output_variable1_loss: 0.0025 - output_variable2_loss: 6.2992e-04 - val_loss: 0.0151 - val_output_variable1_loss: 0.0143 - val_output_variable2_loss: 8.1393e-04
# Epoch 26/100
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0031 - output_variable1_loss: 0.0025 - output_variable2_loss: 6.3530e-04 - val_loss: 0.0127 - val_output_variable1_loss: 0.0119 - val_output_variable2_loss: 7.3291e-04
# Epoch 27/100
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0029 - output_variable1_loss: 0.0022 - output_variable2_loss: 6.1680e-04 - val_loss: 0.0124 - val_output_variable1_loss: 0.0117 - val_output_variable2_loss: 6.6717e-04
# Epoch 28/100
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0029 - output_variable1_loss: 0.0022 - output_variable2_loss: 6.2129e-04 - val_loss: 0.0115 - val_output_variable1_loss: 0.0110 - val_output_variable2_loss: 5.5971e-04
# Epoch 29/100
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0030 - output_variable1_loss: 0.0022 - output_variable2_loss: 7.0501e-04 - val_loss: 0.0112 - val_output_variable1_loss: 0.0105 - val_output_variable2_loss: 6.5743e-04
# Epoch 30/100
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0030 - output_variable1_loss: 0.0022 - output_variable2_loss: 7.8478e-04 - val_loss: 0.0115 - val_output_variable1_loss: 0.0108 - val_output_variable2_loss: 6.2204e-04
# Epoch 31/100
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0030 - output_variable1_loss: 0.0023 - output_variable2_loss: 7.1780e-04 - val_loss: 0.0119 - val_output_variable1_loss: 0.0111 - val_output_variable2_loss: 7.5424e-04
# Epoch 32/100
# 15/15 [==============================] - 0s 30ms/step - loss: 0.0029 - output_variable1_loss: 0.0022 - output_variable2_loss: 6.6579e-04 - val_loss: 0.0100 - val_output_variable1_loss: 0.0092 - val_output_variable2_loss: 8.4011e-04
# Epoch 33/100
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0029 - output_variable1_loss: 0.0022 - output_variable2_loss: 6.8307e-04 - val_loss: 0.0100 - val_output_variable1_loss: 0.0094 - val_output_variable2_loss: 5.8228e-04
# Epoch 1/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0033 - output_variable1_loss: 0.0026 - output_variable2_loss: 6.6227e-04 - val_loss: 0.0193 - val_output_variable1_loss: 0.0177 - val_output_variable2_loss: 0.0016
# Epoch 2/100
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0035 - output_variable1_loss: 0.0028 - output_variable2_loss: 6.9101e-04 - val_loss: 0.0189 - val_output_variable1_loss: 0.0095 - val_output_variable2_loss: 0.0094
# Epoch 3/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0077 - output_variable1_loss: 0.0054 - output_variable2_loss: 0.0022 - val_loss: 0.0172 - val_output_variable1_loss: 0.0084 - val_output_variable2_loss: 0.0088
# Epoch 4/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0065 - output_variable1_loss: 0.0034 - output_variable2_loss: 0.0030 - val_loss: 0.0337 - val_output_variable1_loss: 0.0233 - val_output_variable2_loss: 0.0103
# Epoch 5/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0061 - output_variable1_loss: 0.0039 - output_variable2_loss: 0.0022 - val_loss: 0.0230 - val_output_variable1_loss: 0.0208 - val_output_variable2_loss: 0.0023
# Epoch 6/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0042 - output_variable1_loss: 0.0031 - output_variable2_loss: 0.0011 - val_loss: 0.0242 - val_output_variable1_loss: 0.0220 - val_output_variable2_loss: 0.0022
# Epoch 7/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0038 - output_variable1_loss: 0.0028 - output_variable2_loss: 0.0010 - val_loss: 0.0220 - val_output_variable1_loss: 0.0197 - val_output_variable2_loss: 0.0023
# Training time = 98.30883121490479 seconds

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss_1):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss_1[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error 1", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss_2):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss_2[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error 2", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
# Evaluate the model on the test data
predictions_1 = []
predictions_2 = []
#print(len(eval_target_variables))

for i in range(len(Y_val)):
    current_batch = X_val[i].reshape((1, NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))
    curr_pred1, curr_pred2 = model.predict(current_batch)
    predictions_1.append(curr_pred1)
    predictions_2.append(curr_pred2)
# Out:
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_1):
    ax = axs[i]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_val[i, :, 0], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_2):
    ax = axs[i]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_val[i, :, 1], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
rmse = 0
for i in range(len(predictions_1)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_1[i][0], Y_val[i, :, 0]))}')
    rmse += sqrt(mean_squared_error(predictions_1[i][0], Y_val[i, :, 0]))

rmse /= len(predictions_1)    
print(f"RMSE for {columns_to_predict[0]} = {rmse}")

rmse = 0
for i in range(len(predictions_2)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_2[i][0], Y_val[i, :, 1]))}')
    rmse += sqrt(mean_squared_error(predictions_2[i][0], Y_val[i, :, 1]))

rmse /= len(predictions_2)    
print(f"RMSE for {columns_to_predict[1]} = {rmse}")
# Out:
# RMSE for kg_CO2/kWh = 0.12383406279968825
# RMSE for Avg solar generation = 0.046549793370874525

# %%
# Evaluate the model on the test data
predictions_1_test = []
predictions_2_test = []
#print(len(eval_target_variables))

total_time = 0

for i in range(len(Y_test)):
    current_batch = X_test[i].reshape((1, NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))
    start = time.time()
    curr_pred1, curr_pred2 = model.predict(current_batch)
    end = time.time()
    total_time += end-start
    predictions_1_test.append(curr_pred1)
    predictions_2_test.append(curr_pred2)
    
print(f"Average prediction time is {total_time/len(Y_test)} seconds")
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# Average prediction time is 0.05006101608276367 seconds

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_1_test):
    ax = axs[i]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_test[i, :, 0], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_2_test):
    ax = axs[i]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_test[i, :, 1], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
rmse = 0
for i in range(len(predictions_1_test)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_1[i][0], Y_val[i, :, 0]))}')
    rmse += sqrt(mean_squared_error(predictions_1_test[i][0], Y_test[i, :, 0]))

rmse /= len(predictions_1_test)    
print(f"RMSE for {columns_to_predict[0]} = {rmse}")

rmse = 0
for i in range(len(predictions_2_test)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_2[i][0], Y_val[i, :, 1]))}')
    rmse += sqrt(mean_squared_error(predictions_2_test[i][0], Y_test[i, :, 1]))

rmse /= len(predictions_2_test)    
print(f"RMSE for {columns_to_predict[1]} = {rmse}")
# Out:
# RMSE for kg_CO2/kWh = 0.13856095977402735
# RMSE for Avg solar generation = 0.039196243276056086

# %%
a = []
for column in predictions_1_test:
    a.append(column[0])
    
b = []
for column in predictions_2_test:
    b.append(column[0])

predictions1 = pd.DataFrame(a).T
predictions1.to_csv('../data/results/carbon_gru.csv', index=False, header=False)
predictions2 = pd.DataFrame(b).T
predictions2.to_csv('../data/results/solar_gru.csv', index=False, header=False)
