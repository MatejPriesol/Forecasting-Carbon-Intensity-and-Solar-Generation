# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras
from sklearn.metrics import mean_squared_error
from math import sqrt
# Out:
# WARNING:tensorflow:From C:\Users\Matej\Documents\GitHub\thesis-forecasting\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
train = pd.read_csv("../data/schemas/warm_up/TrainSet.csv", sep=",")
validation = pd.read_csv("../data/schemas/warm_up/ValidationSet.csv", sep=",")
test = pd.read_csv("../data/schemas/warm_up/TestSet.csv", sep=",")

# %%
# Global variables

NUM_OF_TIMESTEPS_INPUT = 48
NUM_OF_TIMESTEPS_OUTPUT = 24

THRESHOLD = 0.4   # For feature selection

# %%
columns_to_predict = ["kg_CO2/kWh", "Avg solar generation"]

independent_variables = []

for column in train:
    if abs(train[column].corr(train[columns_to_predict[0]])) > THRESHOLD: #or abs(train[column].corr(train[columns_to_predict[1]])) > THRESHOLD:
        independent_variables.append(column)

independent_variables = [var for var in independent_variables if var not in columns_to_predict]
    
if "Index" in independent_variables:
    independent_variables.remove("Index")
if "Solar Generation (W/kW)_1" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_1")
if "Solar Generation (W/kW)_2" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_2")
if "Solar Generation (W/kW)_3" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_3")
    
print(independent_variables)
# Out:
# ['Hour_1', 'Hour_2', 'Hour_3', 'Occupant Count (people)_3', '12h Outdoor Drybulb Temperature (C)', '24h Outdoor Drybulb Temperature (C)', '12h Outdoor Relative Humidity (%)', '6h Direct Solar Radiation (W/m2)', '12h Direct Solar Radiation (W/m2)']

# %% [markdown]
# Prepare the data

# %%
# Split the X and Y for all sets

# Train set
X_train_default = train[independent_variables]
Y_train_default = train[columns_to_predict]

# Validation set, also include the data from train that was used only as output to get more datapoints
X_val_default = pd.concat([X_train_default.tail(NUM_OF_TIMESTEPS_OUTPUT), validation[independent_variables]], ignore_index=True)
Y_val_default = pd.concat([Y_train_default.tail(NUM_OF_TIMESTEPS_OUTPUT), validation[columns_to_predict]], ignore_index=True)

# Test set, also include the data from train that was used only as output to get more datapoints
X_test_default = pd.concat([X_val_default.tail(NUM_OF_TIMESTEPS_OUTPUT), test[independent_variables]], ignore_index=True)
Y_test_default = pd.concat([Y_val_default.tail(NUM_OF_TIMESTEPS_OUTPUT), test[columns_to_predict]], ignore_index=True)

NUM_OF_ROWS_TRAIN, NUM_OF_FEATURES = X_train_default.shape

print(X_train_default.shape)
print(X_val_default.shape)
print(X_test_default.shape)
# Out:
# (576, 9)
# (96, 9)
# (96, 9)

# %%
# Function to prepare the data into batches that will be passed into the model

def create_sequences(input_data, output_data, timesteps_input, timesteps_output):
    sequences, targets = [], []
    for i in range(len(input_data) - timesteps_input - timesteps_output + 1):
        seq = input_data[i:i + timesteps_input]
        target = output_data[i + timesteps_input: i + timesteps_input + timesteps_output]
        sequences.append(seq)
        targets.append(target)

    return np.array(sequences), np.array(targets)

# %%
X_train, Y_train = create_sequences(X_train_default, Y_train_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)
X_val, Y_val = create_sequences(X_val_default, Y_val_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)
X_test, Y_test = create_sequences(X_test_default, Y_test_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)

print(f"X_train = {X_train.shape}, Y_train = {Y_train.shape}\n"
      f"X_val = {X_val.shape}, Y_val = {Y_val.shape}\n"
      f"X_test = {X_test.shape}, Y_test = {Y_test.shape}")
# Out:
# X_train = (505, 48, 9), Y_train = (505, 24, 2)
# X_val = (25, 48, 9), Y_val = (25, 24, 2)
# X_test = (25, 48, 9), Y_test = (25, 24, 2)

# %%
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras import layers, models

tscv = TimeSeriesSplit(n_splits = 4, test_size=24) # For cross-validation

callback = keras.callbacks.EarlyStopping(monitor='loss', patience = 7) #patience parameter to be adjusted

loss = []
val_loss = []
loss_1 = []
val_loss_1 = []
loss_2 = []
val_loss_2 = []

# Input layer
input_layer = layers.Input(shape=(NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))

# Dense layers for variable 1
lstm1 = layers.GRU(48, activation='leaky_relu', return_sequences=True)(input_layer)
lstm2 = layers.GRU(48, activation='leaky_relu', return_sequences=True)(lstm1)
lstm3 = layers.GRU(24, activation='leaky_relu', return_sequences=False)(lstm2)
output_variable1 = layers.Dense(24, name='output_variable1')(lstm3)

# Dense layers for variable 2
dense4 = layers.GRU(48, activation='leaky_relu', return_sequences=True)(input_layer)
dense5 = layers.GRU(48, activation='leaky_relu', return_sequences=True)(dense4)
dense6 = layers.GRU(24, activation='leaky_relu', return_sequences=False)(dense5)
output_variable2 = layers.Dense(24, name='output_variable2')(dense6)


# Define the model
model = models.Model(inputs=input_layer, outputs=[output_variable1, output_variable2])

model.compile(
    optimizer='adam',
    loss={'output_variable1': 'mean_squared_error', 'output_variable2': 'mean_squared_error'}
) #types of optimizer, loss function to be adjusted
    
    
history = model.fit(X_train, y={"output_variable1": Y_train[:, :, 0], 
                                "output_variable2": Y_train[:, :, 1]}, epochs=200, verbose=1)
# Out:
# WARNING:tensorflow:From C:\Users\Matej\Documents\GitHub\thesis-forecasting\venv\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# WARNING:tensorflow:From C:\Users\Matej\Documents\GitHub\thesis-forecasting\venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# Epoch 1/200
# WARNING:tensorflow:From C:\Users\Matej\Documents\GitHub\thesis-forecasting\venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# WARNING:tensorflow:From C:\Users\Matej\Documents\GitHub\thesis-forecasting\venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# 16/16 [==============================] - 6s 25ms/step - loss: 0.4882 - output_variable1_loss: 0.3154 - output_variable2_loss: 0.1728
# Epoch 2/200
# 16/16 [==============================] - 0s 25ms/step - loss: 0.2835 - output_variable1_loss: 0.1574 - output_variable2_loss: 0.1261
# Epoch 3/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.1712 - output_variable1_loss: 0.0857 - output_variable2_loss: 0.0855
# Epoch 4/200
# 16/16 [==============================] - 0s 25ms/step - loss: 0.1084 - output_variable1_loss: 0.0588 - output_variable2_loss: 0.0496
# Epoch 5/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0792 - output_variable1_loss: 0.0487 - output_variable2_loss: 0.0306
# Epoch 6/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0617 - output_variable1_loss: 0.0411 - output_variable2_loss: 0.0206
# Epoch 7/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0497 - output_variable1_loss: 0.0345 - output_variable2_loss: 0.0153
# Epoch 8/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0436 - output_variable1_loss: 0.0321 - output_variable2_loss: 0.0116
# Epoch 9/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0382 - output_variable1_loss: 0.0290 - output_variable2_loss: 0.0092
# Epoch 10/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0348 - output_variable1_loss: 0.0273 - output_variable2_loss: 0.0075
# Epoch 11/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0319 - output_variable1_loss: 0.0254 - output_variable2_loss: 0.0064
# Epoch 12/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0294 - output_variable1_loss: 0.0237 - output_variable2_loss: 0.0057
# Epoch 13/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0279 - output_variable1_loss: 0.0224 - output_variable2_loss: 0.0055
# Epoch 14/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0266 - output_variable1_loss: 0.0219 - output_variable2_loss: 0.0047
# Epoch 15/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0252 - output_variable1_loss: 0.0209 - output_variable2_loss: 0.0043
# Epoch 16/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0242 - output_variable1_loss: 0.0202 - output_variable2_loss: 0.0040
# Epoch 17/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0234 - output_variable1_loss: 0.0196 - output_variable2_loss: 0.0038
# Epoch 18/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0231 - output_variable1_loss: 0.0194 - output_variable2_loss: 0.0036
# Epoch 19/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0239 - output_variable1_loss: 0.0203 - output_variable2_loss: 0.0036
# Epoch 20/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0221 - output_variable1_loss: 0.0186 - output_variable2_loss: 0.0035
# Epoch 21/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0214 - output_variable1_loss: 0.0181 - output_variable2_loss: 0.0033
# Epoch 22/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0220 - output_variable1_loss: 0.0188 - output_variable2_loss: 0.0032
# Epoch 23/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0219 - output_variable1_loss: 0.0187 - output_variable2_loss: 0.0032
# Epoch 24/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0213 - output_variable1_loss: 0.0181 - output_variable2_loss: 0.0032
# Epoch 25/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0212 - output_variable1_loss: 0.0181 - output_variable2_loss: 0.0031
# Epoch 26/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0207 - output_variable1_loss: 0.0175 - output_variable2_loss: 0.0032
# Epoch 27/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0201 - output_variable1_loss: 0.0170 - output_variable2_loss: 0.0031
# Epoch 28/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0204 - output_variable1_loss: 0.0173 - output_variable2_loss: 0.0031
# Epoch 29/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0199 - output_variable1_loss: 0.0168 - output_variable2_loss: 0.0031
# Epoch 30/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0193 - output_variable1_loss: 0.0163 - output_variable2_loss: 0.0029
# Epoch 31/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0191 - output_variable1_loss: 0.0163 - output_variable2_loss: 0.0028
# Epoch 32/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0193 - output_variable1_loss: 0.0163 - output_variable2_loss: 0.0029
# Epoch 33/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0187 - output_variable1_loss: 0.0159 - output_variable2_loss: 0.0028
# Epoch 34/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0182 - output_variable1_loss: 0.0155 - output_variable2_loss: 0.0027
# Epoch 35/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0178 - output_variable1_loss: 0.0151 - output_variable2_loss: 0.0027
# Epoch 36/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0180 - output_variable1_loss: 0.0153 - output_variable2_loss: 0.0027
# Epoch 37/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0176 - output_variable1_loss: 0.0150 - output_variable2_loss: 0.0027
# Epoch 38/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0174 - output_variable1_loss: 0.0147 - output_variable2_loss: 0.0027
# Epoch 39/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0179 - output_variable1_loss: 0.0152 - output_variable2_loss: 0.0027
# Epoch 40/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0170 - output_variable1_loss: 0.0143 - output_variable2_loss: 0.0027
# Epoch 41/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0170 - output_variable1_loss: 0.0144 - output_variable2_loss: 0.0026
# Epoch 42/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0165 - output_variable1_loss: 0.0139 - output_variable2_loss: 0.0026
# Epoch 43/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0166 - output_variable1_loss: 0.0141 - output_variable2_loss: 0.0025
# Epoch 44/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0159 - output_variable1_loss: 0.0134 - output_variable2_loss: 0.0025
# Epoch 45/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0157 - output_variable1_loss: 0.0132 - output_variable2_loss: 0.0025
# Epoch 46/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0154 - output_variable1_loss: 0.0129 - output_variable2_loss: 0.0025
# Epoch 47/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0168 - output_variable1_loss: 0.0143 - output_variable2_loss: 0.0025
# Epoch 48/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0164 - output_variable1_loss: 0.0139 - output_variable2_loss: 0.0025
# Epoch 49/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0153 - output_variable1_loss: 0.0128 - output_variable2_loss: 0.0025
# Epoch 50/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0155 - output_variable1_loss: 0.0130 - output_variable2_loss: 0.0024
# Epoch 51/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0152 - output_variable1_loss: 0.0126 - output_variable2_loss: 0.0025
# Epoch 52/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0147 - output_variable1_loss: 0.0121 - output_variable2_loss: 0.0026
# Epoch 53/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0145 - output_variable1_loss: 0.0119 - output_variable2_loss: 0.0026
# Epoch 54/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0142 - output_variable1_loss: 0.0118 - output_variable2_loss: 0.0024
# Epoch 55/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0139 - output_variable1_loss: 0.0115 - output_variable2_loss: 0.0024
# Epoch 56/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0135 - output_variable1_loss: 0.0113 - output_variable2_loss: 0.0022
# Epoch 57/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0135 - output_variable1_loss: 0.0112 - output_variable2_loss: 0.0022
# Epoch 58/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0130 - output_variable1_loss: 0.0108 - output_variable2_loss: 0.0022
# Epoch 59/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0128 - output_variable1_loss: 0.0107 - output_variable2_loss: 0.0022
# Epoch 60/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0128 - output_variable1_loss: 0.0106 - output_variable2_loss: 0.0022
# Epoch 61/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0124 - output_variable1_loss: 0.0101 - output_variable2_loss: 0.0022
# Epoch 62/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0126 - output_variable1_loss: 0.0103 - output_variable2_loss: 0.0023
# Epoch 63/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0123 - output_variable1_loss: 0.0101 - output_variable2_loss: 0.0022
# Epoch 64/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0122 - output_variable1_loss: 0.0101 - output_variable2_loss: 0.0021
# Epoch 65/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0125 - output_variable1_loss: 0.0104 - output_variable2_loss: 0.0021
# Epoch 66/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0116 - output_variable1_loss: 0.0095 - output_variable2_loss: 0.0021
# Epoch 67/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0115 - output_variable1_loss: 0.0094 - output_variable2_loss: 0.0021
# Epoch 68/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0119 - output_variable1_loss: 0.0097 - output_variable2_loss: 0.0021
# Epoch 69/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0110 - output_variable1_loss: 0.0090 - output_variable2_loss: 0.0021
# Epoch 70/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0112 - output_variable1_loss: 0.0090 - output_variable2_loss: 0.0022
# Epoch 71/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0111 - output_variable1_loss: 0.0090 - output_variable2_loss: 0.0021
# Epoch 72/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0112 - output_variable1_loss: 0.0092 - output_variable2_loss: 0.0020
# Epoch 73/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0108 - output_variable1_loss: 0.0089 - output_variable2_loss: 0.0020
# Epoch 74/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0103 - output_variable1_loss: 0.0083 - output_variable2_loss: 0.0019
# Epoch 75/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0103 - output_variable1_loss: 0.0083 - output_variable2_loss: 0.0019
# Epoch 76/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0101 - output_variable1_loss: 0.0083 - output_variable2_loss: 0.0019
# Epoch 77/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0101 - output_variable1_loss: 0.0082 - output_variable2_loss: 0.0019
# Epoch 78/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0098 - output_variable1_loss: 0.0080 - output_variable2_loss: 0.0018
# Epoch 79/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0098 - output_variable1_loss: 0.0078 - output_variable2_loss: 0.0020
# Epoch 80/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0097 - output_variable1_loss: 0.0078 - output_variable2_loss: 0.0019
# Epoch 81/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0093 - output_variable1_loss: 0.0075 - output_variable2_loss: 0.0018
# Epoch 82/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0096 - output_variable1_loss: 0.0078 - output_variable2_loss: 0.0017
# Epoch 83/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0100 - output_variable1_loss: 0.0081 - output_variable2_loss: 0.0019
# Epoch 84/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0092 - output_variable1_loss: 0.0073 - output_variable2_loss: 0.0019
# Epoch 85/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0089 - output_variable1_loss: 0.0071 - output_variable2_loss: 0.0018
# Epoch 86/200
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0090 - output_variable1_loss: 0.0073 - output_variable2_loss: 0.0017
# Epoch 87/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0087 - output_variable1_loss: 0.0070 - output_variable2_loss: 0.0017
# Epoch 88/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0086 - output_variable1_loss: 0.0068 - output_variable2_loss: 0.0018
# Epoch 89/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0085 - output_variable1_loss: 0.0069 - output_variable2_loss: 0.0017
# Epoch 90/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0086 - output_variable1_loss: 0.0069 - output_variable2_loss: 0.0017
# Epoch 91/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0080 - output_variable1_loss: 0.0064 - output_variable2_loss: 0.0016
# Epoch 92/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0081 - output_variable1_loss: 0.0066 - output_variable2_loss: 0.0015
# Epoch 93/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0079 - output_variable1_loss: 0.0064 - output_variable2_loss: 0.0015
# Epoch 94/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0079 - output_variable1_loss: 0.0064 - output_variable2_loss: 0.0015
# Epoch 95/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0077 - output_variable1_loss: 0.0062 - output_variable2_loss: 0.0015
# Epoch 96/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0078 - output_variable1_loss: 0.0063 - output_variable2_loss: 0.0015
# Epoch 97/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0073 - output_variable1_loss: 0.0059 - output_variable2_loss: 0.0014
# Epoch 98/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0072 - output_variable1_loss: 0.0058 - output_variable2_loss: 0.0014
# Epoch 99/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0069 - output_variable1_loss: 0.0055 - output_variable2_loss: 0.0013
# Epoch 100/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0068 - output_variable1_loss: 0.0055 - output_variable2_loss: 0.0013
# Epoch 101/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0066 - output_variable1_loss: 0.0054 - output_variable2_loss: 0.0013
# Epoch 102/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0067 - output_variable1_loss: 0.0052 - output_variable2_loss: 0.0014
# Epoch 103/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0064 - output_variable1_loss: 0.0051 - output_variable2_loss: 0.0013
# Epoch 104/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0068 - output_variable1_loss: 0.0055 - output_variable2_loss: 0.0013
# Epoch 105/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0067 - output_variable1_loss: 0.0055 - output_variable2_loss: 0.0012
# Epoch 106/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0065 - output_variable1_loss: 0.0052 - output_variable2_loss: 0.0013
# Epoch 107/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0064 - output_variable1_loss: 0.0051 - output_variable2_loss: 0.0012
# Epoch 108/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0062 - output_variable1_loss: 0.0050 - output_variable2_loss: 0.0012
# Epoch 109/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0059 - output_variable1_loss: 0.0048 - output_variable2_loss: 0.0011
# Epoch 110/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0061 - output_variable1_loss: 0.0050 - output_variable2_loss: 0.0011
# Epoch 111/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0060 - output_variable1_loss: 0.0049 - output_variable2_loss: 0.0011
# Epoch 112/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0059 - output_variable1_loss: 0.0048 - output_variable2_loss: 0.0012
# Epoch 113/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0057 - output_variable1_loss: 0.0045 - output_variable2_loss: 0.0012
# Epoch 114/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0057 - output_variable1_loss: 0.0046 - output_variable2_loss: 0.0011
# Epoch 115/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0057 - output_variable1_loss: 0.0046 - output_variable2_loss: 0.0011
# Epoch 116/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0056 - output_variable1_loss: 0.0044 - output_variable2_loss: 0.0012
# Epoch 117/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0054 - output_variable1_loss: 0.0043 - output_variable2_loss: 0.0011
# Epoch 118/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0053 - output_variable1_loss: 0.0043 - output_variable2_loss: 0.0010
# Epoch 119/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0052 - output_variable1_loss: 0.0042 - output_variable2_loss: 9.9805e-04
# Epoch 120/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0051 - output_variable1_loss: 0.0041 - output_variable2_loss: 0.0010
# Epoch 121/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0053 - output_variable1_loss: 0.0043 - output_variable2_loss: 0.0010
# Epoch 122/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0052 - output_variable1_loss: 0.0042 - output_variable2_loss: 0.0010
# Epoch 123/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0051 - output_variable1_loss: 0.0040 - output_variable2_loss: 0.0011
# Epoch 124/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0050 - output_variable1_loss: 0.0040 - output_variable2_loss: 0.0010
# Epoch 125/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0049 - output_variable1_loss: 0.0040 - output_variable2_loss: 9.6429e-04
# Epoch 126/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0049 - output_variable1_loss: 0.0040 - output_variable2_loss: 9.2106e-04
# Epoch 127/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0050 - output_variable1_loss: 0.0040 - output_variable2_loss: 0.0010
# Epoch 128/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0049 - output_variable1_loss: 0.0038 - output_variable2_loss: 0.0010
# Epoch 129/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0049 - output_variable1_loss: 0.0039 - output_variable2_loss: 9.2503e-04
# Epoch 130/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0047 - output_variable1_loss: 0.0038 - output_variable2_loss: 9.0134e-04
# Epoch 131/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0047 - output_variable1_loss: 0.0038 - output_variable2_loss: 9.2862e-04
# Epoch 132/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0047 - output_variable1_loss: 0.0038 - output_variable2_loss: 8.7885e-04
# Epoch 133/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0048 - output_variable1_loss: 0.0039 - output_variable2_loss: 9.0155e-04
# Epoch 134/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0046 - output_variable1_loss: 0.0036 - output_variable2_loss: 9.5982e-04
# Epoch 135/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0045 - output_variable1_loss: 0.0035 - output_variable2_loss: 9.4319e-04
# Epoch 136/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0044 - output_variable1_loss: 0.0035 - output_variable2_loss: 8.9783e-04
# Epoch 137/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0044 - output_variable1_loss: 0.0035 - output_variable2_loss: 9.2442e-04
# Epoch 138/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0044 - output_variable1_loss: 0.0035 - output_variable2_loss: 9.3047e-04
# Epoch 139/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0044 - output_variable1_loss: 0.0034 - output_variable2_loss: 9.3134e-04
# Epoch 140/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0043 - output_variable1_loss: 0.0034 - output_variable2_loss: 8.8449e-04
# Epoch 141/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0044 - output_variable1_loss: 0.0035 - output_variable2_loss: 8.9222e-04
# Epoch 142/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0043 - output_variable1_loss: 0.0034 - output_variable2_loss: 8.7921e-04
# Epoch 143/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0044 - output_variable1_loss: 0.0035 - output_variable2_loss: 8.4390e-04
# Epoch 144/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0042 - output_variable1_loss: 0.0034 - output_variable2_loss: 8.5490e-04
# Epoch 145/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0042 - output_variable1_loss: 0.0033 - output_variable2_loss: 8.2646e-04
# Epoch 146/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0040 - output_variable1_loss: 0.0032 - output_variable2_loss: 7.9354e-04
# Epoch 147/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0040 - output_variable1_loss: 0.0032 - output_variable2_loss: 8.0137e-04
# Epoch 148/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0041 - output_variable1_loss: 0.0033 - output_variable2_loss: 8.0912e-04
# Epoch 149/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0040 - output_variable1_loss: 0.0031 - output_variable2_loss: 8.4125e-04
# Epoch 150/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0039 - output_variable1_loss: 0.0031 - output_variable2_loss: 8.4024e-04
# Epoch 151/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0039 - output_variable1_loss: 0.0031 - output_variable2_loss: 8.1729e-04
# Epoch 152/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0039 - output_variable1_loss: 0.0031 - output_variable2_loss: 8.0236e-04
# Epoch 153/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0039 - output_variable1_loss: 0.0031 - output_variable2_loss: 8.1895e-04
# Epoch 154/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0039 - output_variable1_loss: 0.0031 - output_variable2_loss: 7.9258e-04
# Epoch 155/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0039 - output_variable1_loss: 0.0031 - output_variable2_loss: 8.1491e-04
# Epoch 156/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0038 - output_variable1_loss: 0.0030 - output_variable2_loss: 8.0931e-04
# Epoch 157/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0038 - output_variable1_loss: 0.0030 - output_variable2_loss: 7.9915e-04
# Epoch 158/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0037 - output_variable1_loss: 0.0029 - output_variable2_loss: 7.6054e-04
# Epoch 159/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0036 - output_variable1_loss: 0.0029 - output_variable2_loss: 7.5852e-04
# Epoch 160/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0036 - output_variable1_loss: 0.0029 - output_variable2_loss: 7.9154e-04
# Epoch 161/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0037 - output_variable1_loss: 0.0029 - output_variable2_loss: 7.9864e-04
# Epoch 162/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0036 - output_variable1_loss: 0.0029 - output_variable2_loss: 7.5924e-04
# Epoch 163/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0037 - output_variable1_loss: 0.0028 - output_variable2_loss: 8.4778e-04
# Epoch 164/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0036 - output_variable1_loss: 0.0028 - output_variable2_loss: 8.1387e-04
# Epoch 165/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0035 - output_variable1_loss: 0.0028 - output_variable2_loss: 7.2942e-04
# Epoch 166/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0035 - output_variable1_loss: 0.0028 - output_variable2_loss: 7.0284e-04
# Epoch 167/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0034 - output_variable1_loss: 0.0027 - output_variable2_loss: 6.9952e-04
# Epoch 168/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0034 - output_variable1_loss: 0.0027 - output_variable2_loss: 7.0800e-04
# Epoch 169/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0035 - output_variable1_loss: 0.0027 - output_variable2_loss: 8.3912e-04
# Epoch 170/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0036 - output_variable1_loss: 0.0029 - output_variable2_loss: 7.5252e-04
# Epoch 171/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0036 - output_variable1_loss: 0.0029 - output_variable2_loss: 7.0792e-04
# Epoch 172/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0034 - output_variable1_loss: 0.0027 - output_variable2_loss: 7.5497e-04
# Epoch 173/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0034 - output_variable1_loss: 0.0027 - output_variable2_loss: 7.0731e-04
# Epoch 174/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0034 - output_variable1_loss: 0.0027 - output_variable2_loss: 7.0779e-04
# Epoch 175/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0034 - output_variable1_loss: 0.0027 - output_variable2_loss: 6.9150e-04
# Epoch 176/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0035 - output_variable1_loss: 0.0027 - output_variable2_loss: 7.7962e-04
# Epoch 177/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0035 - output_variable1_loss: 0.0026 - output_variable2_loss: 8.3467e-04
# Epoch 178/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0033 - output_variable1_loss: 0.0026 - output_variable2_loss: 7.4846e-04
# Epoch 179/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0034 - output_variable1_loss: 0.0026 - output_variable2_loss: 7.7716e-04
# Epoch 180/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0033 - output_variable1_loss: 0.0025 - output_variable2_loss: 7.4120e-04
# Epoch 181/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0032 - output_variable1_loss: 0.0025 - output_variable2_loss: 6.9951e-04
# Epoch 182/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0033 - output_variable1_loss: 0.0025 - output_variable2_loss: 7.4802e-04
# Epoch 183/200
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0033 - output_variable1_loss: 0.0026 - output_variable2_loss: 7.4628e-04
# Epoch 184/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0034 - output_variable1_loss: 0.0026 - output_variable2_loss: 7.9844e-04
# Epoch 185/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0031 - output_variable1_loss: 0.0024 - output_variable2_loss: 7.1858e-04
# Epoch 186/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0032 - output_variable1_loss: 0.0025 - output_variable2_loss: 7.0971e-04
# Epoch 187/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0032 - output_variable1_loss: 0.0025 - output_variable2_loss: 6.9833e-04
# Epoch 188/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0031 - output_variable1_loss: 0.0025 - output_variable2_loss: 6.9438e-04
# Epoch 189/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0033 - output_variable1_loss: 0.0026 - output_variable2_loss: 6.7545e-04
# Epoch 190/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0032 - output_variable1_loss: 0.0025 - output_variable2_loss: 6.8097e-04
# Epoch 191/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0031 - output_variable1_loss: 0.0024 - output_variable2_loss: 7.3654e-04
# Epoch 192/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0031 - output_variable1_loss: 0.0023 - output_variable2_loss: 7.6110e-04
# Epoch 193/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0030 - output_variable1_loss: 0.0023 - output_variable2_loss: 6.9713e-04
# Epoch 194/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0029 - output_variable1_loss: 0.0022 - output_variable2_loss: 6.5751e-04
# Epoch 195/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0029 - output_variable1_loss: 0.0022 - output_variable2_loss: 6.9610e-04
# Epoch 196/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0030 - output_variable1_loss: 0.0023 - output_variable2_loss: 7.1774e-04
# Epoch 197/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0029 - output_variable1_loss: 0.0023 - output_variable2_loss: 6.4205e-04
# Epoch 198/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0030 - output_variable1_loss: 0.0023 - output_variable2_loss: 6.7086e-04
# Epoch 199/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0029 - output_variable1_loss: 0.0023 - output_variable2_loss: 6.5172e-04
# Epoch 200/200
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0028 - output_variable1_loss: 0.0022 - output_variable2_loss: 6.4343e-04

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss_1):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss_1[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error 1", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss_2):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss_2[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error 2", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Evaluate the model on the test data
predictions_1 = []
predictions_2 = []
#print(len(eval_target_variables))

for i in range(len(Y_val)):
    current_batch = X_val[i].reshape((1, NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))
    curr_pred1, curr_pred2 = model.predict(current_batch)
    predictions_1.append(curr_pred1)
    predictions_2.append(curr_pred2)
# Out:
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_1):
    ax = axs[i]
    # TODO seems to work but check why column[0]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_val[i, :, 0], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_2):
    ax = axs[i]
    # TODO seems to work but check why column[0]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_val[i, :, 1], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
rmse = 0
for i in range(len(predictions_1)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_1[i][0], Y_val[i, :, 0]))}')
    rmse += sqrt(mean_squared_error(predictions_1[i][0], Y_val[i, :, 0]))

rmse /= len(predictions_1)    
print(f"RMSE for {columns_to_predict[0]} = {rmse}")

rmse = 0
for i in range(len(predictions_2)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_2[i][0], Y_val[i, :, 1]))}')
    rmse += sqrt(mean_squared_error(predictions_2[i][0], Y_val[i, :, 1]))

rmse /= len(predictions_2)    
print(f"RMSE for {columns_to_predict[1]} = {rmse}")
# Out:
# RMSE for kg_CO2/kWh = 0.17042868185450533
# RMSE for Avg solar generation = 0.03742229119802107

# %%
# Evaluate the model on the test data
predictions_1_test = []
predictions_2_test = []
#print(len(eval_target_variables))

for i in range(len(Y_test)):
    current_batch = X_test[i].reshape((1, NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))
    curr_pred1, curr_pred2 = model.predict(current_batch)
    predictions_1_test.append(curr_pred1)
    predictions_2_test.append(curr_pred2)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_1_test):
    ax = axs[i]
    # TODO seems to work but check why column[0]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_test[i, :, 0], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_2_test):
    ax = axs[i]
    # TODO seems to work but check why column[0]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_test[i, :, 1], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
rmse = 0
for i in range(len(predictions_1_test)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_1[i][0], Y_val[i, :, 0]))}')
    rmse += sqrt(mean_squared_error(predictions_1_test[i][0], Y_test[i, :, 0]))

rmse /= len(predictions_1_test)    
print(f"RMSE for {columns_to_predict[0]} = {rmse}")

rmse = 0
for i in range(len(predictions_2_test)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_2[i][0], Y_val[i, :, 1]))}')
    rmse += sqrt(mean_squared_error(predictions_2_test[i][0], Y_test[i, :, 1]))

rmse /= len(predictions_2_test)    
print(f"RMSE for {columns_to_predict[1]} = {rmse}")
# Out:
# RMSE for kg_CO2/kWh = 0.17994551582341856
# RMSE for Avg solar generation = 0.04084982057106251
