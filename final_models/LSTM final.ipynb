# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
train = pd.read_csv("../data/schemas/warm_up/TrainSet.csv", sep=",")
validation = pd.read_csv("../data/schemas/warm_up/ValidationSet.csv", sep=",")
test = pd.read_csv("../data/schemas/warm_up/TestSet.csv", sep=",")

# %%
# Global variables

NUM_OF_TIMESTEPS_INPUT = 48
NUM_OF_TIMESTEPS_OUTPUT = 24

THRESHOLD = 0.4   # For feature selection

# %%
columns_to_predict = ["kg_CO2/kWh", "Avg solar generation"]

independent_variables = []

for column in train:
    if abs(train[column].corr(train[columns_to_predict[0]])) > THRESHOLD: #or abs(train[column].corr(train[columns_to_predict[1]])) > THRESHOLD:
        independent_variables.append(column)

independent_variables = [var for var in independent_variables if var not in columns_to_predict]
    
if "Index" in independent_variables:
    independent_variables.remove("Index")
if "Solar Generation (W/kW)_1" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_1")
if "Solar Generation (W/kW)_2" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_2")
if "Solar Generation (W/kW)_3" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_3")
    
print(independent_variables)
# Out:
# ['Hour_1', 'Hour_2', 'Hour_3', 'Occupant Count (people)_3', '12h Outdoor Drybulb Temperature (C)', '24h Outdoor Drybulb Temperature (C)', '12h Outdoor Relative Humidity (%)', '6h Direct Solar Radiation (W/m2)', '12h Direct Solar Radiation (W/m2)']

# %% [markdown]
# Prepare the data

# %%
# Split the X and Y for all sets

# Train set
X_train_default = train[independent_variables]
Y_train_default = train[columns_to_predict]

# Validation set, also include the data from train that was used only as output to get more datapoints
X_val_default = pd.concat([X_train_default.tail(NUM_OF_TIMESTEPS_OUTPUT), validation[independent_variables]], ignore_index=True)
Y_val_default = pd.concat([Y_train_default.tail(NUM_OF_TIMESTEPS_OUTPUT), validation[columns_to_predict]], ignore_index=True)

# Test set, also include the data from train that was used only as output to get more datapoints
X_test_default = pd.concat([X_val_default.tail(NUM_OF_TIMESTEPS_OUTPUT), test[independent_variables]], ignore_index=True)
Y_test_default = pd.concat([Y_val_default.tail(NUM_OF_TIMESTEPS_OUTPUT), test[columns_to_predict]], ignore_index=True)

NUM_OF_ROWS_TRAIN, NUM_OF_FEATURES = X_train_default.shape

print(X_train_default.shape)
print(X_val_default.shape)
print(X_test_default.shape)
# Out:
# (576, 9)
# (96, 9)
# (96, 9)

# %%
# Function to prepare the data into batches that will be passed into the model

def create_sequences(input_data, output_data, timesteps_input, timesteps_output):
    sequences, targets = [], []
    for i in range(len(input_data) - timesteps_input - timesteps_output + 1):
        seq = input_data[i:i + timesteps_input]
        target = output_data[i + timesteps_input: i + timesteps_input + timesteps_output]
        sequences.append(seq)
        targets.append(target)

    return np.array(sequences), np.array(targets)

# %%
X_train, Y_train = create_sequences(X_train_default, Y_train_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)
X_val, Y_val = create_sequences(X_val_default, Y_val_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)
X_test, Y_test = create_sequences(X_test_default, Y_test_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)

print(f"X_train = {X_train.shape}, Y_train = {Y_train.shape}\n"
      f"X_val = {X_val.shape}, Y_val = {Y_val.shape}\n"
      f"X_test = {X_test.shape}, Y_test = {Y_test.shape}")
# Out:
# X_train = (505, 48, 9), Y_train = (505, 24, 2)
# X_val = (25, 48, 9), Y_val = (25, 24, 2)
# X_test = (25, 48, 9), Y_test = (25, 24, 2)

# %%
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras import layers, models
import time

tscv = TimeSeriesSplit(n_splits = 4, test_size=24) # For cross-validation

callback = keras.callbacks.EarlyStopping(monitor='loss', patience = 7) #patience parameter to be adjusted

loss = []
val_loss = []
loss_1 = []
val_loss_1 = []
loss_2 = []
val_loss_2 = []

# Input layer
input_layer = layers.Input(shape=(NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))

# Dense layers for variable 1
lstm1 = layers.LSTM(48, activation='leaky_relu', return_sequences=True)(input_layer)
lstm2 = layers.LSTM(48, activation='leaky_relu', return_sequences=True)(lstm1)
lstm3 = layers.LSTM(24, activation='leaky_relu', return_sequences=False)(lstm2)
output_variable1 = layers.Dense(24, name='output_variable1')(lstm3)

# Dense layers for variable 2
dense4 = layers.LSTM(48, activation='leaky_relu', return_sequences=True)(input_layer)
dense5 = layers.LSTM(48, activation='leaky_relu', return_sequences=True)(dense4)
dense6 = layers.LSTM(24, activation='leaky_relu', return_sequences=False)(dense5)
output_variable2 = layers.Dense(24, name='output_variable2')(dense6)

# Define the model
model = models.Model(inputs=input_layer, outputs=[output_variable1, output_variable2])

model.compile(
    optimizer='adam',
    loss={'output_variable1': 'mean_squared_error', 'output_variable2': 'mean_squared_error'}
) #types of optimizer, loss function to be adjusted
    
start = time.time()

for train_data, test_data in tscv.split(X_train):
    X_train_current_split, X_test_current_split = X_train[train_data], X_train[test_data]
    y_train_current_split, y_test_current_split = Y_train[train_data], Y_train[test_data]
    
    history = model.fit(X_train_current_split, y={"output_variable1": y_train_current_split[:, :, 0], 
                                                  "output_variable2": y_train_current_split[:, :, 1]},
              epochs=100, 
              validation_data=(
                  X_test_current_split,
                {
                    "output_variable1": y_test_current_split[:, :, 0],
                    "output_variable2": y_test_current_split[:, :, 1],
                },
              ),
              # validation_split = 0.8,
              verbose=1,
              callbacks=callback
    )
    loss.append(model.history.history['loss'])
    val_loss.append(model.history.history['val_loss'])
    
    loss_1.append(model.history.history['output_variable1_loss'])
    val_loss_1.append(model.history.history['val_output_variable1_loss'])
    
    loss_2.append(model.history.history['output_variable2_loss'])
    val_loss_2.append(model.history.history['val_output_variable2_loss'])
    
end = time.time()

print(f"Training time = {end - start} seconds")
# Out:
# Epoch 1/100
# 13/13 [==============================] - 13s 179ms/step - loss: 0.4863 - output_variable1_loss: 0.3177 - output_variable2_loss: 0.1686 - val_loss: 0.7294 - val_output_variable1_loss: 0.6362 - val_output_variable2_loss: 0.0932
# Epoch 2/100
# 13/13 [==============================] - 1s 58ms/step - loss: 0.3556 - output_variable1_loss: 0.2139 - output_variable2_loss: 0.1417 - val_loss: 0.5259 - val_output_variable1_loss: 0.4419 - val_output_variable2_loss: 0.0840
# Epoch 3/100
# 13/13 [==============================] - 1s 60ms/step - loss: 0.2502 - output_variable1_loss: 0.1265 - output_variable2_loss: 0.1237 - val_loss: 0.3266 - val_output_variable1_loss: 0.2506 - val_output_variable2_loss: 0.0759
# Epoch 4/100
# 13/13 [==============================] - 1s 61ms/step - loss: 0.1815 - output_variable1_loss: 0.0735 - output_variable2_loss: 0.1080 - val_loss: 0.1916 - val_output_variable1_loss: 0.1224 - val_output_variable2_loss: 0.0692
# Epoch 5/100
# 13/13 [==============================] - 1s 54ms/step - loss: 0.1426 - output_variable1_loss: 0.0535 - output_variable2_loss: 0.0891 - val_loss: 0.1005 - val_output_variable1_loss: 0.0377 - val_output_variable2_loss: 0.0628
# Epoch 6/100
# 13/13 [==============================] - 1s 57ms/step - loss: 0.1123 - output_variable1_loss: 0.0422 - output_variable2_loss: 0.0701 - val_loss: 0.1397 - val_output_variable1_loss: 0.0854 - val_output_variable2_loss: 0.0543
# Epoch 7/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0938 - output_variable1_loss: 0.0395 - output_variable2_loss: 0.0543 - val_loss: 0.0489 - val_output_variable1_loss: 0.0096 - val_output_variable2_loss: 0.0393
# Epoch 8/100
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0811 - output_variable1_loss: 0.0391 - output_variable2_loss: 0.0420 - val_loss: 0.1013 - val_output_variable1_loss: 0.0666 - val_output_variable2_loss: 0.0347
# Epoch 9/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0680 - output_variable1_loss: 0.0376 - output_variable2_loss: 0.0303 - val_loss: 0.0409 - val_output_variable1_loss: 0.0169 - val_output_variable2_loss: 0.0241
# Epoch 10/100
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0584 - output_variable1_loss: 0.0363 - output_variable2_loss: 0.0221 - val_loss: 0.0569 - val_output_variable1_loss: 0.0323 - val_output_variable2_loss: 0.0245
# Epoch 11/100
# 13/13 [==============================] - 1s 58ms/step - loss: 0.0521 - output_variable1_loss: 0.0344 - output_variable2_loss: 0.0177 - val_loss: 0.0427 - val_output_variable1_loss: 0.0248 - val_output_variable2_loss: 0.0179
# Epoch 12/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0491 - output_variable1_loss: 0.0333 - output_variable2_loss: 0.0158 - val_loss: 0.0580 - val_output_variable1_loss: 0.0410 - val_output_variable2_loss: 0.0170
# Epoch 13/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0462 - output_variable1_loss: 0.0325 - output_variable2_loss: 0.0137 - val_loss: 0.0504 - val_output_variable1_loss: 0.0337 - val_output_variable2_loss: 0.0167
# Epoch 14/100
# 13/13 [==============================] - 1s 59ms/step - loss: 0.0435 - output_variable1_loss: 0.0316 - output_variable2_loss: 0.0119 - val_loss: 0.0508 - val_output_variable1_loss: 0.0361 - val_output_variable2_loss: 0.0148
# Epoch 15/100
# 13/13 [==============================] - 1s 52ms/step - loss: 0.0431 - output_variable1_loss: 0.0323 - output_variable2_loss: 0.0108 - val_loss: 0.0628 - val_output_variable1_loss: 0.0486 - val_output_variable2_loss: 0.0142
# Epoch 16/100
# 13/13 [==============================] - 1s 53ms/step - loss: 0.0389 - output_variable1_loss: 0.0293 - output_variable2_loss: 0.0095 - val_loss: 0.0543 - val_output_variable1_loss: 0.0401 - val_output_variable2_loss: 0.0142
# Epoch 17/100
# 13/13 [==============================] - 1s 52ms/step - loss: 0.0369 - output_variable1_loss: 0.0283 - output_variable2_loss: 0.0086 - val_loss: 0.0607 - val_output_variable1_loss: 0.0452 - val_output_variable2_loss: 0.0156
# Epoch 18/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0340 - output_variable1_loss: 0.0266 - output_variable2_loss: 0.0074 - val_loss: 0.0526 - val_output_variable1_loss: 0.0388 - val_output_variable2_loss: 0.0138
# Epoch 19/100
# 13/13 [==============================] - 1s 52ms/step - loss: 0.0327 - output_variable1_loss: 0.0262 - output_variable2_loss: 0.0065 - val_loss: 0.0497 - val_output_variable1_loss: 0.0395 - val_output_variable2_loss: 0.0102
# Epoch 20/100
# 13/13 [==============================] - 1s 53ms/step - loss: 0.0312 - output_variable1_loss: 0.0256 - output_variable2_loss: 0.0056 - val_loss: 0.0471 - val_output_variable1_loss: 0.0363 - val_output_variable2_loss: 0.0108
# Epoch 21/100
# 13/13 [==============================] - 1s 52ms/step - loss: 0.0295 - output_variable1_loss: 0.0245 - output_variable2_loss: 0.0050 - val_loss: 0.0574 - val_output_variable1_loss: 0.0465 - val_output_variable2_loss: 0.0108
# Epoch 22/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0280 - output_variable1_loss: 0.0233 - output_variable2_loss: 0.0047 - val_loss: 0.0473 - val_output_variable1_loss: 0.0384 - val_output_variable2_loss: 0.0089
# Epoch 23/100
# 13/13 [==============================] - 1s 60ms/step - loss: 0.0270 - output_variable1_loss: 0.0226 - output_variable2_loss: 0.0043 - val_loss: 0.0636 - val_output_variable1_loss: 0.0556 - val_output_variable2_loss: 0.0081
# Epoch 24/100
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0244 - output_variable1_loss: 0.0203 - output_variable2_loss: 0.0041 - val_loss: 0.0648 - val_output_variable1_loss: 0.0568 - val_output_variable2_loss: 0.0080
# Epoch 25/100
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0230 - output_variable1_loss: 0.0189 - output_variable2_loss: 0.0040 - val_loss: 0.0627 - val_output_variable1_loss: 0.0551 - val_output_variable2_loss: 0.0076
# Epoch 26/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0218 - output_variable1_loss: 0.0178 - output_variable2_loss: 0.0040 - val_loss: 0.0745 - val_output_variable1_loss: 0.0677 - val_output_variable2_loss: 0.0067
# Epoch 27/100
# 13/13 [==============================] - 1s 52ms/step - loss: 0.0198 - output_variable1_loss: 0.0161 - output_variable2_loss: 0.0037 - val_loss: 0.0562 - val_output_variable1_loss: 0.0492 - val_output_variable2_loss: 0.0070
# Epoch 28/100
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0185 - output_variable1_loss: 0.0150 - output_variable2_loss: 0.0035 - val_loss: 0.0631 - val_output_variable1_loss: 0.0549 - val_output_variable2_loss: 0.0081
# Epoch 29/100
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0171 - output_variable1_loss: 0.0138 - output_variable2_loss: 0.0032 - val_loss: 0.0690 - val_output_variable1_loss: 0.0615 - val_output_variable2_loss: 0.0076
# Epoch 30/100
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0160 - output_variable1_loss: 0.0128 - output_variable2_loss: 0.0032 - val_loss: 0.0588 - val_output_variable1_loss: 0.0518 - val_output_variable2_loss: 0.0070
# Epoch 31/100
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0157 - output_variable1_loss: 0.0125 - output_variable2_loss: 0.0032 - val_loss: 0.0613 - val_output_variable1_loss: 0.0555 - val_output_variable2_loss: 0.0058
# Epoch 32/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0138 - output_variable1_loss: 0.0108 - output_variable2_loss: 0.0029 - val_loss: 0.0576 - val_output_variable1_loss: 0.0513 - val_output_variable2_loss: 0.0063
# Epoch 33/100
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0132 - output_variable1_loss: 0.0103 - output_variable2_loss: 0.0030 - val_loss: 0.0657 - val_output_variable1_loss: 0.0601 - val_output_variable2_loss: 0.0056
# Epoch 34/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0125 - output_variable1_loss: 0.0096 - output_variable2_loss: 0.0029 - val_loss: 0.0626 - val_output_variable1_loss: 0.0574 - val_output_variable2_loss: 0.0052
# Epoch 35/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0118 - output_variable1_loss: 0.0089 - output_variable2_loss: 0.0029 - val_loss: 0.0599 - val_output_variable1_loss: 0.0546 - val_output_variable2_loss: 0.0053
# Epoch 36/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0112 - output_variable1_loss: 0.0085 - output_variable2_loss: 0.0027 - val_loss: 0.0745 - val_output_variable1_loss: 0.0691 - val_output_variable2_loss: 0.0053
# Epoch 37/100
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0112 - output_variable1_loss: 0.0083 - output_variable2_loss: 0.0029 - val_loss: 0.0752 - val_output_variable1_loss: 0.0700 - val_output_variable2_loss: 0.0052
# Epoch 38/100
# 13/13 [==============================] - 1s 58ms/step - loss: 0.0109 - output_variable1_loss: 0.0082 - output_variable2_loss: 0.0027 - val_loss: 0.0727 - val_output_variable1_loss: 0.0673 - val_output_variable2_loss: 0.0054
# Epoch 39/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0106 - output_variable1_loss: 0.0077 - output_variable2_loss: 0.0028 - val_loss: 0.0793 - val_output_variable1_loss: 0.0738 - val_output_variable2_loss: 0.0055
# Epoch 40/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0098 - output_variable1_loss: 0.0073 - output_variable2_loss: 0.0025 - val_loss: 0.0800 - val_output_variable1_loss: 0.0749 - val_output_variable2_loss: 0.0051
# Epoch 41/100
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0100 - output_variable1_loss: 0.0073 - output_variable2_loss: 0.0026 - val_loss: 0.0805 - val_output_variable1_loss: 0.0753 - val_output_variable2_loss: 0.0052
# Epoch 42/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0101 - output_variable1_loss: 0.0074 - output_variable2_loss: 0.0027 - val_loss: 0.0811 - val_output_variable1_loss: 0.0761 - val_output_variable2_loss: 0.0050
# Epoch 43/100
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0093 - output_variable1_loss: 0.0069 - output_variable2_loss: 0.0025 - val_loss: 0.0746 - val_output_variable1_loss: 0.0694 - val_output_variable2_loss: 0.0052
# Epoch 44/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0094 - output_variable1_loss: 0.0069 - output_variable2_loss: 0.0025 - val_loss: 0.0706 - val_output_variable1_loss: 0.0656 - val_output_variable2_loss: 0.0050
# Epoch 45/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0094 - output_variable1_loss: 0.0069 - output_variable2_loss: 0.0025 - val_loss: 0.0791 - val_output_variable1_loss: 0.0746 - val_output_variable2_loss: 0.0045
# Epoch 46/100
# 13/13 [==============================] - 1s 58ms/step - loss: 0.0087 - output_variable1_loss: 0.0064 - output_variable2_loss: 0.0023 - val_loss: 0.0831 - val_output_variable1_loss: 0.0785 - val_output_variable2_loss: 0.0045
# Epoch 47/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0086 - output_variable1_loss: 0.0063 - output_variable2_loss: 0.0022 - val_loss: 0.0775 - val_output_variable1_loss: 0.0725 - val_output_variable2_loss: 0.0051
# Epoch 48/100
# 13/13 [==============================] - 1s 58ms/step - loss: 0.0086 - output_variable1_loss: 0.0062 - output_variable2_loss: 0.0025 - val_loss: 0.0749 - val_output_variable1_loss: 0.0702 - val_output_variable2_loss: 0.0048
# Epoch 49/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0087 - output_variable1_loss: 0.0063 - output_variable2_loss: 0.0024 - val_loss: 0.0661 - val_output_variable1_loss: 0.0609 - val_output_variable2_loss: 0.0052
# Epoch 50/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0094 - output_variable1_loss: 0.0071 - output_variable2_loss: 0.0023 - val_loss: 0.0728 - val_output_variable1_loss: 0.0680 - val_output_variable2_loss: 0.0049
# Epoch 51/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0100 - output_variable1_loss: 0.0078 - output_variable2_loss: 0.0022 - val_loss: 0.0778 - val_output_variable1_loss: 0.0733 - val_output_variable2_loss: 0.0044
# Epoch 52/100
# 13/13 [==============================] - 1s 67ms/step - loss: 0.0090 - output_variable1_loss: 0.0068 - output_variable2_loss: 0.0021 - val_loss: 0.0793 - val_output_variable1_loss: 0.0741 - val_output_variable2_loss: 0.0051
# Epoch 53/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0083 - output_variable1_loss: 0.0059 - output_variable2_loss: 0.0024 - val_loss: 0.0849 - val_output_variable1_loss: 0.0772 - val_output_variable2_loss: 0.0077
# Epoch 54/100
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0085 - output_variable1_loss: 0.0057 - output_variable2_loss: 0.0028 - val_loss: 0.0766 - val_output_variable1_loss: 0.0701 - val_output_variable2_loss: 0.0065
# Epoch 55/100
# 13/13 [==============================] - 1s 58ms/step - loss: 0.0081 - output_variable1_loss: 0.0058 - output_variable2_loss: 0.0023 - val_loss: 0.0906 - val_output_variable1_loss: 0.0846 - val_output_variable2_loss: 0.0059
# Epoch 56/100
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0079 - output_variable1_loss: 0.0056 - output_variable2_loss: 0.0023 - val_loss: 0.0813 - val_output_variable1_loss: 0.0773 - val_output_variable2_loss: 0.0040
# Epoch 57/100
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0075 - output_variable1_loss: 0.0053 - output_variable2_loss: 0.0022 - val_loss: 0.0794 - val_output_variable1_loss: 0.0750 - val_output_variable2_loss: 0.0045
# Epoch 58/100
# 13/13 [==============================] - 1s 60ms/step - loss: 0.0075 - output_variable1_loss: 0.0054 - output_variable2_loss: 0.0021 - val_loss: 0.0811 - val_output_variable1_loss: 0.0760 - val_output_variable2_loss: 0.0051
# Epoch 59/100
# 13/13 [==============================] - 1s 61ms/step - loss: 0.0073 - output_variable1_loss: 0.0052 - output_variable2_loss: 0.0021 - val_loss: 0.0778 - val_output_variable1_loss: 0.0735 - val_output_variable2_loss: 0.0043
# Epoch 60/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0074 - output_variable1_loss: 0.0053 - output_variable2_loss: 0.0021 - val_loss: 0.0762 - val_output_variable1_loss: 0.0715 - val_output_variable2_loss: 0.0046
# Epoch 61/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0070 - output_variable1_loss: 0.0050 - output_variable2_loss: 0.0020 - val_loss: 0.0784 - val_output_variable1_loss: 0.0735 - val_output_variable2_loss: 0.0049
# Epoch 62/100
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0069 - output_variable1_loss: 0.0048 - output_variable2_loss: 0.0021 - val_loss: 0.0853 - val_output_variable1_loss: 0.0808 - val_output_variable2_loss: 0.0045
# Epoch 63/100
# 13/13 [==============================] - 1s 62ms/step - loss: 0.0069 - output_variable1_loss: 0.0048 - output_variable2_loss: 0.0021 - val_loss: 0.0804 - val_output_variable1_loss: 0.0759 - val_output_variable2_loss: 0.0045
# Epoch 64/100
# 13/13 [==============================] - 1s 63ms/step - loss: 0.0067 - output_variable1_loss: 0.0049 - output_variable2_loss: 0.0018 - val_loss: 0.0778 - val_output_variable1_loss: 0.0731 - val_output_variable2_loss: 0.0046
# Epoch 65/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0067 - output_variable1_loss: 0.0049 - output_variable2_loss: 0.0018 - val_loss: 0.0777 - val_output_variable1_loss: 0.0734 - val_output_variable2_loss: 0.0043
# Epoch 66/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0064 - output_variable1_loss: 0.0046 - output_variable2_loss: 0.0018 - val_loss: 0.0812 - val_output_variable1_loss: 0.0767 - val_output_variable2_loss: 0.0045
# Epoch 67/100
# 13/13 [==============================] - 1s 60ms/step - loss: 0.0062 - output_variable1_loss: 0.0044 - output_variable2_loss: 0.0018 - val_loss: 0.0794 - val_output_variable1_loss: 0.0749 - val_output_variable2_loss: 0.0046
# Epoch 68/100
# 13/13 [==============================] - 1s 65ms/step - loss: 0.0063 - output_variable1_loss: 0.0044 - output_variable2_loss: 0.0018 - val_loss: 0.0816 - val_output_variable1_loss: 0.0765 - val_output_variable2_loss: 0.0050
# Epoch 69/100
# 13/13 [==============================] - 1s 63ms/step - loss: 0.0063 - output_variable1_loss: 0.0044 - output_variable2_loss: 0.0019 - val_loss: 0.0766 - val_output_variable1_loss: 0.0712 - val_output_variable2_loss: 0.0054
# Epoch 70/100
# 13/13 [==============================] - 1s 63ms/step - loss: 0.0062 - output_variable1_loss: 0.0044 - output_variable2_loss: 0.0019 - val_loss: 0.0783 - val_output_variable1_loss: 0.0740 - val_output_variable2_loss: 0.0043
# Epoch 71/100
# 13/13 [==============================] - 1s 60ms/step - loss: 0.0061 - output_variable1_loss: 0.0043 - output_variable2_loss: 0.0018 - val_loss: 0.0805 - val_output_variable1_loss: 0.0762 - val_output_variable2_loss: 0.0042
# Epoch 72/100
# 13/13 [==============================] - 1s 60ms/step - loss: 0.0059 - output_variable1_loss: 0.0042 - output_variable2_loss: 0.0017 - val_loss: 0.0808 - val_output_variable1_loss: 0.0759 - val_output_variable2_loss: 0.0049
# Epoch 73/100
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0059 - output_variable1_loss: 0.0042 - output_variable2_loss: 0.0017 - val_loss: 0.0785 - val_output_variable1_loss: 0.0739 - val_output_variable2_loss: 0.0047
# Epoch 74/100
# 13/13 [==============================] - 1s 63ms/step - loss: 0.0056 - output_variable1_loss: 0.0040 - output_variable2_loss: 0.0017 - val_loss: 0.0784 - val_output_variable1_loss: 0.0747 - val_output_variable2_loss: 0.0038
# Epoch 75/100
# 13/13 [==============================] - 1s 70ms/step - loss: 0.0058 - output_variable1_loss: 0.0040 - output_variable2_loss: 0.0017 - val_loss: 0.0788 - val_output_variable1_loss: 0.0746 - val_output_variable2_loss: 0.0041
# Epoch 76/100
# 13/13 [==============================] - 1s 63ms/step - loss: 0.0058 - output_variable1_loss: 0.0040 - output_variable2_loss: 0.0017 - val_loss: 0.0774 - val_output_variable1_loss: 0.0730 - val_output_variable2_loss: 0.0045
# Epoch 77/100
# 13/13 [==============================] - 1s 65ms/step - loss: 0.0058 - output_variable1_loss: 0.0039 - output_variable2_loss: 0.0019 - val_loss: 0.0799 - val_output_variable1_loss: 0.0757 - val_output_variable2_loss: 0.0042
# Epoch 78/100
# 13/13 [==============================] - 1s 63ms/step - loss: 0.0056 - output_variable1_loss: 0.0038 - output_variable2_loss: 0.0018 - val_loss: 0.0815 - val_output_variable1_loss: 0.0775 - val_output_variable2_loss: 0.0041
# Epoch 79/100
# 13/13 [==============================] - 1s 58ms/step - loss: 0.0055 - output_variable1_loss: 0.0037 - output_variable2_loss: 0.0017 - val_loss: 0.0787 - val_output_variable1_loss: 0.0748 - val_output_variable2_loss: 0.0039
# Epoch 80/100
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0053 - output_variable1_loss: 0.0036 - output_variable2_loss: 0.0016 - val_loss: 0.0750 - val_output_variable1_loss: 0.0709 - val_output_variable2_loss: 0.0041
# Epoch 81/100
# 13/13 [==============================] - 1s 60ms/step - loss: 0.0053 - output_variable1_loss: 0.0037 - output_variable2_loss: 0.0016 - val_loss: 0.0756 - val_output_variable1_loss: 0.0713 - val_output_variable2_loss: 0.0043
# Epoch 82/100
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0055 - output_variable1_loss: 0.0039 - output_variable2_loss: 0.0016 - val_loss: 0.0806 - val_output_variable1_loss: 0.0758 - val_output_variable2_loss: 0.0049
# Epoch 83/100
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0053 - output_variable1_loss: 0.0037 - output_variable2_loss: 0.0016 - val_loss: 0.0779 - val_output_variable1_loss: 0.0737 - val_output_variable2_loss: 0.0042
# Epoch 84/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0051 - output_variable1_loss: 0.0036 - output_variable2_loss: 0.0015 - val_loss: 0.0821 - val_output_variable1_loss: 0.0776 - val_output_variable2_loss: 0.0045
# Epoch 85/100
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0050 - output_variable1_loss: 0.0035 - output_variable2_loss: 0.0015 - val_loss: 0.0814 - val_output_variable1_loss: 0.0771 - val_output_variable2_loss: 0.0043
# Epoch 86/100
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0051 - output_variable1_loss: 0.0034 - output_variable2_loss: 0.0016 - val_loss: 0.0790 - val_output_variable1_loss: 0.0745 - val_output_variable2_loss: 0.0044
# Epoch 87/100
# 13/13 [==============================] - 1s 58ms/step - loss: 0.0051 - output_variable1_loss: 0.0034 - output_variable2_loss: 0.0017 - val_loss: 0.0809 - val_output_variable1_loss: 0.0772 - val_output_variable2_loss: 0.0037
# Epoch 88/100
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0053 - output_variable1_loss: 0.0035 - output_variable2_loss: 0.0018 - val_loss: 0.0797 - val_output_variable1_loss: 0.0751 - val_output_variable2_loss: 0.0046
# Epoch 89/100
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0050 - output_variable1_loss: 0.0035 - output_variable2_loss: 0.0015 - val_loss: 0.0814 - val_output_variable1_loss: 0.0772 - val_output_variable2_loss: 0.0042
# Epoch 90/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0050 - output_variable1_loss: 0.0035 - output_variable2_loss: 0.0014 - val_loss: 0.0671 - val_output_variable1_loss: 0.0629 - val_output_variable2_loss: 0.0042
# Epoch 91/100
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0050 - output_variable1_loss: 0.0035 - output_variable2_loss: 0.0015 - val_loss: 0.0839 - val_output_variable1_loss: 0.0790 - val_output_variable2_loss: 0.0049
# Epoch 92/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0049 - output_variable1_loss: 0.0034 - output_variable2_loss: 0.0015 - val_loss: 0.0750 - val_output_variable1_loss: 0.0706 - val_output_variable2_loss: 0.0044
# Epoch 93/100
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0047 - output_variable1_loss: 0.0033 - output_variable2_loss: 0.0014 - val_loss: 0.0774 - val_output_variable1_loss: 0.0733 - val_output_variable2_loss: 0.0041
# Epoch 94/100
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0047 - output_variable1_loss: 0.0033 - output_variable2_loss: 0.0014 - val_loss: 0.0726 - val_output_variable1_loss: 0.0683 - val_output_variable2_loss: 0.0043
# Epoch 95/100
# 13/13 [==============================] - 1s 58ms/step - loss: 0.0047 - output_variable1_loss: 0.0033 - output_variable2_loss: 0.0014 - val_loss: 0.0737 - val_output_variable1_loss: 0.0692 - val_output_variable2_loss: 0.0045
# Epoch 96/100
# 13/13 [==============================] - 1s 59ms/step - loss: 0.0046 - output_variable1_loss: 0.0031 - output_variable2_loss: 0.0014 - val_loss: 0.0748 - val_output_variable1_loss: 0.0706 - val_output_variable2_loss: 0.0042
# Epoch 97/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0046 - output_variable1_loss: 0.0032 - output_variable2_loss: 0.0014 - val_loss: 0.0703 - val_output_variable1_loss: 0.0661 - val_output_variable2_loss: 0.0042
# Epoch 98/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0050 - output_variable1_loss: 0.0036 - output_variable2_loss: 0.0013 - val_loss: 0.0674 - val_output_variable1_loss: 0.0632 - val_output_variable2_loss: 0.0041
# Epoch 99/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0048 - output_variable1_loss: 0.0034 - output_variable2_loss: 0.0014 - val_loss: 0.0789 - val_output_variable1_loss: 0.0744 - val_output_variable2_loss: 0.0045
# Epoch 100/100
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0045 - output_variable1_loss: 0.0031 - output_variable2_loss: 0.0014 - val_loss: 0.0741 - val_output_variable1_loss: 0.0699 - val_output_variable2_loss: 0.0042
# Epoch 1/100
# 14/14 [==============================] - 1s 62ms/step - loss: 0.0077 - output_variable1_loss: 0.0062 - output_variable2_loss: 0.0015 - val_loss: 0.0381 - val_output_variable1_loss: 0.0313 - val_output_variable2_loss: 0.0068
# Epoch 2/100
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0072 - output_variable1_loss: 0.0057 - output_variable2_loss: 0.0015 - val_loss: 0.0320 - val_output_variable1_loss: 0.0245 - val_output_variable2_loss: 0.0074
# Epoch 3/100
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0061 - output_variable1_loss: 0.0047 - output_variable2_loss: 0.0015 - val_loss: 0.0442 - val_output_variable1_loss: 0.0348 - val_output_variable2_loss: 0.0094
# Epoch 4/100
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0059 - output_variable1_loss: 0.0045 - output_variable2_loss: 0.0014 - val_loss: 0.0360 - val_output_variable1_loss: 0.0289 - val_output_variable2_loss: 0.0071
# Epoch 5/100
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0050 - output_variable1_loss: 0.0036 - output_variable2_loss: 0.0014 - val_loss: 0.0408 - val_output_variable1_loss: 0.0320 - val_output_variable2_loss: 0.0088
# Epoch 6/100
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0049 - output_variable1_loss: 0.0035 - output_variable2_loss: 0.0014 - val_loss: 0.0434 - val_output_variable1_loss: 0.0372 - val_output_variable2_loss: 0.0062
# Epoch 7/100
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0058 - output_variable1_loss: 0.0043 - output_variable2_loss: 0.0015 - val_loss: 0.0563 - val_output_variable1_loss: 0.0473 - val_output_variable2_loss: 0.0090
# Epoch 8/100
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0062 - output_variable1_loss: 0.0049 - output_variable2_loss: 0.0014 - val_loss: 0.0376 - val_output_variable1_loss: 0.0314 - val_output_variable2_loss: 0.0062
# Epoch 9/100
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0059 - output_variable1_loss: 0.0044 - output_variable2_loss: 0.0014 - val_loss: 0.0396 - val_output_variable1_loss: 0.0311 - val_output_variable2_loss: 0.0085
# Epoch 10/100
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0048 - output_variable1_loss: 0.0034 - output_variable2_loss: 0.0014 - val_loss: 0.0427 - val_output_variable1_loss: 0.0333 - val_output_variable2_loss: 0.0093
# Epoch 11/100
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0044 - output_variable1_loss: 0.0030 - output_variable2_loss: 0.0013 - val_loss: 0.0417 - val_output_variable1_loss: 0.0352 - val_output_variable2_loss: 0.0065
# Epoch 12/100
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0043 - output_variable1_loss: 0.0030 - output_variable2_loss: 0.0013 - val_loss: 0.0389 - val_output_variable1_loss: 0.0308 - val_output_variable2_loss: 0.0081
# Epoch 13/100
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0041 - output_variable1_loss: 0.0028 - output_variable2_loss: 0.0013 - val_loss: 0.0452 - val_output_variable1_loss: 0.0386 - val_output_variable2_loss: 0.0066
# Epoch 14/100
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0040 - output_variable1_loss: 0.0027 - output_variable2_loss: 0.0013 - val_loss: 0.0417 - val_output_variable1_loss: 0.0325 - val_output_variable2_loss: 0.0092
# Epoch 15/100
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0040 - output_variable1_loss: 0.0027 - output_variable2_loss: 0.0013 - val_loss: 0.0396 - val_output_variable1_loss: 0.0332 - val_output_variable2_loss: 0.0063
# Epoch 16/100
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0039 - output_variable1_loss: 0.0026 - output_variable2_loss: 0.0013 - val_loss: 0.0485 - val_output_variable1_loss: 0.0380 - val_output_variable2_loss: 0.0105
# Epoch 17/100
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0038 - output_variable1_loss: 0.0026 - output_variable2_loss: 0.0013 - val_loss: 0.0447 - val_output_variable1_loss: 0.0371 - val_output_variable2_loss: 0.0076
# Epoch 18/100
# 14/14 [==============================] - 1s 57ms/step - loss: 0.0038 - output_variable1_loss: 0.0026 - output_variable2_loss: 0.0012 - val_loss: 0.0456 - val_output_variable1_loss: 0.0360 - val_output_variable2_loss: 0.0095
# Epoch 19/100
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0039 - output_variable1_loss: 0.0027 - output_variable2_loss: 0.0012 - val_loss: 0.0441 - val_output_variable1_loss: 0.0352 - val_output_variable2_loss: 0.0088
# Epoch 20/100
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0038 - output_variable1_loss: 0.0026 - output_variable2_loss: 0.0012 - val_loss: 0.0431 - val_output_variable1_loss: 0.0345 - val_output_variable2_loss: 0.0085
# Epoch 21/100
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0038 - output_variable1_loss: 0.0026 - output_variable2_loss: 0.0012 - val_loss: 0.0413 - val_output_variable1_loss: 0.0342 - val_output_variable2_loss: 0.0071
# Epoch 22/100
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0037 - output_variable1_loss: 0.0025 - output_variable2_loss: 0.0012 - val_loss: 0.0463 - val_output_variable1_loss: 0.0365 - val_output_variable2_loss: 0.0098
# Epoch 23/100
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0036 - output_variable1_loss: 0.0024 - output_variable2_loss: 0.0012 - val_loss: 0.0458 - val_output_variable1_loss: 0.0363 - val_output_variable2_loss: 0.0095
# Epoch 24/100
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0036 - output_variable1_loss: 0.0024 - output_variable2_loss: 0.0011 - val_loss: 0.0450 - val_output_variable1_loss: 0.0363 - val_output_variable2_loss: 0.0087
# Epoch 25/100
# 14/14 [==============================] - 1s 52ms/step - loss: 0.0036 - output_variable1_loss: 0.0024 - output_variable2_loss: 0.0012 - val_loss: 0.0474 - val_output_variable1_loss: 0.0398 - val_output_variable2_loss: 0.0076
# Epoch 26/100
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0039 - output_variable1_loss: 0.0024 - output_variable2_loss: 0.0015 - val_loss: 0.0447 - val_output_variable1_loss: 0.0359 - val_output_variable2_loss: 0.0088
# Epoch 27/100
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0038 - output_variable1_loss: 0.0024 - output_variable2_loss: 0.0014 - val_loss: 0.0495 - val_output_variable1_loss: 0.0418 - val_output_variable2_loss: 0.0077
# Epoch 28/100
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0036 - output_variable1_loss: 0.0023 - output_variable2_loss: 0.0013 - val_loss: 0.0463 - val_output_variable1_loss: 0.0393 - val_output_variable2_loss: 0.0071
# Epoch 29/100
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0035 - output_variable1_loss: 0.0023 - output_variable2_loss: 0.0012 - val_loss: 0.0481 - val_output_variable1_loss: 0.0379 - val_output_variable2_loss: 0.0103
# Epoch 30/100
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0037 - output_variable1_loss: 0.0024 - output_variable2_loss: 0.0013 - val_loss: 0.0429 - val_output_variable1_loss: 0.0344 - val_output_variable2_loss: 0.0085
# Epoch 31/100
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0036 - output_variable1_loss: 0.0024 - output_variable2_loss: 0.0011 - val_loss: 0.0449 - val_output_variable1_loss: 0.0359 - val_output_variable2_loss: 0.0090
# Epoch 32/100
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0035 - output_variable1_loss: 0.0024 - output_variable2_loss: 0.0011 - val_loss: 0.0468 - val_output_variable1_loss: 0.0380 - val_output_variable2_loss: 0.0087
# Epoch 33/100
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0037 - output_variable1_loss: 0.0024 - output_variable2_loss: 0.0013 - val_loss: 0.0514 - val_output_variable1_loss: 0.0411 - val_output_variable2_loss: 0.0103
# Epoch 34/100
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0035 - output_variable1_loss: 0.0022 - output_variable2_loss: 0.0013 - val_loss: 0.0516 - val_output_variable1_loss: 0.0413 - val_output_variable2_loss: 0.0103
# Epoch 35/100
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0033 - output_variable1_loss: 0.0022 - output_variable2_loss: 0.0011 - val_loss: 0.0459 - val_output_variable1_loss: 0.0362 - val_output_variable2_loss: 0.0097
# Epoch 36/100
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0033 - output_variable1_loss: 0.0023 - output_variable2_loss: 0.0011 - val_loss: 0.0487 - val_output_variable1_loss: 0.0396 - val_output_variable2_loss: 0.0091
# Epoch 37/100
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0034 - output_variable1_loss: 0.0023 - output_variable2_loss: 0.0011 - val_loss: 0.0486 - val_output_variable1_loss: 0.0405 - val_output_variable2_loss: 0.0081
# Epoch 38/100
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0034 - output_variable1_loss: 0.0023 - output_variable2_loss: 0.0011 - val_loss: 0.0535 - val_output_variable1_loss: 0.0451 - val_output_variable2_loss: 0.0084
# Epoch 39/100
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0033 - output_variable1_loss: 0.0023 - output_variable2_loss: 0.0011 - val_loss: 0.0520 - val_output_variable1_loss: 0.0442 - val_output_variable2_loss: 0.0078
# Epoch 40/100
# 14/14 [==============================] - 1s 59ms/step - loss: 0.0033 - output_variable1_loss: 0.0022 - output_variable2_loss: 0.0011 - val_loss: 0.0483 - val_output_variable1_loss: 0.0399 - val_output_variable2_loss: 0.0083
# Epoch 41/100
# 14/14 [==============================] - 1s 52ms/step - loss: 0.0033 - output_variable1_loss: 0.0022 - output_variable2_loss: 0.0011 - val_loss: 0.0499 - val_output_variable1_loss: 0.0400 - val_output_variable2_loss: 0.0099
# Epoch 42/100
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0032 - output_variable1_loss: 0.0021 - output_variable2_loss: 0.0011 - val_loss: 0.0464 - val_output_variable1_loss: 0.0380 - val_output_variable2_loss: 0.0084
# Epoch 43/100
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0032 - output_variable1_loss: 0.0021 - output_variable2_loss: 0.0011 - val_loss: 0.0471 - val_output_variable1_loss: 0.0385 - val_output_variable2_loss: 0.0087
# Epoch 44/100
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0032 - output_variable1_loss: 0.0022 - output_variable2_loss: 0.0010 - val_loss: 0.0520 - val_output_variable1_loss: 0.0415 - val_output_variable2_loss: 0.0105
# Epoch 45/100
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0033 - output_variable1_loss: 0.0022 - output_variable2_loss: 0.0010 - val_loss: 0.0468 - val_output_variable1_loss: 0.0368 - val_output_variable2_loss: 0.0101
# Epoch 46/100
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0033 - output_variable1_loss: 0.0022 - output_variable2_loss: 0.0011 - val_loss: 0.0442 - val_output_variable1_loss: 0.0363 - val_output_variable2_loss: 0.0079
# Epoch 47/100
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0030 - output_variable1_loss: 0.0020 - output_variable2_loss: 0.0010 - val_loss: 0.0476 - val_output_variable1_loss: 0.0367 - val_output_variable2_loss: 0.0109
# Epoch 48/100
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0030 - output_variable1_loss: 0.0020 - output_variable2_loss: 0.0010 - val_loss: 0.0465 - val_output_variable1_loss: 0.0385 - val_output_variable2_loss: 0.0080
# Epoch 49/100
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0031 - output_variable1_loss: 0.0021 - output_variable2_loss: 0.0010 - val_loss: 0.0527 - val_output_variable1_loss: 0.0444 - val_output_variable2_loss: 0.0083
# Epoch 50/100
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0037 - output_variable1_loss: 0.0026 - output_variable2_loss: 0.0011 - val_loss: 0.0404 - val_output_variable1_loss: 0.0317 - val_output_variable2_loss: 0.0087
# Epoch 51/100
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0035 - output_variable1_loss: 0.0024 - output_variable2_loss: 0.0010 - val_loss: 0.0429 - val_output_variable1_loss: 0.0342 - val_output_variable2_loss: 0.0087
# Epoch 52/100
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0036 - output_variable1_loss: 0.0025 - output_variable2_loss: 0.0010 - val_loss: 0.0426 - val_output_variable1_loss: 0.0342 - val_output_variable2_loss: 0.0084
# Epoch 53/100
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0033 - output_variable1_loss: 0.0023 - output_variable2_loss: 0.0010 - val_loss: 0.0478 - val_output_variable1_loss: 0.0390 - val_output_variable2_loss: 0.0088
# Epoch 54/100
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0031 - output_variable1_loss: 0.0021 - output_variable2_loss: 0.0010 - val_loss: 0.0453 - val_output_variable1_loss: 0.0371 - val_output_variable2_loss: 0.0082
# Epoch 55/100
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0030 - output_variable1_loss: 0.0021 - output_variable2_loss: 9.3104e-04 - val_loss: 0.0451 - val_output_variable1_loss: 0.0363 - val_output_variable2_loss: 0.0088
# Epoch 1/100
# 15/15 [==============================] - 1s 58ms/step - loss: 0.0052 - output_variable1_loss: 0.0038 - output_variable2_loss: 0.0014 - val_loss: 0.0172 - val_output_variable1_loss: 0.0128 - val_output_variable2_loss: 0.0044
# Epoch 2/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0050 - output_variable1_loss: 0.0034 - output_variable2_loss: 0.0016 - val_loss: 0.0168 - val_output_variable1_loss: 0.0144 - val_output_variable2_loss: 0.0024
# Epoch 3/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0047 - output_variable1_loss: 0.0029 - output_variable2_loss: 0.0017 - val_loss: 0.0153 - val_output_variable1_loss: 0.0119 - val_output_variable2_loss: 0.0034
# Epoch 4/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0042 - output_variable1_loss: 0.0029 - output_variable2_loss: 0.0013 - val_loss: 0.0154 - val_output_variable1_loss: 0.0123 - val_output_variable2_loss: 0.0031
# Epoch 5/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0190 - output_variable1_loss: 0.0176 - output_variable2_loss: 0.0014 - val_loss: 0.0128 - val_output_variable1_loss: 0.0108 - val_output_variable2_loss: 0.0020
# Epoch 6/100
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0137 - output_variable1_loss: 0.0125 - output_variable2_loss: 0.0012 - val_loss: 0.0098 - val_output_variable1_loss: 0.0073 - val_output_variable2_loss: 0.0024
# Epoch 7/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0102 - output_variable1_loss: 0.0090 - output_variable2_loss: 0.0011 - val_loss: 0.0122 - val_output_variable1_loss: 0.0103 - val_output_variable2_loss: 0.0019
# Epoch 8/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0069 - output_variable1_loss: 0.0058 - output_variable2_loss: 0.0011 - val_loss: 0.0097 - val_output_variable1_loss: 0.0070 - val_output_variable2_loss: 0.0027
# Epoch 9/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0060 - output_variable1_loss: 0.0050 - output_variable2_loss: 0.0011 - val_loss: 0.0113 - val_output_variable1_loss: 0.0088 - val_output_variable2_loss: 0.0025
# Epoch 10/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0050 - output_variable1_loss: 0.0040 - output_variable2_loss: 9.6897e-04 - val_loss: 0.0096 - val_output_variable1_loss: 0.0073 - val_output_variable2_loss: 0.0023
# Epoch 11/100
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0048 - output_variable1_loss: 0.0038 - output_variable2_loss: 9.5939e-04 - val_loss: 0.0092 - val_output_variable1_loss: 0.0072 - val_output_variable2_loss: 0.0020
# Epoch 1/100
# 16/16 [==============================] - 1s 58ms/step - loss: 0.0046 - output_variable1_loss: 0.0036 - output_variable2_loss: 0.0010 - val_loss: 0.0382 - val_output_variable1_loss: 0.0346 - val_output_variable2_loss: 0.0035
# Epoch 2/100
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0048 - output_variable1_loss: 0.0035 - output_variable2_loss: 0.0014 - val_loss: 0.0375 - val_output_variable1_loss: 0.0362 - val_output_variable2_loss: 0.0014
# Epoch 3/100
# 16/16 [==============================] - 1s 56ms/step - loss: 0.0048 - output_variable1_loss: 0.0034 - output_variable2_loss: 0.0013 - val_loss: 0.0380 - val_output_variable1_loss: 0.0360 - val_output_variable2_loss: 0.0020
# Epoch 4/100
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0046 - output_variable1_loss: 0.0031 - output_variable2_loss: 0.0015 - val_loss: 0.0438 - val_output_variable1_loss: 0.0398 - val_output_variable2_loss: 0.0040
# Epoch 5/100
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0083 - output_variable1_loss: 0.0058 - output_variable2_loss: 0.0025 - val_loss: 0.0415 - val_output_variable1_loss: 0.0389 - val_output_variable2_loss: 0.0026
# Epoch 6/100
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0074 - output_variable1_loss: 0.0053 - output_variable2_loss: 0.0021 - val_loss: 0.0378 - val_output_variable1_loss: 0.0352 - val_output_variable2_loss: 0.0026
# Epoch 7/100
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0052 - output_variable1_loss: 0.0037 - output_variable2_loss: 0.0015 - val_loss: 0.0331 - val_output_variable1_loss: 0.0312 - val_output_variable2_loss: 0.0019
# Epoch 8/100
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0049 - output_variable1_loss: 0.0032 - output_variable2_loss: 0.0017 - val_loss: 0.0477 - val_output_variable1_loss: 0.0446 - val_output_variable2_loss: 0.0031
# Epoch 9/100
# 16/16 [==============================] - 1s 60ms/step - loss: 0.0047 - output_variable1_loss: 0.0034 - output_variable2_loss: 0.0013 - val_loss: 0.0402 - val_output_variable1_loss: 0.0389 - val_output_variable2_loss: 0.0012
# Epoch 10/100
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0061 - output_variable1_loss: 0.0043 - output_variable2_loss: 0.0018 - val_loss: 0.0386 - val_output_variable1_loss: 0.0367 - val_output_variable2_loss: 0.0019
# Epoch 11/100
# 16/16 [==============================] - 1s 56ms/step - loss: 0.0088 - output_variable1_loss: 0.0070 - output_variable2_loss: 0.0018 - val_loss: 0.0264 - val_output_variable1_loss: 0.0219 - val_output_variable2_loss: 0.0046
# Training time = 150.28755855560303 seconds

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss_1):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss_1[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error 1", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss_2):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss_2[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error 2", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
# Evaluate the model on the test data
predictions_1 = []
predictions_2 = []
#print(len(eval_target_variables))

for i in range(len(Y_val)):
    current_batch = X_val[i].reshape((1, NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))
    curr_pred1, curr_pred2 = model.predict(current_batch)
    predictions_1.append(curr_pred1)
    predictions_2.append(curr_pred2)
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 48ms/step

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_1):
    ax = axs[i]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_val[i, :, 0], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_2):
    ax = axs[i]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_val[i, :, 1], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
rmse = 0
for i in range(len(predictions_1)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_1[i][0], Y_val[i, :, 0]))}')
    rmse += sqrt(mean_squared_error(predictions_1[i][0], Y_val[i, :, 0]))

rmse /= len(predictions_1)    
print(f"RMSE for {columns_to_predict[0]} = {rmse}")

rmse = 0
for i in range(len(predictions_2)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_2[i][0], Y_val[i, :, 1]))}')
    rmse += sqrt(mean_squared_error(predictions_2[i][0], Y_val[i, :, 1]))

rmse /= len(predictions_2)    
print(f"RMSE for {columns_to_predict[1]} = {rmse}")
# Out:
# RMSE for kg_CO2/kWh = 0.13728709894155594
# RMSE for Avg solar generation = 0.08074949949004488

# %%
# Evaluate the model on the test data
predictions_1_test = []
predictions_2_test = []
#print(len(eval_target_variables))

total_time = 0

for i in range(len(Y_test)):
    current_batch = X_test[i].reshape((1, NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))
    start = time.time()
    curr_pred1, curr_pred2 = model.predict(current_batch)
    end = time.time()
    total_time += end-start
    predictions_1_test.append(curr_pred1)
    predictions_2_test.append(curr_pred2)
    
print(f"Average prediction time is {total_time/len(Y_test)} seconds")
# Out:
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# Average prediction time is 0.11357223510742187 seconds

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_1_test):
    ax = axs[i]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_test[i, :, 0], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_2_test):
    ax = axs[i]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_test[i, :, 1], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
rmse = 0
for i in range(len(predictions_1_test)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_1[i][0], Y_val[i, :, 0]))}')
    rmse += sqrt(mean_squared_error(predictions_1_test[i][0], Y_test[i, :, 0]))

rmse /= len(predictions_1_test)    
print(f"RMSE for {columns_to_predict[0]} = {rmse}")

rmse = 0
for i in range(len(predictions_2_test)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_2[i][0], Y_val[i, :, 1]))}')
    rmse += sqrt(mean_squared_error(predictions_2_test[i][0], Y_test[i, :, 1]))

rmse /= len(predictions_2_test)    
print(f"RMSE for {columns_to_predict[1]} = {rmse}")
# Out:
# RMSE for kg_CO2/kWh = 0.13072675713506354
# RMSE for Avg solar generation = 0.04644692099613115

# %%
a = []
for column in predictions_1_test:
    a.append(column[0])
    
b = []
for column in predictions_2_test:
    b.append(column[0])

predictions1 = pd.DataFrame(a).T
predictions1.to_csv('../data/results/carbon_lstm.csv', index=False, header=False)
predictions2 = pd.DataFrame(b).T
predictions2.to_csv('../data/results/solar_lstm.csv', index=False, header=False)
