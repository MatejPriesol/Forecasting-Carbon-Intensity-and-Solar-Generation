# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
train = pd.read_csv("../data/schemas/warm_up/TrainSet.csv", sep=",")
validation = pd.read_csv("../data/schemas/warm_up/ValidationSet.csv", sep=",")
test = pd.read_csv("../data/schemas/warm_up/TestSet.csv", sep=",")

# %%
# Global variables

NUM_OF_TIMESTEPS_INPUT = 48
NUM_OF_TIMESTEPS_OUTPUT = 24

THRESHOLD = 0.35   # For feature selection

# %%
columns_to_predict = ["kg_CO2/kWh", "Avg solar generation"]

independent_variables = []

for column in train:
    if abs(train[column].corr(train[columns_to_predict[0]])) > THRESHOLD: #or abs(train[column].corr(train[columns_to_predict[1]])) > THRESHOLD:
        independent_variables.append(column)

independent_variables = [var for var in independent_variables if var not in columns_to_predict]
    
if "Index" in independent_variables:
    independent_variables.remove("Index")
if "Solar Generation (W/kW)_1" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_1")
if "Solar Generation (W/kW)_2" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_2")
if "Solar Generation (W/kW)_3" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_3")
    
print(independent_variables)
# Out:
# ['Hour_1', 'Day Type_1', 'Occupant Count (people)_1', 'Hour_2', 'Day Type_2', 'Hour_3', 'Day Type_3', 'Occupant Count (people)_3', 'Outdoor Drybulb Temperature (C)', 'Diffuse Solar Radiation (W/m2)', '12h Outdoor Drybulb Temperature (C)', '24h Outdoor Drybulb Temperature (C)', '12h Outdoor Relative Humidity (%)', '6h Direct Solar Radiation (W/m2)', '12h Direct Solar Radiation (W/m2)']

# %% [markdown]
# Prepare the data

# %%
# Split the X and Y for all sets

# Train set
X_train_default = train[independent_variables]
Y_train_default = train[columns_to_predict]

# Validation set, also include the data from train that was used only as output to get more datapoints
X_val_default = pd.concat([X_train_default.tail(NUM_OF_TIMESTEPS_OUTPUT), validation[independent_variables]], ignore_index=True)
Y_val_default = pd.concat([Y_train_default.tail(NUM_OF_TIMESTEPS_OUTPUT), validation[columns_to_predict]], ignore_index=True)

# Test set, also include the data from train that was used only as output to get more datapoints
X_test_default = pd.concat([X_val_default.tail(NUM_OF_TIMESTEPS_OUTPUT), test[independent_variables]], ignore_index=True)
Y_test_default = pd.concat([Y_val_default.tail(NUM_OF_TIMESTEPS_OUTPUT), test[columns_to_predict]], ignore_index=True)

NUM_OF_ROWS_TRAIN, NUM_OF_FEATURES = X_train_default.shape

print(X_train_default.shape)
print(X_val_default.shape)
print(X_test_default.shape)
# Out:
# (576, 15)
# (96, 15)
# (96, 15)

# %%
# Function to prepare the data into batches that will be passed into the model

def create_sequences(input_data, output_data, timesteps_input, timesteps_output):
    sequences, targets = [], []
    for i in range(len(input_data) - timesteps_input - timesteps_output + 1):
        seq = input_data[i:i + timesteps_input]
        target = output_data[i + timesteps_input: i + timesteps_input + timesteps_output]
        sequences.append(seq)
        targets.append(target)

    return np.array(sequences), np.array(targets)

# %%
X_train, Y_train = create_sequences(X_train_default, Y_train_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)
X_val, Y_val = create_sequences(X_val_default, Y_val_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)
X_test, Y_test = create_sequences(X_test_default, Y_test_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)

print(f"X_train = {X_train.shape}, Y_train = {Y_train.shape}\n"
      f"X_val = {X_val.shape}, Y_val = {Y_val.shape}\n"
      f"X_test = {X_test.shape}, Y_test = {Y_test.shape}")
# Out:
# X_train = (505, 48, 15), Y_train = (505, 24, 2)
# X_val = (25, 48, 15), Y_val = (25, 24, 2)
# X_test = (25, 48, 15), Y_test = (25, 24, 2)

# %%
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras import layers, models

tscv = TimeSeriesSplit(n_splits = 4, test_size=24) # For cross-validation

callback = keras.callbacks.EarlyStopping(monitor='loss', patience = 5) #patience parameter to be adjusted

loss = []
val_loss = []
loss_1 = []
val_loss_1 = []
loss_2 = []
val_loss_2 = []

# Input layer
input_layer = layers.Input(shape=(NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))

# Dense layers for variable 1
lstm1 = layers.LSTM(48, activation='leaky_relu', return_sequences=True)(input_layer)
lstm2 = layers.LSTM(48, activation='leaky_relu', return_sequences=True)(lstm1)
lstm3 = layers.LSTM(24, activation='leaky_relu', return_sequences=False)(lstm2)
output_variable1 = layers.Dense(24, name='output_variable1')(lstm3)

# Dense layers for variable 2
dense4 = layers.LSTM(48, activation='leaky_relu', return_sequences=True)(input_layer)
dense5 = layers.LSTM(48, activation='leaky_relu', return_sequences=True)(dense4)
dense6 = layers.LSTM(24, activation='leaky_relu', return_sequences=False)(dense5)
output_variable2 = layers.Dense(24, name='output_variable2')(dense6)

# Define the model
model = models.Model(inputs=input_layer, outputs=[output_variable1, output_variable2])

model.compile(
    optimizer='adam',
    loss={'output_variable1': 'mean_squared_error', 'output_variable2': 'mean_squared_error'}
) #types of optimizer, loss function to be adjusted
    
    
for train_data, test_data in tscv.split(X_train):
    X_train_current_split, X_test_current_split = X_train[train_data], X_train[test_data]
    y_train_current_split, y_test_current_split = Y_train[train_data], Y_train[test_data]
    
    history = model.fit(X_train_current_split, y={"output_variable1": y_train_current_split[:, :, 0], 
                                                  "output_variable2": y_train_current_split[:, :, 1]},
              epochs=200, 
              validation_data=(
                  X_test_current_split,
                {
                    "output_variable1": y_test_current_split[:, :, 0],
                    "output_variable2": y_test_current_split[:, :, 1],
                },
              ),
              # validation_split = 0.8,
              verbose=1,
              callbacks=callback
    )
    loss.append(model.history.history['loss'])
    val_loss.append(model.history.history['val_loss'])
    
    loss_1.append(model.history.history['output_variable1_loss'])
    val_loss_1.append(model.history.history['val_output_variable1_loss'])
    
    loss_2.append(model.history.history['output_variable2_loss'])
    val_loss_2.append(model.history.history['val_output_variable2_loss'])
# Out:
# Epoch 1/200
# 13/13 [==============================] - 7s 80ms/step - loss: 0.4716 - output_variable1_loss: 0.3018 - output_variable2_loss: 0.1698 - val_loss: 0.7425 - val_output_variable1_loss: 0.6430 - val_output_variable2_loss: 0.0996
# Epoch 2/200
# 13/13 [==============================] - 0s 28ms/step - loss: 0.3687 - output_variable1_loss: 0.2247 - output_variable2_loss: 0.1439 - val_loss: 0.5352 - val_output_variable1_loss: 0.4483 - val_output_variable2_loss: 0.0869
# Epoch 3/200
# 13/13 [==============================] - 0s 28ms/step - loss: 0.2700 - output_variable1_loss: 0.1497 - output_variable2_loss: 0.1203 - val_loss: 0.3171 - val_output_variable1_loss: 0.2412 - val_output_variable2_loss: 0.0759
# Epoch 4/200
# 13/13 [==============================] - 0s 29ms/step - loss: 0.1678 - output_variable1_loss: 0.0719 - output_variable2_loss: 0.0958 - val_loss: 0.2139 - val_output_variable1_loss: 0.1501 - val_output_variable2_loss: 0.0638
# Epoch 5/200
# 13/13 [==============================] - 0s 29ms/step - loss: 0.1202 - output_variable1_loss: 0.0421 - output_variable2_loss: 0.0781 - val_loss: 0.1200 - val_output_variable1_loss: 0.0654 - val_output_variable2_loss: 0.0546
# Epoch 6/200
# 13/13 [==============================] - 0s 28ms/step - loss: 0.1050 - output_variable1_loss: 0.0434 - output_variable2_loss: 0.0617 - val_loss: 0.1997 - val_output_variable1_loss: 0.1516 - val_output_variable2_loss: 0.0481
# Epoch 7/200
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0881 - output_variable1_loss: 0.0392 - output_variable2_loss: 0.0490 - val_loss: 0.1097 - val_output_variable1_loss: 0.0695 - val_output_variable2_loss: 0.0402
# Epoch 8/200
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0746 - output_variable1_loss: 0.0352 - output_variable2_loss: 0.0394 - val_loss: 0.1537 - val_output_variable1_loss: 0.1159 - val_output_variable2_loss: 0.0378
# Epoch 9/200
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0652 - output_variable1_loss: 0.0344 - output_variable2_loss: 0.0308 - val_loss: 0.1462 - val_output_variable1_loss: 0.1183 - val_output_variable2_loss: 0.0279
# Epoch 10/200
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0579 - output_variable1_loss: 0.0336 - output_variable2_loss: 0.0243 - val_loss: 0.1353 - val_output_variable1_loss: 0.1084 - val_output_variable2_loss: 0.0269
# Epoch 11/200
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0532 - output_variable1_loss: 0.0326 - output_variable2_loss: 0.0205 - val_loss: 0.1454 - val_output_variable1_loss: 0.1220 - val_output_variable2_loss: 0.0234
# Epoch 12/200
# 13/13 [==============================] - 0s 31ms/step - loss: 0.0493 - output_variable1_loss: 0.0321 - output_variable2_loss: 0.0173 - val_loss: 0.1290 - val_output_variable1_loss: 0.1079 - val_output_variable2_loss: 0.0211
# Epoch 13/200
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0464 - output_variable1_loss: 0.0317 - output_variable2_loss: 0.0147 - val_loss: 0.1267 - val_output_variable1_loss: 0.1087 - val_output_variable2_loss: 0.0180
# Epoch 14/200
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0439 - output_variable1_loss: 0.0308 - output_variable2_loss: 0.0132 - val_loss: 0.1236 - val_output_variable1_loss: 0.1074 - val_output_variable2_loss: 0.0161
# Epoch 15/200
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0412 - output_variable1_loss: 0.0293 - output_variable2_loss: 0.0119 - val_loss: 0.1142 - val_output_variable1_loss: 0.0994 - val_output_variable2_loss: 0.0148
# Epoch 16/200
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0397 - output_variable1_loss: 0.0286 - output_variable2_loss: 0.0111 - val_loss: 0.0828 - val_output_variable1_loss: 0.0666 - val_output_variable2_loss: 0.0162
# Epoch 17/200
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0367 - output_variable1_loss: 0.0269 - output_variable2_loss: 0.0098 - val_loss: 0.0917 - val_output_variable1_loss: 0.0786 - val_output_variable2_loss: 0.0131
# Epoch 18/200
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0339 - output_variable1_loss: 0.0251 - output_variable2_loss: 0.0088 - val_loss: 0.1059 - val_output_variable1_loss: 0.0939 - val_output_variable2_loss: 0.0120
# Epoch 19/200
# 13/13 [==============================] - 0s 37ms/step - loss: 0.0313 - output_variable1_loss: 0.0235 - output_variable2_loss: 0.0078 - val_loss: 0.1193 - val_output_variable1_loss: 0.1062 - val_output_variable2_loss: 0.0131
# Epoch 20/200
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0286 - output_variable1_loss: 0.0215 - output_variable2_loss: 0.0071 - val_loss: 0.0811 - val_output_variable1_loss: 0.0693 - val_output_variable2_loss: 0.0118
# Epoch 21/200
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0260 - output_variable1_loss: 0.0195 - output_variable2_loss: 0.0066 - val_loss: 0.0998 - val_output_variable1_loss: 0.0890 - val_output_variable2_loss: 0.0108
# Epoch 22/200
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0233 - output_variable1_loss: 0.0174 - output_variable2_loss: 0.0059 - val_loss: 0.1043 - val_output_variable1_loss: 0.0960 - val_output_variable2_loss: 0.0083
# Epoch 23/200
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0208 - output_variable1_loss: 0.0158 - output_variable2_loss: 0.0050 - val_loss: 0.0939 - val_output_variable1_loss: 0.0846 - val_output_variable2_loss: 0.0093
# Epoch 24/200
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0191 - output_variable1_loss: 0.0141 - output_variable2_loss: 0.0049 - val_loss: 0.0845 - val_output_variable1_loss: 0.0746 - val_output_variable2_loss: 0.0100
# Epoch 25/200
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0187 - output_variable1_loss: 0.0139 - output_variable2_loss: 0.0048 - val_loss: 0.0721 - val_output_variable1_loss: 0.0617 - val_output_variable2_loss: 0.0104
# Epoch 26/200
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0176 - output_variable1_loss: 0.0136 - output_variable2_loss: 0.0040 - val_loss: 0.0851 - val_output_variable1_loss: 0.0768 - val_output_variable2_loss: 0.0083
# Epoch 27/200
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0155 - output_variable1_loss: 0.0121 - output_variable2_loss: 0.0034 - val_loss: 0.0958 - val_output_variable1_loss: 0.0883 - val_output_variable2_loss: 0.0075
# Epoch 28/200
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0144 - output_variable1_loss: 0.0113 - output_variable2_loss: 0.0031 - val_loss: 0.0867 - val_output_variable1_loss: 0.0803 - val_output_variable2_loss: 0.0064
# Epoch 29/200
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0131 - output_variable1_loss: 0.0102 - output_variable2_loss: 0.0029 - val_loss: 0.0860 - val_output_variable1_loss: 0.0784 - val_output_variable2_loss: 0.0077
# Epoch 30/200
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0126 - output_variable1_loss: 0.0094 - output_variable2_loss: 0.0032 - val_loss: 0.0954 - val_output_variable1_loss: 0.0880 - val_output_variable2_loss: 0.0074
# Epoch 31/200
# 13/13 [==============================] - 0s 31ms/step - loss: 0.0133 - output_variable1_loss: 0.0100 - output_variable2_loss: 0.0032 - val_loss: 0.1089 - val_output_variable1_loss: 0.1026 - val_output_variable2_loss: 0.0063
# Epoch 32/200
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0119 - output_variable1_loss: 0.0089 - output_variable2_loss: 0.0030 - val_loss: 0.1039 - val_output_variable1_loss: 0.0954 - val_output_variable2_loss: 0.0085
# Epoch 33/200
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0107 - output_variable1_loss: 0.0080 - output_variable2_loss: 0.0027 - val_loss: 0.0987 - val_output_variable1_loss: 0.0920 - val_output_variable2_loss: 0.0068
# Epoch 34/200
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0104 - output_variable1_loss: 0.0077 - output_variable2_loss: 0.0027 - val_loss: 0.0990 - val_output_variable1_loss: 0.0917 - val_output_variable2_loss: 0.0073
# Epoch 35/200
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0101 - output_variable1_loss: 0.0075 - output_variable2_loss: 0.0026 - val_loss: 0.1033 - val_output_variable1_loss: 0.0951 - val_output_variable2_loss: 0.0082
# Epoch 36/200
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0096 - output_variable1_loss: 0.0071 - output_variable2_loss: 0.0025 - val_loss: 0.1285 - val_output_variable1_loss: 0.1209 - val_output_variable2_loss: 0.0076
# Epoch 37/200
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0091 - output_variable1_loss: 0.0067 - output_variable2_loss: 0.0024 - val_loss: 0.1155 - val_output_variable1_loss: 0.1088 - val_output_variable2_loss: 0.0067
# Epoch 38/200
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0090 - output_variable1_loss: 0.0066 - output_variable2_loss: 0.0024 - val_loss: 0.1033 - val_output_variable1_loss: 0.0958 - val_output_variable2_loss: 0.0075
# Epoch 39/200
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0088 - output_variable1_loss: 0.0065 - output_variable2_loss: 0.0023 - val_loss: 0.1407 - val_output_variable1_loss: 0.1341 - val_output_variable2_loss: 0.0067
# Epoch 40/200
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0083 - output_variable1_loss: 0.0062 - output_variable2_loss: 0.0022 - val_loss: 0.1119 - val_output_variable1_loss: 0.1037 - val_output_variable2_loss: 0.0082
# Epoch 41/200
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0085 - output_variable1_loss: 0.0063 - output_variable2_loss: 0.0022 - val_loss: 0.1163 - val_output_variable1_loss: 0.1095 - val_output_variable2_loss: 0.0068
# Epoch 42/200
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0081 - output_variable1_loss: 0.0060 - output_variable2_loss: 0.0021 - val_loss: 0.1091 - val_output_variable1_loss: 0.1011 - val_output_variable2_loss: 0.0080
# Epoch 43/200
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0085 - output_variable1_loss: 0.0064 - output_variable2_loss: 0.0020 - val_loss: 0.1122 - val_output_variable1_loss: 0.1056 - val_output_variable2_loss: 0.0066
# Epoch 44/200
# 13/13 [==============================] - 1s 40ms/step - loss: 0.0080 - output_variable1_loss: 0.0058 - output_variable2_loss: 0.0022 - val_loss: 0.0992 - val_output_variable1_loss: 0.0929 - val_output_variable2_loss: 0.0063
# Epoch 45/200
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0080 - output_variable1_loss: 0.0059 - output_variable2_loss: 0.0021 - val_loss: 0.1177 - val_output_variable1_loss: 0.1103 - val_output_variable2_loss: 0.0074
# Epoch 46/200
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0081 - output_variable1_loss: 0.0060 - output_variable2_loss: 0.0021 - val_loss: 0.1180 - val_output_variable1_loss: 0.1097 - val_output_variable2_loss: 0.0083
# Epoch 47/200
# 13/13 [==============================] - 0s 31ms/step - loss: 0.0076 - output_variable1_loss: 0.0056 - output_variable2_loss: 0.0020 - val_loss: 0.1368 - val_output_variable1_loss: 0.1291 - val_output_variable2_loss: 0.0078
# Epoch 48/200
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0074 - output_variable1_loss: 0.0053 - output_variable2_loss: 0.0021 - val_loss: 0.1190 - val_output_variable1_loss: 0.1126 - val_output_variable2_loss: 0.0064
# Epoch 49/200
# 13/13 [==============================] - 0s 31ms/step - loss: 0.0073 - output_variable1_loss: 0.0050 - output_variable2_loss: 0.0023 - val_loss: 0.1222 - val_output_variable1_loss: 0.1152 - val_output_variable2_loss: 0.0070
# Epoch 50/200
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0070 - output_variable1_loss: 0.0048 - output_variable2_loss: 0.0021 - val_loss: 0.1359 - val_output_variable1_loss: 0.1288 - val_output_variable2_loss: 0.0071
# Epoch 51/200
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0068 - output_variable1_loss: 0.0048 - output_variable2_loss: 0.0020 - val_loss: 0.1276 - val_output_variable1_loss: 0.1205 - val_output_variable2_loss: 0.0070
# Epoch 52/200
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0067 - output_variable1_loss: 0.0048 - output_variable2_loss: 0.0019 - val_loss: 0.1472 - val_output_variable1_loss: 0.1396 - val_output_variable2_loss: 0.0075
# Epoch 53/200
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0066 - output_variable1_loss: 0.0047 - output_variable2_loss: 0.0019 - val_loss: 0.1324 - val_output_variable1_loss: 0.1251 - val_output_variable2_loss: 0.0073
# Epoch 54/200
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0064 - output_variable1_loss: 0.0046 - output_variable2_loss: 0.0019 - val_loss: 0.1395 - val_output_variable1_loss: 0.1329 - val_output_variable2_loss: 0.0066
# Epoch 55/200
# 13/13 [==============================] - 0s 30ms/step - loss: 0.0067 - output_variable1_loss: 0.0047 - output_variable2_loss: 0.0020 - val_loss: 0.1379 - val_output_variable1_loss: 0.1312 - val_output_variable2_loss: 0.0068
# Epoch 56/200
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0066 - output_variable1_loss: 0.0048 - output_variable2_loss: 0.0018 - val_loss: 0.1339 - val_output_variable1_loss: 0.1269 - val_output_variable2_loss: 0.0070
# Epoch 57/200
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0065 - output_variable1_loss: 0.0046 - output_variable2_loss: 0.0019 - val_loss: 0.1389 - val_output_variable1_loss: 0.1311 - val_output_variable2_loss: 0.0078
# Epoch 58/200
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0065 - output_variable1_loss: 0.0045 - output_variable2_loss: 0.0020 - val_loss: 0.1336 - val_output_variable1_loss: 0.1266 - val_output_variable2_loss: 0.0070
# Epoch 59/200
# 13/13 [==============================] - 0s 31ms/step - loss: 0.0063 - output_variable1_loss: 0.0045 - output_variable2_loss: 0.0019 - val_loss: 0.1363 - val_output_variable1_loss: 0.1274 - val_output_variable2_loss: 0.0088
# Epoch 60/200
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0064 - output_variable1_loss: 0.0046 - output_variable2_loss: 0.0018 - val_loss: 0.1349 - val_output_variable1_loss: 0.1274 - val_output_variable2_loss: 0.0075
# Epoch 61/200
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0061 - output_variable1_loss: 0.0044 - output_variable2_loss: 0.0017 - val_loss: 0.1288 - val_output_variable1_loss: 0.1216 - val_output_variable2_loss: 0.0072
# Epoch 62/200
# 13/13 [==============================] - 0s 31ms/step - loss: 0.0059 - output_variable1_loss: 0.0043 - output_variable2_loss: 0.0016 - val_loss: 0.1415 - val_output_variable1_loss: 0.1332 - val_output_variable2_loss: 0.0083
# Epoch 63/200
# 13/13 [==============================] - 0s 31ms/step - loss: 0.0057 - output_variable1_loss: 0.0041 - output_variable2_loss: 0.0017 - val_loss: 0.1462 - val_output_variable1_loss: 0.1367 - val_output_variable2_loss: 0.0095
# Epoch 64/200
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0058 - output_variable1_loss: 0.0041 - output_variable2_loss: 0.0018 - val_loss: 0.1359 - val_output_variable1_loss: 0.1272 - val_output_variable2_loss: 0.0087
# Epoch 65/200
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0059 - output_variable1_loss: 0.0042 - output_variable2_loss: 0.0017 - val_loss: 0.1343 - val_output_variable1_loss: 0.1265 - val_output_variable2_loss: 0.0078
# Epoch 66/200
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0058 - output_variable1_loss: 0.0042 - output_variable2_loss: 0.0016 - val_loss: 0.1282 - val_output_variable1_loss: 0.1201 - val_output_variable2_loss: 0.0082
# Epoch 67/200
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0057 - output_variable1_loss: 0.0041 - output_variable2_loss: 0.0017 - val_loss: 0.1333 - val_output_variable1_loss: 0.1240 - val_output_variable2_loss: 0.0093
# Epoch 68/200
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0059 - output_variable1_loss: 0.0039 - output_variable2_loss: 0.0019 - val_loss: 0.1375 - val_output_variable1_loss: 0.1288 - val_output_variable2_loss: 0.0087
# Epoch 1/200
# 14/14 [==============================] - 0s 35ms/step - loss: 0.0106 - output_variable1_loss: 0.0086 - output_variable2_loss: 0.0020 - val_loss: 0.0446 - val_output_variable1_loss: 0.0401 - val_output_variable2_loss: 0.0046
# Epoch 2/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0098 - output_variable1_loss: 0.0080 - output_variable2_loss: 0.0018 - val_loss: 0.0725 - val_output_variable1_loss: 0.0687 - val_output_variable2_loss: 0.0039
# Epoch 3/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0111 - output_variable1_loss: 0.0094 - output_variable2_loss: 0.0018 - val_loss: 0.0275 - val_output_variable1_loss: 0.0244 - val_output_variable2_loss: 0.0031
# Epoch 4/200
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0085 - output_variable1_loss: 0.0069 - output_variable2_loss: 0.0017 - val_loss: 0.0249 - val_output_variable1_loss: 0.0217 - val_output_variable2_loss: 0.0031
# Epoch 5/200
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0071 - output_variable1_loss: 0.0055 - output_variable2_loss: 0.0015 - val_loss: 0.0268 - val_output_variable1_loss: 0.0240 - val_output_variable2_loss: 0.0029
# Epoch 6/200
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0063 - output_variable1_loss: 0.0047 - output_variable2_loss: 0.0016 - val_loss: 0.0247 - val_output_variable1_loss: 0.0202 - val_output_variable2_loss: 0.0045
# Epoch 7/200
# 14/14 [==============================] - 1s 37ms/step - loss: 0.0059 - output_variable1_loss: 0.0043 - output_variable2_loss: 0.0017 - val_loss: 0.0253 - val_output_variable1_loss: 0.0209 - val_output_variable2_loss: 0.0044
# Epoch 8/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0058 - output_variable1_loss: 0.0042 - output_variable2_loss: 0.0017 - val_loss: 0.0251 - val_output_variable1_loss: 0.0214 - val_output_variable2_loss: 0.0037
# Epoch 9/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0060 - output_variable1_loss: 0.0042 - output_variable2_loss: 0.0018 - val_loss: 0.0249 - val_output_variable1_loss: 0.0218 - val_output_variable2_loss: 0.0031
# Epoch 10/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0056 - output_variable1_loss: 0.0040 - output_variable2_loss: 0.0016 - val_loss: 0.0242 - val_output_variable1_loss: 0.0214 - val_output_variable2_loss: 0.0029
# Epoch 11/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0055 - output_variable1_loss: 0.0038 - output_variable2_loss: 0.0017 - val_loss: 0.0339 - val_output_variable1_loss: 0.0316 - val_output_variable2_loss: 0.0024
# Epoch 12/200
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0055 - output_variable1_loss: 0.0038 - output_variable2_loss: 0.0017 - val_loss: 0.0263 - val_output_variable1_loss: 0.0234 - val_output_variable2_loss: 0.0028
# Epoch 13/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0054 - output_variable1_loss: 0.0039 - output_variable2_loss: 0.0015 - val_loss: 0.0481 - val_output_variable1_loss: 0.0446 - val_output_variable2_loss: 0.0034
# Epoch 14/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0055 - output_variable1_loss: 0.0040 - output_variable2_loss: 0.0014 - val_loss: 0.0620 - val_output_variable1_loss: 0.0586 - val_output_variable2_loss: 0.0034
# Epoch 15/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0052 - output_variable1_loss: 0.0037 - output_variable2_loss: 0.0014 - val_loss: 0.0278 - val_output_variable1_loss: 0.0241 - val_output_variable2_loss: 0.0037
# Epoch 16/200
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0049 - output_variable1_loss: 0.0034 - output_variable2_loss: 0.0015 - val_loss: 0.0459 - val_output_variable1_loss: 0.0423 - val_output_variable2_loss: 0.0036
# Epoch 17/200
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0048 - output_variable1_loss: 0.0033 - output_variable2_loss: 0.0014 - val_loss: 0.0464 - val_output_variable1_loss: 0.0432 - val_output_variable2_loss: 0.0033
# Epoch 18/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0047 - output_variable1_loss: 0.0033 - output_variable2_loss: 0.0014 - val_loss: 0.0530 - val_output_variable1_loss: 0.0496 - val_output_variable2_loss: 0.0033
# Epoch 19/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0048 - output_variable1_loss: 0.0033 - output_variable2_loss: 0.0015 - val_loss: 0.0668 - val_output_variable1_loss: 0.0628 - val_output_variable2_loss: 0.0040
# Epoch 20/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0046 - output_variable1_loss: 0.0032 - output_variable2_loss: 0.0014 - val_loss: 0.0649 - val_output_variable1_loss: 0.0612 - val_output_variable2_loss: 0.0036
# Epoch 21/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0047 - output_variable1_loss: 0.0032 - output_variable2_loss: 0.0015 - val_loss: 0.0449 - val_output_variable1_loss: 0.0423 - val_output_variable2_loss: 0.0026
# Epoch 22/200
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0046 - output_variable1_loss: 0.0032 - output_variable2_loss: 0.0014 - val_loss: 0.0444 - val_output_variable1_loss: 0.0413 - val_output_variable2_loss: 0.0031
# Epoch 23/200
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0045 - output_variable1_loss: 0.0031 - output_variable2_loss: 0.0014 - val_loss: 0.0619 - val_output_variable1_loss: 0.0583 - val_output_variable2_loss: 0.0036
# Epoch 24/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0044 - output_variable1_loss: 0.0031 - output_variable2_loss: 0.0013 - val_loss: 0.0642 - val_output_variable1_loss: 0.0613 - val_output_variable2_loss: 0.0029
# Epoch 25/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0045 - output_variable1_loss: 0.0031 - output_variable2_loss: 0.0014 - val_loss: 0.0530 - val_output_variable1_loss: 0.0492 - val_output_variable2_loss: 0.0038
# Epoch 26/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0044 - output_variable1_loss: 0.0031 - output_variable2_loss: 0.0013 - val_loss: 0.0638 - val_output_variable1_loss: 0.0600 - val_output_variable2_loss: 0.0038
# Epoch 27/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0045 - output_variable1_loss: 0.0033 - output_variable2_loss: 0.0013 - val_loss: 0.0341 - val_output_variable1_loss: 0.0310 - val_output_variable2_loss: 0.0031
# Epoch 28/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0045 - output_variable1_loss: 0.0031 - output_variable2_loss: 0.0013 - val_loss: 0.0536 - val_output_variable1_loss: 0.0501 - val_output_variable2_loss: 0.0035
# Epoch 29/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0045 - output_variable1_loss: 0.0032 - output_variable2_loss: 0.0013 - val_loss: 0.0483 - val_output_variable1_loss: 0.0451 - val_output_variable2_loss: 0.0032
# Epoch 30/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0042 - output_variable1_loss: 0.0030 - output_variable2_loss: 0.0013 - val_loss: 0.0509 - val_output_variable1_loss: 0.0470 - val_output_variable2_loss: 0.0039
# Epoch 31/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0042 - output_variable1_loss: 0.0029 - output_variable2_loss: 0.0013 - val_loss: 0.0572 - val_output_variable1_loss: 0.0546 - val_output_variable2_loss: 0.0026
# Epoch 32/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0041 - output_variable1_loss: 0.0028 - output_variable2_loss: 0.0014 - val_loss: 0.0588 - val_output_variable1_loss: 0.0553 - val_output_variable2_loss: 0.0035
# Epoch 33/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0040 - output_variable1_loss: 0.0028 - output_variable2_loss: 0.0012 - val_loss: 0.0595 - val_output_variable1_loss: 0.0568 - val_output_variable2_loss: 0.0027
# Epoch 34/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0039 - output_variable1_loss: 0.0027 - output_variable2_loss: 0.0012 - val_loss: 0.0480 - val_output_variable1_loss: 0.0446 - val_output_variable2_loss: 0.0035
# Epoch 35/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0039 - output_variable1_loss: 0.0027 - output_variable2_loss: 0.0012 - val_loss: 0.0436 - val_output_variable1_loss: 0.0403 - val_output_variable2_loss: 0.0033
# Epoch 36/200
# 14/14 [==============================] - 0s 34ms/step - loss: 0.0038 - output_variable1_loss: 0.0027 - output_variable2_loss: 0.0012 - val_loss: 0.0518 - val_output_variable1_loss: 0.0493 - val_output_variable2_loss: 0.0026
# Epoch 37/200
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0040 - output_variable1_loss: 0.0027 - output_variable2_loss: 0.0013 - val_loss: 0.0628 - val_output_variable1_loss: 0.0599 - val_output_variable2_loss: 0.0029
# Epoch 38/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0039 - output_variable1_loss: 0.0027 - output_variable2_loss: 0.0012 - val_loss: 0.0360 - val_output_variable1_loss: 0.0329 - val_output_variable2_loss: 0.0031
# Epoch 39/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0039 - output_variable1_loss: 0.0027 - output_variable2_loss: 0.0012 - val_loss: 0.0583 - val_output_variable1_loss: 0.0549 - val_output_variable2_loss: 0.0034
# Epoch 40/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0038 - output_variable1_loss: 0.0027 - output_variable2_loss: 0.0011 - val_loss: 0.0348 - val_output_variable1_loss: 0.0314 - val_output_variable2_loss: 0.0034
# Epoch 41/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0038 - output_variable1_loss: 0.0026 - output_variable2_loss: 0.0011 - val_loss: 0.0482 - val_output_variable1_loss: 0.0440 - val_output_variable2_loss: 0.0042
# Epoch 42/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0039 - output_variable1_loss: 0.0027 - output_variable2_loss: 0.0012 - val_loss: 0.0568 - val_output_variable1_loss: 0.0535 - val_output_variable2_loss: 0.0033
# Epoch 43/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0037 - output_variable1_loss: 0.0025 - output_variable2_loss: 0.0012 - val_loss: 0.0501 - val_output_variable1_loss: 0.0474 - val_output_variable2_loss: 0.0027
# Epoch 44/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0038 - output_variable1_loss: 0.0025 - output_variable2_loss: 0.0014 - val_loss: 0.0399 - val_output_variable1_loss: 0.0365 - val_output_variable2_loss: 0.0034
# Epoch 45/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0036 - output_variable1_loss: 0.0024 - output_variable2_loss: 0.0012 - val_loss: 0.0418 - val_output_variable1_loss: 0.0383 - val_output_variable2_loss: 0.0036
# Epoch 46/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0035 - output_variable1_loss: 0.0024 - output_variable2_loss: 0.0011 - val_loss: 0.0440 - val_output_variable1_loss: 0.0409 - val_output_variable2_loss: 0.0031
# Epoch 47/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0035 - output_variable1_loss: 0.0025 - output_variable2_loss: 0.0011 - val_loss: 0.0418 - val_output_variable1_loss: 0.0386 - val_output_variable2_loss: 0.0032
# Epoch 48/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0036 - output_variable1_loss: 0.0025 - output_variable2_loss: 0.0011 - val_loss: 0.0401 - val_output_variable1_loss: 0.0357 - val_output_variable2_loss: 0.0044
# Epoch 49/200
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0039 - output_variable1_loss: 0.0026 - output_variable2_loss: 0.0012 - val_loss: 0.0423 - val_output_variable1_loss: 0.0399 - val_output_variable2_loss: 0.0024
# Epoch 50/200
# 14/14 [==============================] - 0s 32ms/step - loss: 0.0040 - output_variable1_loss: 0.0029 - output_variable2_loss: 0.0011 - val_loss: 0.0589 - val_output_variable1_loss: 0.0557 - val_output_variable2_loss: 0.0033
# Epoch 51/200
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0044 - output_variable1_loss: 0.0033 - output_variable2_loss: 0.0011 - val_loss: 0.0426 - val_output_variable1_loss: 0.0394 - val_output_variable2_loss: 0.0032
# Epoch 1/200
# 15/15 [==============================] - 1s 34ms/step - loss: 0.0055 - output_variable1_loss: 0.0043 - output_variable2_loss: 0.0012 - val_loss: 0.0149 - val_output_variable1_loss: 0.0125 - val_output_variable2_loss: 0.0024
# Epoch 2/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0049 - output_variable1_loss: 0.0036 - output_variable2_loss: 0.0012 - val_loss: 0.0132 - val_output_variable1_loss: 0.0094 - val_output_variable2_loss: 0.0038
# Epoch 3/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0052 - output_variable1_loss: 0.0040 - output_variable2_loss: 0.0012 - val_loss: 0.0152 - val_output_variable1_loss: 0.0133 - val_output_variable2_loss: 0.0019
# Epoch 4/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0049 - output_variable1_loss: 0.0036 - output_variable2_loss: 0.0013 - val_loss: 0.0179 - val_output_variable1_loss: 0.0154 - val_output_variable2_loss: 0.0025
# Epoch 5/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0041 - output_variable1_loss: 0.0030 - output_variable2_loss: 0.0011 - val_loss: 0.0143 - val_output_variable1_loss: 0.0118 - val_output_variable2_loss: 0.0025
# Epoch 6/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0038 - output_variable1_loss: 0.0027 - output_variable2_loss: 0.0011 - val_loss: 0.0168 - val_output_variable1_loss: 0.0134 - val_output_variable2_loss: 0.0034
# Epoch 7/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0037 - output_variable1_loss: 0.0026 - output_variable2_loss: 0.0011 - val_loss: 0.0143 - val_output_variable1_loss: 0.0121 - val_output_variable2_loss: 0.0021
# Epoch 8/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0035 - output_variable1_loss: 0.0024 - output_variable2_loss: 0.0011 - val_loss: 0.0154 - val_output_variable1_loss: 0.0128 - val_output_variable2_loss: 0.0026
# Epoch 9/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0036 - output_variable1_loss: 0.0023 - output_variable2_loss: 0.0012 - val_loss: 0.0154 - val_output_variable1_loss: 0.0125 - val_output_variable2_loss: 0.0029
# Epoch 10/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0034 - output_variable1_loss: 0.0024 - output_variable2_loss: 0.0010 - val_loss: 0.0140 - val_output_variable1_loss: 0.0116 - val_output_variable2_loss: 0.0024
# Epoch 11/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0035 - output_variable1_loss: 0.0025 - output_variable2_loss: 0.0010 - val_loss: 0.0134 - val_output_variable1_loss: 0.0112 - val_output_variable2_loss: 0.0022
# Epoch 12/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0034 - output_variable1_loss: 0.0024 - output_variable2_loss: 9.8852e-04 - val_loss: 0.0145 - val_output_variable1_loss: 0.0116 - val_output_variable2_loss: 0.0030
# Epoch 13/200
# 15/15 [==============================] - 1s 35ms/step - loss: 0.0035 - output_variable1_loss: 0.0025 - output_variable2_loss: 0.0010 - val_loss: 0.0138 - val_output_variable1_loss: 0.0114 - val_output_variable2_loss: 0.0024
# Epoch 14/200
# 15/15 [==============================] - 1s 33ms/step - loss: 0.0034 - output_variable1_loss: 0.0024 - output_variable2_loss: 9.4688e-04 - val_loss: 0.0148 - val_output_variable1_loss: 0.0130 - val_output_variable2_loss: 0.0018
# Epoch 15/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0033 - output_variable1_loss: 0.0023 - output_variable2_loss: 9.8369e-04 - val_loss: 0.0138 - val_output_variable1_loss: 0.0119 - val_output_variable2_loss: 0.0019
# Epoch 16/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0032 - output_variable1_loss: 0.0022 - output_variable2_loss: 9.2766e-04 - val_loss: 0.0147 - val_output_variable1_loss: 0.0119 - val_output_variable2_loss: 0.0028
# Epoch 17/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0031 - output_variable1_loss: 0.0022 - output_variable2_loss: 9.7757e-04 - val_loss: 0.0144 - val_output_variable1_loss: 0.0120 - val_output_variable2_loss: 0.0024
# Epoch 18/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0032 - output_variable1_loss: 0.0022 - output_variable2_loss: 9.7410e-04 - val_loss: 0.0157 - val_output_variable1_loss: 0.0129 - val_output_variable2_loss: 0.0028
# Epoch 19/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0032 - output_variable1_loss: 0.0022 - output_variable2_loss: 9.8078e-04 - val_loss: 0.0143 - val_output_variable1_loss: 0.0121 - val_output_variable2_loss: 0.0022
# Epoch 20/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0030 - output_variable1_loss: 0.0021 - output_variable2_loss: 9.3998e-04 - val_loss: 0.0158 - val_output_variable1_loss: 0.0128 - val_output_variable2_loss: 0.0030
# Epoch 21/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0030 - output_variable1_loss: 0.0020 - output_variable2_loss: 9.4185e-04 - val_loss: 0.0143 - val_output_variable1_loss: 0.0119 - val_output_variable2_loss: 0.0024
# Epoch 22/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0030 - output_variable1_loss: 0.0020 - output_variable2_loss: 9.8312e-04 - val_loss: 0.0149 - val_output_variable1_loss: 0.0124 - val_output_variable2_loss: 0.0025
# Epoch 23/200
# 15/15 [==============================] - 0s 33ms/step - loss: 0.0030 - output_variable1_loss: 0.0020 - output_variable2_loss: 9.5172e-04 - val_loss: 0.0154 - val_output_variable1_loss: 0.0123 - val_output_variable2_loss: 0.0031
# Epoch 24/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0031 - output_variable1_loss: 0.0022 - output_variable2_loss: 9.6540e-04 - val_loss: 0.0160 - val_output_variable1_loss: 0.0127 - val_output_variable2_loss: 0.0034
# Epoch 25/200
# 15/15 [==============================] - 0s 33ms/step - loss: 0.0031 - output_variable1_loss: 0.0021 - output_variable2_loss: 9.3508e-04 - val_loss: 0.0150 - val_output_variable1_loss: 0.0130 - val_output_variable2_loss: 0.0019
# Epoch 26/200
# 15/15 [==============================] - 0s 33ms/step - loss: 0.0030 - output_variable1_loss: 0.0021 - output_variable2_loss: 8.4409e-04 - val_loss: 0.0131 - val_output_variable1_loss: 0.0113 - val_output_variable2_loss: 0.0018
# Epoch 27/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0030 - output_variable1_loss: 0.0021 - output_variable2_loss: 8.6298e-04 - val_loss: 0.0148 - val_output_variable1_loss: 0.0124 - val_output_variable2_loss: 0.0024
# Epoch 28/200
# 15/15 [==============================] - 0s 33ms/step - loss: 0.0029 - output_variable1_loss: 0.0020 - output_variable2_loss: 9.0966e-04 - val_loss: 0.0143 - val_output_variable1_loss: 0.0125 - val_output_variable2_loss: 0.0017
# Epoch 29/200
# 15/15 [==============================] - 0s 33ms/step - loss: 0.0030 - output_variable1_loss: 0.0021 - output_variable2_loss: 9.3523e-04 - val_loss: 0.0146 - val_output_variable1_loss: 0.0120 - val_output_variable2_loss: 0.0026
# Epoch 30/200
# 15/15 [==============================] - 1s 34ms/step - loss: 0.0030 - output_variable1_loss: 0.0021 - output_variable2_loss: 8.8729e-04 - val_loss: 0.0146 - val_output_variable1_loss: 0.0125 - val_output_variable2_loss: 0.0021
# Epoch 31/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0029 - output_variable1_loss: 0.0021 - output_variable2_loss: 8.5916e-04 - val_loss: 0.0160 - val_output_variable1_loss: 0.0142 - val_output_variable2_loss: 0.0019
# Epoch 32/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0031 - output_variable1_loss: 0.0021 - output_variable2_loss: 9.9453e-04 - val_loss: 0.0149 - val_output_variable1_loss: 0.0126 - val_output_variable2_loss: 0.0023
# Epoch 33/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0032 - output_variable1_loss: 0.0020 - output_variable2_loss: 0.0012 - val_loss: 0.0139 - val_output_variable1_loss: 0.0122 - val_output_variable2_loss: 0.0018
# Epoch 34/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0032 - output_variable1_loss: 0.0020 - output_variable2_loss: 0.0012 - val_loss: 0.0137 - val_output_variable1_loss: 0.0115 - val_output_variable2_loss: 0.0023
# Epoch 35/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0028 - output_variable1_loss: 0.0020 - output_variable2_loss: 8.6100e-04 - val_loss: 0.0147 - val_output_variable1_loss: 0.0128 - val_output_variable2_loss: 0.0019
# Epoch 36/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0027 - output_variable1_loss: 0.0019 - output_variable2_loss: 8.2731e-04 - val_loss: 0.0135 - val_output_variable1_loss: 0.0112 - val_output_variable2_loss: 0.0023
# Epoch 37/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0027 - output_variable1_loss: 0.0019 - output_variable2_loss: 7.8060e-04 - val_loss: 0.0146 - val_output_variable1_loss: 0.0124 - val_output_variable2_loss: 0.0021
# Epoch 38/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0027 - output_variable1_loss: 0.0019 - output_variable2_loss: 8.0275e-04 - val_loss: 0.0138 - val_output_variable1_loss: 0.0118 - val_output_variable2_loss: 0.0021
# Epoch 39/200
# 15/15 [==============================] - 0s 33ms/step - loss: 0.0027 - output_variable1_loss: 0.0018 - output_variable2_loss: 8.2855e-04 - val_loss: 0.0138 - val_output_variable1_loss: 0.0124 - val_output_variable2_loss: 0.0014
# Epoch 40/200
# 15/15 [==============================] - 1s 34ms/step - loss: 0.0026 - output_variable1_loss: 0.0018 - output_variable2_loss: 8.2052e-04 - val_loss: 0.0150 - val_output_variable1_loss: 0.0133 - val_output_variable2_loss: 0.0017
# Epoch 41/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0030 - output_variable1_loss: 0.0021 - output_variable2_loss: 8.9733e-04 - val_loss: 0.0149 - val_output_variable1_loss: 0.0122 - val_output_variable2_loss: 0.0028
# Epoch 42/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0029 - output_variable1_loss: 0.0021 - output_variable2_loss: 8.5280e-04 - val_loss: 0.0147 - val_output_variable1_loss: 0.0129 - val_output_variable2_loss: 0.0018
# Epoch 43/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0031 - output_variable1_loss: 0.0022 - output_variable2_loss: 9.1165e-04 - val_loss: 0.0138 - val_output_variable1_loss: 0.0118 - val_output_variable2_loss: 0.0020
# Epoch 44/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0029 - output_variable1_loss: 0.0020 - output_variable2_loss: 9.2043e-04 - val_loss: 0.0141 - val_output_variable1_loss: 0.0122 - val_output_variable2_loss: 0.0019
# Epoch 45/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0026 - output_variable1_loss: 0.0018 - output_variable2_loss: 7.9280e-04 - val_loss: 0.0146 - val_output_variable1_loss: 0.0123 - val_output_variable2_loss: 0.0023
# Epoch 46/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0025 - output_variable1_loss: 0.0018 - output_variable2_loss: 7.5375e-04 - val_loss: 0.0151 - val_output_variable1_loss: 0.0127 - val_output_variable2_loss: 0.0024
# Epoch 47/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0025 - output_variable1_loss: 0.0018 - output_variable2_loss: 7.7530e-04 - val_loss: 0.0136 - val_output_variable1_loss: 0.0114 - val_output_variable2_loss: 0.0022
# Epoch 48/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0027 - output_variable1_loss: 0.0019 - output_variable2_loss: 8.5575e-04 - val_loss: 0.0141 - val_output_variable1_loss: 0.0110 - val_output_variable2_loss: 0.0032
# Epoch 49/200
# 15/15 [==============================] - 0s 31ms/step - loss: 0.0027 - output_variable1_loss: 0.0018 - output_variable2_loss: 8.4321e-04 - val_loss: 0.0148 - val_output_variable1_loss: 0.0131 - val_output_variable2_loss: 0.0017
# Epoch 50/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0026 - output_variable1_loss: 0.0018 - output_variable2_loss: 8.0255e-04 - val_loss: 0.0137 - val_output_variable1_loss: 0.0115 - val_output_variable2_loss: 0.0022
# Epoch 51/200
# 15/15 [==============================] - 0s 32ms/step - loss: 0.0026 - output_variable1_loss: 0.0018 - output_variable2_loss: 7.6451e-04 - val_loss: 0.0146 - val_output_variable1_loss: 0.0131 - val_output_variable2_loss: 0.0015
# Epoch 1/200
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0032 - output_variable1_loss: 0.0024 - output_variable2_loss: 8.2886e-04 - val_loss: 0.0165 - val_output_variable1_loss: 0.0142 - val_output_variable2_loss: 0.0023
# Epoch 2/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0035 - output_variable1_loss: 0.0024 - output_variable2_loss: 0.0011 - val_loss: 0.0096 - val_output_variable1_loss: 0.0067 - val_output_variable2_loss: 0.0029
# Epoch 3/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0037 - output_variable1_loss: 0.0025 - output_variable2_loss: 0.0012 - val_loss: 0.0176 - val_output_variable1_loss: 0.0081 - val_output_variable2_loss: 0.0095
# Epoch 4/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0043 - output_variable1_loss: 0.0023 - output_variable2_loss: 0.0021 - val_loss: 0.0099 - val_output_variable1_loss: 0.0060 - val_output_variable2_loss: 0.0039
# Epoch 5/200
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0036 - output_variable1_loss: 0.0022 - output_variable2_loss: 0.0013 - val_loss: 0.0136 - val_output_variable1_loss: 0.0102 - val_output_variable2_loss: 0.0034
# Epoch 6/200
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0037 - output_variable1_loss: 0.0023 - output_variable2_loss: 0.0014 - val_loss: 0.0120 - val_output_variable1_loss: 0.0080 - val_output_variable2_loss: 0.0040

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss_1):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss_1[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error 1", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss_2):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss_2[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error 2", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
# Evaluate the model on the test data
predictions_1 = []
predictions_2 = []
#print(len(eval_target_variables))

for i in range(len(Y_val)):
    current_batch = X_val[i].reshape((1, NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))
    curr_pred1, curr_pred2 = model.predict(current_batch)
    predictions_1.append(curr_pred1)
    predictions_2.append(curr_pred2)
# Out:
# 1/1 [==============================] - 1s 695ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_1):
    ax = axs[i]
    # TODO seems to work but check why column[0]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_val[i, :, 0], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_2):
    ax = axs[i]
    # TODO seems to work but check why column[0]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_val[i, :, 1], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
rmse = 0
for i in range(len(predictions_1)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_1[i][0], Y_val[i, :, 0]))}')
    rmse += sqrt(mean_squared_error(predictions_1[i][0], Y_val[i, :, 0]))

rmse /= len(predictions_1)    
print(f"RMSE for {columns_to_predict[0]} = {rmse}")

rmse = 0
for i in range(len(predictions_2)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_2[i][0], Y_val[i, :, 1]))}')
    rmse += sqrt(mean_squared_error(predictions_2[i][0], Y_val[i, :, 1]))

rmse /= len(predictions_2)    
print(f"RMSE for {columns_to_predict[1]} = {rmse}")
# Out:
# RMSE for kg_CO2/kWh = 0.17691653557972875
# RMSE for Avg solar generation = 0.04261921971838528

# %%
# Evaluate the model on the test data
predictions_1_test = []
predictions_2_test = []
#print(len(eval_target_variables))

for i in range(len(Y_test)):
    current_batch = X_test[i].reshape((1, NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))
    curr_pred1, curr_pred2 = model.predict(current_batch)
    predictions_1_test.append(curr_pred1)
    predictions_2_test.append(curr_pred2)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_1_test):
    ax = axs[i]
    # TODO seems to work but check why column[0]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_test[i, :, 0], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_2_test):
    ax = axs[i]
    # TODO seems to work but check why column[0]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_test[i, :, 1], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
rmse = 0
for i in range(len(predictions_1_test)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_1[i][0], Y_val[i, :, 0]))}')
    rmse += sqrt(mean_squared_error(predictions_1_test[i][0], Y_test[i, :, 0]))

rmse /= len(predictions_1_test)    
print(f"RMSE for {columns_to_predict[0]} = {rmse}")

rmse = 0
for i in range(len(predictions_2_test)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_2[i][0], Y_val[i, :, 1]))}')
    rmse += sqrt(mean_squared_error(predictions_2_test[i][0], Y_test[i, :, 1]))

rmse /= len(predictions_2_test)    
print(f"RMSE for {columns_to_predict[1]} = {rmse}")
# Out:
# RMSE for kg_CO2/kWh = 0.11801738991228922
# RMSE for Avg solar generation = 0.09849265716462886
