# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
train = pd.read_csv("../data/schemas/warm_up/TrainSet.csv", sep=",")
validation = pd.read_csv("../data/schemas/warm_up/ValidationSet.csv", sep=",")
test = pd.read_csv("../data/schemas/warm_up/TestSet.csv", sep=",")

# %%
# Global variables

NUM_OF_TIMESTEPS_INPUT = 48
NUM_OF_TIMESTEPS_OUTPUT = 24

THRESHOLD = 0.4   # For feature selection

# %%
columns_to_predict = ["kg_CO2/kWh", "Avg solar generation"]

independent_variables = []

for column in train:
    if abs(train[column].corr(train[columns_to_predict[0]])) > THRESHOLD: #or abs(train[column].corr(train[columns_to_predict[1]])) > THRESHOLD:
        independent_variables.append(column)

independent_variables = [var for var in independent_variables if var not in columns_to_predict]
    
if "Index" in independent_variables:
    independent_variables.remove("Index")
if "Solar Generation (W/kW)_1" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_1")
if "Solar Generation (W/kW)_2" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_2")
if "Solar Generation (W/kW)_3" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_3")
    
print(independent_variables)
# Out:
# ['Hour_1', 'Hour_2', 'Hour_3', 'Occupant Count (people)_3', '12h Outdoor Drybulb Temperature (C)', '24h Outdoor Drybulb Temperature (C)', '12h Outdoor Relative Humidity (%)', '6h Direct Solar Radiation (W/m2)', '12h Direct Solar Radiation (W/m2)']

# %% [markdown]
# Prepare the data

# %%
# Split the X and Y for all sets

# Train set
X_train_default = train[independent_variables]
Y_train_default = train[columns_to_predict]

# Validation set, also include the data from train that was used only as output to get more datapoints
X_val_default = pd.concat([X_train_default.tail(NUM_OF_TIMESTEPS_OUTPUT), validation[independent_variables]], ignore_index=True)
Y_val_default = pd.concat([Y_train_default.tail(NUM_OF_TIMESTEPS_OUTPUT), validation[columns_to_predict]], ignore_index=True)

# Test set, also include the data from train that was used only as output to get more datapoints
X_test_default = pd.concat([X_val_default.tail(NUM_OF_TIMESTEPS_OUTPUT), test[independent_variables]], ignore_index=True)
Y_test_default = pd.concat([Y_val_default.tail(NUM_OF_TIMESTEPS_OUTPUT), test[columns_to_predict]], ignore_index=True)

NUM_OF_ROWS_TRAIN, NUM_OF_FEATURES = X_train_default.shape

print(X_train_default.shape)
print(X_val_default.shape)
print(X_test_default.shape)
# Out:
# (576, 9)
# (96, 9)
# (96, 9)

# %%
# Function to prepare the data into batches that will be passed into the model

def create_sequences(input_data, output_data, timesteps_input, timesteps_output):
    sequences, targets = [], []
    for i in range(len(input_data) - timesteps_input - timesteps_output + 1):
        seq = input_data[i:i + timesteps_input]
        target = output_data[i + timesteps_input: i + timesteps_input + timesteps_output]
        sequences.append(seq)
        targets.append(target)

    return np.array(sequences), np.array(targets)

# %%
X_train, Y_train = create_sequences(X_train_default, Y_train_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)
X_val, Y_val = create_sequences(X_val_default, Y_val_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)
X_test, Y_test = create_sequences(X_test_default, Y_test_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)

print(f"X_train = {X_train.shape}, Y_train = {Y_train.shape}\n"
      f"X_val = {X_val.shape}, Y_val = {Y_val.shape}\n"
      f"X_test = {X_test.shape}, Y_test = {Y_test.shape}")
# Out:
# X_train = (505, 48, 9), Y_train = (505, 24, 2)
# X_val = (25, 48, 9), Y_val = (25, 24, 2)
# X_test = (25, 48, 9), Y_test = (25, 24, 2)

# %%
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras import layers, models
import time

tscv = TimeSeriesSplit(n_splits = 4, test_size=24) # For cross-validation

callback = keras.callbacks.EarlyStopping(monitor='loss', patience = 4) #patience parameter to be adjusted

loss = []
val_loss = []
loss_1 = []
val_loss_1 = []
loss_2 = []
val_loss_2 = []

# Input layer
input_layer = layers.Input(shape=(NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))

# Dense layers for variable 1
lstm1 = layers.LSTM(48, activation='leaky_relu', return_sequences=True)(input_layer)
lstm2 = layers.LSTM(48, activation='leaky_relu', return_sequences=True)(lstm1)
lstm3 = layers.LSTM(24, activation='leaky_relu', return_sequences=False)(lstm2)
output_variable1 = layers.Dense(24, name='output_variable1')(lstm3)

# Dense layers for variable 2
dense4 = layers.LSTM(48, activation='leaky_relu', return_sequences=True)(input_layer)
dense5 = layers.LSTM(48, activation='leaky_relu', return_sequences=True)(dense4)
dense6 = layers.LSTM(24, activation='leaky_relu', return_sequences=False)(dense5)
output_variable2 = layers.Dense(24, name='output_variable2')(dense6)

# Define the model
model = models.Model(inputs=input_layer, outputs=[output_variable1, output_variable2])

model.compile(
    optimizer='adam',
    loss={'output_variable1': 'mean_squared_error', 'output_variable2': 'mean_squared_error'}
) #types of optimizer, loss function to be adjusted
    
start = time.time()

for train_data, test_data in tscv.split(X_train):
    X_train_current_split, X_test_current_split = X_train[train_data], X_train[test_data]
    y_train_current_split, y_test_current_split = Y_train[train_data], Y_train[test_data]
    
    history = model.fit(X_train_current_split, y={"output_variable1": y_train_current_split[:, :, 0], 
                                                  "output_variable2": y_train_current_split[:, :, 1]},
              epochs=50, 
              validation_data=(
                  X_test_current_split,
                {
                    "output_variable1": y_test_current_split[:, :, 0],
                    "output_variable2": y_test_current_split[:, :, 1],
                },
              ),
              # validation_split = 0.8,
              verbose=1,
              callbacks=callback
    )
    loss.append(model.history.history['loss'])
    val_loss.append(model.history.history['val_loss'])
    
    loss_1.append(model.history.history['output_variable1_loss'])
    val_loss_1.append(model.history.history['val_output_variable1_loss'])
    
    loss_2.append(model.history.history['output_variable2_loss'])
    val_loss_2.append(model.history.history['val_output_variable2_loss'])
    
end = time.time()

print(f"Training time = {end - start} seconds")
# Out:
# Epoch 1/50
# 13/13 [==============================] - 17s 201ms/step - loss: 0.4642 - output_variable1_loss: 0.2942 - output_variable2_loss: 0.1700 - val_loss: 0.7076 - val_output_variable1_loss: 0.6111 - val_output_variable2_loss: 0.0964
# Epoch 2/50
# 13/13 [==============================] - 1s 57ms/step - loss: 0.3603 - output_variable1_loss: 0.2176 - output_variable2_loss: 0.1427 - val_loss: 0.4942 - val_output_variable1_loss: 0.4109 - val_output_variable2_loss: 0.0834
# Epoch 3/50
# 13/13 [==============================] - 1s 58ms/step - loss: 0.2820 - output_variable1_loss: 0.1575 - output_variable2_loss: 0.1245 - val_loss: 0.3554 - val_output_variable1_loss: 0.2799 - val_output_variable2_loss: 0.0755
# Epoch 4/50
# 13/13 [==============================] - 1s 57ms/step - loss: 0.2203 - output_variable1_loss: 0.1114 - output_variable2_loss: 0.1090 - val_loss: 0.2673 - val_output_variable1_loss: 0.1948 - val_output_variable2_loss: 0.0725
# Epoch 5/50
# 13/13 [==============================] - 1s 54ms/step - loss: 0.1643 - output_variable1_loss: 0.0752 - output_variable2_loss: 0.0891 - val_loss: 0.1720 - val_output_variable1_loss: 0.1057 - val_output_variable2_loss: 0.0663
# Epoch 6/50
# 13/13 [==============================] - 1s 57ms/step - loss: 0.1226 - output_variable1_loss: 0.0520 - output_variable2_loss: 0.0705 - val_loss: 0.1301 - val_output_variable1_loss: 0.0783 - val_output_variable2_loss: 0.0518
# Epoch 7/50
# 13/13 [==============================] - 1s 58ms/step - loss: 0.0909 - output_variable1_loss: 0.0411 - output_variable2_loss: 0.0498 - val_loss: 0.1068 - val_output_variable1_loss: 0.0638 - val_output_variable2_loss: 0.0429
# Epoch 8/50
# 13/13 [==============================] - 1s 53ms/step - loss: 0.0756 - output_variable1_loss: 0.0406 - output_variable2_loss: 0.0350 - val_loss: 0.0536 - val_output_variable1_loss: 0.0214 - val_output_variable2_loss: 0.0322
# Epoch 9/50
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0662 - output_variable1_loss: 0.0404 - output_variable2_loss: 0.0258 - val_loss: 0.0469 - val_output_variable1_loss: 0.0178 - val_output_variable2_loss: 0.0291
# Epoch 10/50
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0572 - output_variable1_loss: 0.0371 - output_variable2_loss: 0.0201 - val_loss: 0.0467 - val_output_variable1_loss: 0.0229 - val_output_variable2_loss: 0.0238
# Epoch 11/50
# 13/13 [==============================] - 1s 58ms/step - loss: 0.0524 - output_variable1_loss: 0.0359 - output_variable2_loss: 0.0165 - val_loss: 0.0482 - val_output_variable1_loss: 0.0274 - val_output_variable2_loss: 0.0207
# Epoch 12/50
# 13/13 [==============================] - 1s 63ms/step - loss: 0.0491 - output_variable1_loss: 0.0347 - output_variable2_loss: 0.0144 - val_loss: 0.0639 - val_output_variable1_loss: 0.0449 - val_output_variable2_loss: 0.0190
# Epoch 13/50
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0465 - output_variable1_loss: 0.0338 - output_variable2_loss: 0.0127 - val_loss: 0.0651 - val_output_variable1_loss: 0.0473 - val_output_variable2_loss: 0.0179
# Epoch 14/50
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0469 - output_variable1_loss: 0.0354 - output_variable2_loss: 0.0115 - val_loss: 0.0628 - val_output_variable1_loss: 0.0469 - val_output_variable2_loss: 0.0159
# Epoch 15/50
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0437 - output_variable1_loss: 0.0331 - output_variable2_loss: 0.0106 - val_loss: 0.0650 - val_output_variable1_loss: 0.0495 - val_output_variable2_loss: 0.0155
# Epoch 16/50
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0435 - output_variable1_loss: 0.0333 - output_variable2_loss: 0.0102 - val_loss: 0.0285 - val_output_variable1_loss: 0.0144 - val_output_variable2_loss: 0.0141
# Epoch 17/50
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0420 - output_variable1_loss: 0.0331 - output_variable2_loss: 0.0089 - val_loss: 0.0449 - val_output_variable1_loss: 0.0312 - val_output_variable2_loss: 0.0137
# Epoch 18/50
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0384 - output_variable1_loss: 0.0306 - output_variable2_loss: 0.0078 - val_loss: 0.0420 - val_output_variable1_loss: 0.0280 - val_output_variable2_loss: 0.0140
# Epoch 19/50
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0354 - output_variable1_loss: 0.0284 - output_variable2_loss: 0.0070 - val_loss: 0.0548 - val_output_variable1_loss: 0.0425 - val_output_variable2_loss: 0.0123
# Epoch 20/50
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0341 - output_variable1_loss: 0.0273 - output_variable2_loss: 0.0068 - val_loss: 0.0589 - val_output_variable1_loss: 0.0461 - val_output_variable2_loss: 0.0128
# Epoch 21/50
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0326 - output_variable1_loss: 0.0264 - output_variable2_loss: 0.0062 - val_loss: 0.0515 - val_output_variable1_loss: 0.0399 - val_output_variable2_loss: 0.0116
# Epoch 22/50
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0320 - output_variable1_loss: 0.0261 - output_variable2_loss: 0.0059 - val_loss: 0.0496 - val_output_variable1_loss: 0.0383 - val_output_variable2_loss: 0.0113
# Epoch 23/50
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0298 - output_variable1_loss: 0.0243 - output_variable2_loss: 0.0055 - val_loss: 0.0551 - val_output_variable1_loss: 0.0443 - val_output_variable2_loss: 0.0108
# Epoch 24/50
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0274 - output_variable1_loss: 0.0223 - output_variable2_loss: 0.0051 - val_loss: 0.0712 - val_output_variable1_loss: 0.0619 - val_output_variable2_loss: 0.0094
# Epoch 25/50
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0252 - output_variable1_loss: 0.0210 - output_variable2_loss: 0.0043 - val_loss: 0.0692 - val_output_variable1_loss: 0.0595 - val_output_variable2_loss: 0.0097
# Epoch 26/50
# 13/13 [==============================] - 1s 53ms/step - loss: 0.0240 - output_variable1_loss: 0.0199 - output_variable2_loss: 0.0040 - val_loss: 0.0645 - val_output_variable1_loss: 0.0550 - val_output_variable2_loss: 0.0095
# Epoch 27/50
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0218 - output_variable1_loss: 0.0179 - output_variable2_loss: 0.0039 - val_loss: 0.0759 - val_output_variable1_loss: 0.0659 - val_output_variable2_loss: 0.0100
# Epoch 28/50
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0210 - output_variable1_loss: 0.0173 - output_variable2_loss: 0.0037 - val_loss: 0.0947 - val_output_variable1_loss: 0.0849 - val_output_variable2_loss: 0.0098
# Epoch 29/50
# 13/13 [==============================] - 1s 67ms/step - loss: 0.0203 - output_variable1_loss: 0.0162 - output_variable2_loss: 0.0040 - val_loss: 0.0846 - val_output_variable1_loss: 0.0724 - val_output_variable2_loss: 0.0122
# Epoch 30/50
# 13/13 [==============================] - 1s 59ms/step - loss: 0.0190 - output_variable1_loss: 0.0149 - output_variable2_loss: 0.0041 - val_loss: 0.0866 - val_output_variable1_loss: 0.0769 - val_output_variable2_loss: 0.0097
# Epoch 31/50
# 13/13 [==============================] - 1s 60ms/step - loss: 0.0184 - output_variable1_loss: 0.0143 - output_variable2_loss: 0.0041 - val_loss: 0.0851 - val_output_variable1_loss: 0.0759 - val_output_variable2_loss: 0.0091
# Epoch 32/50
# 13/13 [==============================] - 1s 58ms/step - loss: 0.0163 - output_variable1_loss: 0.0129 - output_variable2_loss: 0.0034 - val_loss: 0.0755 - val_output_variable1_loss: 0.0643 - val_output_variable2_loss: 0.0112
# Epoch 33/50
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0153 - output_variable1_loss: 0.0120 - output_variable2_loss: 0.0033 - val_loss: 0.0875 - val_output_variable1_loss: 0.0788 - val_output_variable2_loss: 0.0087
# Epoch 34/50
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0147 - output_variable1_loss: 0.0116 - output_variable2_loss: 0.0030 - val_loss: 0.0761 - val_output_variable1_loss: 0.0669 - val_output_variable2_loss: 0.0092
# Epoch 35/50
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0150 - output_variable1_loss: 0.0119 - output_variable2_loss: 0.0031 - val_loss: 0.0861 - val_output_variable1_loss: 0.0767 - val_output_variable2_loss: 0.0093
# Epoch 36/50
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0132 - output_variable1_loss: 0.0100 - output_variable2_loss: 0.0032 - val_loss: 0.0890 - val_output_variable1_loss: 0.0799 - val_output_variable2_loss: 0.0091
# Epoch 37/50
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0131 - output_variable1_loss: 0.0103 - output_variable2_loss: 0.0028 - val_loss: 0.0785 - val_output_variable1_loss: 0.0703 - val_output_variable2_loss: 0.0081
# Epoch 38/50
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0118 - output_variable1_loss: 0.0091 - output_variable2_loss: 0.0027 - val_loss: 0.0857 - val_output_variable1_loss: 0.0781 - val_output_variable2_loss: 0.0076
# Epoch 39/50
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0119 - output_variable1_loss: 0.0092 - output_variable2_loss: 0.0027 - val_loss: 0.0791 - val_output_variable1_loss: 0.0709 - val_output_variable2_loss: 0.0082
# Epoch 40/50
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0118 - output_variable1_loss: 0.0092 - output_variable2_loss: 0.0026 - val_loss: 0.0886 - val_output_variable1_loss: 0.0804 - val_output_variable2_loss: 0.0082
# Epoch 41/50
# 13/13 [==============================] - 1s 54ms/step - loss: 0.0114 - output_variable1_loss: 0.0089 - output_variable2_loss: 0.0025 - val_loss: 0.0823 - val_output_variable1_loss: 0.0736 - val_output_variable2_loss: 0.0087
# Epoch 42/50
# 13/13 [==============================] - 1s 58ms/step - loss: 0.0109 - output_variable1_loss: 0.0084 - output_variable2_loss: 0.0025 - val_loss: 0.0828 - val_output_variable1_loss: 0.0750 - val_output_variable2_loss: 0.0078
# Epoch 43/50
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0103 - output_variable1_loss: 0.0078 - output_variable2_loss: 0.0025 - val_loss: 0.0847 - val_output_variable1_loss: 0.0769 - val_output_variable2_loss: 0.0078
# Epoch 44/50
# 13/13 [==============================] - 1s 55ms/step - loss: 0.0100 - output_variable1_loss: 0.0074 - output_variable2_loss: 0.0026 - val_loss: 0.0842 - val_output_variable1_loss: 0.0766 - val_output_variable2_loss: 0.0075
# Epoch 45/50
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0100 - output_variable1_loss: 0.0069 - output_variable2_loss: 0.0031 - val_loss: 0.0882 - val_output_variable1_loss: 0.0790 - val_output_variable2_loss: 0.0092
# Epoch 46/50
# 13/13 [==============================] - 1s 53ms/step - loss: 0.0094 - output_variable1_loss: 0.0068 - output_variable2_loss: 0.0026 - val_loss: 0.0869 - val_output_variable1_loss: 0.0803 - val_output_variable2_loss: 0.0067
# Epoch 47/50
# 13/13 [==============================] - 1s 57ms/step - loss: 0.0090 - output_variable1_loss: 0.0068 - output_variable2_loss: 0.0022 - val_loss: 0.0840 - val_output_variable1_loss: 0.0771 - val_output_variable2_loss: 0.0069
# Epoch 48/50
# 13/13 [==============================] - 1s 63ms/step - loss: 0.0090 - output_variable1_loss: 0.0066 - output_variable2_loss: 0.0024 - val_loss: 0.0780 - val_output_variable1_loss: 0.0714 - val_output_variable2_loss: 0.0066
# Epoch 49/50
# 13/13 [==============================] - 1s 56ms/step - loss: 0.0086 - output_variable1_loss: 0.0065 - output_variable2_loss: 0.0021 - val_loss: 0.0798 - val_output_variable1_loss: 0.0734 - val_output_variable2_loss: 0.0065
# Epoch 50/50
# 13/13 [==============================] - 1s 58ms/step - loss: 0.0093 - output_variable1_loss: 0.0073 - output_variable2_loss: 0.0020 - val_loss: 0.0863 - val_output_variable1_loss: 0.0803 - val_output_variable2_loss: 0.0060
# Epoch 1/50
# 14/14 [==============================] - 1s 62ms/step - loss: 0.0136 - output_variable1_loss: 0.0114 - output_variable2_loss: 0.0022 - val_loss: 0.0499 - val_output_variable1_loss: 0.0369 - val_output_variable2_loss: 0.0131
# Epoch 2/50
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0119 - output_variable1_loss: 0.0098 - output_variable2_loss: 0.0021 - val_loss: 0.0465 - val_output_variable1_loss: 0.0312 - val_output_variable2_loss: 0.0153
# Epoch 3/50
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0104 - output_variable1_loss: 0.0084 - output_variable2_loss: 0.0020 - val_loss: 0.0435 - val_output_variable1_loss: 0.0292 - val_output_variable2_loss: 0.0142
# Epoch 4/50
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0094 - output_variable1_loss: 0.0075 - output_variable2_loss: 0.0020 - val_loss: 0.0511 - val_output_variable1_loss: 0.0310 - val_output_variable2_loss: 0.0201
# Epoch 5/50
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0092 - output_variable1_loss: 0.0071 - output_variable2_loss: 0.0021 - val_loss: 0.0595 - val_output_variable1_loss: 0.0440 - val_output_variable2_loss: 0.0156
# Epoch 6/50
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0081 - output_variable1_loss: 0.0062 - output_variable2_loss: 0.0019 - val_loss: 0.0580 - val_output_variable1_loss: 0.0423 - val_output_variable2_loss: 0.0157
# Epoch 7/50
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0081 - output_variable1_loss: 0.0061 - output_variable2_loss: 0.0019 - val_loss: 0.0455 - val_output_variable1_loss: 0.0344 - val_output_variable2_loss: 0.0111
# Epoch 8/50
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0084 - output_variable1_loss: 0.0063 - output_variable2_loss: 0.0021 - val_loss: 0.0509 - val_output_variable1_loss: 0.0405 - val_output_variable2_loss: 0.0104
# Epoch 9/50
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0084 - output_variable1_loss: 0.0060 - output_variable2_loss: 0.0025 - val_loss: 0.0554 - val_output_variable1_loss: 0.0403 - val_output_variable2_loss: 0.0151
# Epoch 10/50
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0073 - output_variable1_loss: 0.0053 - output_variable2_loss: 0.0020 - val_loss: 0.0575 - val_output_variable1_loss: 0.0393 - val_output_variable2_loss: 0.0182
# Epoch 11/50
# 14/14 [==============================] - 1s 53ms/step - loss: 0.0068 - output_variable1_loss: 0.0050 - output_variable2_loss: 0.0018 - val_loss: 0.0565 - val_output_variable1_loss: 0.0393 - val_output_variable2_loss: 0.0172
# Epoch 12/50
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0065 - output_variable1_loss: 0.0049 - output_variable2_loss: 0.0017 - val_loss: 0.0498 - val_output_variable1_loss: 0.0334 - val_output_variable2_loss: 0.0164
# Epoch 13/50
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0064 - output_variable1_loss: 0.0048 - output_variable2_loss: 0.0016 - val_loss: 0.0599 - val_output_variable1_loss: 0.0419 - val_output_variable2_loss: 0.0180
# Epoch 14/50
# 14/14 [==============================] - 1s 62ms/step - loss: 0.0062 - output_variable1_loss: 0.0047 - output_variable2_loss: 0.0016 - val_loss: 0.0647 - val_output_variable1_loss: 0.0432 - val_output_variable2_loss: 0.0215
# Epoch 15/50
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0062 - output_variable1_loss: 0.0046 - output_variable2_loss: 0.0016 - val_loss: 0.0590 - val_output_variable1_loss: 0.0391 - val_output_variable2_loss: 0.0200
# Epoch 16/50
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0067 - output_variable1_loss: 0.0050 - output_variable2_loss: 0.0017 - val_loss: 0.0513 - val_output_variable1_loss: 0.0311 - val_output_variable2_loss: 0.0201
# Epoch 17/50
# 14/14 [==============================] - 1s 55ms/step - loss: 0.0080 - output_variable1_loss: 0.0063 - output_variable2_loss: 0.0016 - val_loss: 0.0494 - val_output_variable1_loss: 0.0322 - val_output_variable2_loss: 0.0172
# Epoch 18/50
# 14/14 [==============================] - 1s 54ms/step - loss: 0.0069 - output_variable1_loss: 0.0052 - output_variable2_loss: 0.0017 - val_loss: 0.0509 - val_output_variable1_loss: 0.0344 - val_output_variable2_loss: 0.0166
# Epoch 19/50
# 14/14 [==============================] - 1s 56ms/step - loss: 0.0062 - output_variable1_loss: 0.0046 - output_variable2_loss: 0.0016 - val_loss: 0.0585 - val_output_variable1_loss: 0.0414 - val_output_variable2_loss: 0.0172
# Epoch 1/50
# 15/15 [==============================] - 1s 59ms/step - loss: 0.0081 - output_variable1_loss: 0.0059 - output_variable2_loss: 0.0022 - val_loss: 0.0403 - val_output_variable1_loss: 0.0385 - val_output_variable2_loss: 0.0019
# Epoch 2/50
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0076 - output_variable1_loss: 0.0053 - output_variable2_loss: 0.0023 - val_loss: 0.0376 - val_output_variable1_loss: 0.0337 - val_output_variable2_loss: 0.0038
# Epoch 3/50
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0080 - output_variable1_loss: 0.0055 - output_variable2_loss: 0.0025 - val_loss: 0.0371 - val_output_variable1_loss: 0.0351 - val_output_variable2_loss: 0.0020
# Epoch 4/50
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0070 - output_variable1_loss: 0.0050 - output_variable2_loss: 0.0020 - val_loss: 0.0396 - val_output_variable1_loss: 0.0372 - val_output_variable2_loss: 0.0024
# Epoch 5/50
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0067 - output_variable1_loss: 0.0046 - output_variable2_loss: 0.0021 - val_loss: 0.0427 - val_output_variable1_loss: 0.0396 - val_output_variable2_loss: 0.0031
# Epoch 6/50
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0068 - output_variable1_loss: 0.0047 - output_variable2_loss: 0.0021 - val_loss: 0.0345 - val_output_variable1_loss: 0.0330 - val_output_variable2_loss: 0.0015
# Epoch 7/50
# 15/15 [==============================] - 1s 56ms/step - loss: 0.0066 - output_variable1_loss: 0.0047 - output_variable2_loss: 0.0020 - val_loss: 0.0390 - val_output_variable1_loss: 0.0377 - val_output_variable2_loss: 0.0013
# Epoch 8/50
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0061 - output_variable1_loss: 0.0045 - output_variable2_loss: 0.0017 - val_loss: 0.0368 - val_output_variable1_loss: 0.0356 - val_output_variable2_loss: 0.0012
# Epoch 9/50
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0058 - output_variable1_loss: 0.0041 - output_variable2_loss: 0.0017 - val_loss: 0.0369 - val_output_variable1_loss: 0.0348 - val_output_variable2_loss: 0.0021
# Epoch 10/50
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0060 - output_variable1_loss: 0.0042 - output_variable2_loss: 0.0018 - val_loss: 0.0373 - val_output_variable1_loss: 0.0344 - val_output_variable2_loss: 0.0029
# Epoch 11/50
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0056 - output_variable1_loss: 0.0040 - output_variable2_loss: 0.0017 - val_loss: 0.0358 - val_output_variable1_loss: 0.0334 - val_output_variable2_loss: 0.0024
# Epoch 12/50
# 15/15 [==============================] - 1s 60ms/step - loss: 0.0057 - output_variable1_loss: 0.0041 - output_variable2_loss: 0.0016 - val_loss: 0.0389 - val_output_variable1_loss: 0.0364 - val_output_variable2_loss: 0.0025
# Epoch 13/50
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0056 - output_variable1_loss: 0.0039 - output_variable2_loss: 0.0016 - val_loss: 0.0357 - val_output_variable1_loss: 0.0341 - val_output_variable2_loss: 0.0015
# Epoch 14/50
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0054 - output_variable1_loss: 0.0039 - output_variable2_loss: 0.0015 - val_loss: 0.0384 - val_output_variable1_loss: 0.0366 - val_output_variable2_loss: 0.0018
# Epoch 15/50
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0053 - output_variable1_loss: 0.0039 - output_variable2_loss: 0.0014 - val_loss: 0.0323 - val_output_variable1_loss: 0.0308 - val_output_variable2_loss: 0.0015
# Epoch 16/50
# 15/15 [==============================] - 1s 53ms/step - loss: 0.0051 - output_variable1_loss: 0.0037 - output_variable2_loss: 0.0014 - val_loss: 0.0358 - val_output_variable1_loss: 0.0346 - val_output_variable2_loss: 0.0012
# Epoch 17/50
# 15/15 [==============================] - 1s 54ms/step - loss: 0.0049 - output_variable1_loss: 0.0035 - output_variable2_loss: 0.0014 - val_loss: 0.0351 - val_output_variable1_loss: 0.0331 - val_output_variable2_loss: 0.0020
# Epoch 18/50
# 15/15 [==============================] - 1s 55ms/step - loss: 0.0050 - output_variable1_loss: 0.0036 - output_variable2_loss: 0.0014 - val_loss: 0.0345 - val_output_variable1_loss: 0.0327 - val_output_variable2_loss: 0.0018
# Epoch 19/50
# 15/15 [==============================] - 1s 57ms/step - loss: 0.0051 - output_variable1_loss: 0.0037 - output_variable2_loss: 0.0014 - val_loss: 0.0359 - val_output_variable1_loss: 0.0338 - val_output_variable2_loss: 0.0021
# Epoch 20/50
# 15/15 [==============================] - 1s 56ms/step - loss: 0.0054 - output_variable1_loss: 0.0040 - output_variable2_loss: 0.0014 - val_loss: 0.0349 - val_output_variable1_loss: 0.0336 - val_output_variable2_loss: 0.0014
# Epoch 21/50
# 15/15 [==============================] - 1s 56ms/step - loss: 0.0052 - output_variable1_loss: 0.0037 - output_variable2_loss: 0.0014 - val_loss: 0.0355 - val_output_variable1_loss: 0.0339 - val_output_variable2_loss: 0.0017
# Epoch 1/50
# 16/16 [==============================] - 1s 58ms/step - loss: 0.0061 - output_variable1_loss: 0.0047 - output_variable2_loss: 0.0014 - val_loss: 0.0292 - val_output_variable1_loss: 0.0194 - val_output_variable2_loss: 0.0099
# Epoch 2/50
# 16/16 [==============================] - 1s 55ms/step - loss: 0.0068 - output_variable1_loss: 0.0041 - output_variable2_loss: 0.0027 - val_loss: 0.0238 - val_output_variable1_loss: 0.0202 - val_output_variable2_loss: 0.0036
# Epoch 3/50
# 16/16 [==============================] - 1s 55ms/step - loss: 0.0062 - output_variable1_loss: 0.0039 - output_variable2_loss: 0.0023 - val_loss: 0.0219 - val_output_variable1_loss: 0.0190 - val_output_variable2_loss: 0.0030
# Epoch 4/50
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0061 - output_variable1_loss: 0.0045 - output_variable2_loss: 0.0017 - val_loss: 0.0171 - val_output_variable1_loss: 0.0155 - val_output_variable2_loss: 0.0017
# Epoch 5/50
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0058 - output_variable1_loss: 0.0042 - output_variable2_loss: 0.0016 - val_loss: 0.0252 - val_output_variable1_loss: 0.0234 - val_output_variable2_loss: 0.0018
# Epoch 6/50
# 16/16 [==============================] - 1s 56ms/step - loss: 0.0066 - output_variable1_loss: 0.0045 - output_variable2_loss: 0.0021 - val_loss: 0.0564 - val_output_variable1_loss: 0.0544 - val_output_variable2_loss: 0.0020
# Epoch 7/50
# 16/16 [==============================] - 1s 59ms/step - loss: 0.0100 - output_variable1_loss: 0.0083 - output_variable2_loss: 0.0017 - val_loss: 0.0338 - val_output_variable1_loss: 0.0323 - val_output_variable2_loss: 0.0015
# Epoch 8/50
# 16/16 [==============================] - 1s 56ms/step - loss: 0.0075 - output_variable1_loss: 0.0061 - output_variable2_loss: 0.0014 - val_loss: 0.0217 - val_output_variable1_loss: 0.0198 - val_output_variable2_loss: 0.0019
# Epoch 9/50
# 16/16 [==============================] - 1s 53ms/step - loss: 0.0055 - output_variable1_loss: 0.0042 - output_variable2_loss: 0.0013 - val_loss: 0.0219 - val_output_variable1_loss: 0.0199 - val_output_variable2_loss: 0.0020
# Epoch 10/50
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0050 - output_variable1_loss: 0.0037 - output_variable2_loss: 0.0013 - val_loss: 0.0222 - val_output_variable1_loss: 0.0201 - val_output_variable2_loss: 0.0022
# Epoch 11/50
# 16/16 [==============================] - 1s 55ms/step - loss: 0.0050 - output_variable1_loss: 0.0037 - output_variable2_loss: 0.0013 - val_loss: 0.0185 - val_output_variable1_loss: 0.0153 - val_output_variable2_loss: 0.0032
# Epoch 12/50
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0057 - output_variable1_loss: 0.0042 - output_variable2_loss: 0.0015 - val_loss: 0.0199 - val_output_variable1_loss: 0.0179 - val_output_variable2_loss: 0.0020
# Epoch 13/50
# 16/16 [==============================] - 1s 57ms/step - loss: 0.0053 - output_variable1_loss: 0.0039 - output_variable2_loss: 0.0014 - val_loss: 0.0226 - val_output_variable1_loss: 0.0212 - val_output_variable2_loss: 0.0014
# Epoch 14/50
# 16/16 [==============================] - 1s 54ms/step - loss: 0.0052 - output_variable1_loss: 0.0040 - output_variable2_loss: 0.0013 - val_loss: 0.0192 - val_output_variable1_loss: 0.0171 - val_output_variable2_loss: 0.0021
# Training time = 97.78649187088013 seconds

# %%
plt.figure(figsize=(12, 12))

for i, column in enumerate(loss_1):
    plt.subplot(2, 2, i+1)
    plt.plot(column, label="Train error")
    plt.plot(val_loss_1[i], label="Validation error")
    plt.xlabel('Epoch')
    plt.ylabel('Validation loss (MSE)')
    plt.legend()
    plt.title(f'Validation loss for Fold {i+1}')

plt.suptitle('Validation Loss across folds for Carbon Intensity in MLP', fontsize=18, y=1)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 12))

for i, column in enumerate(loss_2):
    plt.subplot(2, 2, i+1)
    plt.plot(column, label="Train error")
    plt.plot(val_loss_2[i], label="Validation error")
    plt.xlabel('Epoch')
    plt.ylabel('Validation loss (MSE)')
    plt.legend()
    plt.title(f'Validation loss for Fold {i+1}')

plt.suptitle('Validation Loss across folds for Solar Generation in MLP', fontsize=18, y=1)
plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
# Evaluate the model on the test data
predictions_1 = []
predictions_2 = []
#print(len(eval_target_variables))

for i in range(len(Y_val)):
    current_batch = X_val[i].reshape((1, NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))
    curr_pred1, curr_pred2 = model.predict(current_batch)
    predictions_1.append(curr_pred1)
    predictions_2.append(curr_pred2)
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 42ms/step

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_1):
    ax = axs[i]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_val[i, :, 0], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_2):
    ax = axs[i]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_val[i, :, 1], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
rmse = 0
for i in range(len(predictions_1)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_1[i][0], Y_val[i, :, 0]))}')
    rmse += sqrt(mean_squared_error(predictions_1[i][0], Y_val[i, :, 0]))

rmse /= len(predictions_1)    
print(f"RMSE for {columns_to_predict[0]} = {rmse}")

rmse = 0
for i in range(len(predictions_2)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_2[i][0], Y_val[i, :, 1]))}')
    rmse += sqrt(mean_squared_error(predictions_2[i][0], Y_val[i, :, 1]))

rmse /= len(predictions_2)    
print(f"RMSE for {columns_to_predict[1]} = {rmse}")
# Out:
# RMSE for kg_CO2/kWh = 0.1586490377388846
# RMSE for Avg solar generation = 0.06396654728806578

# %%
# Evaluate the model on the test data
predictions_1_test = []
predictions_2_test = []
#print(len(eval_target_variables))

total_time = 0

for i in range(len(Y_test)):
    current_batch = X_test[i].reshape((1, NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))
    start = time.time()
    curr_pred1, curr_pred2 = model.predict(current_batch)
    end = time.time()
    total_time += end-start
    predictions_1_test.append(curr_pred1)
    predictions_2_test.append(curr_pred2)
    
print(f"Average prediction time is {total_time/len(Y_test)} seconds")
# Out:
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 58ms/step
# Average prediction time is 0.12064948081970214 seconds

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_1_test):
    ax = axs[i]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_test[i, :, 0], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_2_test):
    ax = axs[i]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_test[i, :, 1], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
rmse = 0
for i in range(len(predictions_1_test)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_1[i][0], Y_val[i, :, 0]))}')
    rmse += sqrt(mean_squared_error(predictions_1_test[i][0], Y_test[i, :, 0]))

rmse /= len(predictions_1_test)    
print(f"RMSE for {columns_to_predict[0]} = {rmse}")

rmse = 0
for i in range(len(predictions_2_test)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_2[i][0], Y_val[i, :, 1]))}')
    rmse += sqrt(mean_squared_error(predictions_2_test[i][0], Y_test[i, :, 1]))

rmse /= len(predictions_2_test)    
print(f"RMSE for {columns_to_predict[1]} = {rmse}")
# Out:
# RMSE for kg_CO2/kWh = 0.1310822578144158
# RMSE for Avg solar generation = 0.06048547657806075

# %%
a = []
for column in predictions_1_test:
    a.append(column[0])
    
b = []
for column in predictions_2_test:
    b.append(column[0])

predictions1 = pd.DataFrame(a).T
predictions1.to_csv('../data/results/carbon_lstm.csv', index=False, header=False)
predictions2 = pd.DataFrame(b).T
predictions2.to_csv('../data/results/solar_lstm.csv', index=False, header=False)
