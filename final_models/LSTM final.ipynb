# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras
from sklearn.metrics import mean_squared_error
from math import sqrt
# Out:
# WARNING:tensorflow:From C:\Users\Matej\Documents\GitHub\thesis-forecasting\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
train = pd.read_csv("../data/schemas/warm_up/TrainSet.csv", sep=",")
validation = pd.read_csv("../data/schemas/warm_up/ValidationSet.csv", sep=",")
test = pd.read_csv("../data/schemas/warm_up/TestSet.csv", sep=",")

# %%
# Global variables

NUM_OF_TIMESTEPS_INPUT = 48
NUM_OF_TIMESTEPS_OUTPUT = 24

THRESHOLD = 0.4   # For feature selection

# %%
columns_to_predict = ["kg_CO2/kWh", "Avg solar generation"]

independent_variables = []

for column in train:
    if abs(train[column].corr(train[columns_to_predict[0]])) > THRESHOLD: #or abs(train[column].corr(train[columns_to_predict[1]])) > THRESHOLD:
        independent_variables.append(column)

independent_variables = [var for var in independent_variables if var not in columns_to_predict]
    
if "Index" in independent_variables:
    independent_variables.remove("Index")
if "Solar Generation (W/kW)_1" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_1")
if "Solar Generation (W/kW)_2" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_2")
if "Solar Generation (W/kW)_3" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_3")
    
print(independent_variables)
# Out:
# ['Hour_1', 'Hour_2', 'Hour_3', 'Occupant Count (people)_3', '12h Outdoor Drybulb Temperature (C)', '24h Outdoor Drybulb Temperature (C)', '12h Outdoor Relative Humidity (%)', '6h Direct Solar Radiation (W/m2)', '12h Direct Solar Radiation (W/m2)']

# %% [markdown]
# Prepare the data

# %%
# Split the X and Y for all sets

# Train set
X_train_default = train[independent_variables]
Y_train_default = train[columns_to_predict]

# Validation set, also include the data from train that was used only as output to get more datapoints
X_val_default = pd.concat([X_train_default.tail(NUM_OF_TIMESTEPS_OUTPUT), validation[independent_variables]], ignore_index=True)
Y_val_default = pd.concat([Y_train_default.tail(NUM_OF_TIMESTEPS_OUTPUT), validation[columns_to_predict]], ignore_index=True)

# Test set, also include the data from train that was used only as output to get more datapoints
X_test_default = pd.concat([X_val_default.tail(NUM_OF_TIMESTEPS_OUTPUT), test[independent_variables]], ignore_index=True)
Y_test_default = pd.concat([Y_val_default.tail(NUM_OF_TIMESTEPS_OUTPUT), test[columns_to_predict]], ignore_index=True)

NUM_OF_ROWS_TRAIN, NUM_OF_FEATURES = X_train_default.shape

print(X_train_default.shape)
print(X_val_default.shape)
print(X_test_default.shape)
# Out:
# (576, 9)
# (96, 9)
# (96, 9)

# %%
# Function to prepare the data into batches that will be passed into the model

def create_sequences(input_data, output_data, timesteps_input, timesteps_output):
    sequences, targets = [], []
    for i in range(len(input_data) - timesteps_input - timesteps_output + 1):
        seq = input_data[i:i + timesteps_input]
        target = output_data[i + timesteps_input: i + timesteps_input + timesteps_output]
        sequences.append(seq)
        targets.append(target)

    return np.array(sequences), np.array(targets)

# %%
X_train, Y_train = create_sequences(X_train_default, Y_train_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)
X_val, Y_val = create_sequences(X_val_default, Y_val_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)
X_test, Y_test = create_sequences(X_test_default, Y_test_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)

print(f"X_train = {X_train.shape}, Y_train = {Y_train.shape}\n"
      f"X_val = {X_val.shape}, Y_val = {Y_val.shape}\n"
      f"X_test = {X_test.shape}, Y_test = {Y_test.shape}")
# Out:
# X_train = (505, 48, 9), Y_train = (505, 24, 2)
# X_val = (25, 48, 9), Y_val = (25, 24, 2)
# X_test = (25, 48, 9), Y_test = (25, 24, 2)

# %%
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras import layers, models

tscv = TimeSeriesSplit(n_splits = 4, test_size=24) # For cross-validation

callback = keras.callbacks.EarlyStopping(monitor='loss', patience = 5) #patience parameter to be adjusted

loss = []
val_loss = []
loss_1 = []
val_loss_1 = []
loss_2 = []
val_loss_2 = []

# Input layer
input_layer = layers.Input(shape=(NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))

# Dense layers for variable 1
lstm1 = layers.LSTM(96, activation='leaky_relu', return_sequences=True)(input_layer)
lstm2 = layers.LSTM(48, activation='leaky_relu', return_sequences=True)(lstm1)
lstm3 = layers.LSTM(48, activation='leaky_relu', return_sequences=False)(lstm2)
output_variable1 = layers.Dense(24, name='output_variable1')(lstm3)

# Dense layers for variable 2
dense4 = layers.LSTM(96, activation='leaky_relu', return_sequences=True)(input_layer)
dense5 = layers.LSTM(48, activation='leaky_relu', return_sequences=True)(dense4)
dense6 = layers.LSTM(48, activation='leaky_relu', return_sequences=False)(dense5)
output_variable2 = layers.Dense(24, name='output_variable2')(dense6)

# Define the model
model = models.Model(inputs=input_layer, outputs=[output_variable1, output_variable2])

model.compile(
    optimizer='adam',
    loss={'output_variable1': 'mean_squared_error', 'output_variable2': 'mean_squared_error'}
) #types of optimizer, loss function to be adjusted
    
    
for train_data, test_data in tscv.split(X_train):
    X_train_current_split, X_test_current_split = X_train[train_data], X_train[test_data]
    y_train_current_split, y_test_current_split = Y_train[train_data], Y_train[test_data]
    
    history = model.fit(X_train_current_split, y={"output_variable1": y_train_current_split[:, :, 0], 
                                                  "output_variable2": y_train_current_split[:, :, 1]},
              epochs=100, 
              validation_data=(
                  X_test_current_split,
                {
                    "output_variable1": y_test_current_split[:, :, 0],
                    "output_variable2": y_test_current_split[:, :, 1],
                },
              ),
              # validation_split = 0.8,
              verbose=1,
              callbacks=callback
    )
    loss.append(model.history.history['loss'])
    val_loss.append(model.history.history['val_loss'])
    
    loss_1.append(model.history.history['output_variable1_loss'])
    val_loss_1.append(model.history.history['val_output_variable1_loss'])
    
    loss_2.append(model.history.history['output_variable2_loss'])
    val_loss_2.append(model.history.history['val_output_variable2_loss'])
# Out:
# WARNING:tensorflow:From C:\Users\Matej\Documents\GitHub\thesis-forecasting\venv\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# WARNING:tensorflow:From C:\Users\Matej\Documents\GitHub\thesis-forecasting\venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\Matej\Documents\GitHub\thesis-forecasting\venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# WARNING:tensorflow:From C:\Users\Matej\Documents\GitHub\thesis-forecasting\venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# 13/13 [==============================] - 7s 106ms/step - loss: 0.4476 - output_variable1_loss: 0.2785 - output_variable2_loss: 0.1691 - val_loss: 0.6129 - val_output_variable1_loss: 0.5195 - val_output_variable2_loss: 0.0934
# Epoch 2/100
# 13/13 [==============================] - 0s 37ms/step - loss: 0.2671 - output_variable1_loss: 0.1347 - output_variable2_loss: 0.1324 - val_loss: 0.3218 - val_output_variable1_loss: 0.2466 - val_output_variable2_loss: 0.0753
# Epoch 3/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.1672 - output_variable1_loss: 0.0572 - output_variable2_loss: 0.1099 - val_loss: 0.1168 - val_output_variable1_loss: 0.0459 - val_output_variable2_loss: 0.0710
# Epoch 4/100
# 13/13 [==============================] - 0s 38ms/step - loss: 0.1411 - output_variable1_loss: 0.0421 - output_variable2_loss: 0.0990 - val_loss: 0.1117 - val_output_variable1_loss: 0.0420 - val_output_variable2_loss: 0.0697
# Epoch 5/100
# 13/13 [==============================] - 0s 38ms/step - loss: 0.1150 - output_variable1_loss: 0.0391 - output_variable2_loss: 0.0759 - val_loss: 0.1186 - val_output_variable1_loss: 0.0604 - val_output_variable2_loss: 0.0582
# Epoch 6/100
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0832 - output_variable1_loss: 0.0366 - output_variable2_loss: 0.0466 - val_loss: 0.0969 - val_output_variable1_loss: 0.0463 - val_output_variable2_loss: 0.0506
# Epoch 7/100
# 13/13 [==============================] - 1s 41ms/step - loss: 0.0611 - output_variable1_loss: 0.0344 - output_variable2_loss: 0.0267 - val_loss: 0.0736 - val_output_variable1_loss: 0.0404 - val_output_variable2_loss: 0.0331
# Epoch 8/100
# 13/13 [==============================] - 1s 42ms/step - loss: 0.0496 - output_variable1_loss: 0.0323 - output_variable2_loss: 0.0173 - val_loss: 0.0800 - val_output_variable1_loss: 0.0533 - val_output_variable2_loss: 0.0267
# Epoch 9/100
# 13/13 [==============================] - 1s 42ms/step - loss: 0.0453 - output_variable1_loss: 0.0320 - output_variable2_loss: 0.0132 - val_loss: 0.0572 - val_output_variable1_loss: 0.0315 - val_output_variable2_loss: 0.0257
# Epoch 10/100
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0422 - output_variable1_loss: 0.0305 - output_variable2_loss: 0.0118 - val_loss: 0.0364 - val_output_variable1_loss: 0.0207 - val_output_variable2_loss: 0.0157
# Epoch 11/100
# 13/13 [==============================] - 0s 38ms/step - loss: 0.0395 - output_variable1_loss: 0.0295 - output_variable2_loss: 0.0100 - val_loss: 0.0659 - val_output_variable1_loss: 0.0510 - val_output_variable2_loss: 0.0149
# Epoch 12/100
# 13/13 [==============================] - 1s 41ms/step - loss: 0.0355 - output_variable1_loss: 0.0269 - output_variable2_loss: 0.0086 - val_loss: 0.0713 - val_output_variable1_loss: 0.0555 - val_output_variable2_loss: 0.0158
# Epoch 13/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.0337 - output_variable1_loss: 0.0262 - output_variable2_loss: 0.0075 - val_loss: 0.0397 - val_output_variable1_loss: 0.0274 - val_output_variable2_loss: 0.0123
# Epoch 14/100
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0320 - output_variable1_loss: 0.0256 - output_variable2_loss: 0.0064 - val_loss: 0.0413 - val_output_variable1_loss: 0.0291 - val_output_variable2_loss: 0.0122
# Epoch 15/100
# 13/13 [==============================] - 0s 38ms/step - loss: 0.0287 - output_variable1_loss: 0.0228 - output_variable2_loss: 0.0059 - val_loss: 0.0511 - val_output_variable1_loss: 0.0387 - val_output_variable2_loss: 0.0123
# Epoch 16/100
# 13/13 [==============================] - 0s 38ms/step - loss: 0.0273 - output_variable1_loss: 0.0220 - output_variable2_loss: 0.0053 - val_loss: 0.0431 - val_output_variable1_loss: 0.0318 - val_output_variable2_loss: 0.0114
# Epoch 17/100
# 13/13 [==============================] - 0s 39ms/step - loss: 0.0265 - output_variable1_loss: 0.0215 - output_variable2_loss: 0.0050 - val_loss: 0.0417 - val_output_variable1_loss: 0.0302 - val_output_variable2_loss: 0.0115
# Epoch 18/100
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0266 - output_variable1_loss: 0.0221 - output_variable2_loss: 0.0045 - val_loss: 0.0611 - val_output_variable1_loss: 0.0520 - val_output_variable2_loss: 0.0092
# Epoch 19/100
# 13/13 [==============================] - 0s 38ms/step - loss: 0.0236 - output_variable1_loss: 0.0191 - output_variable2_loss: 0.0045 - val_loss: 0.0631 - val_output_variable1_loss: 0.0557 - val_output_variable2_loss: 0.0074
# Epoch 20/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.0224 - output_variable1_loss: 0.0179 - output_variable2_loss: 0.0045 - val_loss: 0.0723 - val_output_variable1_loss: 0.0656 - val_output_variable2_loss: 0.0068
# Epoch 21/100
# 13/13 [==============================] - 1s 41ms/step - loss: 0.0219 - output_variable1_loss: 0.0173 - output_variable2_loss: 0.0046 - val_loss: 0.0819 - val_output_variable1_loss: 0.0733 - val_output_variable2_loss: 0.0086
# Epoch 22/100
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0218 - output_variable1_loss: 0.0175 - output_variable2_loss: 0.0043 - val_loss: 0.0694 - val_output_variable1_loss: 0.0617 - val_output_variable2_loss: 0.0076
# Epoch 23/100
# 13/13 [==============================] - 1s 42ms/step - loss: 0.0207 - output_variable1_loss: 0.0164 - output_variable2_loss: 0.0043 - val_loss: 0.0725 - val_output_variable1_loss: 0.0639 - val_output_variable2_loss: 0.0086
# Epoch 24/100
# 13/13 [==============================] - 1s 42ms/step - loss: 0.0194 - output_variable1_loss: 0.0154 - output_variable2_loss: 0.0040 - val_loss: 0.0771 - val_output_variable1_loss: 0.0692 - val_output_variable2_loss: 0.0079
# Epoch 25/100
# 13/13 [==============================] - 0s 38ms/step - loss: 0.0188 - output_variable1_loss: 0.0149 - output_variable2_loss: 0.0039 - val_loss: 0.0962 - val_output_variable1_loss: 0.0887 - val_output_variable2_loss: 0.0075
# Epoch 26/100
# 13/13 [==============================] - 0s 34ms/step - loss: 0.0209 - output_variable1_loss: 0.0167 - output_variable2_loss: 0.0042 - val_loss: 0.0790 - val_output_variable1_loss: 0.0718 - val_output_variable2_loss: 0.0073
# Epoch 27/100
# 13/13 [==============================] - 0s 37ms/step - loss: 0.0172 - output_variable1_loss: 0.0140 - output_variable2_loss: 0.0032 - val_loss: 0.0740 - val_output_variable1_loss: 0.0669 - val_output_variable2_loss: 0.0071
# Epoch 28/100
# 13/13 [==============================] - 0s 38ms/step - loss: 0.0164 - output_variable1_loss: 0.0133 - output_variable2_loss: 0.0032 - val_loss: 0.1005 - val_output_variable1_loss: 0.0936 - val_output_variable2_loss: 0.0069
# Epoch 29/100
# 13/13 [==============================] - 0s 38ms/step - loss: 0.0150 - output_variable1_loss: 0.0119 - output_variable2_loss: 0.0031 - val_loss: 0.0737 - val_output_variable1_loss: 0.0669 - val_output_variable2_loss: 0.0068
# Epoch 30/100
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0163 - output_variable1_loss: 0.0131 - output_variable2_loss: 0.0033 - val_loss: 0.0896 - val_output_variable1_loss: 0.0800 - val_output_variable2_loss: 0.0096
# Epoch 31/100
# 13/13 [==============================] - 0s 38ms/step - loss: 0.0143 - output_variable1_loss: 0.0116 - output_variable2_loss: 0.0027 - val_loss: 0.0709 - val_output_variable1_loss: 0.0630 - val_output_variable2_loss: 0.0079
# Epoch 32/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.0141 - output_variable1_loss: 0.0114 - output_variable2_loss: 0.0027 - val_loss: 0.1055 - val_output_variable1_loss: 0.0963 - val_output_variable2_loss: 0.0093
# Epoch 33/100
# 13/13 [==============================] - 0s 38ms/step - loss: 0.0133 - output_variable1_loss: 0.0108 - output_variable2_loss: 0.0025 - val_loss: 0.0864 - val_output_variable1_loss: 0.0755 - val_output_variable2_loss: 0.0109
# Epoch 34/100
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0120 - output_variable1_loss: 0.0097 - output_variable2_loss: 0.0023 - val_loss: 0.0976 - val_output_variable1_loss: 0.0854 - val_output_variable2_loss: 0.0122
# Epoch 35/100
# 13/13 [==============================] - 0s 37ms/step - loss: 0.0114 - output_variable1_loss: 0.0092 - output_variable2_loss: 0.0023 - val_loss: 0.0951 - val_output_variable1_loss: 0.0852 - val_output_variable2_loss: 0.0099
# Epoch 36/100
# 13/13 [==============================] - 0s 37ms/step - loss: 0.0106 - output_variable1_loss: 0.0084 - output_variable2_loss: 0.0022 - val_loss: 0.1043 - val_output_variable1_loss: 0.0943 - val_output_variable2_loss: 0.0100
# Epoch 37/100
# 13/13 [==============================] - 1s 41ms/step - loss: 0.0103 - output_variable1_loss: 0.0082 - output_variable2_loss: 0.0021 - val_loss: 0.1073 - val_output_variable1_loss: 0.0955 - val_output_variable2_loss: 0.0118
# Epoch 38/100
# 13/13 [==============================] - 0s 38ms/step - loss: 0.0100 - output_variable1_loss: 0.0078 - output_variable2_loss: 0.0022 - val_loss: 0.0920 - val_output_variable1_loss: 0.0791 - val_output_variable2_loss: 0.0128
# Epoch 39/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.0093 - output_variable1_loss: 0.0074 - output_variable2_loss: 0.0019 - val_loss: 0.0916 - val_output_variable1_loss: 0.0777 - val_output_variable2_loss: 0.0139
# Epoch 40/100
# 13/13 [==============================] - 0s 38ms/step - loss: 0.0090 - output_variable1_loss: 0.0071 - output_variable2_loss: 0.0018 - val_loss: 0.0945 - val_output_variable1_loss: 0.0803 - val_output_variable2_loss: 0.0142
# Epoch 41/100
# 13/13 [==============================] - 1s 41ms/step - loss: 0.0084 - output_variable1_loss: 0.0064 - output_variable2_loss: 0.0020 - val_loss: 0.1083 - val_output_variable1_loss: 0.0873 - val_output_variable2_loss: 0.0209
# Epoch 42/100
# 13/13 [==============================] - 0s 38ms/step - loss: 0.0081 - output_variable1_loss: 0.0061 - output_variable2_loss: 0.0020 - val_loss: 0.0883 - val_output_variable1_loss: 0.0734 - val_output_variable2_loss: 0.0148
# Epoch 43/100
# 13/13 [==============================] - 1s 41ms/step - loss: 0.0084 - output_variable1_loss: 0.0065 - output_variable2_loss: 0.0019 - val_loss: 0.0806 - val_output_variable1_loss: 0.0701 - val_output_variable2_loss: 0.0105
# Epoch 44/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.0090 - output_variable1_loss: 0.0072 - output_variable2_loss: 0.0017 - val_loss: 0.0781 - val_output_variable1_loss: 0.0689 - val_output_variable2_loss: 0.0092
# Epoch 45/100
# 13/13 [==============================] - 0s 37ms/step - loss: 0.0086 - output_variable1_loss: 0.0068 - output_variable2_loss: 0.0018 - val_loss: 0.0852 - val_output_variable1_loss: 0.0732 - val_output_variable2_loss: 0.0120
# Epoch 46/100
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0073 - output_variable1_loss: 0.0055 - output_variable2_loss: 0.0018 - val_loss: 0.0784 - val_output_variable1_loss: 0.0638 - val_output_variable2_loss: 0.0147
# Epoch 47/100
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0070 - output_variable1_loss: 0.0054 - output_variable2_loss: 0.0016 - val_loss: 0.0787 - val_output_variable1_loss: 0.0673 - val_output_variable2_loss: 0.0114
# Epoch 48/100
# 13/13 [==============================] - 0s 37ms/step - loss: 0.0069 - output_variable1_loss: 0.0054 - output_variable2_loss: 0.0015 - val_loss: 0.0780 - val_output_variable1_loss: 0.0670 - val_output_variable2_loss: 0.0110
# Epoch 49/100
# 13/13 [==============================] - 0s 38ms/step - loss: 0.0066 - output_variable1_loss: 0.0051 - output_variable2_loss: 0.0014 - val_loss: 0.0916 - val_output_variable1_loss: 0.0790 - val_output_variable2_loss: 0.0126
# Epoch 50/100
# 13/13 [==============================] - 1s 42ms/step - loss: 0.0062 - output_variable1_loss: 0.0048 - output_variable2_loss: 0.0014 - val_loss: 0.0740 - val_output_variable1_loss: 0.0623 - val_output_variable2_loss: 0.0117
# Epoch 51/100
# 13/13 [==============================] - 1s 43ms/step - loss: 0.0060 - output_variable1_loss: 0.0046 - output_variable2_loss: 0.0015 - val_loss: 0.0734 - val_output_variable1_loss: 0.0621 - val_output_variable2_loss: 0.0114
# Epoch 52/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.0059 - output_variable1_loss: 0.0043 - output_variable2_loss: 0.0016 - val_loss: 0.0853 - val_output_variable1_loss: 0.0711 - val_output_variable2_loss: 0.0142
# Epoch 53/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.0057 - output_variable1_loss: 0.0043 - output_variable2_loss: 0.0014 - val_loss: 0.0702 - val_output_variable1_loss: 0.0592 - val_output_variable2_loss: 0.0110
# Epoch 54/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.0057 - output_variable1_loss: 0.0042 - output_variable2_loss: 0.0015 - val_loss: 0.0661 - val_output_variable1_loss: 0.0555 - val_output_variable2_loss: 0.0106
# Epoch 55/100
# 13/13 [==============================] - 1s 42ms/step - loss: 0.0058 - output_variable1_loss: 0.0044 - output_variable2_loss: 0.0014 - val_loss: 0.0764 - val_output_variable1_loss: 0.0655 - val_output_variable2_loss: 0.0108
# Epoch 56/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.0059 - output_variable1_loss: 0.0044 - output_variable2_loss: 0.0015 - val_loss: 0.0746 - val_output_variable1_loss: 0.0639 - val_output_variable2_loss: 0.0107
# Epoch 57/100
# 13/13 [==============================] - 1s 42ms/step - loss: 0.0094 - output_variable1_loss: 0.0078 - output_variable2_loss: 0.0016 - val_loss: 0.0827 - val_output_variable1_loss: 0.0698 - val_output_variable2_loss: 0.0129
# Epoch 58/100
# 13/13 [==============================] - 0s 38ms/step - loss: 0.0086 - output_variable1_loss: 0.0072 - output_variable2_loss: 0.0014 - val_loss: 0.0844 - val_output_variable1_loss: 0.0704 - val_output_variable2_loss: 0.0140
# Epoch 59/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.0069 - output_variable1_loss: 0.0056 - output_variable2_loss: 0.0013 - val_loss: 0.0730 - val_output_variable1_loss: 0.0618 - val_output_variable2_loss: 0.0112
# Epoch 1/100
# 14/14 [==============================] - 1s 44ms/step - loss: 0.0097 - output_variable1_loss: 0.0079 - output_variable2_loss: 0.0018 - val_loss: 0.0588 - val_output_variable1_loss: 0.0429 - val_output_variable2_loss: 0.0159
# Epoch 2/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.0087 - output_variable1_loss: 0.0071 - output_variable2_loss: 0.0016 - val_loss: 0.0826 - val_output_variable1_loss: 0.0704 - val_output_variable2_loss: 0.0123
# Epoch 3/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.0083 - output_variable1_loss: 0.0068 - output_variable2_loss: 0.0015 - val_loss: 0.0527 - val_output_variable1_loss: 0.0358 - val_output_variable2_loss: 0.0169
# Epoch 4/100
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0069 - output_variable1_loss: 0.0055 - output_variable2_loss: 0.0014 - val_loss: 0.0740 - val_output_variable1_loss: 0.0566 - val_output_variable2_loss: 0.0173
# Epoch 5/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.0058 - output_variable1_loss: 0.0045 - output_variable2_loss: 0.0013 - val_loss: 0.0699 - val_output_variable1_loss: 0.0522 - val_output_variable2_loss: 0.0177
# Epoch 6/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.0054 - output_variable1_loss: 0.0041 - output_variable2_loss: 0.0013 - val_loss: 0.0692 - val_output_variable1_loss: 0.0493 - val_output_variable2_loss: 0.0199
# Epoch 7/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.0056 - output_variable1_loss: 0.0043 - output_variable2_loss: 0.0013 - val_loss: 0.0555 - val_output_variable1_loss: 0.0355 - val_output_variable2_loss: 0.0199
# Epoch 8/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.0054 - output_variable1_loss: 0.0041 - output_variable2_loss: 0.0013 - val_loss: 0.0785 - val_output_variable1_loss: 0.0554 - val_output_variable2_loss: 0.0231
# Epoch 9/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.0050 - output_variable1_loss: 0.0037 - output_variable2_loss: 0.0013 - val_loss: 0.0767 - val_output_variable1_loss: 0.0583 - val_output_variable2_loss: 0.0184
# Epoch 10/100
# 14/14 [==============================] - 1s 47ms/step - loss: 0.0050 - output_variable1_loss: 0.0038 - output_variable2_loss: 0.0011 - val_loss: 0.0720 - val_output_variable1_loss: 0.0508 - val_output_variable2_loss: 0.0212
# Epoch 11/100
# 14/14 [==============================] - 1s 44ms/step - loss: 0.0048 - output_variable1_loss: 0.0037 - output_variable2_loss: 0.0011 - val_loss: 0.0697 - val_output_variable1_loss: 0.0487 - val_output_variable2_loss: 0.0210
# Epoch 12/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0045 - output_variable1_loss: 0.0034 - output_variable2_loss: 0.0010 - val_loss: 0.0703 - val_output_variable1_loss: 0.0498 - val_output_variable2_loss: 0.0205
# Epoch 13/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.0042 - output_variable1_loss: 0.0032 - output_variable2_loss: 9.7515e-04 - val_loss: 0.0700 - val_output_variable1_loss: 0.0474 - val_output_variable2_loss: 0.0226
# Epoch 14/100
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0042 - output_variable1_loss: 0.0032 - output_variable2_loss: 0.0010 - val_loss: 0.0726 - val_output_variable1_loss: 0.0506 - val_output_variable2_loss: 0.0220
# Epoch 15/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.0042 - output_variable1_loss: 0.0032 - output_variable2_loss: 9.4000e-04 - val_loss: 0.0709 - val_output_variable1_loss: 0.0493 - val_output_variable2_loss: 0.0216
# Epoch 16/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.0041 - output_variable1_loss: 0.0031 - output_variable2_loss: 9.2037e-04 - val_loss: 0.0700 - val_output_variable1_loss: 0.0490 - val_output_variable2_loss: 0.0210
# Epoch 17/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.0040 - output_variable1_loss: 0.0031 - output_variable2_loss: 9.6918e-04 - val_loss: 0.0669 - val_output_variable1_loss: 0.0475 - val_output_variable2_loss: 0.0195
# Epoch 18/100
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0040 - output_variable1_loss: 0.0030 - output_variable2_loss: 9.9928e-04 - val_loss: 0.0719 - val_output_variable1_loss: 0.0492 - val_output_variable2_loss: 0.0227
# Epoch 19/100
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0039 - output_variable1_loss: 0.0030 - output_variable2_loss: 9.3994e-04 - val_loss: 0.0705 - val_output_variable1_loss: 0.0476 - val_output_variable2_loss: 0.0229
# Epoch 20/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.0040 - output_variable1_loss: 0.0030 - output_variable2_loss: 9.1370e-04 - val_loss: 0.0692 - val_output_variable1_loss: 0.0459 - val_output_variable2_loss: 0.0233
# Epoch 21/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.0041 - output_variable1_loss: 0.0031 - output_variable2_loss: 9.5336e-04 - val_loss: 0.0670 - val_output_variable1_loss: 0.0416 - val_output_variable2_loss: 0.0254
# Epoch 22/100
# 14/14 [==============================] - 1s 43ms/step - loss: 0.0040 - output_variable1_loss: 0.0030 - output_variable2_loss: 9.7394e-04 - val_loss: 0.0659 - val_output_variable1_loss: 0.0444 - val_output_variable2_loss: 0.0215
# Epoch 23/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.0038 - output_variable1_loss: 0.0029 - output_variable2_loss: 8.9846e-04 - val_loss: 0.0704 - val_output_variable1_loss: 0.0456 - val_output_variable2_loss: 0.0247
# Epoch 24/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.0037 - output_variable1_loss: 0.0028 - output_variable2_loss: 9.0105e-04 - val_loss: 0.0645 - val_output_variable1_loss: 0.0445 - val_output_variable2_loss: 0.0200
# Epoch 25/100
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0036 - output_variable1_loss: 0.0027 - output_variable2_loss: 8.3403e-04 - val_loss: 0.0696 - val_output_variable1_loss: 0.0465 - val_output_variable2_loss: 0.0231
# Epoch 26/100
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0036 - output_variable1_loss: 0.0027 - output_variable2_loss: 8.9966e-04 - val_loss: 0.0690 - val_output_variable1_loss: 0.0492 - val_output_variable2_loss: 0.0197
# Epoch 27/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.0035 - output_variable1_loss: 0.0027 - output_variable2_loss: 8.6994e-04 - val_loss: 0.0734 - val_output_variable1_loss: 0.0489 - val_output_variable2_loss: 0.0245
# Epoch 28/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.0034 - output_variable1_loss: 0.0026 - output_variable2_loss: 8.0225e-04 - val_loss: 0.0726 - val_output_variable1_loss: 0.0492 - val_output_variable2_loss: 0.0235
# Epoch 29/100
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0036 - output_variable1_loss: 0.0027 - output_variable2_loss: 8.9287e-04 - val_loss: 0.0620 - val_output_variable1_loss: 0.0403 - val_output_variable2_loss: 0.0217
# Epoch 30/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.0036 - output_variable1_loss: 0.0028 - output_variable2_loss: 8.2696e-04 - val_loss: 0.0663 - val_output_variable1_loss: 0.0447 - val_output_variable2_loss: 0.0215
# Epoch 31/100
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0036 - output_variable1_loss: 0.0027 - output_variable2_loss: 8.8704e-04 - val_loss: 0.0704 - val_output_variable1_loss: 0.0455 - val_output_variable2_loss: 0.0249
# Epoch 32/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.0035 - output_variable1_loss: 0.0027 - output_variable2_loss: 8.4129e-04 - val_loss: 0.0657 - val_output_variable1_loss: 0.0430 - val_output_variable2_loss: 0.0227
# Epoch 33/100
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0034 - output_variable1_loss: 0.0026 - output_variable2_loss: 8.1338e-04 - val_loss: 0.0701 - val_output_variable1_loss: 0.0473 - val_output_variable2_loss: 0.0228
# Epoch 34/100
# 14/14 [==============================] - 1s 39ms/step - loss: 0.0032 - output_variable1_loss: 0.0025 - output_variable2_loss: 7.4666e-04 - val_loss: 0.0719 - val_output_variable1_loss: 0.0456 - val_output_variable2_loss: 0.0263
# Epoch 35/100
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0033 - output_variable1_loss: 0.0026 - output_variable2_loss: 7.1720e-04 - val_loss: 0.0731 - val_output_variable1_loss: 0.0471 - val_output_variable2_loss: 0.0260
# Epoch 36/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.0032 - output_variable1_loss: 0.0025 - output_variable2_loss: 7.1054e-04 - val_loss: 0.0754 - val_output_variable1_loss: 0.0490 - val_output_variable2_loss: 0.0264
# Epoch 37/100
# 14/14 [==============================] - 1s 41ms/step - loss: 0.0032 - output_variable1_loss: 0.0025 - output_variable2_loss: 7.0839e-04 - val_loss: 0.0729 - val_output_variable1_loss: 0.0485 - val_output_variable2_loss: 0.0244
# Epoch 38/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.0032 - output_variable1_loss: 0.0025 - output_variable2_loss: 6.8778e-04 - val_loss: 0.0769 - val_output_variable1_loss: 0.0504 - val_output_variable2_loss: 0.0265
# Epoch 39/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.0031 - output_variable1_loss: 0.0023 - output_variable2_loss: 7.2880e-04 - val_loss: 0.0739 - val_output_variable1_loss: 0.0500 - val_output_variable2_loss: 0.0239
# Epoch 40/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.0030 - output_variable1_loss: 0.0023 - output_variable2_loss: 7.2188e-04 - val_loss: 0.0783 - val_output_variable1_loss: 0.0510 - val_output_variable2_loss: 0.0273
# Epoch 41/100
# 14/14 [==============================] - 1s 38ms/step - loss: 0.0031 - output_variable1_loss: 0.0023 - output_variable2_loss: 7.2207e-04 - val_loss: 0.0759 - val_output_variable1_loss: 0.0499 - val_output_variable2_loss: 0.0260
# Epoch 42/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.0032 - output_variable1_loss: 0.0025 - output_variable2_loss: 6.9794e-04 - val_loss: 0.0786 - val_output_variable1_loss: 0.0510 - val_output_variable2_loss: 0.0276
# Epoch 43/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.0032 - output_variable1_loss: 0.0025 - output_variable2_loss: 7.1192e-04 - val_loss: 0.0744 - val_output_variable1_loss: 0.0479 - val_output_variable2_loss: 0.0266
# Epoch 44/100
# 14/14 [==============================] - 1s 42ms/step - loss: 0.0031 - output_variable1_loss: 0.0024 - output_variable2_loss: 7.3039e-04 - val_loss: 0.0752 - val_output_variable1_loss: 0.0497 - val_output_variable2_loss: 0.0255
# Epoch 45/100
# 14/14 [==============================] - 1s 40ms/step - loss: 0.0033 - output_variable1_loss: 0.0025 - output_variable2_loss: 7.5961e-04 - val_loss: 0.0785 - val_output_variable1_loss: 0.0516 - val_output_variable2_loss: 0.0269
# Epoch 1/100
# 15/15 [==============================] - 1s 42ms/step - loss: 0.0062 - output_variable1_loss: 0.0046 - output_variable2_loss: 0.0016 - val_loss: 0.0263 - val_output_variable1_loss: 0.0239 - val_output_variable2_loss: 0.0025
# Epoch 2/100
# 15/15 [==============================] - 1s 41ms/step - loss: 0.0058 - output_variable1_loss: 0.0040 - output_variable2_loss: 0.0019 - val_loss: 0.0135 - val_output_variable1_loss: 0.0101 - val_output_variable2_loss: 0.0034
# Epoch 3/100
# 15/15 [==============================] - 1s 42ms/step - loss: 0.0052 - output_variable1_loss: 0.0039 - output_variable2_loss: 0.0014 - val_loss: 0.0307 - val_output_variable1_loss: 0.0293 - val_output_variable2_loss: 0.0014
# Epoch 4/100
# 15/15 [==============================] - 1s 40ms/step - loss: 0.0054 - output_variable1_loss: 0.0042 - output_variable2_loss: 0.0012 - val_loss: 0.0168 - val_output_variable1_loss: 0.0147 - val_output_variable2_loss: 0.0021
# Epoch 5/100
# 15/15 [==============================] - 1s 40ms/step - loss: 0.0051 - output_variable1_loss: 0.0039 - output_variable2_loss: 0.0012 - val_loss: 0.0121 - val_output_variable1_loss: 0.0098 - val_output_variable2_loss: 0.0023
# Epoch 6/100
# 15/15 [==============================] - 1s 40ms/step - loss: 0.0058 - output_variable1_loss: 0.0047 - output_variable2_loss: 0.0011 - val_loss: 0.0115 - val_output_variable1_loss: 0.0092 - val_output_variable2_loss: 0.0023
# Epoch 7/100
# 15/15 [==============================] - 1s 42ms/step - loss: 0.0056 - output_variable1_loss: 0.0046 - output_variable2_loss: 0.0010 - val_loss: 0.0132 - val_output_variable1_loss: 0.0114 - val_output_variable2_loss: 0.0017
# Epoch 8/100
# 15/15 [==============================] - 1s 41ms/step - loss: 0.0047 - output_variable1_loss: 0.0038 - output_variable2_loss: 9.2235e-04 - val_loss: 0.0126 - val_output_variable1_loss: 0.0109 - val_output_variable2_loss: 0.0017
# Epoch 9/100
# 15/15 [==============================] - 1s 40ms/step - loss: 0.0043 - output_variable1_loss: 0.0034 - output_variable2_loss: 9.3709e-04 - val_loss: 0.0134 - val_output_variable1_loss: 0.0121 - val_output_variable2_loss: 0.0013
# Epoch 10/100
# 15/15 [==============================] - 1s 42ms/step - loss: 0.0037 - output_variable1_loss: 0.0028 - output_variable2_loss: 9.0366e-04 - val_loss: 0.0084 - val_output_variable1_loss: 0.0059 - val_output_variable2_loss: 0.0025
# Epoch 11/100
# 15/15 [==============================] - 1s 39ms/step - loss: 0.0036 - output_variable1_loss: 0.0027 - output_variable2_loss: 9.6203e-04 - val_loss: 0.0098 - val_output_variable1_loss: 0.0075 - val_output_variable2_loss: 0.0022
# Epoch 12/100
# 15/15 [==============================] - 1s 40ms/step - loss: 0.0033 - output_variable1_loss: 0.0024 - output_variable2_loss: 9.5420e-04 - val_loss: 0.0101 - val_output_variable1_loss: 0.0080 - val_output_variable2_loss: 0.0021
# Epoch 13/100
# 15/15 [==============================] - 1s 40ms/step - loss: 0.0031 - output_variable1_loss: 0.0023 - output_variable2_loss: 7.5942e-04 - val_loss: 0.0090 - val_output_variable1_loss: 0.0076 - val_output_variable2_loss: 0.0014
# Epoch 14/100
# 15/15 [==============================] - 1s 41ms/step - loss: 0.0031 - output_variable1_loss: 0.0024 - output_variable2_loss: 7.4110e-04 - val_loss: 0.0087 - val_output_variable1_loss: 0.0075 - val_output_variable2_loss: 0.0011
# Epoch 15/100
# 15/15 [==============================] - 1s 40ms/step - loss: 0.0031 - output_variable1_loss: 0.0023 - output_variable2_loss: 8.0119e-04 - val_loss: 0.0087 - val_output_variable1_loss: 0.0073 - val_output_variable2_loss: 0.0014
# Epoch 16/100
# 15/15 [==============================] - 1s 41ms/step - loss: 0.0030 - output_variable1_loss: 0.0022 - output_variable2_loss: 8.6520e-04 - val_loss: 0.0093 - val_output_variable1_loss: 0.0072 - val_output_variable2_loss: 0.0021
# Epoch 17/100
# 15/15 [==============================] - 1s 40ms/step - loss: 0.0033 - output_variable1_loss: 0.0026 - output_variable2_loss: 7.8725e-04 - val_loss: 0.0091 - val_output_variable1_loss: 0.0068 - val_output_variable2_loss: 0.0023
# Epoch 18/100
# 15/15 [==============================] - 1s 42ms/step - loss: 0.0030 - output_variable1_loss: 0.0023 - output_variable2_loss: 7.5095e-04 - val_loss: 0.0085 - val_output_variable1_loss: 0.0074 - val_output_variable2_loss: 0.0010
# Epoch 19/100
# 15/15 [==============================] - 1s 42ms/step - loss: 0.0029 - output_variable1_loss: 0.0021 - output_variable2_loss: 7.1415e-04 - val_loss: 0.0082 - val_output_variable1_loss: 0.0066 - val_output_variable2_loss: 0.0015
# Epoch 20/100
# 15/15 [==============================] - 1s 44ms/step - loss: 0.0028 - output_variable1_loss: 0.0021 - output_variable2_loss: 6.8559e-04 - val_loss: 0.0082 - val_output_variable1_loss: 0.0069 - val_output_variable2_loss: 0.0013
# Epoch 21/100
# 15/15 [==============================] - 1s 41ms/step - loss: 0.0027 - output_variable1_loss: 0.0020 - output_variable2_loss: 6.9246e-04 - val_loss: 0.0086 - val_output_variable1_loss: 0.0071 - val_output_variable2_loss: 0.0015
# Epoch 22/100
# 15/15 [==============================] - 1s 41ms/step - loss: 0.0026 - output_variable1_loss: 0.0020 - output_variable2_loss: 6.3723e-04 - val_loss: 0.0081 - val_output_variable1_loss: 0.0067 - val_output_variable2_loss: 0.0014
# Epoch 23/100
# 15/15 [==============================] - 1s 40ms/step - loss: 0.0027 - output_variable1_loss: 0.0020 - output_variable2_loss: 6.9482e-04 - val_loss: 0.0085 - val_output_variable1_loss: 0.0070 - val_output_variable2_loss: 0.0014
# Epoch 24/100
# 15/15 [==============================] - 1s 42ms/step - loss: 0.0032 - output_variable1_loss: 0.0024 - output_variable2_loss: 7.3276e-04 - val_loss: 0.0084 - val_output_variable1_loss: 0.0070 - val_output_variable2_loss: 0.0014
# Epoch 25/100
# 15/15 [==============================] - 1s 47ms/step - loss: 0.0029 - output_variable1_loss: 0.0022 - output_variable2_loss: 6.8048e-04 - val_loss: 0.0083 - val_output_variable1_loss: 0.0068 - val_output_variable2_loss: 0.0015
# Epoch 26/100
# 15/15 [==============================] - 1s 42ms/step - loss: 0.0027 - output_variable1_loss: 0.0020 - output_variable2_loss: 6.5833e-04 - val_loss: 0.0083 - val_output_variable1_loss: 0.0071 - val_output_variable2_loss: 0.0012
# Epoch 27/100
# 15/15 [==============================] - 1s 43ms/step - loss: 0.0027 - output_variable1_loss: 0.0020 - output_variable2_loss: 6.8044e-04 - val_loss: 0.0084 - val_output_variable1_loss: 0.0069 - val_output_variable2_loss: 0.0014
# Epoch 1/100
# 16/16 [==============================] - 1s 45ms/step - loss: 0.0030 - output_variable1_loss: 0.0023 - output_variable2_loss: 7.0737e-04 - val_loss: 0.0489 - val_output_variable1_loss: 0.0458 - val_output_variable2_loss: 0.0032
# Epoch 2/100
# 16/16 [==============================] - 1s 42ms/step - loss: 0.0034 - output_variable1_loss: 0.0024 - output_variable2_loss: 9.8030e-04 - val_loss: 0.0557 - val_output_variable1_loss: 0.0531 - val_output_variable2_loss: 0.0026
# Epoch 3/100
# 16/16 [==============================] - 1s 44ms/step - loss: 0.0038 - output_variable1_loss: 0.0024 - output_variable2_loss: 0.0013 - val_loss: 0.0413 - val_output_variable1_loss: 0.0396 - val_output_variable2_loss: 0.0017
# Epoch 4/100
# 16/16 [==============================] - 1s 42ms/step - loss: 0.0039 - output_variable1_loss: 0.0026 - output_variable2_loss: 0.0013 - val_loss: 0.0588 - val_output_variable1_loss: 0.0568 - val_output_variable2_loss: 0.0020
# Epoch 5/100
# 16/16 [==============================] - 1s 44ms/step - loss: 0.0038 - output_variable1_loss: 0.0026 - output_variable2_loss: 0.0012 - val_loss: 0.0442 - val_output_variable1_loss: 0.0432 - val_output_variable2_loss: 0.0010
# Epoch 6/100
# 16/16 [==============================] - 1s 46ms/step - loss: 0.0035 - output_variable1_loss: 0.0023 - output_variable2_loss: 0.0012 - val_loss: 0.0468 - val_output_variable1_loss: 0.0457 - val_output_variable2_loss: 0.0011

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss_1):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss_1[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error 1", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss_2):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss_2[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error 2", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
# Evaluate the model on the test data
predictions_1 = []
predictions_2 = []
#print(len(eval_target_variables))

for i in range(len(Y_val)):
    current_batch = X_val[i].reshape((1, NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))
    curr_pred1, curr_pred2 = model.predict(current_batch)
    predictions_1.append(curr_pred1)
    predictions_2.append(curr_pred2)
# Out:
# 1/1 [==============================] - 1s 768ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_1):
    ax = axs[i]
    # TODO seems to work but check why column[0]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_val[i, :, 0], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_2):
    ax = axs[i]
    # TODO seems to work but check why column[0]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_val[i, :, 1], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
rmse = 0
for i in range(len(predictions_1)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_1[i][0], Y_val[i, :, 0]))}')
    rmse += sqrt(mean_squared_error(predictions_1[i][0], Y_val[i, :, 0]))

rmse /= len(predictions_1)    
print(f"RMSE for {columns_to_predict[0]} = {rmse}")

rmse = 0
for i in range(len(predictions_2)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_2[i][0], Y_val[i, :, 1]))}')
    rmse += sqrt(mean_squared_error(predictions_2[i][0], Y_val[i, :, 1]))

rmse /= len(predictions_2)    
print(f"RMSE for {columns_to_predict[1]} = {rmse}")
# Out:
# RMSE for kg_CO2/kWh = 0.15450500807836906
# RMSE for Avg solar generation = 0.03622518988074184

# %%
# Evaluate the model on the test data
predictions_1_test = []
predictions_2_test = []
#print(len(eval_target_variables))

for i in range(len(Y_test)):
    current_batch = X_test[i].reshape((1, NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))
    curr_pred1, curr_pred2 = model.predict(current_batch)
    predictions_1_test.append(curr_pred1)
    predictions_2_test.append(curr_pred2)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_1_test):
    ax = axs[i]
    # TODO seems to work but check why column[0]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_test[i, :, 0], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_2_test):
    ax = axs[i]
    # TODO seems to work but check why column[0]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_test[i, :, 1], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
rmse = 0
for i in range(len(predictions_1_test)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_1[i][0], Y_val[i, :, 0]))}')
    rmse += sqrt(mean_squared_error(predictions_1_test[i][0], Y_test[i, :, 0]))

rmse /= len(predictions_1_test)    
print(f"RMSE for {columns_to_predict[0]} = {rmse}")

rmse = 0
for i in range(len(predictions_2_test)):
    #print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_2[i][0], Y_val[i, :, 1]))}')
    rmse += sqrt(mean_squared_error(predictions_2_test[i][0], Y_test[i, :, 1]))

rmse /= len(predictions_2_test)    
print(f"RMSE for {columns_to_predict[1]} = {rmse}")
# Out:
# RMSE for kg_CO2/kWh = 0.17243218273599717
# RMSE for Avg solar generation = 0.054585737032172135
