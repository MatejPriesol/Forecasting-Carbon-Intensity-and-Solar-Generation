# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras
from sklearn.metrics import mean_squared_error
from math import sqrt
# Out:
# WARNING:tensorflow:From C:\Users\Matej\Documents\GitHub\thesis-forecasting\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
train = pd.read_csv("../data/schemas/warm_up/TrainSet.csv", sep=",")
validation = pd.read_csv("../data/schemas/warm_up/ValidationSet.csv", sep=",")
test = pd.read_csv("../data/schemas/warm_up/TestSet.csv", sep=",")

# %%
# Global variables

NUM_OF_TIMESTEPS_INPUT = 48
NUM_OF_TIMESTEPS_OUTPUT = 24

THRESHOLD = 0.4   # For feature selection

# %%
columns_to_predict = ["kg_CO2/kWh", "Avg solar generation"]

independent_variables = []

for column in train:
    if abs(train[column].corr(train[columns_to_predict[0]])) > THRESHOLD: #or abs(train[column].corr(train[columns_to_predict[1]])) > THRESHOLD:
        independent_variables.append(column)

#[independent_variables.remove(i) for i in columns_to_predict]
independent_variables.remove(columns_to_predict[0])
    
if "Index" in independent_variables:
    independent_variables.remove("Index")
if "Solar Generation (W/kW)_1" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_1")
if "Solar Generation (W/kW)_2" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_2")
if "Solar Generation (W/kW)_3" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_3")
    
print(independent_variables)
# Out:
# ['Hour_1', 'Hour_2', 'Hour_3', 'Occupant Count (people)_3', '12h Outdoor Drybulb Temperature (C)', '24h Outdoor Drybulb Temperature (C)', '12h Outdoor Relative Humidity (%)', '6h Direct Solar Radiation (W/m2)', '12h Direct Solar Radiation (W/m2)']

# %% [markdown]
# Prepare the data

# %%
# Split the X and Y for all sets

# Train set
X_train_default = train[independent_variables]
Y_train_default = train[columns_to_predict]

# Validation set, also include the data from train that was used only as output to get more datapoints
X_val_default = pd.concat([X_train_default.tail(NUM_OF_TIMESTEPS_OUTPUT), validation[independent_variables]], ignore_index=True)
Y_val_default = pd.concat([Y_train_default.tail(NUM_OF_TIMESTEPS_OUTPUT), validation[columns_to_predict]], ignore_index=True)

# Test set, also include the data from train that was used only as output to get more datapoints
X_test_default = pd.concat([X_val_default.tail(NUM_OF_TIMESTEPS_OUTPUT), test[independent_variables]], ignore_index=True)
Y_test_default = pd.concat([Y_val_default.tail(NUM_OF_TIMESTEPS_OUTPUT), test[columns_to_predict]], ignore_index=True)

NUM_OF_ROWS_TRAIN, NUM_OF_FEATURES = X_train_default.shape

print(X_train_default.shape)
print(X_val_default.shape)
print(X_test_default.shape)
# Out:
# (576, 9)
# (96, 9)
# (96, 9)

# %%
# Function to prepare the data into batches that will be passed into the model

def create_sequences(input_data, output_data, timesteps_input, timesteps_output):
    sequences, targets = [], []
    for i in range(len(input_data) - timesteps_input - timesteps_output + 1):
        seq = input_data[i:i + timesteps_input]
        target = output_data[i + timesteps_input: i + timesteps_input + timesteps_output]
        sequences.append(seq)
        targets.append(target)

    return np.array(sequences), np.array(targets)

# %%
X_train, Y_train = create_sequences(X_train_default, Y_train_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)
X_val, Y_val = create_sequences(X_val_default, Y_val_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)
X_test, Y_test = create_sequences(X_test_default, Y_test_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)

print(f"X_train = {X_train.shape}, Y_train = {Y_train.shape}\n"
      f"X_val = {X_val.shape}, Y_val = {Y_val.shape}\n"
      f"X_test = {X_test.shape}, Y_test = {Y_test.shape}")
# Out:
# X_train = (505, 48, 9), Y_train = (505, 24, 2)
# X_val = (25, 48, 9), Y_val = (25, 24, 2)
# X_test = (25, 48, 9), Y_test = (25, 24, 2)

# %%
print(Y_train[:, :, 0])
# Out:
# [[0.59739428 0.49429981 0.38708765 ... 0.73547528 0.69513525 0.71729728]
#  [0.49429981 0.38708765 0.28880037 ... 0.69513525 0.71729728 0.6633147 ]
#  [0.38708765 0.28880037 0.2346659  ... 0.71729728 0.6633147  0.55539687]
#  ...
#  [0.47416969 0.39741721 0.28594384 ... 0.4397153  0.45619247 0.45482902]
#  [0.39741721 0.28594384 0.16805223 ... 0.45619247 0.45482902 0.41836388]
#  [0.28594384 0.16805223 0.12974031 ... 0.45482902 0.41836388 0.39162712]]

# %%
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras import layers, models

tscv = TimeSeriesSplit(n_splits = 4) # For cross-validation

callback = keras.callbacks.EarlyStopping(monitor='loss', patience = 6) #patience parameter to be adjusted

loss = []
val_loss = []
loss_1 = []
val_loss_1 = []
loss_2 = []
val_loss_2 = []

# Input layer
input_layer = layers.Input(shape=(NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))

# Dense layers for variable 1
lstm1 = layers.LSTM(98, activation='tanh', return_sequences=True)(input_layer)
lstm2 = layers.LSTM(48, activation='tanh', return_sequences=True)(lstm1)
lstm3 = layers.LSTM(24, activation='tanh', return_sequences=False)(lstm2)
output_variable1 = layers.Dense(24, name='output_variable1')(lstm3)

# Dense layers for variable 2
dense4 = layers.LSTM(96, activation='tanh', return_sequences=True)(input_layer)
dense5 = layers.LSTM(48, activation='tanh', return_sequences=True)(dense4)
dense6 = layers.LSTM(24, activation='tanh', return_sequences=False)(dense5)
output_variable2 = layers.Dense(24, name='output_variable2')(dense6)

# Define the model
model = models.Model(inputs=input_layer, outputs=[output_variable1, output_variable2])

model.compile(
    optimizer='adam',
    loss={'output_variable1': 'mean_squared_error', 'output_variable2': 'mean_squared_error'}
) #types of optimizer, loss function to be adjusted
    
    
for train_data, test_data in tscv.split(X_train):
    X_train_current_split, X_test_current_split = X_train[train_data], X_train[test_data]
    y_train_current_split, y_test_current_split = Y_train[train_data], Y_train[test_data]
    
    history = model.fit(X_train_current_split, y={"output_variable1": y_train_current_split[:, :, 0], 
                                                  "output_variable2": y_train_current_split[:, :, 1]},
              epochs=100, 
              validation_data=(
                  X_test_current_split,
                {
                    "output_variable1": y_test_current_split[:, :, 0],
                    "output_variable2": y_test_current_split[:, :, 1],
                },
              ),
              # validation_split = 0.8,
              verbose=1,
              callbacks=callback
    )
    loss.append(model.history.history['loss'])
    val_loss.append(model.history.history['val_loss'])
    
    loss_1.append(model.history.history['output_variable1_loss'])
    val_loss_1.append(model.history.history['val_output_variable1_loss'])
    
    loss_2.append(model.history.history['output_variable2_loss'])
    val_loss_2.append(model.history.history['val_output_variable2_loss'])
# Out:
# WARNING:tensorflow:From C:\Users\Matej\Documents\GitHub\thesis-forecasting\venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\Matej\Documents\GitHub\thesis-forecasting\venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# WARNING:tensorflow:From C:\Users\Matej\Documents\GitHub\thesis-forecasting\venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# 4/4 [==============================] - 9s 585ms/step - loss: 0.5901 - output_variable1_loss: 0.3905 - output_variable2_loss: 0.1996 - val_loss: 0.3353 - val_output_variable1_loss: 0.1595 - val_output_variable2_loss: 0.1758
# Epoch 2/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.4264 - output_variable1_loss: 0.2735 - output_variable2_loss: 0.1529 - val_loss: 0.2533 - val_output_variable1_loss: 0.1084 - val_output_variable2_loss: 0.1450
# Epoch 3/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.3113 - output_variable1_loss: 0.1817 - output_variable2_loss: 0.1296 - val_loss: 0.2235 - val_output_variable1_loss: 0.0912 - val_output_variable2_loss: 0.1322
# Epoch 4/100
# 4/4 [==============================] - 0s 53ms/step - loss: 0.2570 - output_variable1_loss: 0.1363 - output_variable2_loss: 0.1207 - val_loss: 0.2134 - val_output_variable1_loss: 0.0883 - val_output_variable2_loss: 0.1251
# Epoch 5/100
# 4/4 [==============================] - 0s 58ms/step - loss: 0.2248 - output_variable1_loss: 0.1113 - output_variable2_loss: 0.1135 - val_loss: 0.2009 - val_output_variable1_loss: 0.0846 - val_output_variable2_loss: 0.1163
# Epoch 6/100
# 4/4 [==============================] - 0s 57ms/step - loss: 0.2004 - output_variable1_loss: 0.0952 - output_variable2_loss: 0.1051 - val_loss: 0.1832 - val_output_variable1_loss: 0.0761 - val_output_variable2_loss: 0.1071
# Epoch 7/100
# 4/4 [==============================] - 0s 58ms/step - loss: 0.1772 - output_variable1_loss: 0.0818 - output_variable2_loss: 0.0954 - val_loss: 0.1673 - val_output_variable1_loss: 0.0703 - val_output_variable2_loss: 0.0970
# Epoch 8/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.1578 - output_variable1_loss: 0.0714 - output_variable2_loss: 0.0864 - val_loss: 0.1496 - val_output_variable1_loss: 0.0668 - val_output_variable2_loss: 0.0827
# Epoch 9/100
# 4/4 [==============================] - 0s 58ms/step - loss: 0.1374 - output_variable1_loss: 0.0635 - output_variable2_loss: 0.0739 - val_loss: 0.1335 - val_output_variable1_loss: 0.0640 - val_output_variable2_loss: 0.0694
# Epoch 10/100
# 4/4 [==============================] - 0s 57ms/step - loss: 0.1214 - output_variable1_loss: 0.0576 - output_variable2_loss: 0.0639 - val_loss: 0.1294 - val_output_variable1_loss: 0.0661 - val_output_variable2_loss: 0.0633
# Epoch 11/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.1136 - output_variable1_loss: 0.0544 - output_variable2_loss: 0.0592 - val_loss: 0.1241 - val_output_variable1_loss: 0.0679 - val_output_variable2_loss: 0.0562
# Epoch 12/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.1053 - output_variable1_loss: 0.0527 - output_variable2_loss: 0.0527 - val_loss: 0.1199 - val_output_variable1_loss: 0.0685 - val_output_variable2_loss: 0.0514
# Epoch 13/100
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0992 - output_variable1_loss: 0.0515 - output_variable2_loss: 0.0478 - val_loss: 0.1107 - val_output_variable1_loss: 0.0642 - val_output_variable2_loss: 0.0465
# Epoch 14/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0944 - output_variable1_loss: 0.0512 - output_variable2_loss: 0.0432 - val_loss: 0.1068 - val_output_variable1_loss: 0.0638 - val_output_variable2_loss: 0.0430
# Epoch 15/100
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0901 - output_variable1_loss: 0.0512 - output_variable2_loss: 0.0389 - val_loss: 0.1018 - val_output_variable1_loss: 0.0642 - val_output_variable2_loss: 0.0377
# Epoch 16/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0868 - output_variable1_loss: 0.0512 - output_variable2_loss: 0.0355 - val_loss: 0.0952 - val_output_variable1_loss: 0.0604 - val_output_variable2_loss: 0.0348
# Epoch 17/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0828 - output_variable1_loss: 0.0511 - output_variable2_loss: 0.0318 - val_loss: 0.0927 - val_output_variable1_loss: 0.0619 - val_output_variable2_loss: 0.0308
# Epoch 18/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0784 - output_variable1_loss: 0.0495 - output_variable2_loss: 0.0289 - val_loss: 0.0936 - val_output_variable1_loss: 0.0661 - val_output_variable2_loss: 0.0275
# Epoch 19/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0745 - output_variable1_loss: 0.0486 - output_variable2_loss: 0.0259 - val_loss: 0.0862 - val_output_variable1_loss: 0.0616 - val_output_variable2_loss: 0.0247
# Epoch 20/100
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0705 - output_variable1_loss: 0.0468 - output_variable2_loss: 0.0236 - val_loss: 0.0826 - val_output_variable1_loss: 0.0605 - val_output_variable2_loss: 0.0221
# Epoch 21/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0653 - output_variable1_loss: 0.0437 - output_variable2_loss: 0.0217 - val_loss: 0.0779 - val_output_variable1_loss: 0.0563 - val_output_variable2_loss: 0.0216
# Epoch 22/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0618 - output_variable1_loss: 0.0418 - output_variable2_loss: 0.0200 - val_loss: 0.0784 - val_output_variable1_loss: 0.0604 - val_output_variable2_loss: 0.0180
# Epoch 23/100
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0589 - output_variable1_loss: 0.0406 - output_variable2_loss: 0.0183 - val_loss: 0.0767 - val_output_variable1_loss: 0.0596 - val_output_variable2_loss: 0.0170
# Epoch 24/100
# 4/4 [==============================] - 0s 59ms/step - loss: 0.0555 - output_variable1_loss: 0.0389 - output_variable2_loss: 0.0166 - val_loss: 0.0720 - val_output_variable1_loss: 0.0561 - val_output_variable2_loss: 0.0160
# Epoch 25/100
# 4/4 [==============================] - 0s 60ms/step - loss: 0.0525 - output_variable1_loss: 0.0364 - output_variable2_loss: 0.0161 - val_loss: 0.0708 - val_output_variable1_loss: 0.0557 - val_output_variable2_loss: 0.0151
# Epoch 26/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0488 - output_variable1_loss: 0.0340 - output_variable2_loss: 0.0149 - val_loss: 0.0632 - val_output_variable1_loss: 0.0491 - val_output_variable2_loss: 0.0141
# Epoch 27/100
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0454 - output_variable1_loss: 0.0317 - output_variable2_loss: 0.0138 - val_loss: 0.0651 - val_output_variable1_loss: 0.0529 - val_output_variable2_loss: 0.0122
# Epoch 28/100
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0423 - output_variable1_loss: 0.0293 - output_variable2_loss: 0.0130 - val_loss: 0.0657 - val_output_variable1_loss: 0.0544 - val_output_variable2_loss: 0.0113
# Epoch 29/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0391 - output_variable1_loss: 0.0273 - output_variable2_loss: 0.0118 - val_loss: 0.0606 - val_output_variable1_loss: 0.0490 - val_output_variable2_loss: 0.0116
# Epoch 30/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0369 - output_variable1_loss: 0.0258 - output_variable2_loss: 0.0111 - val_loss: 0.0576 - val_output_variable1_loss: 0.0480 - val_output_variable2_loss: 0.0096
# Epoch 31/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0356 - output_variable1_loss: 0.0252 - output_variable2_loss: 0.0104 - val_loss: 0.0557 - val_output_variable1_loss: 0.0452 - val_output_variable2_loss: 0.0106
# Epoch 32/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0339 - output_variable1_loss: 0.0240 - output_variable2_loss: 0.0098 - val_loss: 0.0588 - val_output_variable1_loss: 0.0497 - val_output_variable2_loss: 0.0091
# Epoch 33/100
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0320 - output_variable1_loss: 0.0227 - output_variable2_loss: 0.0093 - val_loss: 0.0603 - val_output_variable1_loss: 0.0509 - val_output_variable2_loss: 0.0094
# Epoch 34/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0309 - output_variable1_loss: 0.0218 - output_variable2_loss: 0.0091 - val_loss: 0.0572 - val_output_variable1_loss: 0.0482 - val_output_variable2_loss: 0.0089
# Epoch 35/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0295 - output_variable1_loss: 0.0210 - output_variable2_loss: 0.0085 - val_loss: 0.0529 - val_output_variable1_loss: 0.0444 - val_output_variable2_loss: 0.0085
# Epoch 36/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0282 - output_variable1_loss: 0.0203 - output_variable2_loss: 0.0079 - val_loss: 0.0563 - val_output_variable1_loss: 0.0480 - val_output_variable2_loss: 0.0083
# Epoch 37/100
# 4/4 [==============================] - 0s 58ms/step - loss: 0.0272 - output_variable1_loss: 0.0196 - output_variable2_loss: 0.0076 - val_loss: 0.0555 - val_output_variable1_loss: 0.0482 - val_output_variable2_loss: 0.0073
# Epoch 38/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0268 - output_variable1_loss: 0.0193 - output_variable2_loss: 0.0075 - val_loss: 0.0592 - val_output_variable1_loss: 0.0515 - val_output_variable2_loss: 0.0077
# Epoch 39/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0256 - output_variable1_loss: 0.0187 - output_variable2_loss: 0.0069 - val_loss: 0.0523 - val_output_variable1_loss: 0.0448 - val_output_variable2_loss: 0.0075
# Epoch 40/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0247 - output_variable1_loss: 0.0183 - output_variable2_loss: 0.0064 - val_loss: 0.0537 - val_output_variable1_loss: 0.0464 - val_output_variable2_loss: 0.0073
# Epoch 41/100
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0225 - output_variable1_loss: 0.0163 - output_variable2_loss: 0.0062 - val_loss: 0.0572 - val_output_variable1_loss: 0.0505 - val_output_variable2_loss: 0.0067
# Epoch 42/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0209 - output_variable1_loss: 0.0152 - output_variable2_loss: 0.0057 - val_loss: 0.0479 - val_output_variable1_loss: 0.0411 - val_output_variable2_loss: 0.0068
# Epoch 43/100
# 4/4 [==============================] - 0s 62ms/step - loss: 0.0201 - output_variable1_loss: 0.0146 - output_variable2_loss: 0.0055 - val_loss: 0.0458 - val_output_variable1_loss: 0.0394 - val_output_variable2_loss: 0.0064
# Epoch 44/100
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0189 - output_variable1_loss: 0.0129 - output_variable2_loss: 0.0060 - val_loss: 0.0456 - val_output_variable1_loss: 0.0394 - val_output_variable2_loss: 0.0062
# Epoch 45/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0172 - output_variable1_loss: 0.0119 - output_variable2_loss: 0.0053 - val_loss: 0.0424 - val_output_variable1_loss: 0.0351 - val_output_variable2_loss: 0.0073
# Epoch 46/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0160 - output_variable1_loss: 0.0110 - output_variable2_loss: 0.0050 - val_loss: 0.0386 - val_output_variable1_loss: 0.0332 - val_output_variable2_loss: 0.0054
# Epoch 47/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0152 - output_variable1_loss: 0.0105 - output_variable2_loss: 0.0047 - val_loss: 0.0425 - val_output_variable1_loss: 0.0363 - val_output_variable2_loss: 0.0061
# Epoch 48/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0148 - output_variable1_loss: 0.0102 - output_variable2_loss: 0.0047 - val_loss: 0.0491 - val_output_variable1_loss: 0.0419 - val_output_variable2_loss: 0.0072
# Epoch 49/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0150 - output_variable1_loss: 0.0098 - output_variable2_loss: 0.0052 - val_loss: 0.0472 - val_output_variable1_loss: 0.0419 - val_output_variable2_loss: 0.0052
# Epoch 50/100
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0143 - output_variable1_loss: 0.0091 - output_variable2_loss: 0.0052 - val_loss: 0.0506 - val_output_variable1_loss: 0.0441 - val_output_variable2_loss: 0.0064
# Epoch 51/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0133 - output_variable1_loss: 0.0087 - output_variable2_loss: 0.0046 - val_loss: 0.0440 - val_output_variable1_loss: 0.0390 - val_output_variable2_loss: 0.0051
# Epoch 52/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0127 - output_variable1_loss: 0.0079 - output_variable2_loss: 0.0047 - val_loss: 0.0478 - val_output_variable1_loss: 0.0422 - val_output_variable2_loss: 0.0056
# Epoch 53/100
# 4/4 [==============================] - 0s 58ms/step - loss: 0.0122 - output_variable1_loss: 0.0076 - output_variable2_loss: 0.0046 - val_loss: 0.0412 - val_output_variable1_loss: 0.0353 - val_output_variable2_loss: 0.0059
# Epoch 54/100
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0117 - output_variable1_loss: 0.0074 - output_variable2_loss: 0.0042 - val_loss: 0.0387 - val_output_variable1_loss: 0.0336 - val_output_variable2_loss: 0.0052
# Epoch 55/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0112 - output_variable1_loss: 0.0071 - output_variable2_loss: 0.0041 - val_loss: 0.0497 - val_output_variable1_loss: 0.0444 - val_output_variable2_loss: 0.0053
# Epoch 56/100
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0106 - output_variable1_loss: 0.0069 - output_variable2_loss: 0.0037 - val_loss: 0.0423 - val_output_variable1_loss: 0.0370 - val_output_variable2_loss: 0.0052
# Epoch 57/100
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0101 - output_variable1_loss: 0.0067 - output_variable2_loss: 0.0034 - val_loss: 0.0387 - val_output_variable1_loss: 0.0340 - val_output_variable2_loss: 0.0047
# Epoch 58/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0096 - output_variable1_loss: 0.0064 - output_variable2_loss: 0.0032 - val_loss: 0.0417 - val_output_variable1_loss: 0.0366 - val_output_variable2_loss: 0.0051
# Epoch 59/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0098 - output_variable1_loss: 0.0066 - output_variable2_loss: 0.0032 - val_loss: 0.0467 - val_output_variable1_loss: 0.0421 - val_output_variable2_loss: 0.0046
# Epoch 60/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0099 - output_variable1_loss: 0.0067 - output_variable2_loss: 0.0032 - val_loss: 0.0372 - val_output_variable1_loss: 0.0328 - val_output_variable2_loss: 0.0045
# Epoch 61/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0093 - output_variable1_loss: 0.0064 - output_variable2_loss: 0.0029 - val_loss: 0.0416 - val_output_variable1_loss: 0.0367 - val_output_variable2_loss: 0.0048
# Epoch 62/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0091 - output_variable1_loss: 0.0061 - output_variable2_loss: 0.0029 - val_loss: 0.0415 - val_output_variable1_loss: 0.0375 - val_output_variable2_loss: 0.0039
# Epoch 63/100
# 4/4 [==============================] - 0s 58ms/step - loss: 0.0087 - output_variable1_loss: 0.0057 - output_variable2_loss: 0.0029 - val_loss: 0.0490 - val_output_variable1_loss: 0.0441 - val_output_variable2_loss: 0.0050
# Epoch 64/100
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0087 - output_variable1_loss: 0.0058 - output_variable2_loss: 0.0030 - val_loss: 0.0416 - val_output_variable1_loss: 0.0368 - val_output_variable2_loss: 0.0048
# Epoch 65/100
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0088 - output_variable1_loss: 0.0056 - output_variable2_loss: 0.0032 - val_loss: 0.0394 - val_output_variable1_loss: 0.0353 - val_output_variable2_loss: 0.0041
# Epoch 66/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0083 - output_variable1_loss: 0.0054 - output_variable2_loss: 0.0028 - val_loss: 0.0457 - val_output_variable1_loss: 0.0412 - val_output_variable2_loss: 0.0045
# Epoch 67/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0081 - output_variable1_loss: 0.0055 - output_variable2_loss: 0.0026 - val_loss: 0.0404 - val_output_variable1_loss: 0.0364 - val_output_variable2_loss: 0.0040
# Epoch 68/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0075 - output_variable1_loss: 0.0051 - output_variable2_loss: 0.0024 - val_loss: 0.0408 - val_output_variable1_loss: 0.0365 - val_output_variable2_loss: 0.0042
# Epoch 69/100
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0074 - output_variable1_loss: 0.0050 - output_variable2_loss: 0.0024 - val_loss: 0.0460 - val_output_variable1_loss: 0.0419 - val_output_variable2_loss: 0.0041
# Epoch 70/100
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0075 - output_variable1_loss: 0.0052 - output_variable2_loss: 0.0023 - val_loss: 0.0375 - val_output_variable1_loss: 0.0333 - val_output_variable2_loss: 0.0043
# Epoch 71/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0073 - output_variable1_loss: 0.0050 - output_variable2_loss: 0.0023 - val_loss: 0.0394 - val_output_variable1_loss: 0.0351 - val_output_variable2_loss: 0.0043
# Epoch 72/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0073 - output_variable1_loss: 0.0051 - output_variable2_loss: 0.0022 - val_loss: 0.0483 - val_output_variable1_loss: 0.0445 - val_output_variable2_loss: 0.0039
# Epoch 73/100
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0073 - output_variable1_loss: 0.0051 - output_variable2_loss: 0.0022 - val_loss: 0.0361 - val_output_variable1_loss: 0.0318 - val_output_variable2_loss: 0.0043
# Epoch 74/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0070 - output_variable1_loss: 0.0048 - output_variable2_loss: 0.0022 - val_loss: 0.0382 - val_output_variable1_loss: 0.0340 - val_output_variable2_loss: 0.0042
# Epoch 75/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0069 - output_variable1_loss: 0.0047 - output_variable2_loss: 0.0022 - val_loss: 0.0451 - val_output_variable1_loss: 0.0407 - val_output_variable2_loss: 0.0044
# Epoch 76/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0072 - output_variable1_loss: 0.0050 - output_variable2_loss: 0.0022 - val_loss: 0.0346 - val_output_variable1_loss: 0.0308 - val_output_variable2_loss: 0.0038
# Epoch 77/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0070 - output_variable1_loss: 0.0049 - output_variable2_loss: 0.0021 - val_loss: 0.0425 - val_output_variable1_loss: 0.0380 - val_output_variable2_loss: 0.0045
# Epoch 78/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0068 - output_variable1_loss: 0.0047 - output_variable2_loss: 0.0021 - val_loss: 0.0431 - val_output_variable1_loss: 0.0390 - val_output_variable2_loss: 0.0041
# Epoch 79/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0066 - output_variable1_loss: 0.0045 - output_variable2_loss: 0.0021 - val_loss: 0.0383 - val_output_variable1_loss: 0.0334 - val_output_variable2_loss: 0.0048
# Epoch 80/100
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0067 - output_variable1_loss: 0.0045 - output_variable2_loss: 0.0022 - val_loss: 0.0439 - val_output_variable1_loss: 0.0401 - val_output_variable2_loss: 0.0038
# Epoch 81/100
# 4/4 [==============================] - 0s 73ms/step - loss: 0.0065 - output_variable1_loss: 0.0044 - output_variable2_loss: 0.0021 - val_loss: 0.0395 - val_output_variable1_loss: 0.0349 - val_output_variable2_loss: 0.0046
# Epoch 82/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0064 - output_variable1_loss: 0.0043 - output_variable2_loss: 0.0021 - val_loss: 0.0402 - val_output_variable1_loss: 0.0368 - val_output_variable2_loss: 0.0033
# Epoch 83/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0062 - output_variable1_loss: 0.0042 - output_variable2_loss: 0.0020 - val_loss: 0.0383 - val_output_variable1_loss: 0.0332 - val_output_variable2_loss: 0.0051
# Epoch 84/100
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0061 - output_variable1_loss: 0.0041 - output_variable2_loss: 0.0020 - val_loss: 0.0405 - val_output_variable1_loss: 0.0370 - val_output_variable2_loss: 0.0034
# Epoch 85/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0061 - output_variable1_loss: 0.0040 - output_variable2_loss: 0.0021 - val_loss: 0.0394 - val_output_variable1_loss: 0.0358 - val_output_variable2_loss: 0.0036
# Epoch 86/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0062 - output_variable1_loss: 0.0040 - output_variable2_loss: 0.0022 - val_loss: 0.0391 - val_output_variable1_loss: 0.0354 - val_output_variable2_loss: 0.0037
# Epoch 87/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0060 - output_variable1_loss: 0.0039 - output_variable2_loss: 0.0021 - val_loss: 0.0401 - val_output_variable1_loss: 0.0365 - val_output_variable2_loss: 0.0036
# Epoch 88/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0059 - output_variable1_loss: 0.0039 - output_variable2_loss: 0.0020 - val_loss: 0.0412 - val_output_variable1_loss: 0.0361 - val_output_variable2_loss: 0.0050
# Epoch 89/100
# 4/4 [==============================] - 0s 58ms/step - loss: 0.0065 - output_variable1_loss: 0.0038 - output_variable2_loss: 0.0027 - val_loss: 0.0378 - val_output_variable1_loss: 0.0342 - val_output_variable2_loss: 0.0037
# Epoch 90/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0062 - output_variable1_loss: 0.0038 - output_variable2_loss: 0.0023 - val_loss: 0.0433 - val_output_variable1_loss: 0.0389 - val_output_variable2_loss: 0.0044
# Epoch 91/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0063 - output_variable1_loss: 0.0038 - output_variable2_loss: 0.0025 - val_loss: 0.0372 - val_output_variable1_loss: 0.0331 - val_output_variable2_loss: 0.0041
# Epoch 92/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0059 - output_variable1_loss: 0.0037 - output_variable2_loss: 0.0022 - val_loss: 0.0406 - val_output_variable1_loss: 0.0370 - val_output_variable2_loss: 0.0036
# Epoch 93/100
# 4/4 [==============================] - 0s 57ms/step - loss: 0.0057 - output_variable1_loss: 0.0037 - output_variable2_loss: 0.0020 - val_loss: 0.0415 - val_output_variable1_loss: 0.0363 - val_output_variable2_loss: 0.0052
# Epoch 94/100
# 4/4 [==============================] - 0s 60ms/step - loss: 0.0057 - output_variable1_loss: 0.0036 - output_variable2_loss: 0.0021 - val_loss: 0.0357 - val_output_variable1_loss: 0.0318 - val_output_variable2_loss: 0.0039
# Epoch 95/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0059 - output_variable1_loss: 0.0036 - output_variable2_loss: 0.0022 - val_loss: 0.0427 - val_output_variable1_loss: 0.0387 - val_output_variable2_loss: 0.0040
# Epoch 96/100
# 4/4 [==============================] - 0s 61ms/step - loss: 0.0056 - output_variable1_loss: 0.0037 - output_variable2_loss: 0.0019 - val_loss: 0.0434 - val_output_variable1_loss: 0.0390 - val_output_variable2_loss: 0.0043
# Epoch 97/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0058 - output_variable1_loss: 0.0038 - output_variable2_loss: 0.0020 - val_loss: 0.0377 - val_output_variable1_loss: 0.0336 - val_output_variable2_loss: 0.0041
# Epoch 98/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0056 - output_variable1_loss: 0.0037 - output_variable2_loss: 0.0019 - val_loss: 0.0444 - val_output_variable1_loss: 0.0402 - val_output_variable2_loss: 0.0042
# Epoch 99/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0057 - output_variable1_loss: 0.0038 - output_variable2_loss: 0.0019 - val_loss: 0.0355 - val_output_variable1_loss: 0.0318 - val_output_variable2_loss: 0.0038
# Epoch 100/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0058 - output_variable1_loss: 0.0036 - output_variable2_loss: 0.0022 - val_loss: 0.0416 - val_output_variable1_loss: 0.0366 - val_output_variable2_loss: 0.0051
# Epoch 1/100
# 7/7 [==============================] - 0s 51ms/step - loss: 0.0193 - output_variable1_loss: 0.0156 - output_variable2_loss: 0.0037 - val_loss: 0.0240 - val_output_variable1_loss: 0.0210 - val_output_variable2_loss: 0.0029
# Epoch 2/100
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0197 - output_variable1_loss: 0.0163 - output_variable2_loss: 0.0034 - val_loss: 0.0262 - val_output_variable1_loss: 0.0227 - val_output_variable2_loss: 0.0035
# Epoch 3/100
# 7/7 [==============================] - 0s 46ms/step - loss: 0.0158 - output_variable1_loss: 0.0131 - output_variable2_loss: 0.0028 - val_loss: 0.0281 - val_output_variable1_loss: 0.0255 - val_output_variable2_loss: 0.0026
# Epoch 4/100
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0139 - output_variable1_loss: 0.0117 - output_variable2_loss: 0.0023 - val_loss: 0.0271 - val_output_variable1_loss: 0.0245 - val_output_variable2_loss: 0.0026
# Epoch 5/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0130 - output_variable1_loss: 0.0109 - output_variable2_loss: 0.0021 - val_loss: 0.0269 - val_output_variable1_loss: 0.0247 - val_output_variable2_loss: 0.0022
# Epoch 6/100
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0121 - output_variable1_loss: 0.0103 - output_variable2_loss: 0.0018 - val_loss: 0.0281 - val_output_variable1_loss: 0.0258 - val_output_variable2_loss: 0.0023
# Epoch 7/100
# 7/7 [==============================] - 0s 59ms/step - loss: 0.0113 - output_variable1_loss: 0.0096 - output_variable2_loss: 0.0018 - val_loss: 0.0268 - val_output_variable1_loss: 0.0243 - val_output_variable2_loss: 0.0025
# Epoch 8/100
# 7/7 [==============================] - 0s 51ms/step - loss: 0.0107 - output_variable1_loss: 0.0090 - output_variable2_loss: 0.0017 - val_loss: 0.0267 - val_output_variable1_loss: 0.0244 - val_output_variable2_loss: 0.0023
# Epoch 9/100
# 7/7 [==============================] - 0s 51ms/step - loss: 0.0100 - output_variable1_loss: 0.0084 - output_variable2_loss: 0.0016 - val_loss: 0.0244 - val_output_variable1_loss: 0.0225 - val_output_variable2_loss: 0.0019
# Epoch 10/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0095 - output_variable1_loss: 0.0079 - output_variable2_loss: 0.0016 - val_loss: 0.0245 - val_output_variable1_loss: 0.0224 - val_output_variable2_loss: 0.0021
# Epoch 11/100
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0095 - output_variable1_loss: 0.0079 - output_variable2_loss: 0.0015 - val_loss: 0.0251 - val_output_variable1_loss: 0.0232 - val_output_variable2_loss: 0.0018
# Epoch 12/100
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0098 - output_variable1_loss: 0.0083 - output_variable2_loss: 0.0016 - val_loss: 0.0267 - val_output_variable1_loss: 0.0251 - val_output_variable2_loss: 0.0017
# Epoch 13/100
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0089 - output_variable1_loss: 0.0075 - output_variable2_loss: 0.0015 - val_loss: 0.0225 - val_output_variable1_loss: 0.0207 - val_output_variable2_loss: 0.0018
# Epoch 14/100
# 7/7 [==============================] - 0s 64ms/step - loss: 0.0081 - output_variable1_loss: 0.0067 - output_variable2_loss: 0.0014 - val_loss: 0.0234 - val_output_variable1_loss: 0.0212 - val_output_variable2_loss: 0.0022
# Epoch 15/100
# 7/7 [==============================] - 0s 59ms/step - loss: 0.0076 - output_variable1_loss: 0.0062 - output_variable2_loss: 0.0014 - val_loss: 0.0230 - val_output_variable1_loss: 0.0210 - val_output_variable2_loss: 0.0020
# Epoch 16/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0075 - output_variable1_loss: 0.0061 - output_variable2_loss: 0.0014 - val_loss: 0.0234 - val_output_variable1_loss: 0.0212 - val_output_variable2_loss: 0.0022
# Epoch 17/100
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0074 - output_variable1_loss: 0.0059 - output_variable2_loss: 0.0014 - val_loss: 0.0280 - val_output_variable1_loss: 0.0260 - val_output_variable2_loss: 0.0021
# Epoch 18/100
# 7/7 [==============================] - 0s 51ms/step - loss: 0.0077 - output_variable1_loss: 0.0063 - output_variable2_loss: 0.0014 - val_loss: 0.0215 - val_output_variable1_loss: 0.0195 - val_output_variable2_loss: 0.0021
# Epoch 19/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0072 - output_variable1_loss: 0.0059 - output_variable2_loss: 0.0013 - val_loss: 0.0221 - val_output_variable1_loss: 0.0199 - val_output_variable2_loss: 0.0021
# Epoch 20/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0069 - output_variable1_loss: 0.0056 - output_variable2_loss: 0.0013 - val_loss: 0.0223 - val_output_variable1_loss: 0.0207 - val_output_variable2_loss: 0.0016
# Epoch 21/100
# 7/7 [==============================] - 0s 51ms/step - loss: 0.0067 - output_variable1_loss: 0.0053 - output_variable2_loss: 0.0014 - val_loss: 0.0233 - val_output_variable1_loss: 0.0212 - val_output_variable2_loss: 0.0021
# Epoch 22/100
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0065 - output_variable1_loss: 0.0052 - output_variable2_loss: 0.0013 - val_loss: 0.0223 - val_output_variable1_loss: 0.0195 - val_output_variable2_loss: 0.0028
# Epoch 23/100
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0065 - output_variable1_loss: 0.0051 - output_variable2_loss: 0.0013 - val_loss: 0.0212 - val_output_variable1_loss: 0.0198 - val_output_variable2_loss: 0.0015
# Epoch 24/100
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0062 - output_variable1_loss: 0.0050 - output_variable2_loss: 0.0012 - val_loss: 0.0212 - val_output_variable1_loss: 0.0196 - val_output_variable2_loss: 0.0016
# Epoch 25/100
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0060 - output_variable1_loss: 0.0048 - output_variable2_loss: 0.0012 - val_loss: 0.0225 - val_output_variable1_loss: 0.0205 - val_output_variable2_loss: 0.0020
# Epoch 26/100
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0058 - output_variable1_loss: 0.0046 - output_variable2_loss: 0.0012 - val_loss: 0.0224 - val_output_variable1_loss: 0.0206 - val_output_variable2_loss: 0.0017
# Epoch 27/100
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0058 - output_variable1_loss: 0.0045 - output_variable2_loss: 0.0012 - val_loss: 0.0231 - val_output_variable1_loss: 0.0214 - val_output_variable2_loss: 0.0017
# Epoch 28/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0056 - output_variable1_loss: 0.0044 - output_variable2_loss: 0.0012 - val_loss: 0.0214 - val_output_variable1_loss: 0.0190 - val_output_variable2_loss: 0.0024
# Epoch 29/100
# 7/7 [==============================] - 0s 51ms/step - loss: 0.0057 - output_variable1_loss: 0.0045 - output_variable2_loss: 0.0012 - val_loss: 0.0213 - val_output_variable1_loss: 0.0197 - val_output_variable2_loss: 0.0016
# Epoch 30/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0054 - output_variable1_loss: 0.0043 - output_variable2_loss: 0.0011 - val_loss: 0.0234 - val_output_variable1_loss: 0.0213 - val_output_variable2_loss: 0.0021
# Epoch 31/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0053 - output_variable1_loss: 0.0042 - output_variable2_loss: 0.0011 - val_loss: 0.0216 - val_output_variable1_loss: 0.0197 - val_output_variable2_loss: 0.0019
# Epoch 32/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0052 - output_variable1_loss: 0.0041 - output_variable2_loss: 0.0011 - val_loss: 0.0211 - val_output_variable1_loss: 0.0194 - val_output_variable2_loss: 0.0017
# Epoch 33/100
# 7/7 [==============================] - 0s 55ms/step - loss: 0.0053 - output_variable1_loss: 0.0042 - output_variable2_loss: 0.0011 - val_loss: 0.0212 - val_output_variable1_loss: 0.0193 - val_output_variable2_loss: 0.0018
# Epoch 34/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0051 - output_variable1_loss: 0.0040 - output_variable2_loss: 0.0011 - val_loss: 0.0222 - val_output_variable1_loss: 0.0202 - val_output_variable2_loss: 0.0020
# Epoch 35/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0054 - output_variable1_loss: 0.0043 - output_variable2_loss: 0.0011 - val_loss: 0.0239 - val_output_variable1_loss: 0.0223 - val_output_variable2_loss: 0.0016
# Epoch 36/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0057 - output_variable1_loss: 0.0046 - output_variable2_loss: 0.0011 - val_loss: 0.0232 - val_output_variable1_loss: 0.0212 - val_output_variable2_loss: 0.0020
# Epoch 37/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0053 - output_variable1_loss: 0.0042 - output_variable2_loss: 0.0011 - val_loss: 0.0216 - val_output_variable1_loss: 0.0194 - val_output_variable2_loss: 0.0022
# Epoch 38/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0050 - output_variable1_loss: 0.0039 - output_variable2_loss: 0.0011 - val_loss: 0.0219 - val_output_variable1_loss: 0.0202 - val_output_variable2_loss: 0.0016
# Epoch 39/100
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0051 - output_variable1_loss: 0.0040 - output_variable2_loss: 0.0011 - val_loss: 0.0215 - val_output_variable1_loss: 0.0191 - val_output_variable2_loss: 0.0024
# Epoch 40/100
# 7/7 [==============================] - 0s 54ms/step - loss: 0.0048 - output_variable1_loss: 0.0038 - output_variable2_loss: 0.0011 - val_loss: 0.0204 - val_output_variable1_loss: 0.0187 - val_output_variable2_loss: 0.0017
# Epoch 41/100
# 7/7 [==============================] - 0s 56ms/step - loss: 0.0047 - output_variable1_loss: 0.0036 - output_variable2_loss: 0.0010 - val_loss: 0.0221 - val_output_variable1_loss: 0.0202 - val_output_variable2_loss: 0.0020
# Epoch 42/100
# 7/7 [==============================] - 0s 51ms/step - loss: 0.0047 - output_variable1_loss: 0.0036 - output_variable2_loss: 0.0011 - val_loss: 0.0223 - val_output_variable1_loss: 0.0205 - val_output_variable2_loss: 0.0018
# Epoch 43/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0045 - output_variable1_loss: 0.0035 - output_variable2_loss: 0.0010 - val_loss: 0.0229 - val_output_variable1_loss: 0.0212 - val_output_variable2_loss: 0.0016
# Epoch 44/100
# 7/7 [==============================] - 0s 51ms/step - loss: 0.0046 - output_variable1_loss: 0.0036 - output_variable2_loss: 9.8507e-04 - val_loss: 0.0231 - val_output_variable1_loss: 0.0210 - val_output_variable2_loss: 0.0022
# Epoch 45/100
# 7/7 [==============================] - 0s 51ms/step - loss: 0.0046 - output_variable1_loss: 0.0036 - output_variable2_loss: 9.7759e-04 - val_loss: 0.0214 - val_output_variable1_loss: 0.0197 - val_output_variable2_loss: 0.0017
# Epoch 46/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0044 - output_variable1_loss: 0.0034 - output_variable2_loss: 9.7641e-04 - val_loss: 0.0212 - val_output_variable1_loss: 0.0197 - val_output_variable2_loss: 0.0016
# Epoch 47/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0043 - output_variable1_loss: 0.0033 - output_variable2_loss: 9.7750e-04 - val_loss: 0.0214 - val_output_variable1_loss: 0.0189 - val_output_variable2_loss: 0.0025
# Epoch 48/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0043 - output_variable1_loss: 0.0033 - output_variable2_loss: 0.0010 - val_loss: 0.0211 - val_output_variable1_loss: 0.0195 - val_output_variable2_loss: 0.0016
# Epoch 49/100
# 7/7 [==============================] - 0s 60ms/step - loss: 0.0042 - output_variable1_loss: 0.0033 - output_variable2_loss: 9.6550e-04 - val_loss: 0.0214 - val_output_variable1_loss: 0.0194 - val_output_variable2_loss: 0.0020
# Epoch 50/100
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0042 - output_variable1_loss: 0.0032 - output_variable2_loss: 0.0010 - val_loss: 0.0208 - val_output_variable1_loss: 0.0190 - val_output_variable2_loss: 0.0018
# Epoch 51/100
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0042 - output_variable1_loss: 0.0033 - output_variable2_loss: 9.6620e-04 - val_loss: 0.0200 - val_output_variable1_loss: 0.0180 - val_output_variable2_loss: 0.0020
# Epoch 52/100
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0042 - output_variable1_loss: 0.0032 - output_variable2_loss: 9.7526e-04 - val_loss: 0.0207 - val_output_variable1_loss: 0.0194 - val_output_variable2_loss: 0.0013
# Epoch 53/100
# 7/7 [==============================] - 0s 51ms/step - loss: 0.0041 - output_variable1_loss: 0.0031 - output_variable2_loss: 9.7685e-04 - val_loss: 0.0215 - val_output_variable1_loss: 0.0198 - val_output_variable2_loss: 0.0018
# Epoch 54/100
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0043 - output_variable1_loss: 0.0033 - output_variable2_loss: 0.0010 - val_loss: 0.0209 - val_output_variable1_loss: 0.0191 - val_output_variable2_loss: 0.0018
# Epoch 55/100
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0041 - output_variable1_loss: 0.0032 - output_variable2_loss: 9.5878e-04 - val_loss: 0.0209 - val_output_variable1_loss: 0.0194 - val_output_variable2_loss: 0.0015
# Epoch 56/100
# 7/7 [==============================] - 0s 51ms/step - loss: 0.0040 - output_variable1_loss: 0.0031 - output_variable2_loss: 9.4508e-04 - val_loss: 0.0209 - val_output_variable1_loss: 0.0191 - val_output_variable2_loss: 0.0017
# Epoch 57/100
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0039 - output_variable1_loss: 0.0030 - output_variable2_loss: 9.3967e-04 - val_loss: 0.0217 - val_output_variable1_loss: 0.0199 - val_output_variable2_loss: 0.0018
# Epoch 58/100
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0039 - output_variable1_loss: 0.0030 - output_variable2_loss: 8.9819e-04 - val_loss: 0.0209 - val_output_variable1_loss: 0.0194 - val_output_variable2_loss: 0.0014
# Epoch 59/100
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0038 - output_variable1_loss: 0.0029 - output_variable2_loss: 8.8388e-04 - val_loss: 0.0223 - val_output_variable1_loss: 0.0202 - val_output_variable2_loss: 0.0021
# Epoch 60/100
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0038 - output_variable1_loss: 0.0029 - output_variable2_loss: 9.0793e-04 - val_loss: 0.0212 - val_output_variable1_loss: 0.0197 - val_output_variable2_loss: 0.0014
# Epoch 61/100
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0037 - output_variable1_loss: 0.0028 - output_variable2_loss: 8.8558e-04 - val_loss: 0.0217 - val_output_variable1_loss: 0.0201 - val_output_variable2_loss: 0.0016
# Epoch 62/100
# 7/7 [==============================] - 0s 51ms/step - loss: 0.0038 - output_variable1_loss: 0.0029 - output_variable2_loss: 8.9278e-04 - val_loss: 0.0214 - val_output_variable1_loss: 0.0193 - val_output_variable2_loss: 0.0021
# Epoch 63/100
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0038 - output_variable1_loss: 0.0029 - output_variable2_loss: 9.0469e-04 - val_loss: 0.0212 - val_output_variable1_loss: 0.0199 - val_output_variable2_loss: 0.0013
# Epoch 64/100
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0038 - output_variable1_loss: 0.0029 - output_variable2_loss: 9.1206e-04 - val_loss: 0.0212 - val_output_variable1_loss: 0.0197 - val_output_variable2_loss: 0.0015
# Epoch 65/100
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0037 - output_variable1_loss: 0.0028 - output_variable2_loss: 8.6993e-04 - val_loss: 0.0225 - val_output_variable1_loss: 0.0212 - val_output_variable2_loss: 0.0013
# Epoch 66/100
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0038 - output_variable1_loss: 0.0029 - output_variable2_loss: 8.9935e-04 - val_loss: 0.0220 - val_output_variable1_loss: 0.0199 - val_output_variable2_loss: 0.0021
# Epoch 67/100
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0038 - output_variable1_loss: 0.0029 - output_variable2_loss: 9.2539e-04 - val_loss: 0.0228 - val_output_variable1_loss: 0.0213 - val_output_variable2_loss: 0.0015
# Epoch 68/100
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0038 - output_variable1_loss: 0.0029 - output_variable2_loss: 8.9150e-04 - val_loss: 0.0226 - val_output_variable1_loss: 0.0208 - val_output_variable2_loss: 0.0018
# Epoch 69/100
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0037 - output_variable1_loss: 0.0028 - output_variable2_loss: 8.6323e-04 - val_loss: 0.0216 - val_output_variable1_loss: 0.0201 - val_output_variable2_loss: 0.0014
# Epoch 70/100
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0036 - output_variable1_loss: 0.0027 - output_variable2_loss: 8.6821e-04 - val_loss: 0.0197 - val_output_variable1_loss: 0.0181 - val_output_variable2_loss: 0.0016
# Epoch 71/100
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0035 - output_variable1_loss: 0.0027 - output_variable2_loss: 8.3197e-04 - val_loss: 0.0211 - val_output_variable1_loss: 0.0196 - val_output_variable2_loss: 0.0015
# Epoch 72/100
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0034 - output_variable1_loss: 0.0026 - output_variable2_loss: 8.2318e-04 - val_loss: 0.0208 - val_output_variable1_loss: 0.0194 - val_output_variable2_loss: 0.0014
# Epoch 73/100
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0034 - output_variable1_loss: 0.0026 - output_variable2_loss: 8.0471e-04 - val_loss: 0.0202 - val_output_variable1_loss: 0.0185 - val_output_variable2_loss: 0.0016
# Epoch 74/100
# 7/7 [==============================] - 0s 51ms/step - loss: 0.0034 - output_variable1_loss: 0.0026 - output_variable2_loss: 7.9201e-04 - val_loss: 0.0240 - val_output_variable1_loss: 0.0226 - val_output_variable2_loss: 0.0014
# Epoch 75/100
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0034 - output_variable1_loss: 0.0026 - output_variable2_loss: 7.7562e-04 - val_loss: 0.0232 - val_output_variable1_loss: 0.0218 - val_output_variable2_loss: 0.0015
# Epoch 76/100
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0033 - output_variable1_loss: 0.0025 - output_variable2_loss: 7.7823e-04 - val_loss: 0.0209 - val_output_variable1_loss: 0.0195 - val_output_variable2_loss: 0.0014
# Epoch 77/100
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0032 - output_variable1_loss: 0.0024 - output_variable2_loss: 7.7722e-04 - val_loss: 0.0230 - val_output_variable1_loss: 0.0217 - val_output_variable2_loss: 0.0013
# Epoch 78/100
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0032 - output_variable1_loss: 0.0024 - output_variable2_loss: 7.7402e-04 - val_loss: 0.0233 - val_output_variable1_loss: 0.0216 - val_output_variable2_loss: 0.0016
# Epoch 79/100
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0032 - output_variable1_loss: 0.0025 - output_variable2_loss: 7.7050e-04 - val_loss: 0.0213 - val_output_variable1_loss: 0.0194 - val_output_variable2_loss: 0.0019
# Epoch 80/100
# 7/7 [==============================] - 0s 51ms/step - loss: 0.0031 - output_variable1_loss: 0.0024 - output_variable2_loss: 7.6496e-04 - val_loss: 0.0232 - val_output_variable1_loss: 0.0218 - val_output_variable2_loss: 0.0014
# Epoch 81/100
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0032 - output_variable1_loss: 0.0024 - output_variable2_loss: 7.7052e-04 - val_loss: 0.0215 - val_output_variable1_loss: 0.0199 - val_output_variable2_loss: 0.0016
# Epoch 82/100
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0031 - output_variable1_loss: 0.0023 - output_variable2_loss: 7.5618e-04 - val_loss: 0.0237 - val_output_variable1_loss: 0.0218 - val_output_variable2_loss: 0.0018
# Epoch 83/100
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0031 - output_variable1_loss: 0.0024 - output_variable2_loss: 7.6957e-04 - val_loss: 0.0212 - val_output_variable1_loss: 0.0198 - val_output_variable2_loss: 0.0015
# Epoch 84/100
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0030 - output_variable1_loss: 0.0023 - output_variable2_loss: 7.5832e-04 - val_loss: 0.0213 - val_output_variable1_loss: 0.0199 - val_output_variable2_loss: 0.0014
# Epoch 85/100
# 7/7 [==============================] - 0s 57ms/step - loss: 0.0030 - output_variable1_loss: 0.0023 - output_variable2_loss: 7.3620e-04 - val_loss: 0.0217 - val_output_variable1_loss: 0.0204 - val_output_variable2_loss: 0.0013
# Epoch 86/100
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0032 - output_variable1_loss: 0.0024 - output_variable2_loss: 8.1645e-04 - val_loss: 0.0201 - val_output_variable1_loss: 0.0189 - val_output_variable2_loss: 0.0012
# Epoch 87/100
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0033 - output_variable1_loss: 0.0024 - output_variable2_loss: 8.8918e-04 - val_loss: 0.0211 - val_output_variable1_loss: 0.0190 - val_output_variable2_loss: 0.0021
# Epoch 88/100
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0032 - output_variable1_loss: 0.0023 - output_variable2_loss: 8.9885e-04 - val_loss: 0.0222 - val_output_variable1_loss: 0.0202 - val_output_variable2_loss: 0.0020
# Epoch 89/100
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0031 - output_variable1_loss: 0.0022 - output_variable2_loss: 8.6384e-04 - val_loss: 0.0209 - val_output_variable1_loss: 0.0198 - val_output_variable2_loss: 0.0011
# Epoch 90/100
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0030 - output_variable1_loss: 0.0022 - output_variable2_loss: 8.5497e-04 - val_loss: 0.0210 - val_output_variable1_loss: 0.0198 - val_output_variable2_loss: 0.0012
# Epoch 91/100
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0029 - output_variable1_loss: 0.0021 - output_variable2_loss: 8.0373e-04 - val_loss: 0.0210 - val_output_variable1_loss: 0.0198 - val_output_variable2_loss: 0.0012
# Epoch 92/100
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0029 - output_variable1_loss: 0.0021 - output_variable2_loss: 7.6310e-04 - val_loss: 0.0216 - val_output_variable1_loss: 0.0199 - val_output_variable2_loss: 0.0018
# Epoch 93/100
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0028 - output_variable1_loss: 0.0021 - output_variable2_loss: 7.4138e-04 - val_loss: 0.0229 - val_output_variable1_loss: 0.0213 - val_output_variable2_loss: 0.0016
# Epoch 94/100
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0028 - output_variable1_loss: 0.0020 - output_variable2_loss: 7.4657e-04 - val_loss: 0.0215 - val_output_variable1_loss: 0.0205 - val_output_variable2_loss: 9.9267e-04
# Epoch 95/100
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0027 - output_variable1_loss: 0.0020 - output_variable2_loss: 7.2553e-04 - val_loss: 0.0220 - val_output_variable1_loss: 0.0205 - val_output_variable2_loss: 0.0014
# Epoch 96/100
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0027 - output_variable1_loss: 0.0020 - output_variable2_loss: 6.9020e-04 - val_loss: 0.0218 - val_output_variable1_loss: 0.0203 - val_output_variable2_loss: 0.0014
# Epoch 97/100
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0027 - output_variable1_loss: 0.0020 - output_variable2_loss: 6.9475e-04 - val_loss: 0.0230 - val_output_variable1_loss: 0.0213 - val_output_variable2_loss: 0.0017
# Epoch 98/100
# 7/7 [==============================] - 0s 50ms/step - loss: 0.0027 - output_variable1_loss: 0.0019 - output_variable2_loss: 7.1717e-04 - val_loss: 0.0221 - val_output_variable1_loss: 0.0209 - val_output_variable2_loss: 0.0012
# Epoch 99/100
# 7/7 [==============================] - 0s 58ms/step - loss: 0.0026 - output_variable1_loss: 0.0019 - output_variable2_loss: 7.1819e-04 - val_loss: 0.0223 - val_output_variable1_loss: 0.0202 - val_output_variable2_loss: 0.0021
# Epoch 100/100
# 7/7 [==============================] - 0s 53ms/step - loss: 0.0027 - output_variable1_loss: 0.0019 - output_variable2_loss: 7.5482e-04 - val_loss: 0.0227 - val_output_variable1_loss: 0.0206 - val_output_variable2_loss: 0.0021
# Epoch 1/100
# ...
# Epoch 71/100
# 10/10 [==============================] - 0s 48ms/step - loss: 0.0018 - output_variable1_loss: 0.0012 - output_variable2_loss: 5.7519e-04 - val_loss: 0.0785 - val_output_variable1_loss: 0.0549 - val_output_variable2_loss: 0.0236
# Epoch 72/100
# 10/10 [==============================] - 0s 50ms/step - loss: 0.0018 - output_variable1_loss: 0.0013 - output_variable2_loss: 5.3921e-04 - val_loss: 0.0786 - val_output_variable1_loss: 0.0553 - val_output_variable2_loss: 0.0233
# Epoch 73/100
# 10/10 [==============================] - 1s 57ms/step - loss: 0.0018 - output_variable1_loss: 0.0012 - output_variable2_loss: 5.8498e-04 - val_loss: 0.0774 - val_output_variable1_loss: 0.0541 - val_output_variable2_loss: 0.0232
# Epoch 74/100
# 10/10 [==============================] - 1s 52ms/step - loss: 0.0018 - output_variable1_loss: 0.0012 - output_variable2_loss: 5.7735e-04 - val_loss: 0.0795 - val_output_variable1_loss: 0.0559 - val_output_variable2_loss: 0.0236
# Epoch 75/100
# 10/10 [==============================] - 0s 47ms/step - loss: 0.0017 - output_variable1_loss: 0.0012 - output_variable2_loss: 5.5408e-04 - val_loss: 0.0786 - val_output_variable1_loss: 0.0544 - val_output_variable2_loss: 0.0243
# Epoch 76/100
# 10/10 [==============================] - 0s 47ms/step - loss: 0.0017 - output_variable1_loss: 0.0011 - output_variable2_loss: 5.3702e-04 - val_loss: 0.0781 - val_output_variable1_loss: 0.0547 - val_output_variable2_loss: 0.0234
# Epoch 77/100
# 10/10 [==============================] - 0s 46ms/step - loss: 0.0017 - output_variable1_loss: 0.0011 - output_variable2_loss: 5.1749e-04 - val_loss: 0.0793 - val_output_variable1_loss: 0.0559 - val_output_variable2_loss: 0.0234
# Epoch 78/100
# 10/10 [==============================] - 0s 46ms/step - loss: 0.0017 - output_variable1_loss: 0.0012 - output_variable2_loss: 5.0575e-04 - val_loss: 0.0768 - val_output_variable1_loss: 0.0539 - val_output_variable2_loss: 0.0229
# Epoch 79/100
# 10/10 [==============================] - 0s 48ms/step - loss: 0.0017 - output_variable1_loss: 0.0012 - output_variable2_loss: 5.2027e-04 - val_loss: 0.0846 - val_output_variable1_loss: 0.0586 - val_output_variable2_loss: 0.0260
# Epoch 80/100
# 10/10 [==============================] - 0s 48ms/step - loss: 0.0017 - output_variable1_loss: 0.0011 - output_variable2_loss: 5.2015e-04 - val_loss: 0.0809 - val_output_variable1_loss: 0.0566 - val_output_variable2_loss: 0.0243
# Epoch 81/100
# 10/10 [==============================] - 0s 47ms/step - loss: 0.0016 - output_variable1_loss: 0.0011 - output_variable2_loss: 5.0198e-04 - val_loss: 0.0789 - val_output_variable1_loss: 0.0554 - val_output_variable2_loss: 0.0235
# Epoch 82/100
# 10/10 [==============================] - 0s 47ms/step - loss: 0.0017 - output_variable1_loss: 0.0012 - output_variable2_loss: 5.0666e-04 - val_loss: 0.0806 - val_output_variable1_loss: 0.0568 - val_output_variable2_loss: 0.0238
# Epoch 83/100
# 10/10 [==============================] - 0s 45ms/step - loss: 0.0017 - output_variable1_loss: 0.0012 - output_variable2_loss: 5.1775e-04 - val_loss: 0.0814 - val_output_variable1_loss: 0.0573 - val_output_variable2_loss: 0.0241
# Epoch 84/100
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0016 - output_variable1_loss: 0.0011 - output_variable2_loss: 5.0308e-04 - val_loss: 0.0822 - val_output_variable1_loss: 0.0569 - val_output_variable2_loss: 0.0254
# Epoch 85/100
# 10/10 [==============================] - 0s 48ms/step - loss: 0.0016 - output_variable1_loss: 0.0011 - output_variable2_loss: 4.9054e-04 - val_loss: 0.0811 - val_output_variable1_loss: 0.0559 - val_output_variable2_loss: 0.0251
# Epoch 86/100
# 10/10 [==============================] - 0s 49ms/step - loss: 0.0016 - output_variable1_loss: 0.0011 - output_variable2_loss: 5.1641e-04 - val_loss: 0.0826 - val_output_variable1_loss: 0.0585 - val_output_variable2_loss: 0.0241
# Epoch 87/100
# 10/10 [==============================] - 0s 50ms/step - loss: 0.0016 - output_variable1_loss: 0.0011 - output_variable2_loss: 4.9328e-04 - val_loss: 0.0793 - val_output_variable1_loss: 0.0552 - val_output_variable2_loss: 0.0241
# Epoch 88/100
# 10/10 [==============================] - 0s 47ms/step - loss: 0.0016 - output_variable1_loss: 0.0011 - output_variable2_loss: 4.9874e-04 - val_loss: 0.0801 - val_output_variable1_loss: 0.0557 - val_output_variable2_loss: 0.0244
# Epoch 89/100
# 10/10 [==============================] - 1s 52ms/step - loss: 0.0016 - output_variable1_loss: 0.0011 - output_variable2_loss: 5.0567e-04 - val_loss: 0.0801 - val_output_variable1_loss: 0.0552 - val_output_variable2_loss: 0.0249
# Epoch 90/100
# 10/10 [==============================] - 0s 46ms/step - loss: 0.0017 - output_variable1_loss: 0.0011 - output_variable2_loss: 5.1259e-04 - val_loss: 0.0784 - val_output_variable1_loss: 0.0540 - val_output_variable2_loss: 0.0244
# Epoch 91/100
# 10/10 [==============================] - 0s 46ms/step - loss: 0.0017 - output_variable1_loss: 0.0011 - output_variable2_loss: 5.1651e-04 - val_loss: 0.0818 - val_output_variable1_loss: 0.0558 - val_output_variable2_loss: 0.0260
# Epoch 92/100
# 10/10 [==============================] - 0s 47ms/step - loss: 0.0017 - output_variable1_loss: 0.0012 - output_variable2_loss: 5.0019e-04 - val_loss: 0.0813 - val_output_variable1_loss: 0.0567 - val_output_variable2_loss: 0.0246
# Epoch 93/100
# 10/10 [==============================] - 0s 46ms/step - loss: 0.0016 - output_variable1_loss: 0.0011 - output_variable2_loss: 4.8140e-04 - val_loss: 0.0854 - val_output_variable1_loss: 0.0605 - val_output_variable2_loss: 0.0249
# Epoch 94/100
# 10/10 [==============================] - 0s 47ms/step - loss: 0.0016 - output_variable1_loss: 0.0010 - output_variable2_loss: 5.1255e-04 - val_loss: 0.0821 - val_output_variable1_loss: 0.0573 - val_output_variable2_loss: 0.0248
# Epoch 95/100
# 10/10 [==============================] - 0s 49ms/step - loss: 0.0015 - output_variable1_loss: 0.0010 - output_variable2_loss: 4.9190e-04 - val_loss: 0.0801 - val_output_variable1_loss: 0.0562 - val_output_variable2_loss: 0.0239
# Epoch 96/100
# 10/10 [==============================] - 0s 46ms/step - loss: 0.0015 - output_variable1_loss: 0.0010 - output_variable2_loss: 4.8129e-04 - val_loss: 0.0795 - val_output_variable1_loss: 0.0568 - val_output_variable2_loss: 0.0227
# Epoch 97/100
# 10/10 [==============================] - 0s 49ms/step - loss: 0.0015 - output_variable1_loss: 9.9314e-04 - output_variable2_loss: 4.8913e-04 - val_loss: 0.0811 - val_output_variable1_loss: 0.0560 - val_output_variable2_loss: 0.0250
# Epoch 98/100
# 10/10 [==============================] - 1s 62ms/step - loss: 0.0015 - output_variable1_loss: 9.8520e-04 - output_variable2_loss: 5.1075e-04 - val_loss: 0.0839 - val_output_variable1_loss: 0.0592 - val_output_variable2_loss: 0.0247
# Epoch 99/100
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0015 - output_variable1_loss: 9.8353e-04 - output_variable2_loss: 5.0060e-04 - val_loss: 0.0842 - val_output_variable1_loss: 0.0604 - val_output_variable2_loss: 0.0239
# Epoch 100/100
# 10/10 [==============================] - 0s 49ms/step - loss: 0.0015 - output_variable1_loss: 0.0010 - output_variable2_loss: 4.8220e-04 - val_loss: 0.0830 - val_output_variable1_loss: 0.0591 - val_output_variable2_loss: 0.0239
# Epoch 1/100
# 13/13 [==============================] - 1s 52ms/step - loss: 0.0270 - output_variable1_loss: 0.0214 - output_variable2_loss: 0.0056 - val_loss: 0.0683 - val_output_variable1_loss: 0.0610 - val_output_variable2_loss: 0.0074
# Epoch 2/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0240 - output_variable1_loss: 0.0180 - output_variable2_loss: 0.0060 - val_loss: 0.0481 - val_output_variable1_loss: 0.0440 - val_output_variable2_loss: 0.0041
# Epoch 3/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0191 - output_variable1_loss: 0.0155 - output_variable2_loss: 0.0036 - val_loss: 0.0367 - val_output_variable1_loss: 0.0309 - val_output_variable2_loss: 0.0059
# Epoch 4/100
# 13/13 [==============================] - 1s 60ms/step - loss: 0.0128 - output_variable1_loss: 0.0097 - output_variable2_loss: 0.0030 - val_loss: 0.0483 - val_output_variable1_loss: 0.0431 - val_output_variable2_loss: 0.0053
# Epoch 5/100
# 13/13 [==============================] - 1s 60ms/step - loss: 0.0147 - output_variable1_loss: 0.0125 - output_variable2_loss: 0.0022 - val_loss: 0.0406 - val_output_variable1_loss: 0.0357 - val_output_variable2_loss: 0.0049
# Epoch 6/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0109 - output_variable1_loss: 0.0091 - output_variable2_loss: 0.0018 - val_loss: 0.0375 - val_output_variable1_loss: 0.0326 - val_output_variable2_loss: 0.0049
# Epoch 7/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0079 - output_variable1_loss: 0.0064 - output_variable2_loss: 0.0016 - val_loss: 0.0414 - val_output_variable1_loss: 0.0377 - val_output_variable2_loss: 0.0037
# Epoch 8/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0062 - output_variable1_loss: 0.0047 - output_variable2_loss: 0.0014 - val_loss: 0.0405 - val_output_variable1_loss: 0.0351 - val_output_variable2_loss: 0.0054
# Epoch 9/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0061 - output_variable1_loss: 0.0049 - output_variable2_loss: 0.0013 - val_loss: 0.0390 - val_output_variable1_loss: 0.0336 - val_output_variable2_loss: 0.0055
# Epoch 10/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0054 - output_variable1_loss: 0.0042 - output_variable2_loss: 0.0012 - val_loss: 0.0432 - val_output_variable1_loss: 0.0381 - val_output_variable2_loss: 0.0051
# Epoch 11/100
# 13/13 [==============================] - 1s 45ms/step - loss: 0.0043 - output_variable1_loss: 0.0032 - output_variable2_loss: 0.0011 - val_loss: 0.0413 - val_output_variable1_loss: 0.0349 - val_output_variable2_loss: 0.0065
# Epoch 12/100
# 13/13 [==============================] - 1s 44ms/step - loss: 0.0037 - output_variable1_loss: 0.0026 - output_variable2_loss: 0.0011 - val_loss: 0.0418 - val_output_variable1_loss: 0.0350 - val_output_variable2_loss: 0.0068
# Epoch 13/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0033 - output_variable1_loss: 0.0022 - output_variable2_loss: 0.0011 - val_loss: 0.0427 - val_output_variable1_loss: 0.0367 - val_output_variable2_loss: 0.0060
# Epoch 14/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0032 - output_variable1_loss: 0.0021 - output_variable2_loss: 0.0011 - val_loss: 0.0421 - val_output_variable1_loss: 0.0350 - val_output_variable2_loss: 0.0071
# Epoch 15/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0030 - output_variable1_loss: 0.0019 - output_variable2_loss: 0.0010 - val_loss: 0.0442 - val_output_variable1_loss: 0.0365 - val_output_variable2_loss: 0.0077
# Epoch 16/100
# 13/13 [==============================] - 1s 45ms/step - loss: 0.0028 - output_variable1_loss: 0.0018 - output_variable2_loss: 9.5781e-04 - val_loss: 0.0416 - val_output_variable1_loss: 0.0354 - val_output_variable2_loss: 0.0062
# Epoch 17/100
# 13/13 [==============================] - 1s 45ms/step - loss: 0.0027 - output_variable1_loss: 0.0017 - output_variable2_loss: 9.1770e-04 - val_loss: 0.0441 - val_output_variable1_loss: 0.0370 - val_output_variable2_loss: 0.0071
# Epoch 18/100
# 13/13 [==============================] - 1s 45ms/step - loss: 0.0027 - output_variable1_loss: 0.0017 - output_variable2_loss: 9.3109e-04 - val_loss: 0.0460 - val_output_variable1_loss: 0.0385 - val_output_variable2_loss: 0.0075
# Epoch 19/100
# 13/13 [==============================] - 1s 45ms/step - loss: 0.0026 - output_variable1_loss: 0.0017 - output_variable2_loss: 8.9702e-04 - val_loss: 0.0439 - val_output_variable1_loss: 0.0368 - val_output_variable2_loss: 0.0070
# Epoch 20/100
# 13/13 [==============================] - 1s 45ms/step - loss: 0.0026 - output_variable1_loss: 0.0016 - output_variable2_loss: 0.0010 - val_loss: 0.0468 - val_output_variable1_loss: 0.0381 - val_output_variable2_loss: 0.0087
# Epoch 21/100
# 13/13 [==============================] - 1s 44ms/step - loss: 0.0025 - output_variable1_loss: 0.0015 - output_variable2_loss: 9.8282e-04 - val_loss: 0.0466 - val_output_variable1_loss: 0.0378 - val_output_variable2_loss: 0.0088
# Epoch 22/100
# 13/13 [==============================] - 1s 45ms/step - loss: 0.0023 - output_variable1_loss: 0.0015 - output_variable2_loss: 8.2478e-04 - val_loss: 0.0454 - val_output_variable1_loss: 0.0376 - val_output_variable2_loss: 0.0078
# Epoch 23/100
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0023 - output_variable1_loss: 0.0015 - output_variable2_loss: 7.7617e-04 - val_loss: 0.0469 - val_output_variable1_loss: 0.0387 - val_output_variable2_loss: 0.0082
# Epoch 24/100
# 13/13 [==============================] - 1s 48ms/step - loss: 0.0022 - output_variable1_loss: 0.0015 - output_variable2_loss: 7.3513e-04 - val_loss: 0.0458 - val_output_variable1_loss: 0.0382 - val_output_variable2_loss: 0.0076
# Epoch 25/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0022 - output_variable1_loss: 0.0014 - output_variable2_loss: 7.5439e-04 - val_loss: 0.0444 - val_output_variable1_loss: 0.0368 - val_output_variable2_loss: 0.0076
# Epoch 26/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0021 - output_variable1_loss: 0.0014 - output_variable2_loss: 7.4419e-04 - val_loss: 0.0473 - val_output_variable1_loss: 0.0378 - val_output_variable2_loss: 0.0095
# Epoch 27/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0021 - output_variable1_loss: 0.0014 - output_variable2_loss: 7.1149e-04 - val_loss: 0.0466 - val_output_variable1_loss: 0.0379 - val_output_variable2_loss: 0.0087
# Epoch 28/100
# 13/13 [==============================] - 1s 44ms/step - loss: 0.0020 - output_variable1_loss: 0.0013 - output_variable2_loss: 6.7359e-04 - val_loss: 0.0466 - val_output_variable1_loss: 0.0382 - val_output_variable2_loss: 0.0084
# Epoch 29/100
# 13/13 [==============================] - 1s 44ms/step - loss: 0.0020 - output_variable1_loss: 0.0013 - output_variable2_loss: 6.6943e-04 - val_loss: 0.0458 - val_output_variable1_loss: 0.0376 - val_output_variable2_loss: 0.0082
# Epoch 30/100
# 13/13 [==============================] - 1s 50ms/step - loss: 0.0019 - output_variable1_loss: 0.0013 - output_variable2_loss: 6.6506e-04 - val_loss: 0.0465 - val_output_variable1_loss: 0.0393 - val_output_variable2_loss: 0.0072
# Epoch 31/100
# 13/13 [==============================] - 1s 47ms/step - loss: 0.0020 - output_variable1_loss: 0.0013 - output_variable2_loss: 7.0567e-04 - val_loss: 0.0459 - val_output_variable1_loss: 0.0382 - val_output_variable2_loss: 0.0077
# Epoch 32/100
# 13/13 [==============================] - 1s 45ms/step - loss: 0.0020 - output_variable1_loss: 0.0012 - output_variable2_loss: 7.6381e-04 - val_loss: 0.0507 - val_output_variable1_loss: 0.0391 - val_output_variable2_loss: 0.0116
# Epoch 33/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0024 - output_variable1_loss: 0.0012 - output_variable2_loss: 0.0011 - val_loss: 0.0478 - val_output_variable1_loss: 0.0390 - val_output_variable2_loss: 0.0088
# Epoch 34/100
# 13/13 [==============================] - 1s 45ms/step - loss: 0.0023 - output_variable1_loss: 0.0012 - output_variable2_loss: 0.0011 - val_loss: 0.0496 - val_output_variable1_loss: 0.0381 - val_output_variable2_loss: 0.0114
# Epoch 35/100
# 13/13 [==============================] - 1s 45ms/step - loss: 0.0021 - output_variable1_loss: 0.0012 - output_variable2_loss: 8.8947e-04 - val_loss: 0.0489 - val_output_variable1_loss: 0.0388 - val_output_variable2_loss: 0.0101
# Epoch 36/100
# 13/13 [==============================] - 1s 45ms/step - loss: 0.0020 - output_variable1_loss: 0.0012 - output_variable2_loss: 7.6511e-04 - val_loss: 0.0493 - val_output_variable1_loss: 0.0386 - val_output_variable2_loss: 0.0108

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss_1):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss_1[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error 1", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss_2):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss_2[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error 2", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
# Evaluate the model on the test data
predictions_1 = []
predictions_2 = []
#print(len(eval_target_variables))

for i in range(len(Y_test)):
    current_batch = X_test[i].reshape((1, NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))
    curr_pred1, curr_pred2 = model.predict(current_batch)
    predictions_1.append(curr_pred1)
    predictions_2.append(curr_pred2)

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_1):
    ax = axs[i]
    # TODO seems to work but check why column[0]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_test[i, :, 0], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_2):
    ax = axs[i]
    # TODO seems to work but check why column[0]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_test[i, :, 1], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
rmse = 0
for i in range(len(predictions_1)):
    print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_1[i][0], Y_test[i, :, 0]))}')
    rmse += sqrt(mean_squared_error(predictions_1[i][0], Y_test[i, :, 0]))

rmse /= len(predictions_1)    
print(f"RMSE = {rmse}")

# %%
rmse = 0
for i in range(len(predictions_2)):
    print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_2[i][0], Y_test[i, :, 1]))}')
    rmse += sqrt(mean_squared_error(predictions_2[i][0], Y_test[i, :, 1]))

rmse /= len(predictions_2)    
print(f"RMSE = {rmse}")
