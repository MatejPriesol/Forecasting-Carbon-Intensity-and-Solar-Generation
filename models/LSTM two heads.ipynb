# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
train = pd.read_csv("../data/schemas/warm_up/TrainSet.csv", sep=",")
validation = pd.read_csv("../data/schemas/warm_up/ValidationSet.csv", sep=",")
test = pd.read_csv("../data/schemas/warm_up/TestSet.csv", sep=",")

# %%
# Global variables

NUM_OF_TIMESTEPS_INPUT = 48
NUM_OF_TIMESTEPS_OUTPUT = 24

THRESHOLD = 0.4   # For feature selection

# %%
columns_to_predict = ["kg_CO2/kWh", "Avg solar generation"]

independent_variables = []

for column in train:
    if abs(train[column].corr(train[columns_to_predict[0]])) > THRESHOLD: #or abs(train[column].corr(train[columns_to_predict[1]])) > THRESHOLD:
        independent_variables.append(column)

#[independent_variables.remove(i) for i in columns_to_predict]
independent_variables.remove(columns_to_predict[0])
    
if "Index" in independent_variables:
    independent_variables.remove("Index")
if "Solar Generation (W/kW)_1" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_1")
if "Solar Generation (W/kW)_2" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_2")
if "Solar Generation (W/kW)_3" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_3")
    
print(independent_variables)
# Out:
# ['Hour_1', 'Hour_2', 'Hour_3', 'Occupant Count (people)_3', '12h Outdoor Drybulb Temperature (C)', '24h Outdoor Drybulb Temperature (C)', '12h Outdoor Relative Humidity (%)', '6h Direct Solar Radiation (W/m2)', '12h Direct Solar Radiation (W/m2)']

# %% [markdown]
# Prepare the data

# %%
# Split the X and Y for all sets

# Train set
X_train_default = train[independent_variables]
Y_train_default = train[columns_to_predict]

# Validation set, also include the data from train that was used only as output to get more datapoints
X_val_default = pd.concat([X_train_default.tail(NUM_OF_TIMESTEPS_OUTPUT), validation[independent_variables]], ignore_index=True)
Y_val_default = pd.concat([Y_train_default.tail(NUM_OF_TIMESTEPS_OUTPUT), validation[columns_to_predict]], ignore_index=True)

# Test set, also include the data from train that was used only as output to get more datapoints
X_test_default = pd.concat([X_val_default.tail(NUM_OF_TIMESTEPS_OUTPUT), test[independent_variables]], ignore_index=True)
Y_test_default = pd.concat([Y_val_default.tail(NUM_OF_TIMESTEPS_OUTPUT), test[columns_to_predict]], ignore_index=True)

NUM_OF_ROWS_TRAIN, NUM_OF_FEATURES = X_train_default.shape

print(X_train_default.shape)
print(X_val_default.shape)
print(X_test_default.shape)
# Out:
# (576, 9)
# (96, 9)
# (96, 9)

# %%
# Function to prepare the data into batches that will be passed into the model

def create_sequences(input_data, output_data, timesteps_input, timesteps_output):
    sequences, targets = [], []
    for i in range(len(input_data) - timesteps_input - timesteps_output + 1):
        seq = input_data[i:i + timesteps_input]
        target = output_data[i + timesteps_input: i + timesteps_input + timesteps_output]
        sequences.append(seq)
        targets.append(target)

    return np.array(sequences), np.array(targets)

# %%
X_train, Y_train = create_sequences(X_train_default, Y_train_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)
X_val, Y_val = create_sequences(X_val_default, Y_val_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)
X_test, Y_test = create_sequences(X_test_default, Y_test_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)

print(f"X_train = {X_train.shape}, Y_train = {Y_train.shape}\n"
      f"X_val = {X_val.shape}, Y_val = {Y_val.shape}\n"
      f"X_test = {X_test.shape}, Y_test = {Y_test.shape}")
# Out:
# X_train = (505, 48, 9), Y_train = (505, 24, 2)
# X_val = (25, 48, 9), Y_val = (25, 24, 2)
# X_test = (25, 48, 9), Y_test = (25, 24, 2)

# %%
print(Y_train[:, :, 0])
# Out:
# [[0.59739428 0.49429981 0.38708765 ... 0.73547528 0.69513525 0.71729728]
#  [0.49429981 0.38708765 0.28880037 ... 0.69513525 0.71729728 0.6633147 ]
#  [0.38708765 0.28880037 0.2346659  ... 0.71729728 0.6633147  0.55539687]
#  ...
#  [0.47416969 0.39741721 0.28594384 ... 0.4397153  0.45619247 0.45482902]
#  [0.39741721 0.28594384 0.16805223 ... 0.45619247 0.45482902 0.41836388]
#  [0.28594384 0.16805223 0.12974031 ... 0.45482902 0.41836388 0.39162712]]

# %%
from sklearn.model_selection import TimeSeriesSplit
from tensorflow.keras import layers, models

tscv = TimeSeriesSplit(n_splits = 4) # For cross-validation

callback = keras.callbacks.EarlyStopping(monitor='loss', patience = 6) #patience parameter to be adjusted

loss = []
val_loss = []
loss_1 = []
val_loss_1 = []
loss_2 = []
val_loss_2 = []

# Input layer
input_layer = layers.Input(shape=(NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))

# Dense layers for variable 1
lstm1 = layers.LSTM(98, activation='relu', return_sequences=True)(input_layer)
lstm2 = layers.LSTM(48, activation='relu', return_sequences=True)(lstm1)
lstm3 = layers.LSTM(24, activation='relu', return_sequences=False)(lstm2)
output_variable1 = layers.Dense(24, name='output_variable1')(lstm3)

# Dense layers for variable 2
dense4 = layers.LSTM(96, activation='relu', return_sequences=True)(input_layer)
dense5 = layers.LSTM(48, activation='relu', return_sequences=True)(dense4)
dense6 = layers.LSTM(24, activation='relu', return_sequences=False)(dense5)
output_variable2 = layers.Dense(24, name='output_variable2')(dense6)

# Define the model
model = models.Model(inputs=input_layer, outputs=[output_variable1, output_variable2])

model.compile(
    optimizer='adam',
    loss={'output_variable1': 'mean_squared_error', 'output_variable2': 'mean_squared_error'}
) #types of optimizer, loss function to be adjusted
    
    
for train_data, test_data in tscv.split(X_train):
    X_train_current_split, X_test_current_split = X_train[train_data], X_train[test_data]
    y_train_current_split, y_test_current_split = Y_train[train_data], Y_train[test_data]
    
    history = model.fit(X_train_current_split, y={"output_variable1": y_train_current_split[:, :, 0], 
                                                  "output_variable2": y_train_current_split[:, :, 1]},
              epochs=100, 
              validation_data=(
                  X_test_current_split,
                {
                    "output_variable1": y_test_current_split[:, :, 0],
                    "output_variable2": y_test_current_split[:, :, 1],
                },
              ),
              # validation_split = 0.8,
              verbose=1,
              callbacks=callback
    )
    loss.append(model.history.history['loss'])
    val_loss.append(model.history.history['val_loss'])
    
    loss_1.append(model.history.history['output_variable1_loss'])
    val_loss_1.append(model.history.history['val_output_variable1_loss'])
    
    loss_2.append(model.history.history['output_variable2_loss'])
    val_loss_2.append(model.history.history['val_output_variable2_loss'])
# Out:
# Epoch 1/100
# 4/4 [==============================] - 7s 267ms/step - loss: 0.5978 - output_variable1_loss: 0.4028 - output_variable2_loss: 0.1950 - val_loss: 0.4138 - val_output_variable1_loss: 0.2153 - val_output_variable2_loss: 0.1984
# Epoch 2/100
# 4/4 [==============================] - 0s 44ms/step - loss: 0.5590 - output_variable1_loss: 0.3807 - output_variable2_loss: 0.1782 - val_loss: 0.3720 - val_output_variable1_loss: 0.1936 - val_output_variable2_loss: 0.1784
# Epoch 3/100
# 4/4 [==============================] - 0s 45ms/step - loss: 0.5013 - output_variable1_loss: 0.3371 - output_variable2_loss: 0.1641 - val_loss: 0.3642 - val_output_variable1_loss: 0.1983 - val_output_variable2_loss: 0.1659
# Epoch 4/100
# 4/4 [==============================] - 0s 46ms/step - loss: 0.4485 - output_variable1_loss: 0.2951 - output_variable2_loss: 0.1534 - val_loss: 0.3242 - val_output_variable1_loss: 0.1646 - val_output_variable2_loss: 0.1596
# Epoch 5/100
# 4/4 [==============================] - 0s 45ms/step - loss: 0.4206 - output_variable1_loss: 0.2721 - output_variable2_loss: 0.1485 - val_loss: 0.3114 - val_output_variable1_loss: 0.1558 - val_output_variable2_loss: 0.1557
# Epoch 6/100
# 4/4 [==============================] - 0s 45ms/step - loss: 0.3874 - output_variable1_loss: 0.2439 - output_variable2_loss: 0.1434 - val_loss: 0.2945 - val_output_variable1_loss: 0.1468 - val_output_variable2_loss: 0.1477
# Epoch 7/100
# 4/4 [==============================] - 0s 47ms/step - loss: 0.3573 - output_variable1_loss: 0.2209 - output_variable2_loss: 0.1364 - val_loss: 0.2733 - val_output_variable1_loss: 0.1318 - val_output_variable2_loss: 0.1416
# Epoch 8/100
# 4/4 [==============================] - 0s 48ms/step - loss: 0.3303 - output_variable1_loss: 0.1991 - output_variable2_loss: 0.1312 - val_loss: 0.2630 - val_output_variable1_loss: 0.1253 - val_output_variable2_loss: 0.1378
# Epoch 9/100
# 4/4 [==============================] - 0s 44ms/step - loss: 0.3044 - output_variable1_loss: 0.1781 - output_variable2_loss: 0.1263 - val_loss: 0.2517 - val_output_variable1_loss: 0.1213 - val_output_variable2_loss: 0.1304
# Epoch 10/100
# 4/4 [==============================] - 0s 48ms/step - loss: 0.2814 - output_variable1_loss: 0.1607 - output_variable2_loss: 0.1207 - val_loss: 0.2317 - val_output_variable1_loss: 0.1056 - val_output_variable2_loss: 0.1261
# Epoch 11/100
# 4/4 [==============================] - 0s 47ms/step - loss: 0.2628 - output_variable1_loss: 0.1464 - output_variable2_loss: 0.1165 - val_loss: 0.2191 - val_output_variable1_loss: 0.0974 - val_output_variable2_loss: 0.1217
# Epoch 12/100
# 4/4 [==============================] - 0s 44ms/step - loss: 0.2449 - output_variable1_loss: 0.1319 - output_variable2_loss: 0.1130 - val_loss: 0.2182 - val_output_variable1_loss: 0.0988 - val_output_variable2_loss: 0.1195
# Epoch 13/100
# 4/4 [==============================] - 0s 43ms/step - loss: 0.2287 - output_variable1_loss: 0.1204 - output_variable2_loss: 0.1083 - val_loss: 0.1996 - val_output_variable1_loss: 0.0882 - val_output_variable2_loss: 0.1114
# Epoch 14/100
# 4/4 [==============================] - 0s 47ms/step - loss: 0.2122 - output_variable1_loss: 0.1068 - output_variable2_loss: 0.1054 - val_loss: 0.1901 - val_output_variable1_loss: 0.0832 - val_output_variable2_loss: 0.1068
# Epoch 15/100
# 4/4 [==============================] - 0s 45ms/step - loss: 0.1959 - output_variable1_loss: 0.0962 - output_variable2_loss: 0.0997 - val_loss: 0.1836 - val_output_variable1_loss: 0.0753 - val_output_variable2_loss: 0.1083
# Epoch 16/100
# 4/4 [==============================] - 0s 45ms/step - loss: 0.1849 - output_variable1_loss: 0.0877 - output_variable2_loss: 0.0971 - val_loss: 0.1728 - val_output_variable1_loss: 0.0783 - val_output_variable2_loss: 0.0945
# Epoch 17/100
# 4/4 [==============================] - 0s 45ms/step - loss: 0.1665 - output_variable1_loss: 0.0781 - output_variable2_loss: 0.0883 - val_loss: 0.1672 - val_output_variable1_loss: 0.0768 - val_output_variable2_loss: 0.0904
# Epoch 18/100
# 4/4 [==============================] - 0s 46ms/step - loss: 0.1540 - output_variable1_loss: 0.0711 - output_variable2_loss: 0.0828 - val_loss: 0.1578 - val_output_variable1_loss: 0.0712 - val_output_variable2_loss: 0.0866
# Epoch 19/100
# 4/4 [==============================] - 0s 47ms/step - loss: 0.1402 - output_variable1_loss: 0.0635 - output_variable2_loss: 0.0767 - val_loss: 0.1426 - val_output_variable1_loss: 0.0641 - val_output_variable2_loss: 0.0785
# Epoch 20/100
# 4/4 [==============================] - 0s 46ms/step - loss: 0.1283 - output_variable1_loss: 0.0582 - output_variable2_loss: 0.0701 - val_loss: 0.1287 - val_output_variable1_loss: 0.0571 - val_output_variable2_loss: 0.0716
# Epoch 21/100
# 4/4 [==============================] - 0s 46ms/step - loss: 0.1250 - output_variable1_loss: 0.0607 - output_variable2_loss: 0.0643 - val_loss: 0.1272 - val_output_variable1_loss: 0.0619 - val_output_variable2_loss: 0.0653
# Epoch 22/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.1304 - output_variable1_loss: 0.0714 - output_variable2_loss: 0.0590 - val_loss: 0.1162 - val_output_variable1_loss: 0.0559 - val_output_variable2_loss: 0.0603
# Epoch 23/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.1461 - output_variable1_loss: 0.0891 - output_variable2_loss: 0.0571 - val_loss: 0.1669 - val_output_variable1_loss: 0.1117 - val_output_variable2_loss: 0.0551
# Epoch 24/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.1235 - output_variable1_loss: 0.0603 - output_variable2_loss: 0.0633 - val_loss: 0.1216 - val_output_variable1_loss: 0.0453 - val_output_variable2_loss: 0.0762
# Epoch 25/100
# 4/4 [==============================] - 0s 51ms/step - loss: 0.1175 - output_variable1_loss: 0.0580 - output_variable2_loss: 0.0595 - val_loss: 0.1370 - val_output_variable1_loss: 0.0829 - val_output_variable2_loss: 0.0541
# Epoch 26/100
# 4/4 [==============================] - 0s 51ms/step - loss: 0.1043 - output_variable1_loss: 0.0540 - output_variable2_loss: 0.0503 - val_loss: 0.1072 - val_output_variable1_loss: 0.0501 - val_output_variable2_loss: 0.0570
# Epoch 27/100
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0944 - output_variable1_loss: 0.0475 - output_variable2_loss: 0.0469 - val_loss: 0.1189 - val_output_variable1_loss: 0.0759 - val_output_variable2_loss: 0.0429
# Epoch 28/100
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0883 - output_variable1_loss: 0.0470 - output_variable2_loss: 0.0414 - val_loss: 0.1019 - val_output_variable1_loss: 0.0602 - val_output_variable2_loss: 0.0417
# Epoch 29/100
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0805 - output_variable1_loss: 0.0430 - output_variable2_loss: 0.0375 - val_loss: 0.0977 - val_output_variable1_loss: 0.0613 - val_output_variable2_loss: 0.0364
# Epoch 30/100
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0759 - output_variable1_loss: 0.0420 - output_variable2_loss: 0.0339 - val_loss: 0.0851 - val_output_variable1_loss: 0.0490 - val_output_variable2_loss: 0.0361
# Epoch 31/100
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0728 - output_variable1_loss: 0.0412 - output_variable2_loss: 0.0315 - val_loss: 0.0933 - val_output_variable1_loss: 0.0602 - val_output_variable2_loss: 0.0331
# Epoch 32/100
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0685 - output_variable1_loss: 0.0393 - output_variable2_loss: 0.0292 - val_loss: 0.0814 - val_output_variable1_loss: 0.0510 - val_output_variable2_loss: 0.0304
# Epoch 33/100
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0647 - output_variable1_loss: 0.0378 - output_variable2_loss: 0.0269 - val_loss: 0.0881 - val_output_variable1_loss: 0.0589 - val_output_variable2_loss: 0.0292
# Epoch 34/100
# 4/4 [==============================] - 0s 58ms/step - loss: 0.0616 - output_variable1_loss: 0.0364 - output_variable2_loss: 0.0253 - val_loss: 0.0831 - val_output_variable1_loss: 0.0542 - val_output_variable2_loss: 0.0289
# Epoch 35/100
# 4/4 [==============================] - 0s 55ms/step - loss: 0.0593 - output_variable1_loss: 0.0352 - output_variable2_loss: 0.0241 - val_loss: 0.0820 - val_output_variable1_loss: 0.0557 - val_output_variable2_loss: 0.0263
# Epoch 36/100
# 4/4 [==============================] - 0s 56ms/step - loss: 0.0572 - output_variable1_loss: 0.0343 - output_variable2_loss: 0.0229 - val_loss: 0.0810 - val_output_variable1_loss: 0.0538 - val_output_variable2_loss: 0.0272
# Epoch 37/100
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0551 - output_variable1_loss: 0.0334 - output_variable2_loss: 0.0217 - val_loss: 0.0804 - val_output_variable1_loss: 0.0580 - val_output_variable2_loss: 0.0225
# Epoch 38/100
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0531 - output_variable1_loss: 0.0327 - output_variable2_loss: 0.0204 - val_loss: 0.0751 - val_output_variable1_loss: 0.0520 - val_output_variable2_loss: 0.0231
# Epoch 39/100
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0521 - output_variable1_loss: 0.0323 - output_variable2_loss: 0.0198 - val_loss: 0.0693 - val_output_variable1_loss: 0.0480 - val_output_variable2_loss: 0.0212
# Epoch 40/100
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0504 - output_variable1_loss: 0.0322 - output_variable2_loss: 0.0182 - val_loss: 0.0809 - val_output_variable1_loss: 0.0594 - val_output_variable2_loss: 0.0215
# Epoch 41/100
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0484 - output_variable1_loss: 0.0309 - output_variable2_loss: 0.0175 - val_loss: 0.0803 - val_output_variable1_loss: 0.0599 - val_output_variable2_loss: 0.0203
# Epoch 42/100
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0472 - output_variable1_loss: 0.0305 - output_variable2_loss: 0.0167 - val_loss: 0.0682 - val_output_variable1_loss: 0.0495 - val_output_variable2_loss: 0.0187
# Epoch 43/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0456 - output_variable1_loss: 0.0295 - output_variable2_loss: 0.0161 - val_loss: 0.0742 - val_output_variable1_loss: 0.0551 - val_output_variable2_loss: 0.0191
# Epoch 44/100
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0440 - output_variable1_loss: 0.0287 - output_variable2_loss: 0.0154 - val_loss: 0.0714 - val_output_variable1_loss: 0.0544 - val_output_variable2_loss: 0.0170
# Epoch 45/100
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0434 - output_variable1_loss: 0.0279 - output_variable2_loss: 0.0154 - val_loss: 0.0707 - val_output_variable1_loss: 0.0518 - val_output_variable2_loss: 0.0189
# Epoch 46/100
# 4/4 [==============================] - 0s 65ms/step - loss: 0.0419 - output_variable1_loss: 0.0270 - output_variable2_loss: 0.0149 - val_loss: 0.0678 - val_output_variable1_loss: 0.0510 - val_output_variable2_loss: 0.0168
# Epoch 47/100
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0403 - output_variable1_loss: 0.0262 - output_variable2_loss: 0.0142 - val_loss: 0.0627 - val_output_variable1_loss: 0.0473 - val_output_variable2_loss: 0.0154
# Epoch 48/100
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0394 - output_variable1_loss: 0.0254 - output_variable2_loss: 0.0140 - val_loss: 0.0681 - val_output_variable1_loss: 0.0522 - val_output_variable2_loss: 0.0159
# Epoch 49/100
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0389 - output_variable1_loss: 0.0249 - output_variable2_loss: 0.0140 - val_loss: 0.0669 - val_output_variable1_loss: 0.0512 - val_output_variable2_loss: 0.0157
# Epoch 50/100
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0370 - output_variable1_loss: 0.0241 - output_variable2_loss: 0.0130 - val_loss: 0.0654 - val_output_variable1_loss: 0.0508 - val_output_variable2_loss: 0.0146
# Epoch 51/100
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0363 - output_variable1_loss: 0.0233 - output_variable2_loss: 0.0131 - val_loss: 0.0637 - val_output_variable1_loss: 0.0494 - val_output_variable2_loss: 0.0143
# Epoch 52/100
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0347 - output_variable1_loss: 0.0222 - output_variable2_loss: 0.0125 - val_loss: 0.0625 - val_output_variable1_loss: 0.0478 - val_output_variable2_loss: 0.0147
# Epoch 53/100
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0334 - output_variable1_loss: 0.0213 - output_variable2_loss: 0.0121 - val_loss: 0.0628 - val_output_variable1_loss: 0.0485 - val_output_variable2_loss: 0.0143
# Epoch 54/100
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0320 - output_variable1_loss: 0.0204 - output_variable2_loss: 0.0116 - val_loss: 0.0600 - val_output_variable1_loss: 0.0457 - val_output_variable2_loss: 0.0143
# Epoch 55/100
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0315 - output_variable1_loss: 0.0197 - output_variable2_loss: 0.0117 - val_loss: 0.0603 - val_output_variable1_loss: 0.0451 - val_output_variable2_loss: 0.0152
# Epoch 56/100
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0303 - output_variable1_loss: 0.0191 - output_variable2_loss: 0.0111 - val_loss: 0.0525 - val_output_variable1_loss: 0.0403 - val_output_variable2_loss: 0.0122
# Epoch 57/100
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0295 - output_variable1_loss: 0.0187 - output_variable2_loss: 0.0109 - val_loss: 0.0548 - val_output_variable1_loss: 0.0403 - val_output_variable2_loss: 0.0145
# Epoch 58/100
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0283 - output_variable1_loss: 0.0176 - output_variable2_loss: 0.0107 - val_loss: 0.0535 - val_output_variable1_loss: 0.0402 - val_output_variable2_loss: 0.0133
# Epoch 59/100
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0276 - output_variable1_loss: 0.0169 - output_variable2_loss: 0.0107 - val_loss: 0.0525 - val_output_variable1_loss: 0.0421 - val_output_variable2_loss: 0.0104
# Epoch 60/100
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0261 - output_variable1_loss: 0.0156 - output_variable2_loss: 0.0105 - val_loss: 0.0551 - val_output_variable1_loss: 0.0419 - val_output_variable2_loss: 0.0132
# Epoch 61/100
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0250 - output_variable1_loss: 0.0150 - output_variable2_loss: 0.0100 - val_loss: 0.0552 - val_output_variable1_loss: 0.0427 - val_output_variable2_loss: 0.0125
# Epoch 62/100
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0241 - output_variable1_loss: 0.0142 - output_variable2_loss: 0.0099 - val_loss: 0.0578 - val_output_variable1_loss: 0.0461 - val_output_variable2_loss: 0.0116
# Epoch 63/100
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0229 - output_variable1_loss: 0.0132 - output_variable2_loss: 0.0097 - val_loss: 0.0651 - val_output_variable1_loss: 0.0515 - val_output_variable2_loss: 0.0137
# Epoch 64/100
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0228 - output_variable1_loss: 0.0133 - output_variable2_loss: 0.0095 - val_loss: 0.0628 - val_output_variable1_loss: 0.0514 - val_output_variable2_loss: 0.0115
# Epoch 65/100
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0223 - output_variable1_loss: 0.0130 - output_variable2_loss: 0.0093 - val_loss: 0.0627 - val_output_variable1_loss: 0.0511 - val_output_variable2_loss: 0.0116
# Epoch 66/100
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0213 - output_variable1_loss: 0.0123 - output_variable2_loss: 0.0091 - val_loss: 0.0586 - val_output_variable1_loss: 0.0474 - val_output_variable2_loss: 0.0111
# Epoch 67/100
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0203 - output_variable1_loss: 0.0116 - output_variable2_loss: 0.0087 - val_loss: 0.0586 - val_output_variable1_loss: 0.0481 - val_output_variable2_loss: 0.0104
# Epoch 68/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0195 - output_variable1_loss: 0.0109 - output_variable2_loss: 0.0086 - val_loss: 0.0543 - val_output_variable1_loss: 0.0430 - val_output_variable2_loss: 0.0113
# Epoch 69/100
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0191 - output_variable1_loss: 0.0105 - output_variable2_loss: 0.0087 - val_loss: 0.0531 - val_output_variable1_loss: 0.0418 - val_output_variable2_loss: 0.0113
# Epoch 70/100
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0190 - output_variable1_loss: 0.0103 - output_variable2_loss: 0.0087 - val_loss: 0.0480 - val_output_variable1_loss: 0.0395 - val_output_variable2_loss: 0.0085
# Epoch 71/100
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0190 - output_variable1_loss: 0.0103 - output_variable2_loss: 0.0087 - val_loss: 0.0465 - val_output_variable1_loss: 0.0365 - val_output_variable2_loss: 0.0099
# Epoch 72/100
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0202 - output_variable1_loss: 0.0116 - output_variable2_loss: 0.0086 - val_loss: 0.0481 - val_output_variable1_loss: 0.0355 - val_output_variable2_loss: 0.0126
# Epoch 73/100
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0208 - output_variable1_loss: 0.0124 - output_variable2_loss: 0.0084 - val_loss: 0.0498 - val_output_variable1_loss: 0.0371 - val_output_variable2_loss: 0.0127
# Epoch 74/100
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0205 - output_variable1_loss: 0.0122 - output_variable2_loss: 0.0083 - val_loss: 0.0517 - val_output_variable1_loss: 0.0424 - val_output_variable2_loss: 0.0093
# Epoch 75/100
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0185 - output_variable1_loss: 0.0104 - output_variable2_loss: 0.0081 - val_loss: 0.0568 - val_output_variable1_loss: 0.0466 - val_output_variable2_loss: 0.0103
# Epoch 76/100
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0177 - output_variable1_loss: 0.0101 - output_variable2_loss: 0.0076 - val_loss: 0.0677 - val_output_variable1_loss: 0.0567 - val_output_variable2_loss: 0.0110
# Epoch 77/100
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0179 - output_variable1_loss: 0.0105 - output_variable2_loss: 0.0074 - val_loss: 0.0612 - val_output_variable1_loss: 0.0527 - val_output_variable2_loss: 0.0085
# Epoch 78/100
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0168 - output_variable1_loss: 0.0099 - output_variable2_loss: 0.0069 - val_loss: 0.0579 - val_output_variable1_loss: 0.0491 - val_output_variable2_loss: 0.0088
# Epoch 79/100
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0159 - output_variable1_loss: 0.0089 - output_variable2_loss: 0.0070 - val_loss: 0.0493 - val_output_variable1_loss: 0.0401 - val_output_variable2_loss: 0.0092
# Epoch 80/100
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0160 - output_variable1_loss: 0.0094 - output_variable2_loss: 0.0066 - val_loss: 0.0466 - val_output_variable1_loss: 0.0388 - val_output_variable2_loss: 0.0077
# Epoch 81/100
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0150 - output_variable1_loss: 0.0088 - output_variable2_loss: 0.0062 - val_loss: 0.0487 - val_output_variable1_loss: 0.0404 - val_output_variable2_loss: 0.0082
# Epoch 82/100
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0146 - output_variable1_loss: 0.0084 - output_variable2_loss: 0.0062 - val_loss: 0.0540 - val_output_variable1_loss: 0.0439 - val_output_variable2_loss: 0.0102
# Epoch 83/100
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0147 - output_variable1_loss: 0.0085 - output_variable2_loss: 0.0062 - val_loss: 0.0688 - val_output_variable1_loss: 0.0589 - val_output_variable2_loss: 0.0099
# Epoch 84/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0155 - output_variable1_loss: 0.0091 - output_variable2_loss: 0.0063 - val_loss: 0.0517 - val_output_variable1_loss: 0.0436 - val_output_variable2_loss: 0.0082
# Epoch 85/100
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0146 - output_variable1_loss: 0.0082 - output_variable2_loss: 0.0064 - val_loss: 0.0514 - val_output_variable1_loss: 0.0441 - val_output_variable2_loss: 0.0073
# Epoch 86/100
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0140 - output_variable1_loss: 0.0078 - output_variable2_loss: 0.0061 - val_loss: 0.0490 - val_output_variable1_loss: 0.0411 - val_output_variable2_loss: 0.0079
# Epoch 87/100
# 4/4 [==============================] - 0s 53ms/step - loss: 0.0134 - output_variable1_loss: 0.0075 - output_variable2_loss: 0.0059 - val_loss: 0.0497 - val_output_variable1_loss: 0.0399 - val_output_variable2_loss: 0.0098
# Epoch 88/100
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0132 - output_variable1_loss: 0.0074 - output_variable2_loss: 0.0058 - val_loss: 0.0492 - val_output_variable1_loss: 0.0413 - val_output_variable2_loss: 0.0079
# Epoch 89/100
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0128 - output_variable1_loss: 0.0073 - output_variable2_loss: 0.0055 - val_loss: 0.0490 - val_output_variable1_loss: 0.0418 - val_output_variable2_loss: 0.0072
# Epoch 90/100
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0127 - output_variable1_loss: 0.0072 - output_variable2_loss: 0.0056 - val_loss: 0.0519 - val_output_variable1_loss: 0.0445 - val_output_variable2_loss: 0.0074
# Epoch 91/100
# 4/4 [==============================] - 0s 54ms/step - loss: 0.0121 - output_variable1_loss: 0.0071 - output_variable2_loss: 0.0050 - val_loss: 0.0534 - val_output_variable1_loss: 0.0458 - val_output_variable2_loss: 0.0075
# Epoch 92/100
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0121 - output_variable1_loss: 0.0069 - output_variable2_loss: 0.0052 - val_loss: 0.0533 - val_output_variable1_loss: 0.0463 - val_output_variable2_loss: 0.0070
# Epoch 93/100
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0118 - output_variable1_loss: 0.0070 - output_variable2_loss: 0.0048 - val_loss: 0.0497 - val_output_variable1_loss: 0.0430 - val_output_variable2_loss: 0.0067
# Epoch 94/100
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0114 - output_variable1_loss: 0.0068 - output_variable2_loss: 0.0046 - val_loss: 0.0485 - val_output_variable1_loss: 0.0415 - val_output_variable2_loss: 0.0070
# Epoch 95/100
# 4/4 [==============================] - 0s 49ms/step - loss: 0.0113 - output_variable1_loss: 0.0068 - output_variable2_loss: 0.0044 - val_loss: 0.0505 - val_output_variable1_loss: 0.0436 - val_output_variable2_loss: 0.0069
# Epoch 96/100
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0111 - output_variable1_loss: 0.0068 - output_variable2_loss: 0.0043 - val_loss: 0.0494 - val_output_variable1_loss: 0.0424 - val_output_variable2_loss: 0.0070
# Epoch 97/100
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0110 - output_variable1_loss: 0.0066 - output_variable2_loss: 0.0043 - val_loss: 0.0469 - val_output_variable1_loss: 0.0410 - val_output_variable2_loss: 0.0059
# Epoch 98/100
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0110 - output_variable1_loss: 0.0068 - output_variable2_loss: 0.0042 - val_loss: 0.0468 - val_output_variable1_loss: 0.0408 - val_output_variable2_loss: 0.0060
# Epoch 99/100
# 4/4 [==============================] - 0s 47ms/step - loss: 0.0110 - output_variable1_loss: 0.0067 - output_variable2_loss: 0.0043 - val_loss: 0.0471 - val_output_variable1_loss: 0.0410 - val_output_variable2_loss: 0.0061
# Epoch 100/100
# 4/4 [==============================] - 0s 46ms/step - loss: 0.0110 - output_variable1_loss: 0.0067 - output_variable2_loss: 0.0042 - val_loss: 0.0538 - val_output_variable1_loss: 0.0455 - val_output_variable2_loss: 0.0083
# Epoch 1/100
# 7/7 [==============================] - 0s 44ms/step - loss: 0.0267 - output_variable1_loss: 0.0212 - output_variable2_loss: 0.0054 - val_loss: 0.0287 - val_output_variable1_loss: 0.0242 - val_output_variable2_loss: 0.0045
# Epoch 2/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0238 - output_variable1_loss: 0.0190 - output_variable2_loss: 0.0048 - val_loss: 0.0403 - val_output_variable1_loss: 0.0364 - val_output_variable2_loss: 0.0039
# Epoch 3/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0232 - output_variable1_loss: 0.0190 - output_variable2_loss: 0.0042 - val_loss: 0.0273 - val_output_variable1_loss: 0.0233 - val_output_variable2_loss: 0.0039
# Epoch 4/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0193 - output_variable1_loss: 0.0151 - output_variable2_loss: 0.0041 - val_loss: 0.0347 - val_output_variable1_loss: 0.0292 - val_output_variable2_loss: 0.0055
# Epoch 5/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0174 - output_variable1_loss: 0.0133 - output_variable2_loss: 0.0041 - val_loss: 0.0343 - val_output_variable1_loss: 0.0296 - val_output_variable2_loss: 0.0047
# Epoch 6/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0163 - output_variable1_loss: 0.0127 - output_variable2_loss: 0.0036 - val_loss: 0.0290 - val_output_variable1_loss: 0.0247 - val_output_variable2_loss: 0.0043
# Epoch 7/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0159 - output_variable1_loss: 0.0125 - output_variable2_loss: 0.0035 - val_loss: 0.0280 - val_output_variable1_loss: 0.0242 - val_output_variable2_loss: 0.0037
# Epoch 8/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0145 - output_variable1_loss: 0.0112 - output_variable2_loss: 0.0033 - val_loss: 0.0275 - val_output_variable1_loss: 0.0243 - val_output_variable2_loss: 0.0032
# Epoch 9/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0139 - output_variable1_loss: 0.0108 - output_variable2_loss: 0.0031 - val_loss: 0.0341 - val_output_variable1_loss: 0.0299 - val_output_variable2_loss: 0.0042
# Epoch 10/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0130 - output_variable1_loss: 0.0099 - output_variable2_loss: 0.0032 - val_loss: 0.0296 - val_output_variable1_loss: 0.0249 - val_output_variable2_loss: 0.0047
# Epoch 11/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0124 - output_variable1_loss: 0.0093 - output_variable2_loss: 0.0031 - val_loss: 0.0298 - val_output_variable1_loss: 0.0264 - val_output_variable2_loss: 0.0035
# Epoch 12/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0120 - output_variable1_loss: 0.0092 - output_variable2_loss: 0.0028 - val_loss: 0.0279 - val_output_variable1_loss: 0.0251 - val_output_variable2_loss: 0.0028
# Epoch 13/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0124 - output_variable1_loss: 0.0096 - output_variable2_loss: 0.0028 - val_loss: 0.0259 - val_output_variable1_loss: 0.0224 - val_output_variable2_loss: 0.0035
# Epoch 14/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0119 - output_variable1_loss: 0.0091 - output_variable2_loss: 0.0027 - val_loss: 0.0306 - val_output_variable1_loss: 0.0264 - val_output_variable2_loss: 0.0042
# Epoch 15/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0115 - output_variable1_loss: 0.0086 - output_variable2_loss: 0.0030 - val_loss: 0.0263 - val_output_variable1_loss: 0.0228 - val_output_variable2_loss: 0.0035
# Epoch 16/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0134 - output_variable1_loss: 0.0107 - output_variable2_loss: 0.0027 - val_loss: 0.0241 - val_output_variable1_loss: 0.0211 - val_output_variable2_loss: 0.0030
# Epoch 17/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0133 - output_variable1_loss: 0.0108 - output_variable2_loss: 0.0025 - val_loss: 0.0262 - val_output_variable1_loss: 0.0234 - val_output_variable2_loss: 0.0028
# Epoch 18/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0115 - output_variable1_loss: 0.0091 - output_variable2_loss: 0.0023 - val_loss: 0.0312 - val_output_variable1_loss: 0.0283 - val_output_variable2_loss: 0.0029
# Epoch 19/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0115 - output_variable1_loss: 0.0092 - output_variable2_loss: 0.0022 - val_loss: 0.0271 - val_output_variable1_loss: 0.0245 - val_output_variable2_loss: 0.0026
# Epoch 20/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0108 - output_variable1_loss: 0.0086 - output_variable2_loss: 0.0022 - val_loss: 0.0247 - val_output_variable1_loss: 0.0221 - val_output_variable2_loss: 0.0027
# Epoch 21/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0103 - output_variable1_loss: 0.0081 - output_variable2_loss: 0.0022 - val_loss: 0.0260 - val_output_variable1_loss: 0.0232 - val_output_variable2_loss: 0.0028
# Epoch 22/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0098 - output_variable1_loss: 0.0077 - output_variable2_loss: 0.0021 - val_loss: 0.0269 - val_output_variable1_loss: 0.0241 - val_output_variable2_loss: 0.0028
# Epoch 23/100
# 7/7 [==============================] - 0s 41ms/step - loss: 0.0095 - output_variable1_loss: 0.0075 - output_variable2_loss: 0.0021 - val_loss: 0.0242 - val_output_variable1_loss: 0.0216 - val_output_variable2_loss: 0.0025
# Epoch 24/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0097 - output_variable1_loss: 0.0076 - output_variable2_loss: 0.0021 - val_loss: 0.0260 - val_output_variable1_loss: 0.0234 - val_output_variable2_loss: 0.0025
# Epoch 25/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0095 - output_variable1_loss: 0.0074 - output_variable2_loss: 0.0021 - val_loss: 0.0253 - val_output_variable1_loss: 0.0231 - val_output_variable2_loss: 0.0022
# Epoch 26/100
# 7/7 [==============================] - 0s 46ms/step - loss: 0.0092 - output_variable1_loss: 0.0071 - output_variable2_loss: 0.0021 - val_loss: 0.0252 - val_output_variable1_loss: 0.0227 - val_output_variable2_loss: 0.0026
# Epoch 27/100
# 7/7 [==============================] - 0s 45ms/step - loss: 0.0092 - output_variable1_loss: 0.0070 - output_variable2_loss: 0.0022 - val_loss: 0.0266 - val_output_variable1_loss: 0.0240 - val_output_variable2_loss: 0.0026
# Epoch 28/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0094 - output_variable1_loss: 0.0073 - output_variable2_loss: 0.0021 - val_loss: 0.0243 - val_output_variable1_loss: 0.0217 - val_output_variable2_loss: 0.0026
# Epoch 29/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0093 - output_variable1_loss: 0.0070 - output_variable2_loss: 0.0022 - val_loss: 0.0254 - val_output_variable1_loss: 0.0221 - val_output_variable2_loss: 0.0034
# Epoch 30/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0091 - output_variable1_loss: 0.0069 - output_variable2_loss: 0.0022 - val_loss: 0.0253 - val_output_variable1_loss: 0.0231 - val_output_variable2_loss: 0.0021
# Epoch 31/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0089 - output_variable1_loss: 0.0068 - output_variable2_loss: 0.0021 - val_loss: 0.0248 - val_output_variable1_loss: 0.0220 - val_output_variable2_loss: 0.0028
# Epoch 32/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0087 - output_variable1_loss: 0.0068 - output_variable2_loss: 0.0019 - val_loss: 0.0260 - val_output_variable1_loss: 0.0233 - val_output_variable2_loss: 0.0026
# Epoch 33/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0088 - output_variable1_loss: 0.0068 - output_variable2_loss: 0.0020 - val_loss: 0.0257 - val_output_variable1_loss: 0.0233 - val_output_variable2_loss: 0.0024
# Epoch 34/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0087 - output_variable1_loss: 0.0067 - output_variable2_loss: 0.0019 - val_loss: 0.0245 - val_output_variable1_loss: 0.0216 - val_output_variable2_loss: 0.0029
# Epoch 35/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0084 - output_variable1_loss: 0.0065 - output_variable2_loss: 0.0019 - val_loss: 0.0252 - val_output_variable1_loss: 0.0229 - val_output_variable2_loss: 0.0023
# Epoch 36/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0087 - output_variable1_loss: 0.0066 - output_variable2_loss: 0.0021 - val_loss: 0.0250 - val_output_variable1_loss: 0.0224 - val_output_variable2_loss: 0.0026
# Epoch 37/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0094 - output_variable1_loss: 0.0075 - output_variable2_loss: 0.0020 - val_loss: 0.0280 - val_output_variable1_loss: 0.0257 - val_output_variable2_loss: 0.0022
# Epoch 38/100
# 7/7 [==============================] - 0s 44ms/step - loss: 0.0092 - output_variable1_loss: 0.0073 - output_variable2_loss: 0.0019 - val_loss: 0.0243 - val_output_variable1_loss: 0.0213 - val_output_variable2_loss: 0.0029
# Epoch 39/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0089 - output_variable1_loss: 0.0070 - output_variable2_loss: 0.0020 - val_loss: 0.0254 - val_output_variable1_loss: 0.0229 - val_output_variable2_loss: 0.0026
# Epoch 40/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0086 - output_variable1_loss: 0.0068 - output_variable2_loss: 0.0019 - val_loss: 0.0266 - val_output_variable1_loss: 0.0244 - val_output_variable2_loss: 0.0022
# Epoch 41/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0085 - output_variable1_loss: 0.0066 - output_variable2_loss: 0.0018 - val_loss: 0.0234 - val_output_variable1_loss: 0.0206 - val_output_variable2_loss: 0.0028
# Epoch 1/100
# 10/10 [==============================] - 0s 39ms/step - loss: 0.0136 - output_variable1_loss: 0.0115 - output_variable2_loss: 0.0022 - val_loss: 0.0924 - val_output_variable1_loss: 0.0753 - val_output_variable2_loss: 0.0172
# Epoch 2/100
# 10/10 [==============================] - 0s 35ms/step - loss: 0.0131 - output_variable1_loss: 0.0112 - output_variable2_loss: 0.0019 - val_loss: 0.0960 - val_output_variable1_loss: 0.0786 - val_output_variable2_loss: 0.0174
# Epoch 3/100
# 10/10 [==============================] - 0s 35ms/step - loss: 0.0125 - output_variable1_loss: 0.0106 - output_variable2_loss: 0.0019 - val_loss: 0.0948 - val_output_variable1_loss: 0.0765 - val_output_variable2_loss: 0.0182
# Epoch 4/100
# 10/10 [==============================] - 0s 35ms/step - loss: 0.0121 - output_variable1_loss: 0.0103 - output_variable2_loss: 0.0018 - val_loss: 0.0970 - val_output_variable1_loss: 0.0783 - val_output_variable2_loss: 0.0187
# Epoch 5/100
# 10/10 [==============================] - 0s 36ms/step - loss: 0.0114 - output_variable1_loss: 0.0095 - output_variable2_loss: 0.0018 - val_loss: 0.0920 - val_output_variable1_loss: 0.0749 - val_output_variable2_loss: 0.0171
# Epoch 6/100
# 10/10 [==============================] - 0s 36ms/step - loss: 0.0119 - output_variable1_loss: 0.0101 - output_variable2_loss: 0.0018 - val_loss: 0.0887 - val_output_variable1_loss: 0.0714 - val_output_variable2_loss: 0.0173
# Epoch 7/100
# 10/10 [==============================] - 0s 35ms/step - loss: 0.0114 - output_variable1_loss: 0.0096 - output_variable2_loss: 0.0019 - val_loss: 0.1038 - val_output_variable1_loss: 0.0879 - val_output_variable2_loss: 0.0159
# Epoch 8/100
# 10/10 [==============================] - 0s 35ms/step - loss: 0.0110 - output_variable1_loss: 0.0091 - output_variable2_loss: 0.0019 - val_loss: 0.0908 - val_output_variable1_loss: 0.0720 - val_output_variable2_loss: 0.0188
# Epoch 9/100
# 10/10 [==============================] - 0s 36ms/step - loss: 0.0106 - output_variable1_loss: 0.0088 - output_variable2_loss: 0.0018 - val_loss: 0.0869 - val_output_variable1_loss: 0.0663 - val_output_variable2_loss: 0.0207
# Epoch 10/100
# 10/10 [==============================] - 0s 35ms/step - loss: 0.0107 - output_variable1_loss: 0.0090 - output_variable2_loss: 0.0017 - val_loss: 0.0922 - val_output_variable1_loss: 0.0727 - val_output_variable2_loss: 0.0195
# Epoch 11/100
# 10/10 [==============================] - 0s 35ms/step - loss: 0.0123 - output_variable1_loss: 0.0105 - output_variable2_loss: 0.0018 - val_loss: 0.0811 - val_output_variable1_loss: 0.0635 - val_output_variable2_loss: 0.0176
# Epoch 12/100
# 10/10 [==============================] - 0s 35ms/step - loss: 0.0117 - output_variable1_loss: 0.0099 - output_variable2_loss: 0.0017 - val_loss: 0.0872 - val_output_variable1_loss: 0.0690 - val_output_variable2_loss: 0.0182
# Epoch 13/100
# 10/10 [==============================] - 0s 35ms/step - loss: 0.0108 - output_variable1_loss: 0.0091 - output_variable2_loss: 0.0017 - val_loss: 0.0953 - val_output_variable1_loss: 0.0764 - val_output_variable2_loss: 0.0189
# Epoch 14/100
# 10/10 [==============================] - 0s 38ms/step - loss: 0.0110 - output_variable1_loss: 0.0092 - output_variable2_loss: 0.0018 - val_loss: 0.0870 - val_output_variable1_loss: 0.0704 - val_output_variable2_loss: 0.0166
# Epoch 15/100
# 10/10 [==============================] - 0s 35ms/step - loss: 0.0103 - output_variable1_loss: 0.0086 - output_variable2_loss: 0.0017 - val_loss: 0.0858 - val_output_variable1_loss: 0.0651 - val_output_variable2_loss: 0.0208
# Epoch 16/100
# 10/10 [==============================] - 0s 35ms/step - loss: 0.0096 - output_variable1_loss: 0.0079 - output_variable2_loss: 0.0017 - val_loss: 0.0874 - val_output_variable1_loss: 0.0699 - val_output_variable2_loss: 0.0175
# Epoch 17/100
# 10/10 [==============================] - 0s 35ms/step - loss: 0.0100 - output_variable1_loss: 0.0083 - output_variable2_loss: 0.0018 - val_loss: 0.0932 - val_output_variable1_loss: 0.0734 - val_output_variable2_loss: 0.0198
# Epoch 18/100
# 10/10 [==============================] - 0s 35ms/step - loss: 0.0095 - output_variable1_loss: 0.0078 - output_variable2_loss: 0.0017 - val_loss: 0.0933 - val_output_variable1_loss: 0.0733 - val_output_variable2_loss: 0.0201
# Epoch 19/100
# 10/10 [==============================] - 0s 36ms/step - loss: 0.0085 - output_variable1_loss: 0.0069 - output_variable2_loss: 0.0017 - val_loss: 0.0947 - val_output_variable1_loss: 0.0753 - val_output_variable2_loss: 0.0194
# Epoch 20/100
# 10/10 [==============================] - 0s 35ms/step - loss: 0.0090 - output_variable1_loss: 0.0074 - output_variable2_loss: 0.0016 - val_loss: 0.0866 - val_output_variable1_loss: 0.0666 - val_output_variable2_loss: 0.0200
# Epoch 21/100
# 10/10 [==============================] - 0s 35ms/step - loss: 0.0086 - output_variable1_loss: 0.0069 - output_variable2_loss: 0.0017 - val_loss: 0.0911 - val_output_variable1_loss: 0.0724 - val_output_variable2_loss: 0.0187
# Epoch 22/100
# 10/10 [==============================] - 0s 35ms/step - loss: 0.0083 - output_variable1_loss: 0.0067 - output_variable2_loss: 0.0016 - val_loss: 0.0965 - val_output_variable1_loss: 0.0759 - val_output_variable2_loss: 0.0205
# Epoch 23/100
# 10/10 [==============================] - 0s 36ms/step - loss: 0.0083 - output_variable1_loss: 0.0067 - output_variable2_loss: 0.0016 - val_loss: 0.0896 - val_output_variable1_loss: 0.0706 - val_output_variable2_loss: 0.0190
# Epoch 24/100
# 10/10 [==============================] - 0s 36ms/step - loss: 0.0083 - output_variable1_loss: 0.0066 - output_variable2_loss: 0.0017 - val_loss: 0.0873 - val_output_variable1_loss: 0.0658 - val_output_variable2_loss: 0.0215
# Epoch 25/100
# 10/10 [==============================] - 0s 36ms/step - loss: 0.0078 - output_variable1_loss: 0.0061 - output_variable2_loss: 0.0016 - val_loss: 0.0912 - val_output_variable1_loss: 0.0700 - val_output_variable2_loss: 0.0212
# Epoch 26/100
# 10/10 [==============================] - 0s 35ms/step - loss: 0.0083 - output_variable1_loss: 0.0066 - output_variable2_loss: 0.0017 - val_loss: 0.0849 - val_output_variable1_loss: 0.0659 - val_output_variable2_loss: 0.0190
# Epoch 27/100
# 10/10 [==============================] - 0s 35ms/step - loss: 0.0079 - output_variable1_loss: 0.0062 - output_variable2_loss: 0.0017 - val_loss: 0.0875 - val_output_variable1_loss: 0.0671 - val_output_variable2_loss: 0.0203
# Epoch 28/100
# 10/10 [==============================] - 0s 36ms/step - loss: 0.0078 - output_variable1_loss: 0.0062 - output_variable2_loss: 0.0016 - val_loss: 0.0837 - val_output_variable1_loss: 0.0649 - val_output_variable2_loss: 0.0187
# Epoch 29/100
# 10/10 [==============================] - 0s 37ms/step - loss: 0.0074 - output_variable1_loss: 0.0058 - output_variable2_loss: 0.0016 - val_loss: 0.0891 - val_output_variable1_loss: 0.0701 - val_output_variable2_loss: 0.0190
# Epoch 30/100
# 10/10 [==============================] - 0s 37ms/step - loss: 0.0073 - output_variable1_loss: 0.0057 - output_variable2_loss: 0.0016 - val_loss: 0.0889 - val_output_variable1_loss: 0.0708 - val_output_variable2_loss: 0.0181
# Epoch 31/100
# 10/10 [==============================] - 0s 41ms/step - loss: 0.0074 - output_variable1_loss: 0.0057 - output_variable2_loss: 0.0017 - val_loss: 0.0897 - val_output_variable1_loss: 0.0721 - val_output_variable2_loss: 0.0176
# Epoch 32/100
# 10/10 [==============================] - 0s 37ms/step - loss: 0.0074 - output_variable1_loss: 0.0058 - output_variable2_loss: 0.0016 - val_loss: 0.0885 - val_output_variable1_loss: 0.0687 - val_output_variable2_loss: 0.0199
# Epoch 33/100
# 10/10 [==============================] - 0s 36ms/step - loss: 0.0069 - output_variable1_loss: 0.0053 - output_variable2_loss: 0.0016 - val_loss: 0.0871 - val_output_variable1_loss: 0.0680 - val_output_variable2_loss: 0.0191
# Epoch 34/100
# 10/10 [==============================] - 0s 36ms/step - loss: 0.0069 - output_variable1_loss: 0.0052 - output_variable2_loss: 0.0017 - val_loss: 0.0918 - val_output_variable1_loss: 0.0715 - val_output_variable2_loss: 0.0203
# Epoch 35/100
# 10/10 [==============================] - 0s 36ms/step - loss: 0.0067 - output_variable1_loss: 0.0051 - output_variable2_loss: 0.0016 - val_loss: 0.0889 - val_output_variable1_loss: 0.0692 - val_output_variable2_loss: 0.0197
# Epoch 36/100
# 10/10 [==============================] - 0s 37ms/step - loss: 0.0066 - output_variable1_loss: 0.0050 - output_variable2_loss: 0.0016 - val_loss: 0.0897 - val_output_variable1_loss: 0.0701 - val_output_variable2_loss: 0.0196
# Epoch 37/100
# 10/10 [==============================] - 0s 36ms/step - loss: 0.0066 - output_variable1_loss: 0.0050 - output_variable2_loss: 0.0016 - val_loss: 0.0884 - val_output_variable1_loss: 0.0678 - val_output_variable2_loss: 0.0206
# Epoch 38/100
# 10/10 [==============================] - 0s 37ms/step - loss: 0.0065 - output_variable1_loss: 0.0049 - output_variable2_loss: 0.0016 - val_loss: 0.0880 - val_output_variable1_loss: 0.0686 - val_output_variable2_loss: 0.0194
# Epoch 39/100
# 10/10 [==============================] - 0s 36ms/step - loss: 0.0062 - output_variable1_loss: 0.0047 - output_variable2_loss: 0.0015 - val_loss: 0.0896 - val_output_variable1_loss: 0.0694 - val_output_variable2_loss: 0.0202
# Epoch 40/100
# 10/10 [==============================] - 0s 37ms/step - loss: 0.0061 - output_variable1_loss: 0.0046 - output_variable2_loss: 0.0015 - val_loss: 0.0902 - val_output_variable1_loss: 0.0705 - val_output_variable2_loss: 0.0197
# Epoch 41/100
# 10/10 [==============================] - 0s 40ms/step - loss: 0.0061 - output_variable1_loss: 0.0046 - output_variable2_loss: 0.0015 - val_loss: 0.0889 - val_output_variable1_loss: 0.0702 - val_output_variable2_loss: 0.0187
# Epoch 42/100
# 10/10 [==============================] - 0s 37ms/step - loss: 0.0061 - output_variable1_loss: 0.0046 - output_variable2_loss: 0.0015 - val_loss: 0.0929 - val_output_variable1_loss: 0.0709 - val_output_variable2_loss: 0.0220
# Epoch 43/100
# 10/10 [==============================] - 0s 42ms/step - loss: 0.0061 - output_variable1_loss: 0.0045 - output_variable2_loss: 0.0016 - val_loss: 0.0885 - val_output_variable1_loss: 0.0699 - val_output_variable2_loss: 0.0186
# Epoch 44/100
# 10/10 [==============================] - 0s 37ms/step - loss: 0.0062 - output_variable1_loss: 0.0046 - output_variable2_loss: 0.0016 - val_loss: 0.0894 - val_output_variable1_loss: 0.0686 - val_output_variable2_loss: 0.0208
# Epoch 45/100
# 10/10 [==============================] - 0s 36ms/step - loss: 0.0064 - output_variable1_loss: 0.0048 - output_variable2_loss: 0.0016 - val_loss: 0.0852 - val_output_variable1_loss: 0.0663 - val_output_variable2_loss: 0.0189
# Epoch 46/100
# 10/10 [==============================] - 0s 36ms/step - loss: 0.0061 - output_variable1_loss: 0.0044 - output_variable2_loss: 0.0017 - val_loss: 0.0877 - val_output_variable1_loss: 0.0674 - val_output_variable2_loss: 0.0203
# Epoch 47/100
# 10/10 [==============================] - 0s 42ms/step - loss: 0.0059 - output_variable1_loss: 0.0044 - output_variable2_loss: 0.0015 - val_loss: 0.0849 - val_output_variable1_loss: 0.0666 - val_output_variable2_loss: 0.0184
# Epoch 48/100
# 10/10 [==============================] - 0s 37ms/step - loss: 0.0057 - output_variable1_loss: 0.0042 - output_variable2_loss: 0.0015 - val_loss: 0.0871 - val_output_variable1_loss: 0.0677 - val_output_variable2_loss: 0.0195
# Epoch 49/100
# 10/10 [==============================] - 0s 36ms/step - loss: 0.0056 - output_variable1_loss: 0.0041 - output_variable2_loss: 0.0015 - val_loss: 0.0868 - val_output_variable1_loss: 0.0666 - val_output_variable2_loss: 0.0202
# Epoch 50/100
# 10/10 [==============================] - 0s 37ms/step - loss: 0.0054 - output_variable1_loss: 0.0039 - output_variable2_loss: 0.0015 - val_loss: 0.0872 - val_output_variable1_loss: 0.0675 - val_output_variable2_loss: 0.0197
# Epoch 51/100
# 10/10 [==============================] - 0s 38ms/step - loss: 0.0054 - output_variable1_loss: 0.0039 - output_variable2_loss: 0.0015 - val_loss: 0.0895 - val_output_variable1_loss: 0.0684 - val_output_variable2_loss: 0.0210
# Epoch 52/100
# 10/10 [==============================] - 0s 37ms/step - loss: 0.0055 - output_variable1_loss: 0.0040 - output_variable2_loss: 0.0015 - val_loss: 0.0854 - val_output_variable1_loss: 0.0670 - val_output_variable2_loss: 0.0185
# Epoch 53/100
# 10/10 [==============================] - 0s 41ms/step - loss: 0.0054 - output_variable1_loss: 0.0040 - output_variable2_loss: 0.0014 - val_loss: 0.0900 - val_output_variable1_loss: 0.0693 - val_output_variable2_loss: 0.0207
# Epoch 54/100
# 10/10 [==============================] - 0s 40ms/step - loss: 0.0054 - output_variable1_loss: 0.0040 - output_variable2_loss: 0.0015 - val_loss: 0.0846 - val_output_variable1_loss: 0.0645 - val_output_variable2_loss: 0.0201
# Epoch 55/100
# 10/10 [==============================] - 0s 40ms/step - loss: 0.0054 - output_variable1_loss: 0.0039 - output_variable2_loss: 0.0015 - val_loss: 0.0891 - val_output_variable1_loss: 0.0686 - val_output_variable2_loss: 0.0205
# Epoch 56/100
# 10/10 [==============================] - 0s 37ms/step - loss: 0.0054 - output_variable1_loss: 0.0039 - output_variable2_loss: 0.0015 - val_loss: 0.0875 - val_output_variable1_loss: 0.0665 - val_output_variable2_loss: 0.0210
# Epoch 57/100
# 10/10 [==============================] - 0s 39ms/step - loss: 0.0051 - output_variable1_loss: 0.0037 - output_variable2_loss: 0.0014 - val_loss: 0.0889 - val_output_variable1_loss: 0.0694 - val_output_variable2_loss: 0.0195
# Epoch 58/100
# 10/10 [==============================] - 0s 37ms/step - loss: 0.0051 - output_variable1_loss: 0.0037 - output_variable2_loss: 0.0014 - val_loss: 0.0871 - val_output_variable1_loss: 0.0665 - val_output_variable2_loss: 0.0206
# Epoch 59/100
# 10/10 [==============================] - 0s 37ms/step - loss: 0.0050 - output_variable1_loss: 0.0036 - output_variable2_loss: 0.0014 - val_loss: 0.0875 - val_output_variable1_loss: 0.0661 - val_output_variable2_loss: 0.0215
# Epoch 60/100
# 10/10 [==============================] - 0s 40ms/step - loss: 0.0050 - output_variable1_loss: 0.0036 - output_variable2_loss: 0.0015 - val_loss: 0.0804 - val_output_variable1_loss: 0.0622 - val_output_variable2_loss: 0.0183
# Epoch 61/100
# 10/10 [==============================] - 0s 36ms/step - loss: 0.0050 - output_variable1_loss: 0.0034 - output_variable2_loss: 0.0016 - val_loss: 0.0879 - val_output_variable1_loss: 0.0666 - val_output_variable2_loss: 0.0214
# Epoch 62/100
# 10/10 [==============================] - 0s 38ms/step - loss: 0.0049 - output_variable1_loss: 0.0034 - output_variable2_loss: 0.0016 - val_loss: 0.0854 - val_output_variable1_loss: 0.0669 - val_output_variable2_loss: 0.0185
# Epoch 63/100
# ...
# Epoch 92/100
# 10/10 [==============================] - 0s 40ms/step - loss: 0.0040 - output_variable1_loss: 0.0026 - output_variable2_loss: 0.0013 - val_loss: 0.0852 - val_output_variable1_loss: 0.0637 - val_output_variable2_loss: 0.0214
# Epoch 93/100
# 10/10 [==============================] - 0s 37ms/step - loss: 0.0040 - output_variable1_loss: 0.0026 - output_variable2_loss: 0.0013 - val_loss: 0.0794 - val_output_variable1_loss: 0.0615 - val_output_variable2_loss: 0.0180
# Epoch 94/100
# 10/10 [==============================] - 0s 41ms/step - loss: 0.0039 - output_variable1_loss: 0.0026 - output_variable2_loss: 0.0013 - val_loss: 0.0848 - val_output_variable1_loss: 0.0647 - val_output_variable2_loss: 0.0201
# Epoch 95/100
# 10/10 [==============================] - 0s 41ms/step - loss: 0.0040 - output_variable1_loss: 0.0027 - output_variable2_loss: 0.0013 - val_loss: 0.0816 - val_output_variable1_loss: 0.0614 - val_output_variable2_loss: 0.0202
# Epoch 96/100
# 10/10 [==============================] - 0s 43ms/step - loss: 0.0039 - output_variable1_loss: 0.0026 - output_variable2_loss: 0.0012 - val_loss: 0.0803 - val_output_variable1_loss: 0.0609 - val_output_variable2_loss: 0.0194
# Epoch 97/100
# 10/10 [==============================] - 0s 48ms/step - loss: 0.0038 - output_variable1_loss: 0.0026 - output_variable2_loss: 0.0012 - val_loss: 0.0826 - val_output_variable1_loss: 0.0613 - val_output_variable2_loss: 0.0213
# Epoch 98/100
# 10/10 [==============================] - 0s 42ms/step - loss: 0.0039 - output_variable1_loss: 0.0026 - output_variable2_loss: 0.0012 - val_loss: 0.0833 - val_output_variable1_loss: 0.0637 - val_output_variable2_loss: 0.0196
# Epoch 99/100
# 10/10 [==============================] - 0s 41ms/step - loss: 0.0037 - output_variable1_loss: 0.0025 - output_variable2_loss: 0.0012 - val_loss: 0.0834 - val_output_variable1_loss: 0.0620 - val_output_variable2_loss: 0.0214
# Epoch 100/100
# 10/10 [==============================] - 0s 41ms/step - loss: 0.0037 - output_variable1_loss: 0.0025 - output_variable2_loss: 0.0012 - val_loss: 0.0820 - val_output_variable1_loss: 0.0618 - val_output_variable2_loss: 0.0202
# Epoch 1/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.0208 - output_variable1_loss: 0.0155 - output_variable2_loss: 0.0053 - val_loss: 0.0376 - val_output_variable1_loss: 0.0332 - val_output_variable2_loss: 0.0044
# Epoch 2/100
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0188 - output_variable1_loss: 0.0134 - output_variable2_loss: 0.0055 - val_loss: 0.0402 - val_output_variable1_loss: 0.0354 - val_output_variable2_loss: 0.0048
# Epoch 3/100
# 13/13 [==============================] - 0s 37ms/step - loss: 0.0163 - output_variable1_loss: 0.0116 - output_variable2_loss: 0.0047 - val_loss: 0.0392 - val_output_variable1_loss: 0.0345 - val_output_variable2_loss: 0.0047
# Epoch 4/100
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0125 - output_variable1_loss: 0.0091 - output_variable2_loss: 0.0034 - val_loss: 0.0316 - val_output_variable1_loss: 0.0281 - val_output_variable2_loss: 0.0035
# Epoch 5/100
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0102 - output_variable1_loss: 0.0073 - output_variable2_loss: 0.0029 - val_loss: 0.0376 - val_output_variable1_loss: 0.0328 - val_output_variable2_loss: 0.0048
# Epoch 6/100
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0091 - output_variable1_loss: 0.0065 - output_variable2_loss: 0.0026 - val_loss: 0.0369 - val_output_variable1_loss: 0.0323 - val_output_variable2_loss: 0.0046
# Epoch 7/100
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0080 - output_variable1_loss: 0.0054 - output_variable2_loss: 0.0026 - val_loss: 0.0411 - val_output_variable1_loss: 0.0363 - val_output_variable2_loss: 0.0048
# Epoch 8/100
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0072 - output_variable1_loss: 0.0049 - output_variable2_loss: 0.0023 - val_loss: 0.0420 - val_output_variable1_loss: 0.0371 - val_output_variable2_loss: 0.0049
# Epoch 9/100
# 13/13 [==============================] - 0s 39ms/step - loss: 0.0065 - output_variable1_loss: 0.0046 - output_variable2_loss: 0.0019 - val_loss: 0.0444 - val_output_variable1_loss: 0.0383 - val_output_variable2_loss: 0.0061
# Epoch 10/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.0062 - output_variable1_loss: 0.0044 - output_variable2_loss: 0.0019 - val_loss: 0.0422 - val_output_variable1_loss: 0.0367 - val_output_variable2_loss: 0.0055
# Epoch 11/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.0060 - output_variable1_loss: 0.0042 - output_variable2_loss: 0.0018 - val_loss: 0.0468 - val_output_variable1_loss: 0.0408 - val_output_variable2_loss: 0.0060
# Epoch 12/100
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0063 - output_variable1_loss: 0.0045 - output_variable2_loss: 0.0017 - val_loss: 0.0437 - val_output_variable1_loss: 0.0365 - val_output_variable2_loss: 0.0071
# Epoch 13/100
# 13/13 [==============================] - 0s 37ms/step - loss: 0.0057 - output_variable1_loss: 0.0041 - output_variable2_loss: 0.0017 - val_loss: 0.0415 - val_output_variable1_loss: 0.0358 - val_output_variable2_loss: 0.0057
# Epoch 14/100
# 13/13 [==============================] - 1s 43ms/step - loss: 0.0056 - output_variable1_loss: 0.0036 - output_variable2_loss: 0.0019 - val_loss: 0.0415 - val_output_variable1_loss: 0.0358 - val_output_variable2_loss: 0.0058
# Epoch 15/100
# 13/13 [==============================] - 1s 49ms/step - loss: 0.0053 - output_variable1_loss: 0.0034 - output_variable2_loss: 0.0019 - val_loss: 0.0448 - val_output_variable1_loss: 0.0387 - val_output_variable2_loss: 0.0062
# Epoch 16/100
# 13/13 [==============================] - 1s 41ms/step - loss: 0.0050 - output_variable1_loss: 0.0031 - output_variable2_loss: 0.0018 - val_loss: 0.0423 - val_output_variable1_loss: 0.0370 - val_output_variable2_loss: 0.0053
# Epoch 17/100
# 13/13 [==============================] - 0s 37ms/step - loss: 0.0049 - output_variable1_loss: 0.0031 - output_variable2_loss: 0.0018 - val_loss: 0.0428 - val_output_variable1_loss: 0.0364 - val_output_variable2_loss: 0.0064
# Epoch 18/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.0046 - output_variable1_loss: 0.0030 - output_variable2_loss: 0.0017 - val_loss: 0.0413 - val_output_variable1_loss: 0.0337 - val_output_variable2_loss: 0.0076
# Epoch 19/100
# 13/13 [==============================] - 1s 41ms/step - loss: 0.0046 - output_variable1_loss: 0.0031 - output_variable2_loss: 0.0015 - val_loss: 0.0432 - val_output_variable1_loss: 0.0371 - val_output_variable2_loss: 0.0061
# Epoch 20/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.0044 - output_variable1_loss: 0.0029 - output_variable2_loss: 0.0015 - val_loss: 0.0426 - val_output_variable1_loss: 0.0362 - val_output_variable2_loss: 0.0064
# Epoch 21/100
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0045 - output_variable1_loss: 0.0028 - output_variable2_loss: 0.0017 - val_loss: 0.0426 - val_output_variable1_loss: 0.0362 - val_output_variable2_loss: 0.0063
# Epoch 22/100
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0045 - output_variable1_loss: 0.0029 - output_variable2_loss: 0.0016 - val_loss: 0.0412 - val_output_variable1_loss: 0.0346 - val_output_variable2_loss: 0.0066
# Epoch 23/100
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0042 - output_variable1_loss: 0.0026 - output_variable2_loss: 0.0015 - val_loss: 0.0412 - val_output_variable1_loss: 0.0350 - val_output_variable2_loss: 0.0062
# Epoch 24/100
# 13/13 [==============================] - 0s 38ms/step - loss: 0.0040 - output_variable1_loss: 0.0026 - output_variable2_loss: 0.0014 - val_loss: 0.0411 - val_output_variable1_loss: 0.0352 - val_output_variable2_loss: 0.0059
# Epoch 25/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.0040 - output_variable1_loss: 0.0026 - output_variable2_loss: 0.0014 - val_loss: 0.0426 - val_output_variable1_loss: 0.0368 - val_output_variable2_loss: 0.0058
# Epoch 26/100
# 13/13 [==============================] - 1s 41ms/step - loss: 0.0038 - output_variable1_loss: 0.0025 - output_variable2_loss: 0.0013 - val_loss: 0.0428 - val_output_variable1_loss: 0.0358 - val_output_variable2_loss: 0.0070
# Epoch 27/100
# 13/13 [==============================] - 1s 41ms/step - loss: 0.0037 - output_variable1_loss: 0.0024 - output_variable2_loss: 0.0013 - val_loss: 0.0400 - val_output_variable1_loss: 0.0343 - val_output_variable2_loss: 0.0057
# Epoch 28/100
# 13/13 [==============================] - 0s 37ms/step - loss: 0.0038 - output_variable1_loss: 0.0025 - output_variable2_loss: 0.0013 - val_loss: 0.0415 - val_output_variable1_loss: 0.0337 - val_output_variable2_loss: 0.0078
# Epoch 29/100
# 13/13 [==============================] - 0s 37ms/step - loss: 0.0038 - output_variable1_loss: 0.0025 - output_variable2_loss: 0.0013 - val_loss: 0.0395 - val_output_variable1_loss: 0.0332 - val_output_variable2_loss: 0.0063
# Epoch 30/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.0037 - output_variable1_loss: 0.0024 - output_variable2_loss: 0.0013 - val_loss: 0.0430 - val_output_variable1_loss: 0.0366 - val_output_variable2_loss: 0.0064
# Epoch 31/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.0037 - output_variable1_loss: 0.0024 - output_variable2_loss: 0.0013 - val_loss: 0.0423 - val_output_variable1_loss: 0.0361 - val_output_variable2_loss: 0.0062
# Epoch 32/100
# 13/13 [==============================] - 1s 41ms/step - loss: 0.0037 - output_variable1_loss: 0.0024 - output_variable2_loss: 0.0013 - val_loss: 0.0423 - val_output_variable1_loss: 0.0356 - val_output_variable2_loss: 0.0067
# Epoch 33/100
# 13/13 [==============================] - 0s 37ms/step - loss: 0.0036 - output_variable1_loss: 0.0023 - output_variable2_loss: 0.0013 - val_loss: 0.0426 - val_output_variable1_loss: 0.0349 - val_output_variable2_loss: 0.0076
# Epoch 34/100
# 13/13 [==============================] - 1s 46ms/step - loss: 0.0035 - output_variable1_loss: 0.0023 - output_variable2_loss: 0.0013 - val_loss: 0.0408 - val_output_variable1_loss: 0.0345 - val_output_variable2_loss: 0.0064
# Epoch 35/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.0035 - output_variable1_loss: 0.0023 - output_variable2_loss: 0.0012 - val_loss: 0.0391 - val_output_variable1_loss: 0.0330 - val_output_variable2_loss: 0.0061
# Epoch 36/100
# 13/13 [==============================] - 0s 38ms/step - loss: 0.0035 - output_variable1_loss: 0.0023 - output_variable2_loss: 0.0012 - val_loss: 0.0414 - val_output_variable1_loss: 0.0340 - val_output_variable2_loss: 0.0074
# Epoch 37/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.0034 - output_variable1_loss: 0.0022 - output_variable2_loss: 0.0012 - val_loss: 0.0409 - val_output_variable1_loss: 0.0334 - val_output_variable2_loss: 0.0074
# Epoch 38/100
# 13/13 [==============================] - 0s 38ms/step - loss: 0.0034 - output_variable1_loss: 0.0022 - output_variable2_loss: 0.0012 - val_loss: 0.0401 - val_output_variable1_loss: 0.0334 - val_output_variable2_loss: 0.0067
# Epoch 39/100
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0033 - output_variable1_loss: 0.0022 - output_variable2_loss: 0.0012 - val_loss: 0.0417 - val_output_variable1_loss: 0.0340 - val_output_variable2_loss: 0.0077
# Epoch 40/100
# 13/13 [==============================] - 1s 40ms/step - loss: 0.0034 - output_variable1_loss: 0.0022 - output_variable2_loss: 0.0012 - val_loss: 0.0400 - val_output_variable1_loss: 0.0334 - val_output_variable2_loss: 0.0066
# Epoch 41/100
# 13/13 [==============================] - 0s 39ms/step - loss: 0.0034 - output_variable1_loss: 0.0022 - output_variable2_loss: 0.0012 - val_loss: 0.0401 - val_output_variable1_loss: 0.0343 - val_output_variable2_loss: 0.0059
# Epoch 42/100
# 13/13 [==============================] - 1s 39ms/step - loss: 0.0033 - output_variable1_loss: 0.0021 - output_variable2_loss: 0.0012 - val_loss: 0.0416 - val_output_variable1_loss: 0.0343 - val_output_variable2_loss: 0.0074
# Epoch 43/100
# 13/13 [==============================] - 0s 38ms/step - loss: 0.0033 - output_variable1_loss: 0.0022 - output_variable2_loss: 0.0012 - val_loss: 0.0401 - val_output_variable1_loss: 0.0343 - val_output_variable2_loss: 0.0057
# Epoch 44/100
# 13/13 [==============================] - 1s 41ms/step - loss: 0.0033 - output_variable1_loss: 0.0022 - output_variable2_loss: 0.0011 - val_loss: 0.0401 - val_output_variable1_loss: 0.0339 - val_output_variable2_loss: 0.0062
# Epoch 45/100
# 13/13 [==============================] - 1s 42ms/step - loss: 0.0034 - output_variable1_loss: 0.0023 - output_variable2_loss: 0.0011 - val_loss: 0.0409 - val_output_variable1_loss: 0.0340 - val_output_variable2_loss: 0.0070
# Epoch 46/100
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0033 - output_variable1_loss: 0.0022 - output_variable2_loss: 0.0011 - val_loss: 0.0418 - val_output_variable1_loss: 0.0344 - val_output_variable2_loss: 0.0075
# Epoch 47/100
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0032 - output_variable1_loss: 0.0021 - output_variable2_loss: 0.0011 - val_loss: 0.0421 - val_output_variable1_loss: 0.0356 - val_output_variable2_loss: 0.0065
# Epoch 48/100
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0032 - output_variable1_loss: 0.0021 - output_variable2_loss: 0.0011 - val_loss: 0.0432 - val_output_variable1_loss: 0.0338 - val_output_variable2_loss: 0.0093
# Epoch 49/100
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0032 - output_variable1_loss: 0.0021 - output_variable2_loss: 0.0011 - val_loss: 0.0425 - val_output_variable1_loss: 0.0346 - val_output_variable2_loss: 0.0079
# Epoch 50/100
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0031 - output_variable1_loss: 0.0020 - output_variable2_loss: 0.0011 - val_loss: 0.0411 - val_output_variable1_loss: 0.0333 - val_output_variable2_loss: 0.0078
# Epoch 51/100
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0031 - output_variable1_loss: 0.0020 - output_variable2_loss: 0.0011 - val_loss: 0.0407 - val_output_variable1_loss: 0.0337 - val_output_variable2_loss: 0.0070
# Epoch 52/100
# 13/13 [==============================] - 0s 37ms/step - loss: 0.0030 - output_variable1_loss: 0.0019 - output_variable2_loss: 0.0011 - val_loss: 0.0415 - val_output_variable1_loss: 0.0340 - val_output_variable2_loss: 0.0075
# Epoch 53/100
# 13/13 [==============================] - 1s 45ms/step - loss: 0.0031 - output_variable1_loss: 0.0020 - output_variable2_loss: 0.0011 - val_loss: 0.0400 - val_output_variable1_loss: 0.0327 - val_output_variable2_loss: 0.0073
# Epoch 54/100
# 13/13 [==============================] - 1s 42ms/step - loss: 0.0030 - output_variable1_loss: 0.0019 - output_variable2_loss: 0.0011 - val_loss: 0.0428 - val_output_variable1_loss: 0.0348 - val_output_variable2_loss: 0.0080
# Epoch 55/100
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0031 - output_variable1_loss: 0.0020 - output_variable2_loss: 0.0011 - val_loss: 0.0433 - val_output_variable1_loss: 0.0338 - val_output_variable2_loss: 0.0096
# Epoch 56/100
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0031 - output_variable1_loss: 0.0020 - output_variable2_loss: 0.0011 - val_loss: 0.0437 - val_output_variable1_loss: 0.0358 - val_output_variable2_loss: 0.0079
# Epoch 57/100
# 13/13 [==============================] - 0s 37ms/step - loss: 0.0030 - output_variable1_loss: 0.0020 - output_variable2_loss: 0.0010 - val_loss: 0.0410 - val_output_variable1_loss: 0.0338 - val_output_variable2_loss: 0.0072
# Epoch 58/100
# 13/13 [==============================] - 0s 38ms/step - loss: 0.0030 - output_variable1_loss: 0.0020 - output_variable2_loss: 0.0010 - val_loss: 0.0438 - val_output_variable1_loss: 0.0361 - val_output_variable2_loss: 0.0077

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss_1):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss_1[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error 1", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss_2):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss_2[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error 2", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
# Evaluate the model on the test data
predictions_1 = []
predictions_2 = []
#print(len(eval_target_variables))

for i in range(len(Y_val)):
    current_batch = X_val[i].reshape((1, NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))
    curr_pred1, curr_pred2 = model.predict(current_batch)
    predictions_1.append(curr_pred1)
    predictions_2.append(curr_pred2)
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_1):
    ax = axs[i]
    # TODO seems to work but check why column[0]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_val[i, :, 0], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions_2):
    ax = axs[i]
    # TODO seems to work but check why column[0]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_val[i, :, 1], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
rmse = 0
for i in range(len(predictions_1)):
    print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_1[i][0], Y_val[i, :, 0]))}')
    rmse += sqrt(mean_squared_error(predictions_1[i][0], Y_val[i, :, 0]))

rmse /= len(predictions_1)    
print(f"RMSE = {rmse}")
# Out:
# pred=0, num = 0.1651345725599623
# pred=1, num = 0.1677769382889109
# pred=2, num = 0.16953351685717288
# pred=3, num = 0.16688006905868014
# pred=4, num = 0.1619947317345164
# pred=5, num = 0.16112628722206723
# pred=6, num = 0.16208879747914168
# pred=7, num = 0.1627263277669831
# pred=8, num = 0.16449260455480927
# pred=9, num = 0.16632574400633082
# pred=10, num = 0.1691565229937362
# pred=11, num = 0.15993198362811828
# pred=12, num = 0.14366693296100413
# pred=13, num = 0.12790333212636962
# pred=14, num = 0.11907282602141304
# pred=15, num = 0.11175210474110851
# pred=16, num = 0.10359867525890609
# pred=17, num = 0.09165679796687609
# pred=18, num = 0.08272146944255031
# pred=19, num = 0.07796638083436888
# pred=20, num = 0.07679292648943711
# pred=21, num = 0.08111624713986167
# pred=22, num = 0.09089865946854112
# pred=23, num = 0.09960751018106867
# pred=24, num = 0.10447340008000208
# RMSE = 0.13153581435447745

# %%
rmse = 0
for i in range(len(predictions_2)):
    print(f'pred={i}, num = {sqrt(mean_squared_error(predictions_2[i][0], Y_val[i, :, 1]))}')
    rmse += sqrt(mean_squared_error(predictions_2[i][0], Y_val[i, :, 1]))

rmse /= len(predictions_2)    
print(f"RMSE = {rmse}")
# Out:
# pred=0, num = 0.18502632753143952
# pred=1, num = 0.18101844648370563
# pred=2, num = 0.17370746795507902
# pred=3, num = 0.1653898642536204
# pred=4, num = 0.15152729338305468
# pred=5, num = 0.1372207367608492
# pred=6, num = 0.125282237697403
# pred=7, num = 0.11545506270056832
# pred=8, num = 0.10538213017810981
# pred=9, num = 0.0991363759282399
# pred=10, num = 0.0940477734709614
# pred=11, num = 0.08848245208622771
# pred=12, num = 0.08831804815106019
# pred=13, num = 0.08618871757462575
# pred=14, num = 0.08879071964818996
# pred=15, num = 0.09020298822724813
# pred=16, num = 0.08224356706050019
# pred=17, num = 0.07893740547129233
# pred=18, num = 0.07196970116188867
# pred=19, num = 0.06044527024622939
# pred=20, num = 0.05533989467405545
# pred=21, num = 0.050093585466020774
# pred=22, num = 0.04745378508063541
# pred=23, num = 0.04682235235773166
# pred=24, num = 0.042804719829651984
# RMSE = 0.10045147693513558
