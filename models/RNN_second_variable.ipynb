# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras

# %%
train = pd.read_csv("../data/schemas/warm_up/TrainSet.csv", sep=",")
validation = pd.read_csv("../data/schemas/warm_up/ValidationSet.csv", sep=",")
test = pd.read_csv("../data/schemas/warm_up/TestSet.csv", sep=",")

# %%
# Global variables

NUM_OF_TIMESTEPS_INPUT = 48
NUM_OF_TIMESTEPS_OUTPUT = 24

THRESHOLD = 0.4   # For feature selection

# %%
column_to_predict = "Avg solar generation"

independent_variables = []

for column in train:
    if abs(train[column].corr(train[column_to_predict])) > THRESHOLD:
        independent_variables.append(column)

independent_variables.remove(column_to_predict)
if "Index" in independent_variables:
    independent_variables.remove("Index")
    
if "Solar Generation (W/kW)_1" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_1")
if "Solar Generation (W/kW)_2" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_2")
if "Solar Generation (W/kW)_3" in independent_variables:
    independent_variables.remove("Solar Generation (W/kW)_3")
    
independent_variables
# Out:
# ['Occupant Count (people)_1',
#  'Cooling Load (kWh)_2',
#  'Occupant Count (people)_2',
#  'Cooling Load (kWh)_3',
#  'Occupant Count (people)_3',
#  'Outdoor Drybulb Temperature (C)',
#  'Outdoor Relative Humidity (%)',
#  'Diffuse Solar Radiation (W/m2)',
#  'Direct Solar Radiation (W/m2)',
#  '6h Outdoor Drybulb Temperature (C)',
#  '12h Outdoor Drybulb Temperature (C)',
#  '24h Outdoor Drybulb Temperature (C)',
#  '6h Outdoor Relative Humidity (%)',
#  '12h Outdoor Relative Humidity (%)',
#  '24h Outdoor Relative Humidity (%)',
#  '12h Diffuse Solar Radiation (W/m2)',
#  '24h Diffuse Solar Radiation (W/m2)',
#  '12h Direct Solar Radiation (W/m2)',
#  '24h Direct Solar Radiation (W/m2)']

# %% [markdown]
# Prepare the data

# %%
# Split the X and Y for all sets

# Train set
X_train_default = train[independent_variables]
Y_train_default = train[column_to_predict]

# Validation set, also include the data from train that was used only as output to get more datapoints
X_val_default = pd.concat([X_train_default.tail(NUM_OF_TIMESTEPS_OUTPUT), validation[independent_variables]], ignore_index=True)
Y_val_default = pd.concat([Y_train_default.tail(NUM_OF_TIMESTEPS_OUTPUT), validation[column_to_predict]], ignore_index=True)

# Test set, also include the data from train that was used only as output to get more datapoints
X_test_default = pd.concat([X_val_default.tail(NUM_OF_TIMESTEPS_OUTPUT), test[independent_variables]], ignore_index=True)
Y_test_default = pd.concat([Y_val_default.tail(NUM_OF_TIMESTEPS_OUTPUT), test[column_to_predict]], ignore_index=True)

NUM_OF_ROWS_TRAIN, NUM_OF_FEATURES = X_train_default.shape

print(X_train_default.shape)
print(X_val_default.shape)
print(X_test_default.shape)
# Out:
# (576, 19)
# (96, 19)
# (96, 19)

# %%
# Function to prepare the data into batches that will be passed into the model

def create_sequences(input_data, output_data, timesteps_input, timesteps_output):
    sequences, targets = [], []
    for i in range(len(input_data) - timesteps_input - timesteps_output + 1):
        seq = input_data[i:i + timesteps_input]
        target = output_data[i + timesteps_input: i + timesteps_input + timesteps_output]
        sequences.append(seq)
        targets.append(target)

    return np.array(sequences), np.array(targets)

# %%
X_train, Y_train = create_sequences(X_train_default, Y_train_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)
X_val, Y_val = create_sequences(X_val_default, Y_val_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)
X_test, Y_test = create_sequences(X_test_default, Y_test_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)

print(f"X_train = {X_train.shape}, Y_train = {Y_train.shape}\n"
      f"X_val = {X_val.shape}, Y_val = {Y_val.shape}\n"
      f"X_test = {X_test.shape}, Y_test = {Y_test.shape}")
# Out:
# X_train = (505, 48, 19), Y_train = (505, 24)
# X_val = (25, 48, 19), Y_val = (25, 24)
# X_test = (25, 48, 19), Y_test = (25, 24)

# %%
from sklearn.model_selection import TimeSeriesSplit

tscv = TimeSeriesSplit(n_splits = 4) # For cross-validation

callback = keras.callbacks.EarlyStopping(monitor='loss', patience = 8) #patience parameter to be adjusted

loss = []
val_loss = []

for train_data, test_data in tscv.split(X_train):
    X_train_current_split, X_test_current_split = X_train[train_data], X_train[test_data]
    y_train_current_split, y_test_current_split = Y_train[train_data], Y_train[test_data]
    
    model = keras.Sequential([
        
        # Group by timestamps rather than variables
        keras.layers.Permute((2,1), input_shape=(48, NUM_OF_FEATURES)),
        # include a flatten layer to convert to 1D (used as a first layer instead of reshaping)
        keras.layers.Flatten(input_shape=(NUM_OF_FEATURES, 48)),
        # shape should be vertically, so 48 data points for x1, then x2...
        keras.layers.Dense(1200, activation='tanh'),
        # keras.layers.Dropout(0.2),   no dropout yet
        keras.layers.Dense(600, activation='tanh'),
        keras.layers.Dense(240, activation='tanh'),
        keras.layers.Dense(24)
    ]) #amount of layers & neurons to be adjusted


    model.compile(
        optimizer='adam',
        loss= 'mse'
    ) #types of optimizer, loss function to be adjusted
    
    history = model.fit(X_train_current_split, y_train_current_split,
              epochs=200, 
              validation_data=(X_test_current_split, y_test_current_split),
              # validation_split = 0.8,
              verbose=1,
              callbacks=callback
    )
    
    loss.append(model.history.history['loss'])
    val_loss.append(model.history.history['val_loss'])
# Out:
# Epoch 1/200
# 4/4 [==============================] - 2s 117ms/step - loss: 2.2968 - val_loss: 0.2047
# Epoch 2/200
# 4/4 [==============================] - 0s 39ms/step - loss: 0.2226 - val_loss: 0.1195
# Epoch 3/200
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0923 - val_loss: 0.0790
# Epoch 4/200
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0743 - val_loss: 0.0495
# Epoch 5/200
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0503 - val_loss: 0.0446
# Epoch 6/200
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0411 - val_loss: 0.0309
# Epoch 7/200
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0292 - val_loss: 0.0258
# Epoch 8/200
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0263 - val_loss: 0.0225
# Epoch 9/200
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0227 - val_loss: 0.0207
# Epoch 10/200
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0205 - val_loss: 0.0155
# Epoch 11/200
# 4/4 [==============================] - 0s 45ms/step - loss: 0.0166 - val_loss: 0.0120
# Epoch 12/200
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0145 - val_loss: 0.0118
# Epoch 13/200
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0126 - val_loss: 0.0098
# Epoch 14/200
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0111 - val_loss: 0.0082
# Epoch 15/200
# 4/4 [==============================] - 0s 48ms/step - loss: 0.0102 - val_loss: 0.0081
# Epoch 16/200
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0092 - val_loss: 0.0070
# Epoch 17/200
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0084 - val_loss: 0.0071
# Epoch 18/200
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0078 - val_loss: 0.0062
# Epoch 19/200
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0071 - val_loss: 0.0072
# Epoch 20/200
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0070 - val_loss: 0.0056
# Epoch 21/200
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0067 - val_loss: 0.0058
# Epoch 22/200
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 23/200
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0064 - val_loss: 0.0066
# Epoch 24/200
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0066 - val_loss: 0.0060
# Epoch 25/200
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0061 - val_loss: 0.0061
# Epoch 26/200
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0053 - val_loss: 0.0059
# Epoch 27/200
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0050 - val_loss: 0.0054
# Epoch 28/200
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0046 - val_loss: 0.0061
# Epoch 29/200
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0049 - val_loss: 0.0043
# Epoch 30/200
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0044 - val_loss: 0.0052
# Epoch 31/200
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0043 - val_loss: 0.0048
# Epoch 32/200
# 4/4 [==============================] - 0s 38ms/step - loss: 0.0037 - val_loss: 0.0045
# Epoch 33/200
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0034 - val_loss: 0.0055
# Epoch 34/200
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0040 - val_loss: 0.0047
# Epoch 35/200
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0038 - val_loss: 0.0049
# Epoch 36/200
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0034 - val_loss: 0.0042
# Epoch 37/200
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0031 - val_loss: 0.0046
# Epoch 38/200
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0029 - val_loss: 0.0045
# Epoch 39/200
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0029 - val_loss: 0.0044
# Epoch 40/200
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0031 - val_loss: 0.0054
# Epoch 41/200
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0036 - val_loss: 0.0042
# Epoch 42/200
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0031 - val_loss: 0.0044
# Epoch 43/200
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0028 - val_loss: 0.0048
# Epoch 44/200
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0027 - val_loss: 0.0043
# Epoch 45/200
# 4/4 [==============================] - 0s 52ms/step - loss: 0.0025 - val_loss: 0.0046
# Epoch 46/200
# 4/4 [==============================] - 0s 50ms/step - loss: 0.0026 - val_loss: 0.0046
# Epoch 47/200
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0027 - val_loss: 0.0045
# Epoch 48/200
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0025 - val_loss: 0.0037
# Epoch 49/200
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0022 - val_loss: 0.0037
# Epoch 50/200
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0021 - val_loss: 0.0041
# Epoch 51/200
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0020 - val_loss: 0.0040
# Epoch 52/200
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0020 - val_loss: 0.0040
# Epoch 53/200
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0020 - val_loss: 0.0036
# Epoch 54/200
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0020 - val_loss: 0.0040
# Epoch 55/200
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0020 - val_loss: 0.0037
# Epoch 56/200
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0018 - val_loss: 0.0037
# Epoch 57/200
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0017 - val_loss: 0.0040
# Epoch 58/200
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 59/200
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0019 - val_loss: 0.0042
# Epoch 60/200
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0021 - val_loss: 0.0039
# Epoch 61/200
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0020 - val_loss: 0.0059
# Epoch 62/200
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0033 - val_loss: 0.0057
# Epoch 63/200
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0032 - val_loss: 0.0042
# Epoch 64/200
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0023 - val_loss: 0.0043
# Epoch 65/200
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0023 - val_loss: 0.0035
# Epoch 1/200
# 7/7 [==============================] - 2s 73ms/step - loss: 1.1838 - val_loss: 0.1475
# Epoch 2/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0992 - val_loss: 0.0674
# Epoch 3/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0547 - val_loss: 0.0344
# Epoch 4/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0342 - val_loss: 0.0214
# Epoch 5/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.0223 - val_loss: 0.0167
# Epoch 6/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0174 - val_loss: 0.0129
# Epoch 7/200
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0150 - val_loss: 0.0091
# Epoch 8/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0111 - val_loss: 0.0081
# Epoch 9/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0093 - val_loss: 0.0063
# Epoch 10/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.0080 - val_loss: 0.0050
# Epoch 11/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0070 - val_loss: 0.0044
# Epoch 12/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0063 - val_loss: 0.0038
# Epoch 13/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0054 - val_loss: 0.0035
# Epoch 14/200
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0052 - val_loss: 0.0035
# Epoch 15/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0051 - val_loss: 0.0027
# Epoch 16/200
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0044 - val_loss: 0.0032
# Epoch 17/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0041 - val_loss: 0.0025
# Epoch 18/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0039 - val_loss: 0.0027
# Epoch 19/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0038 - val_loss: 0.0025
# Epoch 20/200
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0036 - val_loss: 0.0026
# Epoch 21/200
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0033 - val_loss: 0.0023
# Epoch 22/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0030 - val_loss: 0.0026
# Epoch 23/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 24/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0030 - val_loss: 0.0023
# Epoch 25/200
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0028 - val_loss: 0.0021
# Epoch 26/200
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0026 - val_loss: 0.0021
# Epoch 27/200
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 28/200
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 29/200
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0026 - val_loss: 0.0020
# Epoch 30/200
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 31/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 32/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 33/200
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 34/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0024 - val_loss: 0.0020
# Epoch 35/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 36/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 37/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0026 - val_loss: 0.0020
# Epoch 38/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.0023 - val_loss: 0.0026
# Epoch 39/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.0027 - val_loss: 0.0034
# Epoch 40/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 41/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 42/200
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0020 - val_loss: 0.0025
# Epoch 43/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 44/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 45/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 46/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 47/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 48/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 49/200
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 50/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 51/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 52/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 53/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 54/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 55/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 56/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 57/200
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 58/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 59/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 60/200
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 61/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 62/200
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 63/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 64/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 65/200
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 66/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 67/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 68/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 69/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 70/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 71/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 72/200
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 73/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 74/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 75/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 76/200
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 77/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 78/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 79/200
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 80/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 81/200
# 7/7 [==============================] - 0s 28ms/step - loss: 9.7660e-04 - val_loss: 0.0013
# Epoch 82/200
# 7/7 [==============================] - 0s 30ms/step - loss: 9.6020e-04 - val_loss: 0.0016
# Epoch 83/200
# 7/7 [==============================] - 0s 30ms/step - loss: 9.5194e-04 - val_loss: 0.0016
# Epoch 84/200
# 7/7 [==============================] - 0s 29ms/step - loss: 9.9016e-04 - val_loss: 0.0012
# Epoch 85/200
# 7/7 [==============================] - 0s 33ms/step - loss: 8.9018e-04 - val_loss: 0.0019
# Epoch 86/200
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0012 - val_loss: 0.0015
# Epoch 87/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 88/200
# 7/7 [==============================] - 0s 32ms/step - loss: 9.7181e-04 - val_loss: 0.0014
# Epoch 89/200
# 7/7 [==============================] - 0s 28ms/step - loss: 9.0147e-04 - val_loss: 0.0015
# Epoch 90/200
# 7/7 [==============================] - 0s 29ms/step - loss: 8.5909e-04 - val_loss: 0.0014
# Epoch 91/200
# 7/7 [==============================] - 0s 30ms/step - loss: 8.5494e-04 - val_loss: 0.0013
# Epoch 92/200
# 7/7 [==============================] - 0s 30ms/step - loss: 8.2853e-04 - val_loss: 0.0014
# Epoch 93/200
# 7/7 [==============================] - 0s 40ms/step - loss: 8.2576e-04 - val_loss: 0.0014
# Epoch 94/200
# 7/7 [==============================] - 0s 32ms/step - loss: 8.3650e-04 - val_loss: 0.0012
# Epoch 95/200
# 7/7 [==============================] - 0s 29ms/step - loss: 7.6901e-04 - val_loss: 0.0013
# Epoch 96/200
# 7/7 [==============================] - 0s 30ms/step - loss: 7.2290e-04 - val_loss: 0.0013
# Epoch 97/200
# 7/7 [==============================] - 0s 29ms/step - loss: 7.0001e-04 - val_loss: 0.0012
# Epoch 98/200
# 7/7 [==============================] - 0s 29ms/step - loss: 7.3156e-04 - val_loss: 0.0014
# Epoch 99/200
# 7/7 [==============================] - 0s 29ms/step - loss: 7.3834e-04 - val_loss: 0.0013
# Epoch 100/200
# 7/7 [==============================] - 0s 29ms/step - loss: 7.7530e-04 - val_loss: 0.0014
# Epoch 101/200
# 7/7 [==============================] - 0s 30ms/step - loss: 8.1756e-04 - val_loss: 0.0019
# Epoch 102/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 103/200
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 104/200
# 7/7 [==============================] - 0s 28ms/step - loss: 8.9261e-04 - val_loss: 0.0014
# Epoch 105/200
# 7/7 [==============================] - 0s 29ms/step - loss: 8.1770e-04 - val_loss: 0.0013
# Epoch 1/200
# 10/10 [==============================] - 2s 49ms/step - loss: 0.7067 - val_loss: 0.0637
# Epoch 2/200
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0501 - val_loss: 0.0405
# Epoch 3/200
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0261 - val_loss: 0.0344
# Epoch 4/200
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0167 - val_loss: 0.0252
# Epoch 5/200
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0110 - val_loss: 0.0241
# Epoch 6/200
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0084 - val_loss: 0.0251
# Epoch 7/200
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0065 - val_loss: 0.0237
# Epoch 8/200
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0056 - val_loss: 0.0225
# Epoch 9/200
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0053 - val_loss: 0.0241
# Epoch 10/200
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0049 - val_loss: 0.0259
# Epoch 11/200
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0042 - val_loss: 0.0243
# Epoch 12/200
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0039 - val_loss: 0.0222
# Epoch 13/200
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0036 - val_loss: 0.0232
# Epoch 14/200
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0034 - val_loss: 0.0209
# Epoch 15/200
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0033 - val_loss: 0.0217
# Epoch 16/200
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0033 - val_loss: 0.0236
# Epoch 17/200
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0033 - val_loss: 0.0227
# Epoch 18/200
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0031 - val_loss: 0.0214
# Epoch 19/200
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0028 - val_loss: 0.0213
# Epoch 20/200
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0026 - val_loss: 0.0214
# Epoch 21/200
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0026 - val_loss: 0.0196
# Epoch 22/200
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0025 - val_loss: 0.0210
# Epoch 23/200
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0024 - val_loss: 0.0197
# Epoch 24/200
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0023 - val_loss: 0.0212
# Epoch 25/200
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0020 - val_loss: 0.0207
# Epoch 26/200
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0019 - val_loss: 0.0203
# Epoch 27/200
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0020 - val_loss: 0.0207
# Epoch 28/200
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0019 - val_loss: 0.0202
# Epoch 29/200
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0019 - val_loss: 0.0219
# Epoch 30/200
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0019 - val_loss: 0.0189
# Epoch 31/200
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0017 - val_loss: 0.0196
# Epoch 32/200
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0016 - val_loss: 0.0184
# Epoch 33/200
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0017 - val_loss: 0.0203
# Epoch 34/200
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0017 - val_loss: 0.0195
# Epoch 35/200
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0018 - val_loss: 0.0205
# Epoch 36/200
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0016 - val_loss: 0.0188
# Epoch 37/200
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0016 - val_loss: 0.0204
# Epoch 38/200
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0016 - val_loss: 0.0188
# Epoch 39/200
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0018 - val_loss: 0.0186
# Epoch 40/200
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0015 - val_loss: 0.0196
# Epoch 41/200
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0014 - val_loss: 0.0204
# Epoch 42/200
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0015 - val_loss: 0.0190
# Epoch 43/200
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0013 - val_loss: 0.0196
# Epoch 44/200
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0013 - val_loss: 0.0188
# Epoch 45/200
# 10/10 [==============================] - 0s 27ms/step - loss: 0.0013 - val_loss: 0.0180
# Epoch 46/200
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0014 - val_loss: 0.0199
# Epoch 47/200
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0012 - val_loss: 0.0177
# Epoch 48/200
# 10/10 [==============================] - 0s 26ms/step - loss: 0.0012 - val_loss: 0.0192
# Epoch 49/200
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0012 - val_loss: 0.0175
# Epoch 50/200
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0011 - val_loss: 0.0192
# Epoch 51/200
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0011 - val_loss: 0.0174
# Epoch 52/200
# 10/10 [==============================] - 0s 25ms/step - loss: 0.
# 13/13 [==============================] - 0s 25ms/step - loss: 9.8686e-04 - val_loss: 0.0039
# Epoch 50/200
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0010 - val_loss: 0.0042
# Epoch 51/200
# 13/13 [==============================] - 0s 26ms/step - loss: 9.9543e-04 - val_loss: 0.0042
# Epoch 52/200
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0011 - val_loss: 0.0049
# Epoch 53/200
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0012 - val_loss: 0.0045
# Epoch 54/200
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0013 - val_loss: 0.0045
# Epoch 55/200
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0013 - val_loss: 0.0041
# Epoch 56/200
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0014 - val_loss: 0.0046
# Epoch 57/200
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0017 - val_loss: 0.0048

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
# Evaluate the model on the test data
predictions = []
#print(len(eval_target_variables))

for i in range(len(Y_val)):
    current_batch = X_val[i].reshape((1, NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))
    curr_pred = model.predict(current_batch)
    predictions.append(curr_pred)
# Out:
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions):
    ax = axs[i]
    # TODO seems to work but check why column[0]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_val[i], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

rmse = 0
for i in range(len(predictions)):
    print(f'pred={i}, num = {sqrt(mean_squared_error(predictions[i][0], Y_val[i]))}')
    rmse += sqrt(mean_squared_error(predictions[i][0], Y_val[i]))

rmse /= len(predictions)    
print(f"RMSE = {rmse}")
# Out:
# pred=0, num = 0.030823989959159574
# pred=1, num = 0.04544740932952192
# pred=2, num = 0.04120930100395544
# pred=3, num = 0.038300985741469236
# pred=4, num = 0.03916819413917225
# pred=5, num = 0.04341940885897632
# pred=6, num = 0.04142376235813291
# pred=7, num = 0.04640453021369451
# pred=8, num = 0.042338713225216366
# pred=9, num = 0.043394463775088314
# pred=10, num = 0.0469171934600399
# pred=11, num = 0.03967744568972836
# pred=12, num = 0.03885732258707312
# pred=13, num = 0.04127683936892095
# pred=14, num = 0.04057516495375547
# pred=15, num = 0.052485475054297105
# pred=16, num = 0.04098689209159726
# pred=17, num = 0.034252461205195296
# pred=18, num = 0.030530533851401975
# pred=19, num = 0.02631035015726547
# pred=20, num = 0.03325530202283296
# pred=21, num = 0.037759823704871326
# pred=22, num = 0.04485532196107074
# pred=23, num = 0.052860572741347506
# pred=24, num = 0.05224220599941938
# RMSE = 0.04099094653812815
