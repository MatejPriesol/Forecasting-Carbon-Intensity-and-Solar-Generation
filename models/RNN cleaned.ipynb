# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras
# Out:
# WARNING:tensorflow:From C:\Users\Matej\Documents\GitHub\thesis-forecasting\venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
train = pd.read_csv("../data/schemas/warm_up/TrainSet.csv", sep=",")
validation = pd.read_csv("../data/schemas/warm_up/ValidationSet.csv", sep=",")
test = pd.read_csv("../data/schemas/warm_up/TestSet.csv", sep=",")

# %%
# Global variables

NUM_OF_TIMESTEPS_INPUT = 48
NUM_OF_TIMESTEPS_OUTPUT = 24

THRESHOLD = 0.4   # For feature selection

# %%
column_to_predict = "kg_CO2/kWh"

independent_variables = []

for column in train:
    if abs(train[column].corr(train[column_to_predict])) > THRESHOLD:
        independent_variables.append(column)

independent_variables.remove(column_to_predict)
if "Index" in independent_variables:
    independent_variables.remove("Index")
independent_variables
# Out:
# ['Hour_1',
#  'Hour_2',
#  'Hour_3',
#  'Occupant Count (people)_3',
#  '12h Outdoor Drybulb Temperature (C)',
#  '24h Outdoor Drybulb Temperature (C)',
#  '12h Outdoor Relative Humidity (%)',
#  '6h Direct Solar Radiation (W/m2)',
#  '12h Direct Solar Radiation (W/m2)']

# %% [markdown]
# Prepare the data

# %%
# Split the X and Y for all sets

# Train set
X_train_default = train[independent_variables]
Y_train_default = train[column_to_predict]

# Validation set, also include the data from train that was used only as output to get more datapoints
X_val_default = pd.concat([X_train_default.tail(NUM_OF_TIMESTEPS_OUTPUT), validation[independent_variables]], ignore_index=True)
Y_val_default = pd.concat([Y_train_default.tail(NUM_OF_TIMESTEPS_OUTPUT), validation[column_to_predict]], ignore_index=True)

# Test set, also include the data from train that was used only as output to get more datapoints
X_test_default = pd.concat([X_val_default.tail(NUM_OF_TIMESTEPS_OUTPUT), test[independent_variables]], ignore_index=True)
Y_test_default = pd.concat([Y_val_default.tail(NUM_OF_TIMESTEPS_OUTPUT), test[column_to_predict]], ignore_index=True)

NUM_OF_ROWS_TRAIN, NUM_OF_FEATURES = X_train_default.shape

print(X_train_default.shape)
print(X_val_default.shape)
print(X_test_default.shape)
# Out:
# (576, 9)
# (96, 9)
# (96, 9)

# %%
# Function to prepare the data into batches that will be passed into the model

def create_sequences(input_data, output_data, timesteps_input, timesteps_output):
    sequences, targets = [], []
    for i in range(len(input_data) - timesteps_input - timesteps_output + 1):
        seq = input_data[i:i + timesteps_input]
        target = output_data[i + timesteps_input: i + timesteps_input + timesteps_output]
        sequences.append(seq)
        targets.append(target)

    return np.array(sequences), np.array(targets)

# %%
X_train, Y_train = create_sequences(X_train_default, Y_train_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)
X_val, Y_val = create_sequences(X_val_default, Y_val_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)
X_test, Y_test = create_sequences(X_test_default, Y_test_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)

print(f"X_train = {X_train.shape}, Y_train = {Y_train.shape}\n"
      f"X_val = {X_val.shape}, Y_val = {Y_val.shape}\n"
      f"X_test = {X_test.shape}, Y_test = {Y_test.shape}")
# Out:
# X_train = (505, 48, 9), Y_train = (505, 24)
# X_val = (25, 48, 9), Y_val = (25, 24)
# X_test = (25, 48, 9), Y_test = (25, 24)

# %%
from sklearn.model_selection import TimeSeriesSplit

tscv = TimeSeriesSplit(n_splits = 4) # For cross-validation

callback = keras.callbacks.EarlyStopping(monitor='loss', patience = 8) #patience parameter to be adjusted

loss = []
val_loss = []

for train_data, test_data in tscv.split(X_train):
    X_train_current_split, X_test_current_split = X_train[train_data], X_train[test_data]
    y_train_current_split, y_test_current_split = Y_train[train_data], Y_train[test_data]
    
    model = keras.Sequential([
        
        # Group by timestamps rather than variables
        keras.layers.Permute((2,1), input_shape=(48, NUM_OF_FEATURES)),
        # include a flatten layer to convert to 1D (used as a first layer instead of reshaping)
        keras.layers.Flatten(input_shape=(NUM_OF_FEATURES, 48)),
        # shape should be vertically, so 48 data points for x1, then x2...
        keras.layers.Dense(1200, activation='tanh'),
        # keras.layers.Dropout(0.2),   no dropout yet
        keras.layers.Dense(600, activation='tanh'),
        keras.layers.Dense(240, activation='tanh'),
        keras.layers.Dense(24)
    ]) #amount of layers & neurons to be adjusted


    model.compile(
        optimizer='adam',
        loss= 'mse'
    ) #types of optimizer, loss function to be adjusted
    
    history = model.fit(X_train_current_split, y_train_current_split,
              epochs=200, 
              validation_data=(X_test_current_split, y_test_current_split),
              # validation_split = 0.8,
              verbose=1,
              callbacks=callback
    )
    
    loss.append(model.history.history['loss'])
    val_loss.append(model.history.history['val_loss'])
# Out:
# Epoch 1/200
# WARNING:tensorflow:From C:\Users\Matej\Documents\GitHub\thesis-forecasting\venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# 4/4 [==============================] - 2s 118ms/step - loss: 1.5575 - val_loss: 0.2195
# Epoch 2/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2587 - val_loss: 0.1169
# Epoch 3/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0844 - val_loss: 0.1195
# Epoch 4/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0614 - val_loss: 0.0692
# Epoch 5/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0327 - val_loss: 0.0534
# Epoch 6/200
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0317 - val_loss: 0.0499
# Epoch 7/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0214 - val_loss: 0.0583
# Epoch 8/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0200 - val_loss: 0.0567
# Epoch 9/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0166 - val_loss: 0.0448
# Epoch 10/200
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0143 - val_loss: 0.0396
# Epoch 11/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0139 - val_loss: 0.0361
# Epoch 12/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0120 - val_loss: 0.0513
# Epoch 13/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0118 - val_loss: 0.0409
# Epoch 14/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0108 - val_loss: 0.0340
# Epoch 15/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0105 - val_loss: 0.0444
# Epoch 16/200
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0096 - val_loss: 0.0429
# Epoch 17/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0090 - val_loss: 0.0444
# Epoch 18/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0087 - val_loss: 0.0411
# Epoch 19/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0085 - val_loss: 0.0398
# Epoch 20/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0079 - val_loss: 0.0413
# Epoch 21/200
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0077 - val_loss: 0.0408
# Epoch 22/200
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0074 - val_loss: 0.0344
# Epoch 23/200
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0071 - val_loss: 0.0384
# Epoch 24/200
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0067 - val_loss: 0.0346
# Epoch 25/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0072 - val_loss: 0.0368
# Epoch 26/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0064 - val_loss: 0.0400
# Epoch 27/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0062 - val_loss: 0.0417
# Epoch 28/200
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0062 - val_loss: 0.0377
# Epoch 29/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0066 - val_loss: 0.0358
# Epoch 30/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0068 - val_loss: 0.0360
# Epoch 31/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0058 - val_loss: 0.0419
# Epoch 32/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0058 - val_loss: 0.0449
# Epoch 33/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0060 - val_loss: 0.0441
# Epoch 34/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0057 - val_loss: 0.0408
# Epoch 35/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0052 - val_loss: 0.0312
# Epoch 36/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0053 - val_loss: 0.0330
# Epoch 37/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0049 - val_loss: 0.0347
# Epoch 38/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0051 - val_loss: 0.0388
# Epoch 39/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0047 - val_loss: 0.0374
# Epoch 40/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0042 - val_loss: 0.0315
# Epoch 41/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0049 - val_loss: 0.0359
# Epoch 42/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0049 - val_loss: 0.0383
# Epoch 43/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0049 - val_loss: 0.0433
# Epoch 44/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0046 - val_loss: 0.0365
# Epoch 45/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0042 - val_loss: 0.0322
# Epoch 46/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0048 - val_loss: 0.0338
# Epoch 47/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0043 - val_loss: 0.0403
# Epoch 48/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0039 - val_loss: 0.0365
# Epoch 49/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0040 - val_loss: 0.0351
# Epoch 50/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0038 - val_loss: 0.0363
# Epoch 51/200
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0043 - val_loss: 0.0381
# Epoch 52/200
# 4/4 [==============================] - 0s 39ms/step - loss: 0.0040 - val_loss: 0.0366
# Epoch 53/200
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0035 - val_loss: 0.0359
# Epoch 54/200
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0037 - val_loss: 0.0356
# Epoch 55/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0032 - val_loss: 0.0371
# Epoch 56/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0035 - val_loss: 0.0379
# Epoch 57/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0036 - val_loss: 0.0316
# Epoch 58/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0037 - val_loss: 0.0349
# Epoch 59/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0034 - val_loss: 0.0398
# Epoch 60/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0032 - val_loss: 0.0393
# Epoch 61/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0032 - val_loss: 0.0349
# Epoch 62/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0030 - val_loss: 0.0371
# Epoch 63/200
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0027 - val_loss: 0.0378
# Epoch 64/200
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0026 - val_loss: 0.0376
# Epoch 65/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0028 - val_loss: 0.0362
# Epoch 66/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0027 - val_loss: 0.0355
# Epoch 67/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0026 - val_loss: 0.0371
# Epoch 68/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0025 - val_loss: 0.0361
# Epoch 69/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0024 - val_loss: 0.0364
# Epoch 70/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0023 - val_loss: 0.0339
# Epoch 71/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0023 - val_loss: 0.0366
# Epoch 72/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0026 - val_loss: 0.0388
# Epoch 73/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0027 - val_loss: 0.0375
# Epoch 74/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0023 - val_loss: 0.0354
# Epoch 75/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0023 - val_loss: 0.0347
# Epoch 76/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0022 - val_loss: 0.0357
# Epoch 77/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0021 - val_loss: 0.0376
# Epoch 78/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0020 - val_loss: 0.0378
# Epoch 79/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0021 - val_loss: 0.0377
# Epoch 80/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0018 - val_loss: 0.0347
# Epoch 81/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0021 - val_loss: 0.0359
# Epoch 82/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0021 - val_loss: 0.0373
# Epoch 83/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0021 - val_loss: 0.0369
# Epoch 84/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0022 - val_loss: 0.0376
# Epoch 85/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0021 - val_loss: 0.0371
# Epoch 86/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0019 - val_loss: 0.0363
# Epoch 87/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0017 - val_loss: 0.0350
# Epoch 88/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0016 - val_loss: 0.0374
# Epoch 89/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0016 - val_loss: 0.0380
# Epoch 90/200
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0017 - val_loss: 0.0382
# Epoch 91/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0018 - val_loss: 0.0348
# Epoch 92/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0016 - val_loss: 0.0350
# Epoch 93/200
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0017 - val_loss: 0.0375
# Epoch 94/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0016 - val_loss: 0.0364
# Epoch 95/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0017 - val_loss: 0.0370
# Epoch 96/200
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0022 - val_loss: 0.0376
# Epoch 97/200
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0020 - val_loss: 0.0381
# Epoch 1/200
# 7/7 [==============================] - 2s 59ms/step - loss: 0.7702 - val_loss: 0.1501
# Epoch 2/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0857 - val_loss: 0.0590
# Epoch 3/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0511 - val_loss: 0.0320
# Epoch 4/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0368 - val_loss: 0.0266
# Epoch 5/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0290 - val_loss: 0.0273
# Epoch 6/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0265 - val_loss: 0.0255
# Epoch 7/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0249 - val_loss: 0.0255
# Epoch 8/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0238 - val_loss: 0.0238
# Epoch 9/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0236 - val_loss: 0.0228
# Epoch 10/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0220 - val_loss: 0.0232
# Epoch 11/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0223 - val_loss: 0.0250
# Epoch 12/200
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0225 - val_loss: 0.0224
# Epoch 13/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0221 - val_loss: 0.0242
# Epoch 14/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0217 - val_loss: 0.0248
# Epoch 15/200
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0210 - val_loss: 0.0240
# Epoch 16/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0195 - val_loss: 0.0224
# Epoch 17/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0197 - val_loss: 0.0246
# Epoch 18/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0195 - val_loss: 0.0234
# Epoch 19/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0188 - val_loss: 0.0241
# Epoch 20/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0185 - val_loss: 0.0249
# Epoch 21/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0177 - val_loss: 0.0242
# Epoch 22/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0159 - val_loss: 0.0210
# Epoch 23/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.0153 - val_loss: 0.0229
# Epoch 24/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0145 - val_loss: 0.0277
# Epoch 25/200
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0139 - val_loss: 0.0313
# Epoch 26/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0163 - val_loss: 0.0380
# Epoch 27/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0173 - val_loss: 0.0246
# Epoch 28/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0145 - val_loss: 0.0241
# Epoch 29/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0139 - val_loss: 0.0266
# Epoch 30/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0134 - val_loss: 0.0249
# Epoch 31/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0116 - val_loss: 0.0276
# Epoch 32/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0119 - val_loss: 0.0301
# Epoch 33/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0107 - val_loss: 0.0256
# Epoch 34/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0106 - val_loss: 0.0284
# Epoch 35/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0102 - val_loss: 0.0238
# Epoch 36/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0092 - val_loss: 0.0267
# Epoch 37/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0087 - val_loss: 0.0227
# Epoch 38/200
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0094 - val_loss: 0.0287
# Epoch 39/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0088 - val_loss: 0.0216
# Epoch 40/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0094 - val_loss: 0.0257
# Epoch 41/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0084 - val_loss: 0.0225
# Epoch 42/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0082 - val_loss: 0.0290
# Epoch 43/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0082 - val_loss: 0.0304
# Epoch 44/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0077 - val_loss: 0.0232
# Epoch 45/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0075 - val_loss: 0.0218
# Epoch 46/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0069 - val_loss: 0.0320
# Epoch 47/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0071 - val_loss: 0.0307
# Epoch 48/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0069 - val_loss: 0.0194
# Epoch 49/200
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0060 - val_loss: 0.0263
# Epoch 50/200
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0058 - val_loss: 0.0260
# Epoch 51/200
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0061 - val_loss: 0.0227
# Epoch 52/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0061 - val_loss: 0.0174
# Epoch 53/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0065 - val_loss: 0.0204
# Epoch 54/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0064 - val_loss: 0.0318
# Epoch 55/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0057 - val_loss: 0.0223
# Epoch 56/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0055 - val_loss: 0.0313
# Epoch 57/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0058 - val_loss: 0.0292
# Epoch 58/200
# 7/7 [==============================] - 0s 27ms/step - loss: 0.0051 - val_loss: 0.0300
# Epoch 59/200
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0055 - val_loss: 0.0339
# Epoch 60/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0057 - val_loss: 0.0181
# Epoch 61/200
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0060 - val_loss: 0.0254
# Epoch 62/200
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0045 - val_loss: 0.0222
# Epoch 63/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0043 - val_loss: 0.0241
# Epoch 64/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0044 - val_loss: 0.0262
# Epoch 65/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0039 - val_loss: 0.0220
# Epoch 66/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0041 - val_loss: 0.0288
# Epoch 67/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0044 - val_loss: 0.0241
# Epoch 68/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0040 - val_loss: 0.0217
# Epoch 69/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0045 - val_loss: 0.0238
# Epoch 70/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0038 - val_loss: 0.0319
# Epoch 71/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0037 - val_loss: 0.0239
# Epoch 72/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0037 - val_loss: 0.0251
# Epoch 73/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0035 - val_loss: 0.0272
# Epoch 74/200
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0033 - val_loss: 0.0254
# Epoch 75/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0031 - val_loss: 0.0373
# Epoch 76/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0036 - val_loss: 0.0409
# Epoch 77/200
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0042 - val_loss: 0.0337
# Epoch 78/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0035 - val_loss: 0.0306
# Epoch 79/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0036 - val_loss: 0.0225
# Epoch 80/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0045 - val_loss: 0.0216
# Epoch 81/200
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0043 - val_loss: 0.0200
# Epoch 82/200
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0039 - val_loss: 0.0212
# Epoch 83/200
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0038 - val_loss: 0.0274
# Epoch 1/200
# 10/10 [==============================] - 2s 46ms/step - loss: 0.6878 - val_loss: 0.0806
# Epoch 2/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0550 - val_loss: 0.0966
# Epoch 3/200
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0348 - val_loss: 0.0520
# Epoch 4/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0278 - val_loss: 0.0644
# Epoch 5/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0249 - val_loss: 0.0503
# Epoch 6/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0225 - val_loss: 0.0582
# Epoch 7/200
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0212 - val_loss: 0.0556
# Epoch 8/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0209 - val_loss: 0.0514
# Epoch 9/200
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0210 - val_loss: 0.0506
# Epoch 10/200
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0200 - val_loss: 0.0525
# Epoch 11/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0210 - val_loss: 0.0446
# Epoch 12/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0196 - val_loss: 0.0477
# Epoch 13/200
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0184 - val_loss: 0.0499
# Epoch 14/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0174 - val_loss: 0.0543
# Epoch 15/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0180 - val_loss: 0.0427
# Epoch 16/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0181 - val_loss: 0.0487
# Epoch 17/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0183 - val_loss: 0.0498
# Epoch 18/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0191 - val_loss: 0.0575
# Epoch 19/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0192 - val_loss: 0.0458
# Epoch 20/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0170 - val_loss: 0.0455
# Epoch 21/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0159 - val_loss: 0.0481
# Epoch 22/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0156 - val_loss: 0.0434
# Epoch 23/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0144 - val_loss: 0.0500
# Epoch 24/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0148 - val_loss: 0.0464
# Epoch 25/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0133 - val_loss: 0.0442
# Epoch 26/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0129 - val_loss: 0.0430
# Epoch 27/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0133 - val_loss: 0.0402
# Epoch 28/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0136 - val_loss: 0.0420
# Epoch 29/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0124 - val_loss: 0.0503
# Epoch 30/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0122 - val_loss: 0.0568
# Epoch 31/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0130 - val_loss: 0.0573
# Epoch 32/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0129 - val_loss: 0.0477
# Epoch 33/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0148 - val_loss: 0.0467
# Epoch 34/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0138 - val_loss: 0.0455
# Epoch 35/200
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0120 - val_loss: 0.0459
# Epoch 36/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0113 - val_loss: 0.0474
# Epoch 37/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0114 - val_loss: 0.0432
# Epoch 38/200
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0112 - val_loss: 0.0628
# Epoch 39/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0106 - val_loss: 0.0451
# Epoch 40/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0102 - val_loss: 0.0490
# Epoch 41/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0099 - val_loss: 0.0616
# Epoch 42/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0105 - val_loss: 0.0621
# Epoch 43/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0089 - val_loss: 0.0522
# Epoch 44/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0092 - val_loss: 0.0662
# Epoch 45/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0092 - val_loss: 0.0598
# Epoch 46/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0081 - val_loss: 0.0558
# Epoch 47/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0083 - val_loss: 0.0554
# Epoch 48/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0078 - val_loss: 0.0588
# Epoch 49/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0100 - val_loss: 0.0556
# Epoch 50/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0088 - val_loss: 0.0557
# Epoch 51/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0080 - val_loss: 0.0616
# Epoch 52/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0077 - val_loss: 0.0589
# Epoch 53/200
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0085 - val_loss: 0.0684
# Epoch 54/200
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0072 - val_loss: 0.0572
# Epoch 55/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0075 - val_loss: 0.0602
# Epoch 56/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0073 - val_loss: 0.0612
# Epoch 57/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0064 - val_loss: 0.0722
# Epoch 58/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0088 - val_loss: 0.0543
# Epoch 59/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0087 - val_loss: 0.0570
# Epoch 60/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0070 - val_loss: 0.0615
# Epoch 61/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0061 - val_loss: 0.0646
# Epoch 62/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0062 - val_loss: 0.0572
# Epoch 63/200
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0067 - val_loss: 0.0650
# Epoch 64/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0068 - val_loss: 0.0533
# Epoch 65/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0067 - val_loss: 0.0598
# Epoch 66/200
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0063 - val_loss: 0.0847
# Epoch 67/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0075 - val_loss: 0.0741
# Epoch 68/200
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0078 - val_loss: 0.0608
# Epoch 69/200
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0058 - val_loss: 0.0724
# Epoch 70/200
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0061 - val_loss: 0.0550
# Epoch 71/200
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0071 - val_loss: 0.0646
# Epoch 72/200
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0058 - val_loss: 0.0604
# Epoch 73/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0056 - val_loss: 0.0649
# Epoch 74/200
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0051 - val_loss: 0.0681
# Epoch 75/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0052 - val_loss: 0.0532
# Epoch 76/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0065 - val_loss: 0.0608
# Epoch 77/200
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0056 - val_loss: 0.0606
# Epoch 78/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0063 - val_loss: 0.0650
# Epoch 79/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0057 - val_loss: 0.0589
# Epoch 80/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0048 - val_loss: 0.0588
# Epoch 81/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0047 - val_loss: 0.0593
# Epoch 82/200
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0044 - val_loss: 0.0720
# Epoch 83/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0059 - val_loss: 0.0558
# Epoch 84/200
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0058 - val_loss: 0.0640
# Epoch 85/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0057 - val_loss: 0.0540
# Epoch 86/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0060 - val_loss: 0.0609
# Epoch 87/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0057 - val_loss: 0.0601
# Epoch 88/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0047 - val_loss: 0.0577
# Epoch 89/200
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0041 - val_loss: 0.0564
# Epoch 90/200
# 10/10 [==============================] - 0s 30ms/step - loss: 0.0046 - val_loss: 0.0616
# Epoch 91/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0040 - val_loss: 0.0603
# Epoch 92/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0042 - val_loss: 0.0719
# Epoch 93/200
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0049 - val_loss: 0.0658
# Epoch 94/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0041 - val_loss: 0.0598
# Epoch 95/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0038 - val_loss: 0.0615
# Epoch 96/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0033 - val_loss: 0.0603
# Epoch 97/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0040 - val_loss: 0.0632
# Epoch 98/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0039 - val_loss: 0.0618
# Epoch 99/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0031 - val_loss: 0.0637
# Epoch 100/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0034 - val_loss: 0.0710
# Epoch 101/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0047 - val_loss: 0.0553
# Epoch 102/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0053 - val_loss: 0.0625
# Epoch 103/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0037 - val_loss: 0.0693
# Epoch 104/200
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0046 - val_loss: 0.0615
# Epoch 105/200
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0039 - val_loss: 0.0652
# Epoch 106/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0037 - val_loss: 0.0649
# Epoch 107/200
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0037 - val_loss: 0.0612
# Epoch 1/200
# 13/13 [==============================] - 2s 34ms/step - loss: 0.4771 - val_loss: 0.0914
# Epoch 2/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0460 - val_loss: 0.0670
# Epoch 3/200
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0340 - val_loss: 0.0622
# Epoch 4/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0299 - val_loss: 0.0603
# Epoch 5/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0280 - val_loss: 0.0517
# Epoch 6/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0260 - val_loss: 0.0485
# Epoch 7/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0273 - val_loss: 0.0499
# Epoch 8/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0262 - val_loss: 0.0428
# Epoch 9/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0228 - val_loss: 0.0379
# Epoch 10/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0223 - val_loss: 0.0435
# Epoch 11/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0220 - val_loss: 0.0381
# Epoch 12/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0211 - val_loss: 0.0351
# Epoch 13/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0203 - val_loss: 0.0349
# Epoch 14/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0206 - val_loss: 0.0354
# Epoch 15/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0191 - val_loss: 0.0374
# Epoch 16/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0211 - val_loss: 0.0325
# Epoch 17/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0184 - val_loss: 0.0311
# Epoch 18/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0173 - val_loss: 0.0305
# Epoch 19/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0174 - val_loss: 0.0344
# Epoch 20/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0189 - val_loss: 0.0322
# Epoch 21/200
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0168 - val_loss: 0.0329
# Epoch 22/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0176 - val_loss: 0.0326
# Epoch 23/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0163 - val_loss: 0.0307
# Epoch 24/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0164 - val_loss: 0.0322
# Epoch 25/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0159 - val_loss: 0.0323
# Epoch 26/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0153 - val_loss: 0.0328
# Epoch 27/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0166 - val_loss: 0.0354
# Epoch 28/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0159 - val_loss: 0.0304
# Epoch 29/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0169 - val_loss: 0.0324
# Epoch 30/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0149 - val_loss: 0.0296
# Epoch 31/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0144 - val_loss: 0.0317
# Epoch 32/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0149 - val_loss: 0.0352
# Epoch 33/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0202 - val_loss: 0.0328
# Epoch 34/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0212 - val_loss: 0.0352
# Epoch 35/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0162 - val_loss: 0.0328
# Epoch 36/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0156 - val_loss: 0.0336
# Epoch 37/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0150 - val_loss: 0.0318
# Epoch 38/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0137 - val_loss: 0.0336
# Epoch 39/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0131 - val_loss: 0.0322
# Epoch 40/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0121 - val_loss: 0.0364
# Epoch 41/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0127 - val_loss: 0.0333
# Epoch 42/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0128 - val_loss: 0.0345
# Epoch 43/200
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0146 - val_loss: 0.0369
# Epoch 44/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0136 - val_loss: 0.0337
# Epoch 45/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0136 - val_loss: 0.0358
# Epoch 46/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0118 - val_loss: 0.0357
# Epoch 47/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0104 - val_loss: 0.0339
# Epoch 48/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0102 - val_loss: 0.0366
# Epoch 49/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0116 - val_loss: 0.0374
# Epoch 50/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0102 - val_loss: 0.0408
# Epoch 51/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0118 - val_loss: 0.0337
# Epoch 52/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0124 - val_loss: 0.0401
# Epoch 53/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0132 - val_loss: 0.0375
# Epoch 54/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0164 - val_loss: 0.0377
# Epoch 55/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0140 - val_loss: 0.0364
# Epoch 56/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0116 - val_loss: 0.0394

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
# Evaluate the model on the test data
predictions = []
#print(len(eval_target_variables))

for i in range(len(Y_val)):
    current_batch = X_val[i].reshape((1, NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))
    curr_pred = model.predict(current_batch)
    predictions.append(curr_pred)
# Out:
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step

# %%
# TODO KEEP THIS FOR NOW CAUSE IT'S SUSPICIOUSLY GOOD

fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions):
    ax = axs[i]
    # TODO seems to work but check why column[0]
    ax.plot(column[0], label="Prediction")
    ax.plot(target_variables[i], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

rmse = 0
for i in range(len(predictions)):
    print(f'pred={i}, num = {sqrt(mean_squared_error(predictions[i][0], target_variables[i]))}')
    rmse += sqrt(mean_squared_error(predictions[i][0], target_variables[i]))

rmse /= len(predictions)    
print(f"RMSE = {rmse}")
# Out:
# pred=0, num = 0.20575754039849403
# pred=1, num = 0.19329235024642744
# pred=2, num = 0.19283177941824745
# pred=3, num = 0.2005496320826634
# pred=4, num = 0.1933691912046877
# pred=5, num = 0.18088683114152124
# pred=6, num = 0.16465856954270913
# pred=7, num = 0.1546337726113051
# pred=8, num = 0.15325414049794336
# pred=9, num = 0.1395223121758116
# pred=10, num = 0.13988133620718426
# pred=11, num = 0.13678556219167412
# pred=12, num = 0.14990308649215134
# pred=13, num = 0.15837931811694858
# pred=14, num = 0.1503631693101974
# pred=15, num = 0.16645107703373335
# pred=16, num = 0.15732834221323674
# pred=17, num = 0.13525182806565803
# pred=18, num = 0.14361685168482927
# pred=19, num = 0.11761278602481678
# pred=20, num = 0.11018278652328833
# pred=21, num = 0.11671825437081398
# pred=22, num = 0.1399490214963243
# pred=23, num = 0.12829263213710274
# pred=24, num = 0.12570609053202342
# RMSE = 0.1542071304687917

# %%
# TODO KEEP THIS FOR NOW CAUSE IT'S SUSPICIOUSLY GOOD

fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions):
    ax = axs[i]
    # TODO seems to work but check why column[0]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_val[i], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

rmse = 0
for i in range(len(predictions)):
    print(f'pred={i}, num = {sqrt(mean_squared_error(predictions[i][0], Y_val[i]))}')
    rmse += sqrt(mean_squared_error(predictions[i][0], Y_val[i]))

rmse /= len(predictions)    
print(f"RMSE = {rmse}")
# Out:
# pred=0, num = 0.18553503326141105
# pred=1, num = 0.17844783466671563
# pred=2, num = 0.16622004322482614
# pred=3, num = 0.17132549753130785
# pred=4, num = 0.17135781589782406
# pred=5, num = 0.17278254308330832
# pred=6, num = 0.15026334030517405
# pred=7, num = 0.13043186917932048
# pred=8, num = 0.12419142617007045
# pred=9, num = 0.1289996271814377
# pred=10, num = 0.12602209644409534
# pred=11, num = 0.1384243043368117
# pred=12, num = 0.13543549747671535
# pred=13, num = 0.1278847947721641
# pred=14, num = 0.13345722035444063
# pred=15, num = 0.13766760228008726
# pred=16, num = 0.14560674970507073
# pred=17, num = 0.14403518927540082
# pred=18, num = 0.1422858850503722
# pred=19, num = 0.1624125954005244
# pred=20, num = 0.17596899737125946
# pred=21, num = 0.17643194003010423
# pred=22, num = 0.15782249239105367
# pred=23, num = 0.15491481425500694
# pred=24, num = 0.14678113417395716
# RMSE = 0.15138825375273837
