# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras

# %%
train = pd.read_csv("../data/schemas/warm_up/TrainSet.csv", sep=",")
validation = pd.read_csv("../data/schemas/warm_up/ValidationSet.csv", sep=",")
test = pd.read_csv("../data/schemas/warm_up/TestSet.csv", sep=",")

# %%
# Global variables

NUM_OF_TIMESTEPS_INPUT = 48
NUM_OF_TIMESTEPS_OUTPUT = 24

THRESHOLD = 0.4   # For feature selection

# %%
column_to_predict = "kg_CO2/kWh"

independent_variables = []

for column in train:
    if abs(train[column].corr(train[column_to_predict])) > THRESHOLD:
        independent_variables.append(column)

independent_variables.remove(column_to_predict)
if "Index" in independent_variables:
    independent_variables.remove("Index")
independent_variables
# Out:
# ['Hour_1',
#  'Hour_2',
#  'Hour_3',
#  'Occupant Count (people)_3',
#  '12h Outdoor Drybulb Temperature (C)',
#  '24h Outdoor Drybulb Temperature (C)',
#  '12h Outdoor Relative Humidity (%)',
#  '6h Direct Solar Radiation (W/m2)',
#  '12h Direct Solar Radiation (W/m2)']

# %% [markdown]
# Prepare the data

# %%
# Split the X and Y for all sets

# Train set
X_train_default = train[independent_variables]
Y_train_default = train[column_to_predict]

# Validation set, also include the data from train that was used only as output to get more datapoints
X_val_default = pd.concat([X_train_default.tail(NUM_OF_TIMESTEPS_OUTPUT), validation[independent_variables]], ignore_index=True)
Y_val_default = pd.concat([Y_train_default.tail(NUM_OF_TIMESTEPS_OUTPUT), validation[column_to_predict]], ignore_index=True)

# Test set, also include the data from train that was used only as output to get more datapoints
X_test_default = pd.concat([X_val_default.tail(NUM_OF_TIMESTEPS_OUTPUT), test[independent_variables]], ignore_index=True)
Y_test_default = pd.concat([Y_val_default.tail(NUM_OF_TIMESTEPS_OUTPUT), test[column_to_predict]], ignore_index=True)

NUM_OF_ROWS_TRAIN, NUM_OF_FEATURES = X_train_default.shape

print(X_train_default.shape)
print(X_val_default.shape)
print(X_test_default.shape)
# Out:
# (576, 9)
# (96, 9)
# (96, 9)

# %%
# Function to prepare the data into batches that will be passed into the model

def create_sequences(input_data, output_data, timesteps_input, timesteps_output):
    sequences, targets = [], []
    for i in range(len(input_data) - timesteps_input - timesteps_output + 1):
        seq = input_data[i:i + timesteps_input]
        target = output_data[i + timesteps_input: i + timesteps_input + timesteps_output]
        sequences.append(seq)
        targets.append(target)

    return np.array(sequences), np.array(targets)

# %%
X_train, Y_train = create_sequences(X_train_default, Y_train_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)
X_val, Y_val = create_sequences(X_val_default, Y_val_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)
X_test, Y_test = create_sequences(X_test_default, Y_test_default, NUM_OF_TIMESTEPS_INPUT, NUM_OF_TIMESTEPS_OUTPUT)

print(f"X_train = {X_train.shape}, Y_train = {Y_train.shape}\n"
      f"X_val = {X_val.shape}, Y_val = {Y_val.shape}\n"
      f"X_test = {X_test.shape}, Y_test = {Y_test.shape}")
# Out:
# X_train = (505, 48, 9), Y_train = (505, 24)
# X_val = (25, 48, 9), Y_val = (25, 24)
# X_test = (25, 48, 9), Y_test = (25, 24)

# %%
from sklearn.model_selection import TimeSeriesSplit

tscv = TimeSeriesSplit(n_splits = 4) # For cross-validation

callback = keras.callbacks.EarlyStopping(monitor='loss', patience = 8) #patience parameter to be adjusted

loss = []
val_loss = []

for train_data, test_data in tscv.split(X_train):
    X_train_current_split, X_test_current_split = X_train[train_data], X_train[test_data]
    y_train_current_split, y_test_current_split = Y_train[train_data], Y_train[test_data]
    
    model = keras.Sequential([
        
        # Group by timestamps rather than variables
        keras.layers.Permute((2,1), input_shape=(NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES)),
        # include a flatten layer to convert to 1D (used as a first layer instead of reshaping)
        keras.layers.Flatten(input_shape=(NUM_OF_FEATURES, NUM_OF_TIMESTEPS_INPUT)),
        # shape should be vertically, so 48 data points for x1, then x2...
        keras.layers.Dense(1200, activation='tanh'),
        # keras.layers.Dropout(0.2),   no dropout yet
        keras.layers.Dense(600, activation='tanh'),
        keras.layers.Dense(240, activation='tanh'),
        keras.layers.Dense(24)
    ]) #amount of layers & neurons to be adjusted


    model.compile(
        optimizer='adam',
        loss= 'mse'
    ) #types of optimizer, loss function to be adjusted
    
    history = model.fit(X_train_current_split, y_train_current_split,
              epochs=200, 
              validation_data=(X_test_current_split, y_test_current_split),
              # validation_split = 0.8,
              verbose=1,
              callbacks=callback
    )
    
    loss.append(model.history.history['loss'])
    val_loss.append(model.history.history['val_loss'])
# Out:
# Epoch 1/200
# 4/4 [==============================] - 1s 52ms/step - loss: 1.5653 - val_loss: 0.2589
# Epoch 2/200
# 4/4 [==============================] - 0s 22ms/step - loss: 0.2579 - val_loss: 0.1369
# Epoch 3/200
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0940 - val_loss: 0.1211
# Epoch 4/200
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0589 - val_loss: 0.0545
# Epoch 5/200
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0374 - val_loss: 0.0516
# Epoch 6/200
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0317 - val_loss: 0.0530
# Epoch 7/200
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0220 - val_loss: 0.0628
# Epoch 8/200
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0216 - val_loss: 0.0554
# Epoch 9/200
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0162 - val_loss: 0.0425
# Epoch 10/200
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0162 - val_loss: 0.0439
# Epoch 11/200
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0149 - val_loss: 0.0478
# Epoch 12/200
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0134 - val_loss: 0.0438
# Epoch 13/200
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0124 - val_loss: 0.0460
# Epoch 14/200
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0127 - val_loss: 0.0404
# Epoch 15/200
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0113 - val_loss: 0.0455
# Epoch 16/200
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0109 - val_loss: 0.0459
# Epoch 17/200
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0108 - val_loss: 0.0438
# Epoch 18/200
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0107 - val_loss: 0.0430
# Epoch 19/200
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0107 - val_loss: 0.0384
# Epoch 20/200
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0105 - val_loss: 0.0554
# Epoch 21/200
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0106 - val_loss: 0.0373
# Epoch 22/200
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0092 - val_loss: 0.0397
# Epoch 23/200
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0084 - val_loss: 0.0451
# Epoch 24/200
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0081 - val_loss: 0.0387
# Epoch 25/200
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0073 - val_loss: 0.0385
# Epoch 26/200
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0072 - val_loss: 0.0408
# Epoch 27/200
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0071 - val_loss: 0.0372
# Epoch 28/200
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0065 - val_loss: 0.0339
# Epoch 29/200
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0068 - val_loss: 0.0361
# Epoch 30/200
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0068 - val_loss: 0.0403
# Epoch 31/200
# 4/4 [==============================] - 0s 25ms/step - loss: 0.
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0107 - val_loss: 0.0592
# Epoch 37/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0107 - val_loss: 0.0606
# Epoch 38/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0105 - val_loss: 0.0506
# Epoch 39/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0092 - val_loss: 0.0611
# Epoch 40/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0088 - val_loss: 0.0494
# Epoch 41/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0122 - val_loss: 0.0643
# Epoch 42/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0099 - val_loss: 0.0541
# Epoch 43/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0091 - val_loss: 0.0656
# Epoch 44/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0095 - val_loss: 0.0540
# Epoch 45/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0090 - val_loss: 0.0720
# Epoch 46/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0102 - val_loss: 0.0576
# Epoch 47/200
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0080 - val_loss: 0.0601
# Epoch 48/200
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0074 - val_loss: 0.0559
# Epoch 49/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0083 - val_loss: 0.0755
# Epoch 50/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0089 - val_loss: 0.0532
# Epoch 51/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0095 - val_loss: 0.0555
# Epoch 52/200
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0090 - val_loss: 0.0658
# Epoch 53/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0094 - val_loss: 0.0629
# Epoch 54/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0079 - val_loss: 0.0743
# Epoch 55/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0090 - val_loss: 0.0611
# Epoch 56/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0072 - val_loss: 0.0658
# Epoch 57/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0064 - val_loss: 0.0609
# Epoch 58/200
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0063 - val_loss: 0.0609
# Epoch 59/200
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0058 - val_loss: 0.0684
# Epoch 60/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0059 - val_loss: 0.0583
# Epoch 61/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0549
# Epoch 62/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0086 - val_loss: 0.0761
# Epoch 63/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0095 - val_loss: 0.0601
# Epoch 64/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0064 - val_loss: 0.0687
# Epoch 65/200
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0083 - val_loss: 0.0559
# Epoch 66/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0063 - val_loss: 0.0629
# Epoch 67/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0058 - val_loss: 0.0610
# Epoch 68/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0059 - val_loss: 0.0584
# Epoch 69/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0048 - val_loss: 0.0604
# Epoch 70/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0566
# Epoch 71/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0053 - val_loss: 0.0660
# Epoch 72/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0588
# Epoch 73/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0058 - val_loss: 0.0649
# Epoch 74/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0054 - val_loss: 0.0609
# Epoch 75/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0052 - val_loss: 0.0715
# Epoch 76/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0611
# Epoch 77/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0045 - val_loss: 0.0694
# Epoch 78/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0045 - val_loss: 0.0629
# Epoch 79/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0615
# Epoch 80/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0044 - val_loss: 0.0721
# Epoch 81/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0047 - val_loss: 0.0722
# Epoch 82/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0044 - val_loss: 0.0565
# Epoch 83/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 0.0601
# Epoch 84/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0050 - val_loss: 0.0665
# Epoch 85/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0045 - val_loss: 0.0599
# Epoch 86/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0064 - val_loss: 0.0639
# Epoch 87/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 0.0555
# Epoch 88/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 0.0570
# Epoch 89/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0048 - val_loss: 0.0616
# Epoch 90/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0050 - val_loss: 0.0713
# Epoch 1/200
# 13/13 [==============================] - 1s 21ms/step - loss: 0.4742 - val_loss: 0.1174
# Epoch 2/200
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0526 - val_loss: 0.0700
# Epoch 3/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0337 - val_loss: 0.0658
# Epoch 4/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0310 - val_loss: 0.0618
# Epoch 5/200
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0285 - val_loss: 0.0584
# Epoch 6/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0257 - val_loss: 0.0502
# Epoch 7/200
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0242 - val_loss: 0.0452
# Epoch 8/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0243 - val_loss: 0.0508
# Epoch 9/200
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0246 - val_loss: 0.0465
# Epoch 10/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0217 - val_loss: 0.0463
# Epoch 11/200
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0236 - val_loss: 0.0449
# Epoch 12/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0212 - val_loss: 0.0377
# Epoch 13/200
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0210 - val_loss: 0.0368
# Epoch 14/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0197 - val_loss: 0.0334
# Epoch 15/200
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0187 - val_loss: 0.0358
# Epoch 16/200
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0205 - val_loss: 0.0373
# Epoch 17/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0200 - val_loss: 0.0359
# Epoch 18/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0187 - val_loss: 0.0336
# Epoch 19/200
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0187 - val_loss: 0.0342
# Epoch 20/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0180 - val_loss: 0.0397
# Epoch 21/200
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0183 - val_loss: 0.0336
# Epoch 22/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0165 - val_loss: 0.0314
# Epoch 23/200
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0164 - val_loss: 0.0333
# Epoch 24/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0158 - val_loss: 0.0374
# Epoch 25/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0155 - val_loss: 0.0375
# Epoch 26/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0163 - val_loss: 0.0314
# Epoch 27/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0165 - val_loss: 0.0364
# Epoch 28/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0165 - val_loss: 0.0349
# Epoch 29/200
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0154 - val_loss: 0.0345
# Epoch 30/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0151 - val_loss: 0.0335
# Epoch 31/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0157 - val_loss: 0.0332
# Epoch 32/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0168 - val_loss: 0.0429
# Epoch 33/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0163 - val_loss: 0.0373
# Epoch 34/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0135 - val_loss: 0.0350
# Epoch 35/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0137 - val_loss: 0.0351
# Epoch 36/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0134 - val_loss: 0.0366
# Epoch 37/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0138 - val_loss: 0.0327
# Epoch 38/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0125 - val_loss: 0.0355
# Epoch 39/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0153 - val_loss: 0.0389
# Epoch 40/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0153 - val_loss: 0.0383
# Epoch 41/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0150 - val_loss: 0.0354
# Epoch 42/200
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0137 - val_loss: 0.0339
# Epoch 43/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0122 - val_loss: 0.0361
# Epoch 44/200
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0113 - val_loss: 0.0344
# Epoch 45/200
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0110 - val_loss: 0.0355
# Epoch 46/200
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0101 - val_loss: 0.0396
# Epoch 47/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0110 - val_loss: 0.0350
# Epoch 48/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0097 - val_loss: 0.0343
# Epoch 49/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0098 - val_loss: 0.0335
# Epoch 50/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0097 - val_loss: 0.0403
# Epoch 51/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0129 - val_loss: 0.0400
# Epoch 52/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0125 - val_loss: 0.0365
# Epoch 53/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0102 - val_loss: 0.0358
# Epoch 54/200
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0096 - val_loss: 0.0392
# Epoch 55/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0100 - val_loss: 0.0351
# Epoch 56/200
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0079 - val_loss: 0.0377
# Epoch 57/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0082 - val_loss: 0.0384
# Epoch 58/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0086 - val_loss: 0.0393
# Epoch 59/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0082 - val_loss: 0.0376
# Epoch 60/200
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0079 - val_loss: 0.0353
# Epoch 61/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0073 - val_loss: 0.0392
# Epoch 62/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0074 - val_loss: 0.0381
# Epoch 63/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0076 - val_loss: 0.0407
# Epoch 64/200
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0079 - val_loss: 0.0368
# Epoch 65/200
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0086 - val_loss: 0.0374
# Epoch 66/200
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0065 - val_loss: 0.0395
# Epoch 67/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0059 - val_loss: 0.0405
# Epoch 68/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0069 - val_loss: 0.0396
# Epoch 69/200
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0122 - val_loss: 0.0414
# Epoch 70/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0102 - val_loss: 0.0404
# Epoch 71/200
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0074 - val_loss: 0.0382
# Epoch 72/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0057 - val_loss: 0.0366
# Epoch 73/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0366
# Epoch 74/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0045 - val_loss: 0.0380
# Epoch 75/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0055 - val_loss: 0.0407
# Epoch 76/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0058 - val_loss: 0.0363
# Epoch 77/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0376
# Epoch 78/200
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0050 - val_loss: 0.0378
# Epoch 79/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0384
# Epoch 80/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0412
# Epoch 81/200
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0066 - val_loss: 0.0395
# Epoch 82/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0073 - val_loss: 0.0391

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
axs = axs.flatten()

for i, column in enumerate(loss):
    ax = axs[i]
    ax.plot(column, label="Train error")
    ax.plot(val_loss[i], label="Validation error")
    ax.title.set_text(i)
    
fig.suptitle("Train vs Validation error", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
# Evaluate the model on the test data
predictions = []
#print(len(eval_target_variables))

for i in range(len(Y_val)):
    current_batch = X_val[i].reshape((1, NUM_OF_TIMESTEPS_INPUT, NUM_OF_FEATURES))
    curr_pred = model.predict(current_batch)
    predictions.append(curr_pred)
# Out:
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
fig, axs = plt.subplots(5, 5, figsize=(25, 25))
axs = axs.flatten()

for i, column in enumerate(predictions):
    ax = axs[i]
    # TODO seems to work but check why column[0]
    ax.plot(column[0], label="Prediction")
    ax.plot(Y_val[i], label="Actual")
    ax.title.set_text(i)

fig.suptitle("RNN", fontsize=24)
plt.tight_layout(rect=[0, 0, 1, 0.98])
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

rmse = 0
for i in range(len(predictions)):
    print(f'pred={i}, num = {sqrt(mean_squared_error(predictions[i][0], Y_val[i]))}')
    rmse += sqrt(mean_squared_error(predictions[i][0], Y_val[i]))

rmse /= len(predictions)    
print(f"RMSE = {rmse}")
# Out:
# pred=0, num = 0.11861036382237491
# pred=1, num = 0.10291124518678291
# pred=2, num = 0.11028761274546377
# pred=3, num = 0.1112279294885782
# pred=4, num = 0.10716419984038013
# pred=5, num = 0.1141031260131994
# pred=6, num = 0.11056230242513611
# pred=7, num = 0.1299286042938758
# pred=8, num = 0.12675044712317618
# pred=9, num = 0.13785276843022937
# pred=10, num = 0.1440396093988761
# pred=11, num = 0.143408618139747
# pred=12, num = 0.13307051440250497
# pred=13, num = 0.12238852147083656
# pred=14, num = 0.11169542081393913
# pred=15, num = 0.10809641193849127
# pred=16, num = 0.11518539019401822
# pred=17, num = 0.1102745295489537
# pred=18, num = 0.1269038578767785
# pred=19, num = 0.11950981292943301
# pred=20, num = 0.1275728014434264
# pred=21, num = 0.11921456301029608
# pred=22, num = 0.10531598457949576
# pred=23, num = 0.12029948463728458
# pred=24, num = 0.10013827839331634
# RMSE = 0.11906049592586378
